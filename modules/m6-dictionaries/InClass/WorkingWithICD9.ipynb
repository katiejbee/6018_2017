# %% [markdown]
# # Working with [ICD9](https://www.cdc.gov/nchs/icd/icd9.htm) Data

# %%
# %matplotlib inline

# %%
import pickle
from collections import defaultdict
from nose.tools import assert_equals

# %%
with open("icd9.pickle","rb") as f0:
    icd9_data = pickle.load(f0)

# %% [markdown]
# ## What does our data look like?

# %%
icd9_data[:5]
#tuple (patient id, ICD9 code, description)
# Out:
# ((56, '198.3', 'SECONDARY MALIGNANT NEOPLASM OF BRAIN AND SPINAL C'),
#  (56, '162.8', 'MALIGNANT NEOPLASM OF OTHER PARTS OF BRONCHUS OR L'),
#  (56, '531.40', 'CHRONIC OR UNSPECIFIED GASTRIC ULCER WITH HEMORRHA'),
#  (56, '276.1', 'HYPOSMOLALITY AND/OR HYPONATREMIA'),
#  (56, '428.0', 'CONGESTIVE HEART FAILURE UNSPECIFIED'))

# %%
for d in icd9_data:
    try: #what if there is no label?
        if "HEP" in d[2]:
            print(d)
    except Exception as Error:
        pass
# Out:
# (78, '070.54', 'CHRONIC HEPATITIS C WITHOUT HEPATIC COMA')
# (106, 'V02.62', 'CARRIER OR SUSPECTED CARRIER OF HEPATITIS C')
# (124, '070.70', 'UNSPECIFIED VIRAL HEPATI                \r')
# (117, '070.54', 'CHRONIC HEPATITIS C WITHOUT HEPATIC COMA')
# (117, '070.44', 'CHR HEPAT C W/ HEP COMA                 \r')
# (117, '572.4', 'HEPATORENAL SYNDROME                    \r')
# (390, '070.70', 'UNSPECIFIED VIRAL HEPATI                \r')
# (433, '070.32', 'CHRON VIR HEP B W/O COMA                \r')
# (433, '070.54', 'CHR HEPAT C W/O HEP COMA                \r')
# (433, '070.30', 'VIR HEP B W/O COM, HEP D                \r')
# (433, '070.70', 'UNSPECIFIED VIRAL HEPATI                \r')
# (590, '571.1', 'ACUTE ALCOHOLIC HEPATITIS')
# (634, '572.4', 'HEPATORENAL SYNDROME                    \r')
# (940, '070.54', 'CHRONIC HEPATITIS C WITHOUT HEPATIC COMA')
# (940, '155.1', 'MALIGNANT NEOPLASM OF INTRAHEPATIC BILE DUCTS')
# (1106, '070.32', 'CHRON VIR HEP B W/O COMA                \r')
# (1100, '070.54', 'CHRONIC HEPATITIS C WITHOUT HEPATIC COMA')
# (1120, '571.1', 'ACUTE ALCOHOLIC HEPATITIS')
# (1245, '070.54', 'CHRONIC HEPATITIS C WITHOUT HEPATIC COMA')
# (1284, '572.2', 'HEPATIC COMA')
# (1329, '070.54', 'CHRONIC HEPATITIS C WITHOUT HEPATIC COMA')
# (1357, '572.2', 'HEPATIC COMA')
# (1357, '572.2', 'HEPATIC COMA                            \r')
# (1357, '572.2', 'HEPATIC COMA                            \r')
# (1380, '572.4', 'HEPATORENAL SYNDROME')
# (1380, '572.2', 'HEPATIC COMA')
# (1494, '572.2', 'HEPATIC COMA')
# (1453, '572.2', 'HEPATIC COMA                            \r')
# (1470, '571.1', 'ACUTE ALCOHOLIC HEPATITIS')
# (1470, '572.4', 'HEPATORENAL SYNDROME')
# (1470, '070.70', 'UNSPECIFIED VIRAL HEPATI                \r')
# (1571, '571.1', 'AC ALCOHOLIC HEPATITIS                  \r')
# (1598, '573.3', 'HEPATITIS UNSPECIFIED')
# (1882, '070.32', 'CHRONIC VIRAL HEPATITIS B WITHOUT HEPATIC COMA WIT')
# (1905, '573.3', 'HEPATITIS UNSPECIFIED')
# (1950, '070.32', 'CHRONIC VIRAL HEPATITIS B WITHOUT HEPATIC COMA WIT')
# (1987, '572.2', 'HEPATIC COMA')
# (2177, '572.2', 'HEPATIC COMA')
# (2195, '572.2', 'HEPATIC COMA')
# (2262, '573.3', 'HEPATITIS UNSPECIFIED')
# (2268, '572.2', 'HEPATIC COMA                            \r')
# (2268, '155.1', 'MALIGNANT NEOPLASM OF INTRAHEPATIC BILE DUCTS')
# (2328, '070.54', 'CHRONIC HEPATITIS C WITHOUT HEPATIC COMA')
# (2483, '070.51', 'ACUTE OR UNSPECIFIED HEPATITIS C WITHOUT HEPATIC C')
# (2478, '572.4', 'HEPATORENAL SYNDROME')
# (2478, '572.2', 'HEPATIC COMA')
# (2493, '070.54', 'CHRONIC HEPATITIS C WITHOUT HEPATIC COMA')
# (2570, '070.54', 'CHRONIC HEPATITIS C WITHOUT HEPATIC COMA')
# (2512, '070.54', 'CHR HEPAT C W/O HEP COMA                \r')

# %% [markdown]
# ### Each element of `icd9_data` is a tuple with three elements
# 1. A patient id
# 1. An ICD9 code
# 1. The label for that ICD9 code

# %% [markdown]
# #### Create a dictionary named `icd9_map` with keys ICD9 code and values the ICD9 label
#
# strip extra white spaces

# %%
#icd9_map = dict(icd9_data[1], icd9_data[2]) ???

icd9_map = {}
for d in icd9_data:
    key = d[1]
    try:
        value = d[2].strip() #remember d[2] is a string, so you can strip it
    except:
        value = "NO LABEL PROVIDED" #just to note, there could be code-value, but if after there was code-none, none would replace the value
    icd9_map[key]=value

# %%
icd9_map
# Out:
# {'008.45': 'INTESTIN INF CLOSTRIOIUM',
#  '035': 'ERYSIPELAS',
#  '038.0': 'STREPTOCOCCAL SEPTICEMIA',
#  '038.10': 'STAPHYLOCOCCAL SEPTICEMIA UNSPECIFIED',
#  '038.11': 'STAPHYLOCOCCUS AUREUS SEPTICEMIA',
#  '038.19': 'OTHER STAPHYLOCOCCAL SEPTICEMIA',
#  '038.3': 'SEPTICEMIA DUE TO ANAEROBES',
#  '038.40': 'GRAM-NEG SEPTICEMIA NOS',
#  '038.42': 'SEPTICEMIA DUE TO ESCHERICHIA COLI (E. COLI)',
#  '038.49': 'GRAM-NEG SEPTICEMIA NEC',
#  '038.8': 'SEPTICEMIA NEC',
#  '038.9': 'UNSPECIFIED SEPTICEMIA',
#  '041.00': 'STREPTOCOCCUS INFECTION IN CONDITIONS CLASSIFIED E',
#  '041.04': 'STREPTOCOCCUS INFECTION',
#  '041.11': 'STAPHYLOCOCCUS INFECTION IN CONDITIONS CLASSIFIED',
#  '041.19': 'STAPHYLOCOCCUS INFECTION IN CONDITIONS CLASSIFIED',
#  '041.3': 'KLEBSIELLA INFECT NOS',
#  '041.4': 'E. COLI INFECT NOS',
#  '041.6': 'PROTEUS INFECTION NOS',
#  '041.7': 'PSEUDOMONAS INFECTION IN CONDITIONS CLASSIFIED ELS',
#  '041.86': 'HELICOBACTER PYLORI INFE',
#  '042': 'HUMAN IMMUNODEFICIENCY VIRUS (HIV) DISEASE',
#  '047.8': 'OTHER SPECIFIED VIRAL MENINGITIS',
#  '049.8': 'OTHER SPECIFIED NON-ARTHROPOD-BORNE VIRAL DISEASES',
#  '053.19': 'HERPES ZOSTER WITH OTHER NERVOUS SYSTEM COMPLICATI',
#  '053.9': 'HERPES ZOSTER NOS',
#  '054.3': 'HERPETIC ENCEPHALITIS',
#  '054.79': 'HERPES SIMPLEX WITH OTHER SPECIFIED COMPLICATIONS',
#  '054.9': 'HERPES SIMPLEX WITHOUT COMPLICATION',
#  '070.30': 'VIR HEP B W/O COM, HEP D',
#  '070.32': 'CHRONIC VIRAL HEPATITIS B WITHOUT HEPATIC COMA WIT',
#  '070.44': 'CHR HEPAT C W/ HEP COMA',
#  '070.51': 'ACUTE OR UNSPECIFIED HEPATITIS C WITHOUT HEPATIC C',
#  '070.54': 'CHR HEPAT C W/O HEP COMA',
#  '070.70': 'UNSPECIFIED VIRAL HEPATI',
#  '079.99': 'UNSPECIFIED VIRAL INFECTION',
#  '088.0': 'BARTONELLOSIS',
#  '112.0': 'CANDIDIASIS OF MOUTH',
#  '112.1': 'CANDIDIASIS OF VULVA AND VAGINA',
#  '112.2': 'CANDIDIASIS OF OTHER UROGENITAL SITES',
#  '112.5': 'DISSEMINATED CANDIDIASIS',
#  '112.84': 'CANDIDAL ESOPHAGITIS',
#  '112.89': 'OTHER CANDIDIASIS OF OTHER SPECIFIED SITES',
#  '117.3': 'ASPERGILLOSIS',
#  '117.9': 'OTHER AND UNSPECIFIED MYCOSES',
#  '136.3': 'PNEUMOCYSTOSIS',
#  '136.9': 'INFECT/PARASITE DIS NOS',
#  '138': 'LATE EFFECTS OF ACUTE POLIOMYELITIS',
#  '150.8': 'MALIGNANT NEOPLASM OF OTHER SPECIFIED PART OF ESOP',
#  '151.0': 'MALIGNANT NEOPLASM OF CARDIA',
#  '152.0': 'MALIGNANT NEOPLASM OF DUODENUM',
#  '153.6': 'MALIGNANT NEOPLASM OF ASCENDING COLON',
#  '155.0': 'MALIGNANT NEOPLASM OF LIVER PRIMARY',
#  '155.1': 'MALIGNANT NEOPLASM OF INTRAHEPATIC BILE DUCTS',
#  '156.0': 'MALIGNANT NEOPLASM OF GALLBLADDER',
#  '156.9': 'MALIGNANT NEOPLASM OF BILIARY TRACT PART UNSPECIFI',
#  '157.0': 'MALIGNANT NEOPLASM OF HEAD OF PANCREAS',
#  '157.1': 'MALIGNANT NEOPLASM OF BODY OF PANCREAS',
#  '157.3': 'MALIGNANT NEOPLASM OF PANCREATIC DUCT',
#  '157.8': 'MALIGNANT NEOPLASM OF OTHER SPECIFIED SITES OF PAN',
#  '157.9': 'MALIGNANT NEOPLASM OF PANCREAS PART UNSPECIFIED',
#  '160.3': 'MALIGNANT NEOPLASM OF ETHMOIDAL SINUS',
#  '162.2': 'MALIG NEO MAIN BRONCHUS',
#  '162.3': 'MALIGNANT NEOPLASM OF UPPER LOBE BRONCHUS OR LUNG',
#  '162.4': 'MALIGNANT NEOPLASM OF MIDDLE LOBE BRONCHUS OR LUNG',
#  '162.5': 'MALIGNANT NEOPLASM OF LOWER LOBE BRONCHUS OR LUNG',
#  '162.8': 'MALIGNANT NEOPLASM OF OTHER PARTS OF BRONCHUS OR L',
#  '162.9': 'MALIGNANT NEOPLASM OF BRONCHUS AND LUNG UNSPECIFIE',
#  '170.0': 'MAL NEO SKULL/FACE BONE',
#  '174.8': 'MALIGNANT NEOPLASM OF OTHER SPECIFIED SITES OF FEM',
#  '185': 'MALIGNANT NEOPLASM OF PROSTATE',
#  '188.9': 'MALIGNANT NEOPLASM OF BLADDER PART UNSPECIFIED',
#  '189.0': 'MALIGNANT NEOPLASM OF KIDNEY EXCEPT PELVIS',
#  '189.1': 'MALIGNANT NEOPLASM OF RENAL PELVIS',
#  '191.3': 'MALIGNANT NEOPLASM OF PARIETAL LOBE',
#  '191.6': 'MAL NEO CEREBELLUM NOS',
#  '191.8': 'MALIGNANT NEOPLASM OF OTHER PARTS OF BRAIN',
#  '191.9': 'MALIGNANT NEOPLASM OF BRAIN UNSPECIFIED SITE',
#  '196.0': 'SECONDARY AND UNSPECIFIED MALIGNANT NEOPLASM OF LY',
#  '196.1': 'SECONDARY AND UNSPECIFIED MALIGNANT NEOPLASM OF IN',
#  '196.2': 'SECONDARY AND UNSPECIFIED MALIGNANT NEOPLASM OF IN',
#  '197.0': 'SECONDARY MALIG NEO LUNG',
#  '197.1': 'SECONDARY MALIGNANT NEOPLASM OF MEDIASTINUM',
#  '197.2': 'SECONDARY MALIGNANT NEOPLASM OF PLEURA',
#  '197.3': 'SECONDARY MALIGNANT NEOPLASM OF OTHER RESPIRATORY',
#  '197.4': 'SECONDARY MALIGNANT NEOPLASM OF SMALL INTESTINE IN',
#  '197.6': 'SECONDARY MALIGNANT NEOPLASM OF RETROPERITONEUM AN',
#  '197.7': 'MALIGNANT NEOPLASM OF LIVER SECONDARY',
#  '197.8': 'SECONDARY MALIGNANT NEOPLASM OF OTHER DIGESTIVE OR',
#  '198.2': 'SECONDARY MALIGNANT NEOPLASM OF SKIN',
#  '198.3': 'SEC MAL NEO BRAIN/SPINE',
#  '198.4': 'SECONDARY MALIGNANT NEOPLASM OF OTHER PARTS OF NER',
#  '198.5': 'SECONDARY MALIGNANT NEOPLASM OF BONE AND BONE MARR',
#  '198.81': 'SECONDARY MALIGNANT NEOPLASM OF BREAST',
#  '198.89': 'SECONDARY MALIGNANT NEOPLASM OF OTHER SPECIFIED SI',
#  '199.1': 'OTHER MALIGNANT NEOPLASM OF UNSPECIFIED SITE',
#  '201.90': "HODGKIN'S DISEASE UNSPECIFIED TYPE UNSPECIFIED SIT",
#  '201.92': 'HODGKINS DIS NOS THORAX',
#  '202.80': 'OTHER MALIGNANT LYMPHOMAS UNSPECIFIED SITE',
#  '203.00': 'MULTIPLE MYELOMA WITHOUT REMISSION',
#  '204.10': 'LYMPHOID LEUKEMIA CHRONIC WITHOUT REMISSION',
#  '205.10': 'MYELOID LEUKEMIA CHRONIC WITHOUT REMISSION',
#  '211.3': 'BENIGN NEOPLASM LG BOWEL',
#  '217': 'BENIGN NEOPLASM OF BREAST',
#  '225.2': 'BENIGN NEOPLASM OF CEREBRAL MENINGES',
#  '237.3': 'NEOPLASM OF UNCERTAIN BEHAVIOR OF PARAGANGLIA',
#  '238.7': 'LYMPHOPROLIFERAT DIS NOS',
#  '238.75': 'NO LABEL PROVIDED',
#  '241.1': 'NONTOXIC MULTINODULAR GOITER',
#  '242.90': 'THYROTOXICOSIS WITHOUT GOITER OR OTHER CAUSE AND W',
#  '244.0': 'POSTSURGICAL HYPOTHYROIDISM',
#  '244.9': 'UNSPECIFIED ACQUIRED HYPOTHYROIDISM',
#  '250.00': 'DIABETES MELLITUS WITHOUT COMPLICATION TYPE II OR',
#  '250.01': 'DIABETES MELLITUS WITHOUT COMPLICATION TYPE I NOT',
#  '250.02': 'DIABETES MELLITUS WITHOUT COMPLICATION TYPE II OR',
#  '250.11': 'DIABETES MELLITUS WITH KETOACIDOSIS TYPE I NOT STA',
#  '250.40': 'DIABETES MELLITUS WITH RENAL MANIFESTATIONS TYPE I',
#  '250.41': 'DIABETES MELLITUS WITH RENAL MANIFESTATIONS TYPE I',
#  '250.42': 'DIABETES MELLITUS WITH RENAL MANIFESTATIONS TYPE I',
#  '250.50': 'DIABETES MELLITUS WITH OPHTHALMIC MANIFESTATIONS T',
#  '250.51': 'DIABETES MELLITUS WITH OPHTHALMIC MANIFESTATIONS T',
#  '250.60': 'DIABETES MELLITUS WITH NEUROLOGICAL MANIFESTATIONS',
#  '250.61': 'DIABETES MELLITUS WITH NEUROLOGICAL MANIFESTATIONS',
#  '250.70': 'DIABETES W/PERIPHERAL CI',
#  '250.71': 'DIABETES MELLITUS WITH PERIPHERAL CIRCULATORY DISO',
#  '250.80': 'DIABETES W/OTH SPEC MANI',
#  '250.81': 'DIABETES MELLITUS WITH OTHER SPECIFIED MANIFESTATI',
#  '250.82': 'DIABETES MELLITUS WITH OTHER SPECIFIED MANIFESTATI',
#  '250.92': 'DIABETES MELLITUS WITH UNSPECIFIED COMPLICATION TY',
#  '251.2': 'HYPOGLYCEMIA UNSPECIFIED',
#  '251.8': 'PANCREATIC DISORDER NEC',
#  '253.5': 'DIABETES INSIPIDUS',
#  '253.6': 'OTHER DISORDERS OF NEUROHYPOPHYSIS',
#  '255.4': 'CORTICOADRENAL INSUFFICIENCY',
#  '257.2': 'TESTICULAR HYPOFUNC NEC',
#  '263.9': 'UNSPECIFIED PROTEIN-CALORIE MALNUTRITION',
#  '269.9': 'UNSPECIFIED NUTRITIONAL DEFICIENCY',
#  '272.0': 'PURE HYPERCHOLESTEROLEM',
#  '272.4': 'OTHER AND UNSPECIFIED HYPERLIPIDEMIA',
#  '273.8': 'OTHER DISORDERS OF PLASMA PROTEIN METABOLISM',
#  '274.82': 'GOUTY TOPHI OF OTHER SITES EXCEPT EAR',
#  '274.9': 'GOUT NOS',
#  '275.0': 'DISORDERS OF IRON METABOLISM',
#  '275.2': 'DISORDERS OF MAGNESIUM METABOLISM',
#  '275.3': 'DIS PHOSPHORUS METABOL',
#  '275.42': 'HYPERCALCEMIA',
#  '275.49': 'OTHER DISORDERS OF CALCIUM METABOLISM',
#  '276.0': 'HYPEROSMOLALITY AND/OR HYPERNATREMIA',
#  '276.1': 'HYPOSMOLALITY AND/OR HYPONATREMIA',
#  '276.2': 'ACIDOSIS',
#  '276.3': 'ALKALOSIS',
#  '276.4': 'MIXED ACID-BASE BALANCE DISORDER',
#  '276.5': 'VOLUME DEPLETION DISORDER',
#  '276.50': 'VOLUME DEPLETION, UNSPEC',
#  '276.51': 'DEHYDRATION',
#  '276.52': 'HYPOVOLEMIA',
#  '276.6': 'FLUID OVERLOAD DISORDER',
#  '276.7': 'HYPERPOTASSEMIA',
#  '276.8': 'HYPOPOTASSEMIA',
#  '276.9': 'ELECTROLYTE AND FLUID DISORDERS NOT ELSEWHERE CLAS',
#  '277.3': 'AMYLOIDOSIS',
#  '278.00': 'OBESITY UNSPECIFIED',
#  '278.01': 'MORBID OBESITY',
#  '280.0': 'IRON DEFICIENCY ANEMIA SECONDARY TO BLOOD LOSS (CH',
#  '280.9': 'IRON DEFIC ANEMIA NOS',
#  '281.2': 'FOLATE-DEFICIENCY ANEMIA',
#  '281.9': 'UNSPECIFIED DEFICIENCY ANEMIA',
#  '283.0': 'AUTOIMMUNE HEMOLYTIC ANEMIAS',
#  '284.1': 'NO LABEL PROVIDED',
#  '284.8': 'APLASTIC ANEMIAS NEC',
#  '285.1': 'AC POSTHEMORRHAG ANEMIA',
#  '285.21': 'ANEMIA IN CHRONIC KIDNEY',
#  '285.22': 'ANEMIA IN NEOPLASTIC DISEASE',
#  '285.29': 'ANEMIA IN OTH CHRONIC IL',
#  '285.8': 'OTHER SPECIFIED ANEMIAS',
#  '285.9': 'ANEMIA NOS',
#  '286.3': 'CONG DEF CLOT FACTOR NEC',
#  '286.5': 'HEMORRHAGIC DISORDER DUE TO CIRCULATING ANTICOAGUL',
#  '286.6': 'DEFIBRINATION SYNDROME',
#  '286.7': 'ACQUIRED COAGULATION FACTOR DEFICIENCY',
#  '286.9': 'OTHER AND UNSPECIFIED COAGULATION DEFECTS',
#  '287.4': 'SECOND THROMBOCYTOPENIA',
#  '287.5': 'THROMBOCYTOPENIA UNSPECIFIED',
#  '287.9': 'UNSPECIFIED HEMORRHAGIC CONDITIONS',
#  '288.0': 'AGRANULOCYTOSIS',
#  '288.60': 'NO LABEL PROVIDED',
#  '288.8': 'OTHER SPECIFIED DISEASE OF WHITE BLOOD CELLS',
#  '289.81': 'PRIMARY HYPERCOAGULABLE STATE',
#  '289.82': 'SECONDARY HYPERCOAGULABLE STATE',
#  '290.0': 'SENILE DEMENTIA UNCOMPLICATED',
#  '290.40': 'ARTERIOSCLEROTIC DEMENTIA UNCOMPLICATED',
#  '291.2': 'OTHER ALCOHOLIC DEMENTIA',
#  '291.81': 'ALCOHOL WITHDRAWAL',
#  '292.81': 'DRUG-INDUCED DELIRIUM',
#  '293.0': 'ACUTE DELIRIUM',
#  '293.9': 'UNSPECIFIED TRANSIENT ORGANIC MENTAL DISORDER',
#  '294.10': 'DEMENTIA IN CONDITIONS CLASSIFIED ELSEWHERE WITHOU',
#  '294.8': 'OTHER SPECIFIED ORGANIC BRAIN SYNDROMES (CHRONIC)',
#  '295.32': 'PARANOID TYPE SCHIZOPHRENIA CHRONIC STATE',
#  '295.90': 'UNSPECIFIED TYPE SCHIZOPHRENIA UNSPECIFIED STATE',
#  '296.7': 'BIPOLAR AFFECTIVE DISORDER UNSPECIFIED',
#  '296.80': 'MANIC-DEPRESSIVE PSYCHOSIS UNSPECIFIED',
#  '298.9': 'UNSPECIFIED PSYCHOSIS',
#  '300.00': 'ANXIETY STATE NOS',
#  '300.3': 'OBSESSIVE-COMPULSIVE DISORDERS',
#  '300.4': 'NEUROTIC DEPRESSION',
#  '303.00': 'ACUTE ALCOHOLIC INTOXICATION IN ALCOHOLISM UNSPECI',
#  '303.01': 'ACUTE ALCOHOLIC INTOXICATION IN ALCOHOLISM CONTINU',
#  '303.02': 'ACUTE ALCOHOLIC INTOXICATION IN ALCOHOLISM EPISODI',
#  '303.90': 'OTHER AND UNSPECIFIED ALCOHOL DEPENDENCE UNSPECIFI',
#  '303.91': 'OTHER AND UNSPECIFIED ALCOHOL DEPENDENCE CONTINUOU',
#  '303.93': 'ALCOH DEP NEC/NOS-REMISS',
#  '304.01': 'OPIOID TYPE DEPENDENCE CONTINUOUS USE',
#  '304.90': 'UNSPECIFIED DRUG DEPENDENCE UNSPECIFIED USE',
#  '305.00': 'NONDEPENDENT ALCOHOL ABUSE UNSPECIFIED DRINKING BE',
#  '305.01': 'NONDEPENDENT ALCOHOL ABUSE CONTINUOUS DRINKING BEH',
#  '305.03': 'NONDEPENDENT ALCOHOL ABUSE IN REMISSION',
#  '305.1': 'TOBACCO USE DISORDER',
#  '305.50': 'NONDEPENDENT OPIOID ABUSE UNSPECIFIED USE',
#  '305.51': 'OPIOID ABUSE-CONTINUOUS',
#  '305.90': 'OTHER MIXED OR UNSPECIFIED DRUG ABUSE UNSPECIFIED',
#  '305.91': 'NONDEPENDENT OTHER MIXED OR UNSPECIFIED DRUG ABUSE',
#  '309.28': 'ADJUSTMENT REACTION WITH MIXED EMOTIONAL FEATURES',
#  '311': 'DEPRESSIVE DISORDER NEC',
#  '317': 'MILD MENTAL RETARDATION',
#  '318.1': 'SEVERE MENTAL RETARDATION',
#  '322.9': 'MENINGITIS UNSPECIFIED',
#  '323.6': 'POSTINFECTIOUS ENCEPHALITIS',
#  '323.8': 'ENCEPHALITIS NEC',
#  '324.0': 'INTRACRANIAL ABSCESS',
#  '325': 'PHLEBITIS AND THROMBOPHLEBITIS OF INTRACRANIAL VEN',
#  '327.23': 'OBSTRUCTIVE SLEEP APNEA',
#  '331.0': "ALZHEIMER'S DISEASE",
#  '331.4': 'OBSTRUCTIVE HYDROCEPHALUS',
#  '331.82': 'DEMENTIA WITH LEWY BODIES',
#  '332.0': 'PARALYSIS AGITANS',
#  '333.2': 'MYOCLONUS',
#  '333.4': "HUNTINGTON'S CHOREA",
#  '333.94': 'NO LABEL PROVIDED',
#  '335.20': 'AMYOTROPHIC LATERAL SCLEROSIS',
#  '336.3': 'MYELOPATHY IN OTHER DISEASES CLASSIFIED ELSEWHERE',
#  '337.1': 'AUT NEUROPTHY IN OTH DIS',
#  '338.29': 'NO LABEL PROVIDED',
#  '340': 'MULTIPLE SCLEROSIS',
#  '342.90': 'UNSPECIFIED HEMIPLEGIA AND HEMIPARESIS AFFECTING U',
#  '344.00': 'QUADRIPLEGIA UNSPECIFIED',
#  '344.1': 'PARAPLEGIA',
#  '344.89': 'OTH SPEC PARALYTIC SYNDR',
#  '344.9': 'PARALYSIS UNSPECIFIED',
#  '345.3': 'GRAND MAL STATUS',
#  '345.71': 'EPILEPSIA PART CONT W/IN',
#  '345.90': 'EPILEPSY UNSPECIFIED WITHOUT INTRACTABLE EPILEPSY',
#  '346.90': 'MIGRAINE UNSPECIFIED WITHOUT INTRACTABLE MIGRAINE',
#  '348.1': 'ANOXIC BRAIN DAMAGE',
#  '348.30': 'ENCEPHALOPATHY, UNSPECIFIED',
#  '348.39': 'OTHER ENCEPHALOPATHY',
#  '348.4': 'COMPRESSION OF BRAIN',
#  '348.8': 'OTHER CONDITIONS OF BRAIN',
#  '348.9': 'BRAIN CONDITION NOS',
#  '349.82': 'TOXIC ENCEPHALOPATHY',
#  '351.0': "BELL'S PALSY",
#  '356.9': 'IDIO PERIPH NEURPTHY NOS',
#  '357.2': 'POLYNEUROPATHY IN DIABETES',
#  '357.4': 'POLYNEUROPATHY IN OTHER DISEASES CLASSIFIED ELSEWH',
#  '357.8': 'OTHER INFLAMMATORY AND TOXIC NEUROPATHY',
#  '359.4': 'TOXIC MYOPATHY',
#  '359.81': 'CRITICAL ILLNESS MYOPATHY',
#  '362.01': 'BACKGROUND DIABETIC RETINOPATHY',
#  '362.21': 'RETROLENTAL FIBROPLASIA',
#  '362.50': 'MACULAR DEGENERATION (SENILE) OF RETINA UNSPECIFIE',
#  '364.9': 'UNSPECIFIED DISORDER OF IRIS AND CILIARY BODY',
#  '365.9': 'UNSPECIFIED GLAUCOMA',
#  '366.9': 'UNSPECIFIED CATARACT',
#  '368.13': 'VISUAL DISCOMFORT',
#  '369.00': 'BLINDNESS OF BOTH EYES IMPAIRMENT LEVEL NOT FURTHE',
#  '369.4': 'LEGAL BLINDNESS-USA DEF',
#  '372.72': 'CONJUNCTIVAL HEMORRHAGE',
#  '377.41': 'ISCHEMIC OPTIC NEUROPTHY',
#  '386.11': 'BENIGN PAROXYSMAL POSITIONAL VERTIGO',
#  '389.9': 'UNSPECIFIED HEARING LOSS',
#  '394.1': 'RHEUMATIC MITRAL INSUFFICIENCY',
#  '396.2': 'MITRAL VALVE INSUFFICIENCY AND AORTIC VALVE STENOS',
#  '396.3': 'MITRAL VALVE INSUFFICIENCY AND AORTIC VALVE INSUFF',
#  '397.0': 'DISEASES OF TRICUSPID VALVE',
#  '398.91': 'RHEUMATIC HEART FAILURE (CONGESTIVE)',
#  '401.0': 'MALIGNANT ESSENTIAL HYPERTENSION',
#  '401.9': 'HYPERTENSION NOS',
#  '402.91': 'UNSPECIFIED HYPERTENSIVE HEART DISEASE WITH HEART',
#  '403.01': 'HYPERTENSIVE KIDNEY DIS',
#  '403.90': 'UNSPECIFIED HYPERTENSIVE RENAL DISEASE WITHOUT REN',
#  '403.91': 'UNSPECIFIED HYPERTENSIVE RENAL DISEASE WITH RENAL',
#  '405.01': 'MALIGNANT RENOVASCULAR HYPERTENSION',
#  '410.11': 'ACUTE MYOCARDIAL INFARCTION OF OTHER ANTERIOR WALL',
#  '410.20': 'ACUTE MYOCARDIAL INFARCTION OF INFEROLATERAL WALL',
#  '410.21': 'ACUTE MYOCARDIAL INFARCTION OF INFEROLATERAL WALL',
#  '410.31': 'ACUTE MYOCARDIAL INFARCTION OF INFEROPOSTERIOR WAL',
#  '410.41': 'ACUTE MYOCARDIAL INFARCTION OF OTHER INFERIOR WALL',
#  '410.71': 'AMI, SUBENDOCARD INFARCT',
#  '410.72': 'AMI, SUBENDOCARD INFARCT',
#  '410.82': 'AMI, OTHER SPEC SITES, S',
#  '410.91': 'ACUTE MYOCARDIAL INFARCTION OF UNSPECIFIED SITE IN',
#  '411.0': 'POSTMYOCARDIAL INFARCTION SYNDROME',
#  '411.1': 'INTERMED CORONARY SYND',
#  '412': 'OLD MYOCARDIAL INFARCT',
#  '413.9': 'OTHER AND UNSPECIFIED ANGINA PECTORIS',
#  '414.00': 'CORNARY ATHERO-VESL NOS',
#  '414.01': 'CORONARY ATHEROSCLEROSIS OF NATIVE CORONARY ARTERY',
#  '414.02': 'CORON ATHEROSCLER AUTOLO',
#  '414.04': 'CORONARY ATHEROSCLEROSIS OF ARTERY BYPASS GRAFT',
#  '414.10': 'ANEURYSM OF HEART (WALL)',
#  '414.11': 'ANEURYSM OF CORONARY VESSELS',
#  '414.8': 'CHR ISCHEMIC HRT DIS NEC',
#  '415.11': 'IATROGENIC PULMONARY EMBOLISM AND INFARCTION',
#  '415.19': 'OTHER PULMONARY EMBOLISM AND INFARCTION',
#  '416.8': 'OTHER CHRONIC PULMONARY HEART DISEASES',
#  '416.9': 'CHRONIC PULMONARY HEART DISEASE UNSPECIFIED',
#  '420.91': 'ACUTE IDIOPATHIC PERICARDITIS',
#  '421.0': 'ACUTE AND SUBACUTE BACTERIAL ENDOCARDITIS',
#  '422.91': 'IDIOPATHIC MYOCARDITIS',
#  '423.0': 'HEMOPERICARDIUM',
#  '423.8': 'OTHER SPECIFIED DISEASES OF PERICARDIUM',
#  '423.9': 'UNSPECIFIED DISEASE OF PERICARDIUM',
#  '424.0': 'MITRAL VALVE DISORDER',
#  '424.1': 'AORTIC VALVE DISORDERS',
#  '424.90': 'ENDOCARDITIS NOS',
#  '425.1': 'HYPERTROPHIC OBSTRUCTIVE CARDIOMYOPATHY',
#  '425.4': 'PRIM CARDIOMYOPATHY NEC',
#  '425.5': 'ALCOHOLIC CARDIOMYOPATHY',
#  '426.0': 'ATRIOVENTRICULAR BLOCK COMPLETE',
#  '426.11': 'FIRST DEGREE ATRIOVENTRICULAR BLOCK',
#  '426.3': 'LEFT BB BLOCK NEC',
#  '426.7': 'ANOMALOUS ATRIOVENTRICULAR EXCITATION',
#  '427.1': 'PAROXYSMAL VENTRICULAR TACHYCARDIA',
#  '427.31': 'ATRIAL FIBRILLATION',
#  '427.32': 'ATRIAL FLUTTER',
#  '427.41': 'VENTRICULAR FIBRILLATION',
#  '427.5': 'CARDIAC ARREST',
#  '427.69': 'PREMATURE BEATS NEC',
#  '427.81': 'SINOATRIAL NODE DYSFUNCTION',
#  '427.89': 'OTHER SPECIFIED CARDIAC DYSRHYTHMIAS',
#  '428.0': 'CONGESTIVE HEART FAILURE',
#  '428.1': 'LEFT HEART FAILURE',
#  '428.20': 'UNSPECIFIED SYSTOLIC HEART FAILURE',
#  '428.21': 'ACUTE SYSTOLIC HRT FAIL',
#  '428.22': 'CHRONIC SYSTOL HRT FAIL',
#  '428.23': 'ACUTE ON CHR SYSTO HRT',
#  '428.30': 'UNSPEC DIASTO HRT FAIL',
#  '428.31': 'ACUTE DIASTOLIC HEART FAILURE',
#  '428.32': 'CHRONIC DIASTOLIC HEART FAILURE',
#  '428.33': 'ACUTE ON CHRONIC DIASTOLIC HEART FAILURE',
#  '428.40': 'UNSPECIFIED COMBINED SYSTOLIC AND DIASTOLIC HEART',
#  '428.41': 'ACUTE COMBINED SYSTOLIC AND DIASTOLIC HEART FAILUR',
#  '428.42': 'CHRONIC COMBINED SYSTOLIC AND DIASTOLIC HEART FAIL',
#  '429.9': 'HEART DISEASE UNSPECIFIED',
#  '430': 'SUBARACHNOID HEMORRHAGE',
#  '431': 'INTRACEREBRAL HEMORRHAGE',
#  '432.1': 'SUBDURAL HEMORRHAGE',
#  '432.9': 'UNSPECIFIED INTRACRANIAL HEMORRHAGE',
#  '433.00': 'OCCLUSION AND STENOSIS OF BASILAR ARTERY WITHOUT C',
#  '433.01': 'OCCLUSION AND STENOSIS OF BASILAR ARTERY WITH CERE',
#  '433.10': 'OCCLUSION AND STENOSIS OF CAROTID ARTERY WITHOUT C',
#  '433.11': 'OCCLUSION AND STENOSIS OF CAROTID ARTERY WITH CERE',
#  '433.20': 'OCCLUSION AND STENOSIS OF VERTEBRAL ARTERY WITHOUT',
#  '433.21': 'OCCLUSION AND STENOSIS OF VERTEBRAL ARTERY WITH CE',
#  '433.30': 'OCCLUSION AND STENOSIS OF MULTIPLE AND BILATERAL P',
#  '433.31': 'OCCLUSION AND STENOSIS OF MULTIPLE AND BILATERAL P',
#  '434.01': 'CEREBRAL THROMBOSIS WITH CEREBRAL INFARCTION',
#  '434.11': 'CEREBRAL EMBOLISM WITH CEREBRAL INFARCTION',
#  '434.91': 'CEREBRAL ARTERY OCCLUSION UNSPECIFIED WITH CEREBRA',
#  '436': 'ACUTE BUT ILL-DEFINED CEREBROVASCULAR DISEASE',
#  '437.0': 'CEREBRAL ATHEROSCLEROSIS',
#  '437.1': 'OTHER GENERALIZED ISCHEMIC CEREBROVASCULAR DISEASE',
#  '438.0': 'LATE EFF CEREB DIS COGNI',
#  '438.11': 'LATE EFF CEREBRO UNSPECI',
#  '438.20': 'HEMIPLEGIA AFFECTING UNSPECIFIED SIDE',
#  '438.82': 'DYSPHAGIA CEREBROVASCULAR DISEASE',
#  '438.83': 'FACIAL WEAKNESS',
#  '438.89': 'OTHER LATE EFFECTS OF CEREBROVASCULAR DISEASE',
#  '438.9': 'UNSPECIFIED LATE EFFECTS OF CEREBROVASCULAR DISEAS',
#  '440.0': 'ATHEROSCLEROSIS OF AORTA',
#  '440.1': 'ATHEROSCLEROSIS OF RENAL ARTERY',
#  '440.20': 'ATHEROSCLEROSIS EXTREMIT',
#  '440.21': 'ATHEROSCLEROSIS OF NATIVE ARTERIES OF THE EXTREMIT',
#  '440.23': 'ATHEROSC EXTREM W/ULCERA',
#  '440.24': 'ATHEROSCLEROSIS OF NATIVE ARTERIES OF THE EXTREMIT',
#  '440.29': 'OTH ATHEROSCLEROS EXTREM',
#  '440.8': 'ATHEROSCLEROSIS NEC',
#  '441.01': 'DISSECTION OF AORTA THORACIC',
#  '441.02': 'DISSECTION OF AORTA ABDOMINAL',
#  '441.03': 'DISSECTION OF AORTA THORACOABDOMINAL',
#  '441.1': 'THORACIC ANEURYSM RUPTURED',
#  '441.2': 'THORACIC AORTIC ANEURYSM',
#  '441.3': 'ABDOMINAL ANEURYSM RUPTURED',
#  '441.4': 'ABDOMINAL ANEURYSM WITHOUT RUPTURE',
#  '441.7': 'THORACOABDOMINAL ANEURYSM WITHOUT RUPTURE',
#  '442.2': 'ILIAC ARTERY ANEURYSM',
#  '442.3': 'ANEURYSM OF ARTERY OF LOWER EXTREMITY',
#  '442.84': 'ANEURYSM OF OTHER VISCERAL ARTERY',
#  '443.29': 'DISSECTION OF OTHER ARTERY',
#  '443.9': 'PERIPH VASCULAR DIS NOS',
#  '444.0': 'ABD AORTIC EMBOLISM',
#  '444.1': 'EMBOLISM AND THROMBOSIS OF THORACIC AORTA',
#  '444.22': 'ARTERIAL EMBOLISM AND THROMBOSIS OF LOWER EXTREMIT',
#  '444.81': 'EMBOLISM AND THROMBOSIS OF ILIAC ARTERY',
#  '447.0': 'ACQ ARTERIOVEN FISTULA',
#  '447.1': 'STRICTURE OF ARTERY',
#  '447.2': 'RUPTURE OF ARTERY',
#  '447.8': 'ARTERIAL DISEASE NEC',
#  '451.84': 'PHLEBITIS AND THROMBOPHLEBITIS OF UPPER EXTREMITIE',
#  '452': 'PORTAL VEIN THROMBOSIS',
#  '453.2': 'EMBOLISM AND THROMBOSIS OF VENA CAVA',
#  '453.41': 'VENOUS EMBOLISM AND THRO',
#  '453.42': 'VENOUS EMBOLISM AND THRO',
#  '453.8': 'EMBOLISM AND THROMBOSIS OF OTHER SPECIFIED VEINS',
#  '455.0': 'INTERNAL HEMORRHOIDS WITHOUT COMPLICATION',
#  '455.8': 'HEMRRHOID NOS W COMP NEC',
#  '456.1': 'ESOPHAGEAL VARICES WITHOUT BLEEDING',
#  '456.20': 'ESOPHAGEAL VARICES IN DISEASES CLASSIFIED ELSEWHER',
#  '456.21': 'ESOPHAGEAL VARICES IN DISEASES CLASSIFIED ELSEWHER',
#  '456.8': 'VARICES OF OTHER SITES',
#  '457.1': 'OTHER LYMPHEDEMA',
#  '458.2': 'IATROGENIC HYPOTENSION',
#  '458.21': 'HYPOTENSION OF HEMODIALY',
#  '458.29': 'OTHER IATROGENIC HYPOTENSION',
#  '458.8': 'OTHER SPECIFIED HYPOTENSION',
#  '458.9': 'HYPOTENSION UNSPECIFIED',
#  '459.0': 'HEMORRHAGE UNSPECIFIED',
#  '459.2': 'COMPRESSION OF VEIN',
#  '459.81': 'VENOUS (PERIPHERAL) INSUFFICIENCY UNSPECIFIED',
#  '465.9': 'ACUTE UPPER RESPIRATORY INFECTIONS OF UNSPECIFIED',
#  '466.0': 'ACUTE BRONCHITIS',
#  '466.11': 'ACUTE RSV BRONCHIOLITIS',
#  '473.9': 'UNSPECIFIED SINUSITIS (CHRONIC)',
#  '478.6': 'EDEMA OF LARYNX',
#  '478.74': 'STENOSIS OF LARYNX',
#  '481': 'PNEUMOCOCCAL PNEUMONIA [STREPTOCOCCUS PNEUMONIAE P',
#  '482.0': 'K. PNEUMONIAE PNEUMONIA',
#  '482.1': 'PSEUDOMONAL PNEUMONIA',
#  '482.41': 'PNEUMONIA STAPHYLOC AURE',
#  '482.49': 'OTHER STAPHYLOCOCCUS PNEUMONIA',
#  '482.83': 'PNEUMONIA DUE TO OTHER GRAM-NEGATIVE BACTERIA',
#  '482.89': 'PNEUMONIA DUE TO OTHER SPECIFIED BACTERIA',
#  '482.9': 'BACTERIAL PNEUMONIA UNSPECIFIED',
#  '485': 'BRONCHOPNEUMONIA ORGANISM UNSPECIFIED',
#  '486': 'PNEUMONIA ORGANISM UNSPECIFIED',
#  '487.1': 'INFLUENZA WITH OTHER RESPIRATORY MANIFESTATIONS',
#  '490': 'BRONCHITIS NOS',
#  '491.21': 'OBSTRUCTIVE CHRONIC BRONCHITIS, WITH (ACUTE) EXACE',
#  '492.0': 'EMPHYSEMATOUS BLEB',
#  '492.8': 'OTHER EMPHYSEMA',
#  '493.20': 'CHRONIC OBSTRUCTIVE ASTH',
#  '493.22': 'CHRONIC OBSTRUCTIVE ASTHMA, WITH (ACUTE) EXACERBAT',
#  '493.90': 'ASTHMA, UNSPECIFIED, UNSPECIFIED',
#  '493.92': 'ASTHMA, UNSPECIFIED, WITH (ACUTE) EXACERBATION',
#  '496': 'CHR AIRWAY OBSTRUCT NEC',
#  '501': 'ASBESTOSIS',
#  '507.0': 'PNEUMONITIS DUE TO INHALATION OF FOOD OR VOMITUS',
#  '508.0': 'ACUTE PULMONARY MANIFESTATIONS DUE TO RADIATION',
#  '510.0': 'EMPYEMA WITH FISTULA',
#  '510.9': 'EMPYEMA WITHOUT FISTULA',
#  '511.0': 'PLEURISY WITHOUT EFFUSION OR CURRENT TUBERCULOSIS',
#  '511.1': 'BACT PLEUR/EFFUS NOT TB',
#  '511.8': 'OTHER SPECIFIED FORMS OF PLEURAL EFFUSION EXCEPT T',
#  '511.9': 'UNSPECIFIED PLEURAL EFFUSION',
#  '512.1': 'IATROGENIC PNEUMOTHORAX',
#  '512.8': 'OTHER SPONTANEOUS PNEUMOTHORAX',
#  '514': 'PULM CONGEST/HYPOSTASIS',
#  '515': 'POSTINFLAMMATORY PULMONARY FIBROSIS',
#  '516.3': 'IDIOPATHIC FIBROSING ALVEOLITIS',
#  '518.0': 'PULMONARY COLLAPSE',
#  '518.3': 'PULMONARY EOSINOPHILIA',
#  '518.5': 'PULMONARY INSUFFICIENCY FOLLOWING TRAUMA AND SURGE',
#  '518.81': 'RESPIRATORY FAILURE',
#  '518.82': 'OTHER PULMONARY INSUFF N',
#  '518.83': 'CHRONIC RESP FAILURE',
#  '518.84': 'ACUTE AND CHRONIC RESPIRATORY FAILURE',
#  '518.89': 'OTHER DISEASES OF LUNG NOT ELSEWHERE CLASSIFIED',
#  '519.02': 'MECH COMPLI OF TRACHEOST',
#  '519.1': 'OTHER DISEASES OF TRACHEA AND BRONCHUS NOT ELSEWHE',
#  '519.19': 'NO LABEL PROVIDED',
#  '525.9': 'UNSPECIFIED DISORDER OF THE TEETH AND SUPPORTING S',
#  '528.0': 'STOMATITIS',
#  '529.0': 'GLOSSITIS',
#  '530.10': 'ESOPHAGITIS UNSPECIFIED',
#  '530.3': 'STRICTURE AND STENOSIS OF ESOPHAGUS',
#  '530.81': 'ESOPHAGEAL REFLUX',
#  '530.84': 'TRACHEOESOPHAGEAL FISTULA',
#  '531.00': 'AC STOMACH ULCER W HEM',
#  '531.40': 'CHRONIC OR UNSPECIFIED GASTRIC ULCER WITH HEMORRHA',
#  '531.50': 'CHRONIC OR UNSPECIFIED GASTRIC ULCER WITH PERFORAT',
#  '531.70': 'CHRONIC GASTRIC ULCER WITHOUT HEMORRHAGE OR PERFOR',
#  '531.90': 'GASTRIC ULCER UNSPECIFIED AS ACUTE OR CHRONIC WITH',
#  '532.20': 'AC DUODEN ULC W HEM/PERF',
#  '532.40': 'CHRONIC OR UNSPECIFIED DUODENAL ULCER WITH HEMORRH',
#  '532.41': 'CHRONIC OR UNSPECIFIED DUODENAL ULCER WITH HEMORRH',
#  '532.50': 'CHRONIC OR UNSPECIFIED DUODENAL ULCER WITH PERFORA',
#  '532.60': 'CHRONIC OR UNSPECIFIED DUODENAL ULCER WITH HEMORRH',
#  '533.40': 'CHRONIC OR UNSPECIFIED PEPTIC ULCER OF UNSPECIFIED',
#  '535.01': 'ACUTE GASTRITIS WITH HEMORRHAGE',
#  '535.40': 'OTHER SPECIFIED GASTRITIS (WITHOUT HEMORRHAGE)',
#  '535.51': 'UNSPECIFIED GASTRITIS AND GASTRODUODENITIS WITH HE',
#  '536.3': 'GASTROPARESIS',
#  '536.42': 'MECH COMPL OF GASTROSTOM',
#  '536.49': 'OTHER GASTROSTOMY COMPLICATIONS',
#  '537.0': 'ACQUIRED HYPERTROPHIC PYLORIC STENOSIS',
#  '537.82': 'ANGIODYSPLASIA OF STOMACH AND DUODENUM (WITHOUT HE',
#  '537.83': 'ANGIODYSPL STOM/DUO W/HE',
#  '540.0': 'ACUTE APPENDICITIS WITH GENERALIZED PERITONITIS',
#  '552.21': 'INCISIONAL HERNIA WITH OBSTRUCTION',
#  '553.21': 'INCISIONAL HERNIA',
#  '553.3': 'DIAPHRAGMATIC HERNIA WITHOUT OBSTRUCTION OR GANGRE',
#  '555.9': 'REGIONAL ENTERITIS OF UNSPECIFIED SITE',
#  '556.9': 'ULCERATIVE COLITIS UNSPECIFIED',
#  '557.0': 'ACUTE VASCULAR INSUFFICIENCY OF INTESTINE',
#  '557.1': 'CHRONIC VASCULAR INSUFFICIENCY OF INTESTINE',
#  '558.9': 'OTHER AND UNSPECIFIED NONINFECTIOUS GASTROENTERITI',
#  '560.1': 'PARALYTIC ILEUS',
#  '560.2': 'VOLVULUS',
#  '560.81': 'INTESTINAL OR PERITONEAL ADHESIONS WITH OBSTRUCTIO',
#  '562.00': 'DIVERTICULOSIS OF SMALL INTESTINE (WITHOUT HEMORRH',
#  '562.10': 'DIVERTICULOSIS OF COLON (WITHOUT HEMORRHAGE)',
#  '562.11': 'DIVERTICULITIS OF COLON (WITHOUT HEMORRHAGE)',
#  '562.12': 'DIVERTICULOSIS OF COLON WITH HEMORRHAGE',
#  '564.00': 'UNSPECIFIED CONSTIPATION',
#  '564.09': 'OTHER CONSTIPATION',
#  '564.1': 'IRRITABLE BOWEL SYNDROME',
#  '567.2': 'SUPPURAT PERITONITIS NEC',
#  '567.23': 'SPONTANEOUS BACTERIAL PE',
#  '567.29': 'OTH SUPPURATIVE PERITONI',
#  '567.89': 'NO LABEL PROVIDED',
#  '568.0': 'PERITONEAL ADHESIONS (POSTOPERATIVE) (POSTINFECTIO',
#  '568.81': 'HEMOPERITONEUM (NONTRAUMATIC)',
#  '568.89': 'PERITONEAL DISORDER NEC',
#  '569.0': 'ANAL & RECTAL POLYP',
#  '569.1': 'RECTAL PROLAPSE',
#  '569.3': 'HEMORRHAGE OF RECTUM AND ANUS',
#  '569.41': 'ULCER OF ANUS AND RECTUM',
#  '569.69': 'OTHR COLOST/ENTEROS COMP',
#  '569.81': 'FISTULA OF INTESTINE EXCLUDING RECTUM AND ANUS',
#  '569.83': 'PERFORATION OF INTESTINE',
#  '569.85': 'ANGIODYSPLA INTES W/HE',
#  '570': 'ACUTE AND SUBACUTE NECROSIS OF LIVER',
#  '571.1': 'AC ALCOHOLIC HEPATITIS',
#  '571.2': 'ALCOHOLIC CIRRHOSIS OF LIVER',
#  '571.5': 'CIRRHOSIS OF LIVER WITHOUT ALCOHOL',
#  '571.6': 'BILIARY CIRRHOSIS',
#  '572.0': 'ABSCESS OF LIVER',
#  '572.2': 'HEPATIC COMA',
#  '572.3': 'PORTAL HYPERTENSION',
#  '572.4': 'HEPATORENAL SYNDROME',
#  '572.8': 'OTHER SEQUELAE OF CHRONIC LIVER DISEASE',
#  '573.3': 'HEPATITIS UNSPECIFIED',
#  '573.8': 'OTHER SPECIFIED DISORDERS OF LIVER',
#  '574.00': 'CALCULUS OF GALLBLADDER WITH ACUTE CHOLECYSTITIS W',
#  '574.10': 'CALCULUS OF GALLBLADDER WITH OTHER CHOLECYSTITIS W',
#  '574.20': 'CHOLELITHIASIS NOS',
#  '574.30': 'CALCULUS OF BILE DUCT WITH ACUTE CHOLECYSTITIS WIT',
#  '574.50': 'CALCULUS OF BILE DUCT WITHOUT CHOLECYSTITIS WITHOU',
#  '574.60': 'CALCULUS OF GALLBLADDER AND BILE DUCT WITH ACUTE C',
#  '575.0': 'ACUTE CHOLECYSTITIS',
#  '575.11': 'CHRONIC CHOLECYSTITIS',
#  '575.5': 'FISTULA OF GALLBLADDER',
#  '575.8': 'OTHER SPECIFIED DISORDERS OF GALLBLADDER',
#  '576.1': 'CHOLANGITIS',
#  '576.2': 'OBSTRUCTION OF BILE DUCT',
#  '576.8': 'OTHER SPECIFIED DISORDERS OF BILIARY TRACT',
#  '577.0': 'ACUTE PANCREATITIS',
#  '577.1': 'CHRONIC PANCREATITIS',
#  '577.8': 'PANCREATIC DISEASE NEC',
#  '578.0': 'HEMATEMESIS',
#  '578.1': 'BLOOD IN STOOL',
#  '578.9': 'HEMORRHAGE OF GASTROINTESTINAL TRACT UNSPECIFIED',
#  '579.0': 'CELIAC DISEASE',
#  '580.89': 'ACUTE GLOMERULONEPHRITIS WITH OTHER SPECIFIED PATH',
#  '582.1': 'CHRONIC GLOMERULONEPHRITIS WITH LESION OF MEMBRANO',
#  '583.81': 'NEPHRITIS NOS IN OTH DIS',
#  '583.9': 'NEPHRITIS NOS',
#  '584.5': 'ACUTE RENAL FAILURE WITH LESION OF TUBULAR NECROSI',
#  '584.9': 'ACUTE RENAL FAILURE UNSPECIFIED',
#  '585': 'CHRONIC RENAL FAILURE',
#  '585.3': 'CHRONIC KIDNEY DISEASE,',
#  '585.4': 'NO LABEL PROVIDED',
#  '585.5': 'NO LABEL PROVIDED',
#  '585.6': 'END STAGE RENAL DISEASE',
#  '585.9': 'NO LABEL PROVIDED',
#  '586': 'RENAL FAILURE UNSPECIFIED',
#  '588.1': 'NEPHROGENIC DIABETES INSIPIDUS',
#  '588.81': 'SECONDARY HYPERPARATHYRO',
#  '588.89': 'OTH SPEC DISORDERS RESUL',
#  '591': 'HYDRONEPHROSIS',
#  '592.0': 'CALCULUS OF KIDNEY',
#  '592.1': 'CALCULUS OF URETER',
#  '593.2': 'CYST OF KIDNEY ACQUIRED',
#  '593.9': 'UNSPECIFIED DISORDER OF KIDNEY AND URETER',
#  '596.4': 'ATONY OF BLADDER',
#  '596.54': 'NEUROGENIC BLADDER NOS',
#  '599.0': 'URIN TRACT INFECTION NOS',
#  '599.7': 'HEMATURIA',
#  '600.0': 'NO LABEL PROVIDED',
#  '600.00': 'HYPERTROPHY BENIGN PROST',
#  '600.01': 'HYPERTROPHY (BENIGN) OF PROSTATE WITH URINARY OBST',
#  '608.83': 'VASCULAR DISORDERS OF MALE GENITAL ORGANS',
#  '611.0': 'INFLAMMATORY DISEASE OF BREAST',
#  '682.0': 'CELLULITIS AND ABSCESS OF FACE',
#  '682.2': 'CELLULITIS OF TRUNK',
#  '682.3': 'CELLULITIS OF ARM',
#  '682.6': 'CELLULITIS OF LEG',
#  '682.7': 'CELLULITIS AND ABSCESS OF FOOT EXCEPT TOES',
#  '693.0': 'DERMATITIS DUE TO DRUGS AND MEDICINES TAKEN INTERN',
#  '696.1': 'OTHER PSORIASIS AND SIMILAR DISORDERS',
#  '698.9': 'UNSPECIFIED PRURITIC DISORDER',
#  '705.1': 'PRICKLY HEAT',
#  '707.0': 'DECUBITUS ULCER',
#  '707.01': 'NO LABEL PROVIDED',
#  '707.03': 'DECUBITUS ULCER, LOWER B',
#  '707.05': 'DECUBITUS ULCER, BUTTOCK',
#  '707.06': 'DECUBITUS ULCER, ANKLE',
#  '707.07': 'DECUBITUS ULCER, HEEL',
#  '707.09': 'DECUBITUS ULCER, OTH SIT',
#  '707.12': 'ULCER OF CALF',
#  '707.13': 'ULCER OF ANKLE',
#  '707.14': 'ULCER OF HEEL/MIDFOOT',
#  '707.15': 'ULCER OF OTH PART FOOT',
#  '707.19': 'ULCER OTH PART LOW LIMB',
#  '709.8': 'OTHER SPECIFIED DISORDERS OF SKIN',
#  '709.9': 'SKIN DISORDER NOS',
#  '711.05': 'PYOGEN ARTHRITIS-PELVIS',
#  '714.0': 'RHEUMATOID ARTHRITIS',
#  '715.35': 'OSTEOARTHROSIS LOCALIZED NOT SPECIFIED WHETHER PRI',
#  '715.90': 'OSTEOARTHROS NOS-UNSPEC',
#  '715.95': 'OSTEOARTHROS NOS-PELVIS',
#  '715.98': 'OSTEOARTHROSIS UNSPECIFIED WHETHER GENERALIZED OR',
#  '719.02': 'EFFUSION OF UPPER ARM JOINT',
#  '719.41': 'JOINT PAIN-SHLDER',
#  '719.7': 'DIFFICULTY IN WALKING',
#  '722.72': 'THOR DISC DIS W MYELOPAT',
#  '723.4': 'BRACHIAL NEURITIS OR RADICULITIS NOS',
#  '724.00': 'SPINAL STENOSIS OF UNSPECIFIED REGION',
#  '724.02': 'SPINAL STENOSIS-LUMBAR',
#  '724.3': 'SCIATICA',
#  '724.5': 'BACKACHE UNSPECIFIED',
#  '725': 'POLYMYALGIA RHEUMATICA',
#  '728.88': 'RHABDOMYOLYSIS',
#  '729.72': 'NO LABEL PROVIDED',
#  '729.73': 'NO LABEL PROVIDED',
#  '730.07': 'ACUTE OSTEOMYELITIS INVOLVING ANKLE AND FOOT',
#  '730.08': 'AC OSTEOMYELITIS NEC',
#  '730.15': 'CHRONIC OSTEOMYELITIS INVOLVING PELVIC REGION AND',
#  '730.17': 'CHRONIC OSTEOMYELITIS INVOLVING ANKLE AND FOOT',
#  '730.18': 'CHRONIC OSTEOMYELITIS INVOLVING OTHER SPECIFIED SI',
#  '730.22': 'UNSPECIFIED OSTEOMYELITIS INVOLVING UPPER ARM',
#  '730.27': 'UNSPECIFIED OSTEOMYELITIS INVOLVING ANKLE AND FOOT',
#  '731.0': 'OSTEITIS DEFORMANS NOS',
#  '731.8': 'OTHER BONE INVOLVEMENT IN DISEASES CLASSIFIED ELSE',
#  '733.00': 'OSTEOPOROSIS UNSPECIFIED',
#  '733.09': 'OSTEOPOROSIS NEC',
#  '733.13': 'PATHOLOG FX OF VERTEBRAE',
#  '737.10': 'KYPHOSIS (ACQUIRED) (POSTURAL)',
#  '737.41': 'KYPHOSIS IN OTH DIS',
#  '737.43': 'SCOLIOSIS IN OTH DIS',
#  '745.5': 'OSTIUM SECUNDUM TYPE ATRIAL SEPTAL DEFECT',
#  '747.0': 'PATENT DUCTUS ARTERIOSUS',
#  '747.83': 'PERSISTENT FETAL CIRCULATION',
#  '754.70': 'TALIPES UNSPECIFIED',
#  '755.26': 'LONGITUDINAL DEFICIENCY RADIAL COMPLETE OR PARTIAL',
#  '755.63': 'CONG HIP DEFORMITY NEC',
#  '756.10': 'CONGENITAL ANOMALY OF SPINE UNSPECIFIED',
#  '758.89': 'OTHER CONDITIONS DUE TO CHROMOSOME ANOMALIES',
#  '764.92': 'FETAL GROWTH RETARDATION 500-749 GRAMS',
#  '765.02': 'DISORDERS RELATING TO EXTREME IMMATURITY OF INFANT',
#  '765.23': '25-26 COMPLETED WEEKS OF GESTATION',
#  '765.24': '27-28 COMPLETED WEEKS OF GESTATION',
#  '769': 'RESPIRATORY DISTRESS SYNDROME IN NEWBORN',
#  '770.7': 'CHRONIC RESPIRATORY DISEASE ARISING IN THE PERINAT',
#  '770.82': 'OTHER APNEA OF NEWBORN',
#  '770.89': 'OTHER RESPIRATORY PROBLEMS AFTER BIRTH',
#  '771.81': 'SEPTICEMIA [SEPSIS] OF NEWBORN',
#  '772.14': 'INTRAVENTRICULAR HEMORRHAGE GRADE IV',
#  '774.2': 'NEONATAL JAUNDICE ASSOCIATED WITH PRETERM DELIVERY',
#  '775.9': 'UNSPECIFIED ENDOCRINE AND METABOLIC DISTURBANCES S',
#  '776.1': 'TRANSIENT NEONATAL THROMBOCYTOPENIA',
#  '779.3': 'FEEDING PROBLEMS IN NEWBORN',
#  '779.81': 'NEONATAL BRADYCARDIA',
#  '779.89': 'OTHER SPECIFIED CONDITIONS ORIGINATING IN THE PERI',
#  '780.09': 'ALTERATION OF CONSCIOUSNESS OTHER',
#  '780.2': 'SYNCOPE AND COLLAPSE',
#  '780.39': 'OTHER CONVULSIONS',
#  '780.4': 'DIZZINESS AND GIDDINESS',
#  '780.57': 'UNSPECIFIED SLEEP APNEA',
#  '780.6': 'FEVER',
#  '780.79': 'OTHER MALAISE AND FATIGUE',
#  '781.2': 'ABNORMALITY OF GAIT',
#  '782.0': 'DISTURBANCE OF SKIN SENSATION',
#  '783.7': 'ADULT FAILURE TO THRIVE',
#  '784.3': 'APHASIA',
#  '784.5': 'OTHER SPEECH DISTURBANCE',
#  '784.7': 'EPISTAXIS',
#  '785.0': 'TACHYCARDIA UNSPECIFIED',
#  '785.51': 'CARDIOGENIC SHOCK',
#  '785.52': 'SEPTIC SHOCK',
#  '785.59': 'OTHER SHOCK WITHOUT TRAUMA',
#  '786.05': 'SHORTNESS OF BREATH',
#  '786.3': 'HEMOPTYSIS',
#  '786.59': 'OTHER CHEST PAIN',
#  '786.6': 'SWELLING MASS OR LUMP IN CHEST',
#  '786.8': 'HICCOUGH',
#  '787.2': 'DYSPHAGIA',
#  '787.6': 'INCONTINENCE OF FECES',
#  '787.91': 'DIARRHEA',
#  '788.20': 'RETENTION OF URINE, UNSP',
#  '788.30': 'URINARY INCONTINENCE UNSPECIFIED',
#  '788.41': 'URINARY FREQUENCY',
#  '788.5': 'OLIGURIA AND ANURIA',
#  '789.30': 'ABDOMINAL OR PELVIC SWELLING MASS OR LUMP UNSPECIF',
#  '789.5': 'ASCITES',
#  '790.01': 'PRECIPITOUS DROP IN HEMATOCRIT',
#  '790.6': 'OTHER ABNORMAL BLOOD CHEMISTRY',
#  '790.7': 'BACTEREMIA',
#  '790.92': 'ABNORMAL COAGULATION PROFILE',
#  '790.99': 'OTH NONSPEC FIND BLOOD',
#  '792.1': 'NONSPECIFIC ABNORMAL FINDINGS IN STOOL CONTENTS',
#  '793.6': 'ABN FIND-ABDOMINAL AREA',
#  '794.00': 'ABN CNS FUNCT STUDY NOS',
#  '794.31': 'NONSPECIFIC ABNORMAL ELECTROCARDIOGRAM (ECG) (EKG)',
#  '795.5': 'NONSPECIFIC REACTION TO TUBERCULIN SKIN TEST WITHO',
#  '796.0': 'NONSPECIFIC ABNORMAL TOXICOLOGICAL FINDINGS',
#  '796.3': 'NONSPECIFIC LOW BLOOD PRESSURE READING',
#  '799.02': 'HYPOXEMIA',
#  '799.4': 'CACHEXIA',
#  '800.21': 'CL SKULL VLT FX W/O HEM',
#  '800.22': 'CLOSED FRACTURE OF VAULT OF SKULL WITH SUBARACHNOI',
#  '800.25': 'CLOSED FRACTURE OF VAULT OF SKULL WITH SUBARACHNOI',
#  '802.0': 'CLOSED FRACTURE OF NASAL BONES',
#  '802.4': 'CLOSED FRACTURE OF MALAR AND MAXILLARY BONES',
#  '803.25': 'OTHER CLOSED SKULL FRACTURE WITH SUBARACHNOID SUBD',
#  '804.25': 'CLOSED FRACTURES INVOLVING SKULL OR FACE WITH OTHE',
#  '804.35': 'CLOSED FRACTURES INVOLVING SKULL OR FACE WITH OTHE',
#  '805.00': 'CLOSED FRACTURE OF CERVICAL VERTEBRA UNSPECIFIED L',
#  '805.02': 'CLOSED FRACTURE OF SECOND CERVICAL VERTEBRA',
#  '805.04': 'CLOSED FRACTURE OF FOURTH CERVICAL VERTEBRA',
#  '805.05': 'CLOSED FRACTURE OF FIFTH CERVICAL VERTEBRA',
#  '805.07': 'CLOSED FRACTURE OF SEVENTH CERVICAL VERTEBRA',
#  '807.06': 'CLOSED FRACTURE OF SIX RIBS',
#  '807.2': 'CLOSED FRACTURE OF STERNUM',
#  '808.0': 'CLOSED FRACTURE OF ACETABULUM',
#  '808.2': 'CLOSED FRACTURE OF PUBIS',
#  '812.00': 'FRACTURE OF UNSPECIFIED PART OF UPPER END OF HUMER',
#  '812.20': 'FRACTURE OF UNSPECIFIED PART OF HUMERUS CLOSED',
#  '813.01': 'FRACTURE OF OLECRANON PROCESS OF ULNA CLOSED',
#  '813.42': 'OTHER CLOSED FRACTURES OF DISTAL END OF RADIUS (AL',
#  '815.00': 'CLOSED FRACTURE OF METACARPAL BONE(S) SITE UNSPECI',
#  '820.21': 'FRACTURE OF INTERTROCHANTERIC SECTION OF FEMUR CLO',
#  '820.22': 'FRACTURE OF SUBTROCHANTERIC SECTION OF FEMUR CLOSE',
#  '820.8': 'FRACTURE OF UNSPECIFIED PART OF NECK OF FEMUR CLOS',
#  '823.00': 'CLOSED FRACTURE OF UPPER END OF TIBIA',
#  '825.25': 'FX METATARSAL-CLOSED',
#  '831.00': 'CLOSED DISLOCATION OF SHOULDER UNSPECIFIED SITE',
#  '840.4': 'ROTATOR CUFF (CAPSULE) SPRAIN',
#  '851.80': 'OTHER AND UNSPECIFIED CEREBRAL LACERATION AND CONT',
#  '851.81': 'OTHER AND UNSPECIFIED CEREBRAL LACERATION AND CONT',
#  '851.82': 'BRAIN LAC NEC-BRIEF COMA',
#  '851.85': 'OTHER AND UNSPECIFIED CEREBRAL LACERATION AND CONT',
#  '852.00': 'SUBARACHNOID HEMORRHAGE FOLLOWING INJURY WITHOUT O',
#  '852.01': 'SUBARACHNOID HEMORRHAGE FOLLOWING INJURY WITHOUT O',
#  '852.20': 'SUBDURAL HEMORRHAGE FOLLOWING INJURY WITHOUT OPEN',
#  '852.21': 'SUBDURAL HEMORRHAGE FOLLOWING INJURY WITHOUT OPEN',
#  '852.22': 'SUBDURAL HEMORRHAGE FOLLOWING INJURY WITHOUT OPEN',
#  '853.00': 'OTHER AND UNSPECIFIED INTRACRANIAL HEMORRHAGE FOLL',
#  '853.05': 'OTHER AND UNSPECIFIED INTRACRANIAL HEMORRHAGE FOLL',
#  '860.0': 'TRAUMATIC PNEUMOTHORAX WITHOUT OPEN WOUND INTO THO',
#  '860.2': 'TRAUMATIC HEMOTHORAX WITHOUT OPEN WOUND INTO THORA',
#  '860.4': 'TRAUMATIC PNEUMOHEMOTHORAX WITHOUT OPEN WOUND INTO',
#  '861.00': 'UNSPECIFIED INJURY OF HEART WITHOUT OPEN WOUND INT',
#  '861.21': 'CONTUSION OF LUNG WITHOUT OPEN WOUND INTO THORAX',
#  '863.89': 'INJURY TO OTHER AND UNSPECIFIED GASTROINTESTINAL S',
#  '864.00': 'UNSPECIFIED INJURY TO LIVER WITHOUT OPEN WOUND INT',
#  '865.04': 'MASSIVE PARENCHYMAL DISRUPTION OF SPLEEN WITHOUT O',
#  '868.02': 'INJURY TO BILE DUCT AND GALLBLADDER WITHOUT OPEN W',
#  '868.03': 'INJURY TO PERITONEUM WITHOUT OPEN WOUND INTO CAVIT',
#  '873.0': 'OPEN WOUND OF SCALP WITHOUT COMPLICATION',
#  '873.1': 'OPEN WOUND OF SCALP COMPLICATED',
#  '873.42': 'OPEN WOUND OF FOREHEAD UNCOMPLICATED',
#  '873.43': 'OPEN WOUND OF LIP UNCOMPLICATED',
#  '873.63': 'OPEN WOUND OF TOOTH (BROKEN) UNCOMPLICATED',
#  '875.0': 'OPEN WOUND OF CHEST (WALL) WITHOUT COMPLICATION',
#  '880.03': 'OPEN WOUND OF UPPER ARM WITHOUT COMPLICATION',
#  '901.0': 'INJURY TO THORACIC AORTA',
#  '902.29': 'INJURY TO OTHER CELIAC AND MESENTERIC ARTERIES',
#  '910.0': 'ABRASION OR FRICTION BURN OF FACE NECK AND SCALP E',
#  '922.32': 'CONTUSION OF BUTTOCK',
#  '933.1': 'FOREIGN BODY IN LARYNX',
#  '934.1': 'FOREIGN BODY IN MAIN BRONCHUS',
#  '934.9': 'FOREIGN BODY IN RESPIRATORY TREE UNSPECIFIED',
#  '958.7': 'TRAUMATIC SUBCUTANEOUS EMPHYSEMA',
#  '965.00': 'POISONING BY OPIUM (ALKALOIDS) UNSPECIFIED',
#  '965.4': 'POISONING BY AROMATIC ANALGESICS NOT ELSEWHERE CLA',
#  '966.1': 'POISONING BY HYDANTOIN DERIVATIVES',
#  '969.4': 'POISONING BY BENZODIAZEPINE-BASED TRANQUILIZERS',
#  '969.8': 'POISONING BY OTHER SPECIFIED PSYCHOTROPIC AGENTS',
#  '991.6': 'HYPOTHERMIA',
#  '995.91': 'SYST INFLAM RESPN WO/ORG',
#  '995.92': 'SYSTEMIC INFLAMMATORY RESPONSE SYNDROME DUE TO INF',
#  '995.93': 'SYSTEMIC INFLAMMATORY RESPONSE SYNDROME DUE TO NON',
#  '995.94': 'SYSTEMIC INFLAMMATORY RESPONSE SYNDROME DUE TO NON',
#  '996.02': 'MECHANICAL COMPLICATION DUE TO HEART VALVE PROSTHE',
#  '996.03': 'MECHANICAL COMPLICATION DUE TO CORONARY BYPASS GRA',
#  '996.04': 'MECHANICAL COMPLICATION OF AUTOMATIC IMPLANTABLE C',
#  '996.09': 'OTHER MECHANICAL COMPLICATION OF CARDIAC DEVICE IM',
#  '996.4': 'MALF INT ORTHPED DEV/GRF',
#  '996.42': 'DISLOC PROSTHETIC JOINT',
#  '996.59': 'MECHANICAL COMPLICATION OF OTHER IMPLANT AND INTER',
#  '996.61': 'INFECTION AND INFLAMMATORY REACTION DUE TO CARDIAC',
#  '996.62': 'INFECTION AND INFLAMMATORY REACTION DUE TO OTHER V',
#  '996.64': 'INFECT DUE TO INDWEL URI',
#  '996.67': 'INFECT DUE TO OTHER ORTH',
#  '996.69': 'INFECT DUE TO OTH PROS I',
#  '996.72': 'COMPL FROM OTH CARDIAC I',
#  '996.73': 'OTHER COMPLICATIONS DUE TO RENAL DIALYSIS DEVICE I',
#  '996.74': 'COMPL FROM OTH VASCULAR',
#  '996.81': 'COMPLIC KIDNEY TRANSPLAN',
#  '996.82': 'COMPLICATIONS OF TRANSPLANTED LIVER',
#  '996.85': 'COMPLICATIONS OF TRANSPLANTED BONE MARROW',
#  '996.86': 'COMPLIC PANCREAS TRANSPL',
#  '997.02': 'IATROGENIC CEREBROVASCULAR INFARCTION OR HEMORRHAG',
#  '997.1': 'SURG COMPL-HEART',
#  '997.2': 'SURG COMP-PERI VASC SYST',
#  '997.3': 'RESPIRATORY COMPLICATIONS NOT ELSEWHERE CLASSIFIED',
#  '997.4': 'DIGEST SYSTEM COMPLIC',
#  '997.5': 'URINARY COMPLICATIONS NOT ELSEWHERE CLASSIFIED',
#  '997.62': 'INFECTION (CHRONIC) OF AMPUTATION STUMP',
#  '997.69': 'OTHER LATE AMPUTATION STUMP COMPLICATION',
#  '997.71': 'VASCULAR COMPLICATIONS OF MESENTERIC ARTERY',
#  '998.11': 'HEMORR COMPLIC PROCEDURE',
#  '998.12': 'HEMATOMA COMPLICATING A PROCEDURE',
#  '998.2': 'ACCIDENTAL OP LACERATION',
#  '998.31': 'DISRUPT INTER OPER WOUND',
#  '998.32': 'DISRUPTION OF EXTERNAL OPERATION WOUND',
#  '998.59': 'OTHER POSTOPERATIVE INFECTION',
#  '998.81': 'EMPHYSEMA (SUBCUTANEOUS) (SURGICAL) RESULTING FROM',
#  '998.89': 'OTHR SPEC COMPL NOT CLAS',
#  '999.1': 'AIR EMBOLISM AS A COMPLICATION OF MEDICAL CARE NOT',
#  '999.3': 'OTHER INFECTION DUE TO MEDICAL CARE NOT ELSEWHERE',
#  '999.8': 'TRANSFUSION REACTION NEC',
#  '999.9': 'COMPLIC MED CARE NEC/NOS',
#  'E814.7': 'MOTOR VEHICLE TRAFFIC ACCIDENT INVOLVING COLLISION',
#  'E815.0': 'OTHER MOTOR VEHICLE TRAFFIC ACCIDENT INVOLVING COL',
#  'E818.7': 'OTHER NONCOLLISION MOTOR VEHICLE TRAFFIC ACCIDENT',
#  'E819.1': 'MOTOR VEHICLE TRAFFIC ACCIDENT OF UNSPECIFIED NATU',
#  'E848': 'ACCIDENTS INVOLVING OTHER VEHICLES NOT ELSEWHERE C',
#  'E849.0': 'HOME ACCIDENTS',
#  'E849.7': 'ACCIDENTS OCCURRING IN RESIDENTIAL INSTITUTION',
#  'E850.2': 'ACCIDENTAL POISONING BY OTHER OPIATES AND RELATED',
#  'E853.2': 'ACCIDENTAL POISONING BY BENZODIAZEPINE-BASED TRANQ',
#  'E855.0': 'ACCIDENTAL POISONING BY ANTICONVULSANT AND ANTI-PA',
#  'E870.0': 'ACCIDENTAL CUT PUNCTURE PERFORATION OR HEMORRHAGE',
#  'E878.0': 'ABN REACT-ORG TRANSPLANT',
#  'E878.2': 'ABN REACT-ANASTOM/GRAFT',
#  'E878.6': 'REMOVAL OF OTHER ORGAN (PARTIAL) (TOTAL) CAUSING A',
#  'E878.8': 'ABN REACT-SURG PROC NEC',
#  'E879.0': 'ABN REACT-CARDIAC CATH',
#  'E879.1': 'ABN REACT-RENAL DIALYSIS',
#  'E879.8': 'OTHER SPECIFIED PROCEDURES AS THE CAUSE OF ABNORMA',
#  'E879.9': 'UNSPECIFIED PROCEDURE AS THE CAUSE OF ABNORMAL REA',
#  'E880.1': 'ACCIDENTAL FALL ON OR FROM SIDEWALK CURB',
#  'E880.9': 'ACCIDENTAL FALL ON OR FROM OTHER STAIRS OR STEPS',
#  'E884.2': 'ACCIDENTAL FALL FROM CHAIR',
#  'E884.6': 'ACCIDENTAL FALL FROM COMMODE',
#  'E884.9': 'OTHER ACCIDENTAL FALL FROM ONE LEVEL TO ANOTHER',
#  'E885.9': 'ACCIDENTAL FALL FROM OTHER SLIPPING TRIPPNG OR STU',
#  'E888.9': 'UNSPECIFIED ACCIDENTAL FALL',
#  'E901.0': 'ACCIDENT DUE TO EXCESSIVE COLD DUE TO WEATHER COND',
#  'E912': 'INHALATION AND INGESTION OF OTHER OBJECT CAUSING O',
#  'E927': 'ACCID FROM OVEREXERTION',
#  'E928.9': 'UNSPECIFIED ACCIDENT',
#  'E929.0': 'LATE EFFECTS OF MOTOR VEHICLE ACCIDENT',
#  'E930.8': 'ADV EFF ANTIBIOTICS NEC',
#  'E931.9': 'OTHER AND UNSPECIFIED ANTI-INFECTIVES CAUSING ADVE',
#  'E932.0': 'ADV EFF CORTICOSTEROIDS',
#  'E933.1': 'ANTINEOPLASTIC AND IMMUNOSUPPRESSIVE DRUGS CAUSING',
#  'E934.2': 'ANTICOAGULANTS CAUSING ADVERSE EFFECTS IN THERAPEU',
#  'E934.4': 'FIBRINOLYSIS-AFFECTING DRUGS CAUSING ADVERSE EFFEC',
#  'E935.9': 'UNSPECIFIED ANALGESIC AND ANTIPYRETIC CAUSING ADVE',
#  'E936.1': 'HYDANTOIN DERIVATIVES CAUSING ADVERSE EFFECTS IN T',
#  'E937.8': 'OTHER SEDATIVES AND HYPNOTICS CAUSING ADVERSE EFFE',
#  'E937.9': 'UNSPECIFIED SEDATIVES AND HYPNOTICS CAUSING ADVERS',
#  'E939.4': 'BENZODIAZEPINE-BASED TRANQUILIZERS CAUSING ADVERSE',
#  'E939.7': 'PSYCHOSTIMULANTS CAUSING ADVERSE EFFECTS IN THERAP',
#  'E939.8': 'OTHER PSYCHOTROPIC AGENTS CAUSING ADVERSE EFFECTS',
#  'E942.0': 'ADV EFF CARD RHYTH REGUL',
#  'E942.1': 'CARDIOTONIC GLYCOSIDES AND DRUGS OF SIMILAR ACTION',
#  'E947.8': 'OTHER DRUGS AND MEDICINAL SUBSTANCES CAUSING ADVER',
#  'E966': 'ASSAULT BY CUTTING AND PIERCING INSTRUMENT',
#  'E980.0': 'POISONING BY ANALGESICS ANTIPYRETICS AND ANTIRHEUM',
#  'V02.62': 'CARRIER OR SUSPECTED CARRIER OF HEPATITIS C',
#  'V05.3': 'NEED FOR PROPHYLACTIC VACCINATION AND INOCULATION',
#  'V08': 'ASYMPTOMATIC HUMAN IMMUNODEFICIENCY VIRUS (HIV) IN',
#  'V09.0': 'INFECTION WITH MICROORGANISMS RESISTANT TO PENICIL',
#  'V09.80': 'INF OTH DRUGS W/O RESIST',
#  'V09.91': 'INF DRUG-RESIST W/ RESIS',
#  'V10.00': 'HX OF GI MALIGNANCY NOS',
#  'V10.04': 'HX OF GASTRIC MALIGNANCY',
#  'V10.05': 'PERSONAL HISTORY OF MALIGNANT NEOPLASM OF LARGE IN',
#  'V10.06': 'PERSONAL HISTORY OF MALIGNANT NEOPLASM OF RECTUM R',
#  'V10.09': 'PERSONAL HISTORY OF MALIGNANT NEOPLASM OF OTHER SI',
#  'V10.11': 'PERSONAL HISTORY OF MALIGNANT NEOPLASM OF BRONCHUS',
#  'V10.3': 'PERSONAL HISTORY OF MALIGNANT NEOPLASM OF BREAST',
#  'V10.41': 'PERSONAL HISTORY OF MALIGNANT NEOPLASM OF CERVIX U',
#  'V10.42': 'PERSONAL HISTORY OF MALIGNANT NEOPLASM OF OTHER PA',
#  'V10.46': 'PERSONAL HISTORY OF MALIGNANT NEOPLASM OF PROSTATE',
#  'V10.51': 'HX OF BLADDER MALIGNANCY',
#  'V10.52': 'HX OF KIDNEY MALIGNANCY',
#  'V10.79': 'PERSONAL HISTORY OF OTHER LYMPHATIC AND HEMATOPOIE',
#  'V10.82': 'PERSONAL HISTORY OF MALIGNANT MELANOMA OF SKIN',
#  'V11.3': 'PERSONAL HISTORY OF ALCOHOLISM',
#  'V12.01': 'PERS HIST TUBERCULOSIS',
#  'V12.51': 'PERSONAL HISTORY OF VENOUS THROMBOSIS AND EMBOLISM',
#  'V12.59': 'PERS HX OTH DIS CIRC SYS',
#  'V13.01': 'PERS HIST URIN CALCULI',
#  'V15.3': 'PERSONAL HISTORY OF IRRADIATION PRESENTING HAZARDS',
#  'V15.81': 'PERSONAL HISTORY OF NONCOMPLIANCE WITH MEDICAL TRE',
#  'V15.82': 'PERSONAL HISTORY OF TOBACCO USE',
#  'V16.0': 'FAMILY HISTORY OF MALIGNANT NEOPLASM OF GASTROINTE',
#  'V16.42': 'FAMILY HISTORY OF MALIGNANT NEOPLASM OF PROSTATE',
#  'V17.3': 'FAMILY HISTORY OF ISCHEMIC HEART DISEASE',
#  'V29.0': 'OBSERVATION FOR SUSPECTED INFECTIOUS CONDITION',
#  'V30.00': 'SINGLE LIVEBORN BORN IN HOSPITAL DELIVERED WITHOUT',
#  'V30.01': 'SINGLE LIVEBORN BORN IN HOSPITAL DELIVERED BY CESA',
#  'V42.0': 'KIDNEY REPLACED BY TRANSPLANT',
#  'V42.2': 'HEART VALVE REPLACED BY TRANSPLANT',
#  'V42.83': 'ORG TISSUE REPL TRANS PA',
#  'V43.3': 'HEART VALVE REPLACED BY OTHER MEANS',
#  'V43.64': 'HIP JOINT REPLACEMENT',
#  'V43.65': 'KNEE JOINT REPLACEMENT',
#  'V44.0': 'TRACHEOSTOMY STATUS',
#  'V44.1': 'GASTROSTOMY STATUS',
#  'V44.3': 'COLOSTOMY STATUS',
#  'V44.4': 'STATUS OF OTHER ARTIFICIAL OPENING OF GASTROINTEST',
#  'V45.01': 'CARDIAC PACEMAKR IN SITU',
#  'V45.02': 'AUTO IMPLANT CARD DEFIBR',
#  'V45.1': 'POSTSURGICAL RENAL DIALYSIS STATUS',
#  'V45.2': 'POSTSURGICAL PRESENCE OF CEREBROSPINAL FLUID DRAIN',
#  'V45.4': 'ARTHRODESIS STATUS',
#  'V45.73': 'ACQUIRED ABSENCE OF KIDNEY',
#  'V45.81': 'AORTOCORONARY BYPASS',
#  'V45.82': 'PERCUTANEOUS TRANSLUMINAL CORONARY ANGIOPLASTY STA',
#  'V46.11': 'DEPENDENCE ON RESPIRATOR',
#  'V46.2': 'DEPENDENCE ON SUPPLEMENTAL OXYGEN',
#  'V49.72': 'OTHR TOE(S) AMPUT STATUS',
#  'V49.75': 'BELOW KNEE AMPUTATION STATUS',
#  'V49.76': 'ABOVE KNEE AMPUTATION STATUS',
#  'V49.83': 'AWAIT ORGAN TRANSPLANT S',
#  'V53.31': 'FITTING AND ADJUSTMENT OF CARDIAC PACEMAKER',
#  'V53.32': 'FITTING AND ADJUSTMENT OF AUTOMATIC IMPLANTABLE CA',
#  'V55.0': 'ATTEN TO TRACHEOSTOMY',
#  'V55.3': 'ATTEN TO COLOSTOMY',
#  'V58.1': 'MAINTENANCE CHEMOTHERAPY',
#  'V58.43': 'AFTRCRE FOLW SURG/TRAUMA',
#  'V58.61': 'LONG-TERM (CURRENT) USE OF ANTICOAGULANTS',
#  'V58.65': 'LONG-TERM (CURRENT) USE OF STEROIDS',
#  'V58.67': 'LONG-TERM (CURRENT) USE',
#  'V60.0': 'LACK OF HOUSING',
#  'V61.0': 'FAMILY DISRUPTION',
#  'V62.5': 'LEGAL CIRCUMSTANCES',
#  'V64.1': 'SURGICAL OR OTHER PROCEDURE NOT CARRIED OUT BECAUS',
#  'V64.4': 'NO LABEL PROVIDED',
#  'V64.41': 'LAPAROSCOPIC SURGICAL PROCEDURE CONVERTED TO OPEN',
#  'V66.7': 'PALLIATIVE CARE',
#  'V70.7': 'EXAMINATION OF PARTICIPANT IN CLINICAL TRIAL'}

# %%
icd9_patients = defaultdict(list) #key 
patient_diagnoses = defaultdict(list) #key is patient, values is all their codes

# %% [markdown]
# ### How many patients are there for each diagnosis?
#
# Create a list named `icd9_patients_list` sorted by the number of patients per diagnosis.

# %%
icd9_patients = defaultdict(list) #the first input it sees, it will make the first value be a list
#dictionary key by the code, then the value is the list of patients with that code

for p,c,l in icd9_data: #the three pieces in the tuple get separated into those variable names
    try:
        icd9_patients[c].append(p)
    except:
        pass

print(icd9_patients)

#def length_element2(x):
#    return len(x[1])
#could pass sort this function (e.g. .sort(length_element2), or could write it in-line
#...I think that that's the right syntax?

icd9_patients_list=list(icd9_patients.items())
icd9_patients_list.sort(key=lambda x: len(x[1]), reverse=True)
# Out:
# defaultdict(<class 'list'>, {'V10.46': [21, 176, 415, 414, 971, 1684, 1940, 2121, 2556], '276.3': [61, 353, 1158, 1579, 1670, 1807, 2187], '174.8': [2297], '531.70': [2266], 'E818.7': [1245], '041.4': [286, 503, 945, 1207, 1266, 2135, 2284], '682.2': [1804, 2512], '197.0': [516, 505, 623, 705, 1182, 1594, 1594, 1594, 1882, 2099, 2297, 2501, 2558, 2558], '730.15': [1890], '441.3': [405], '934.9': [2291], '038.3': [1606, 2225], 'E878.6': [1656], '707.06': [450, 450], '569.85': [1207, 1931, 1931], '599.7': [176, 773, 921, 1151, 1100, 1371, 1470, 2265, 2364, 2493], '447.1': [1702], '682.7': [353, 732, 1979], '492.8': [1336, 1313, 1972, 2135, 2493], '775.9': [2532], 'E879.1': [353, 2512], '825.25': [1610], '593.2': [631, 2328], '428.31': [491, 1158, 2156], '707.01': [443, 450, 450], '451.84': [2262], '272.0': [56, 26, 21, 83, 124, 124, 235, 177, 301, 390, 415, 443, 496, 514, 609, 584, 705, 717, 690, 711, 752, 792, 936, 826, 937, 977, 1038, 1100, 1270, 1290, 1308, 1336, 1357, 1586, 1615, 1659, 1656, 1726, 1744, 1795, 1860, 1822, 1950, 1944, 1999, 2054, 2268, 2284, 2328, 2309, 2385, 2501, 2491, 2550, 2512], '201.90': [31, 1106, 2385], '251.8': [1088, 1594], '428.41': [1855], 'V64.41': [1193], '531.00': [112, 634], '996.73': [634, 2477], '440.1': [832, 1207], '568.0': [12, 2225], '440.20': [1141, 1371, 2187], '805.07': [313], '197.8': [538, 1010], '444.22': [732, 937, 1427, 1944], '868.03': [1766, 1822, 2265], '285.21': [21, 353, 631, 690, 690, 732, 1426, 1371, 1571, 1855, 1855, 1944, 2512, 2512], '162.2': [1534, 1972, 1972, 2057, 2076], '276.50': [908, 1598], '197.6': [1863], '729.72': [1427], 'V45.01': [176, 301, 356, 346, 631, 631, 732, 781, 781, 985, 1332, 1381, 1621, 1641, 1804, 1804, 1832, 1931, 2127, 2272, 2550, 2550], '792.1': [1621], '510.9': [1752], '336.3': [623, 1659], '357.2': [286, 353, 353, 613, 690, 690, 846, 998, 1308, 1944, 2121, 2187, 2187, 2187, 2243, 2272], '070.54': [78, 117, 433, 940, 1100, 1245, 1329, 2328, 2493, 2570, 2512], '198.2': [2074], '198.3': [56, 150, 1594, 1594, 1594, 1656, 2057, 2558], '335.20': [94, 509, 1378, 1358], '532.50': [2286], '969.8': [565], '008.45': [21, 283, 634, 711, 1038, 1158, 1357, 1474, 1534, 1528, 1571, 1606, 1606, 1641, 1860, 1855, 1987, 2014, 2187, 2265], '038.42': [450, 1621, 2284, 2570], '250.51': [745, 998, 1944, 2243], '459.2': [21, 2297], '584.9': [3, 21, 112, 105, 106, 117, 301, 384, 405, 430, 414, 433, 408, 450, 538, 546, 545, 565, 623, 682, 634, 634, 705, 700, 719, 787, 745, 773, 781, 832, 874, 921, 940, 985, 984, 984, 998, 1038, 1079, 1120, 1124, 1092, 1141, 1173, 1193, 1227, 1299, 1266, 1357, 1320, 1371, 1390, 1453, 1488, 1537, 1598, 1606, 1606, 1621, 1670, 1641, 1724, 1790, 1807, 1860, 1832, 1863, 1892, 1944, 1944, 1944, 1972, 1972, 1972, 1972, 1999, 2073, 2074, 2014, 2098, 2177, 2156, 2186, 2180, 2228, 2195, 2178, 2187, 2187, 2268, 2272, 2309, 2291, 2332, 2322, 2364, 2417, 2428, 2484, 2501, 2478, 2503, 2550, 2570, 2512], '722.72': [634], '537.0': [2121], '578.1': [61, 21, 538, 618, 768, 787, 1173, 1197, 1470, 1898, 2135, 2121], '860.0': [1721], '438.89': [21, 21, 157, 1332, 1501], '263.9': [3, 61, 117, 261, 301, 434, 479, 590, 618, 634, 1151, 1197, 1193, 1371, 1528, 1641, 2073, 2057, 2286, 2265], '274.9': [21, 21, 414, 443, 461, 525, 545, 732, 940, 1100, 1427, 1534, 1571, 1571, 1659, 2512], '998.32': [1999, 2309], '787.91': [998, 1621, 1805], '429.9': [609, 1067], '041.04': [433, 2187, 2265], '473.9': [1470], '562.12': [2320], '518.89': [679, 679, 1684, 2471, 2477], '205.10': [404], 'E880.9': [994, 1332, 1726, 2006, 2265, 2265, 2456], '041.11': [732, 984, 1659, 1795, 1752, 1890, 2098], '608.83': [1987], '444.1': [2448], '745.5': [781], '423.9': [433, 532, 516, 1265, 1884, 2180], '427.41': [106, 532, 669, 1855, 1944, 1972, 2071], '511.1': [627, 1972], '359.81': [2178], 'E980.0': [2177], '202.80': [61, 61, 346, 1081, 1579, 1604, 1790, 1984], '711.05': [745], '585.9': [414, 545, 564, 631, 983, 1606, 1621, 2243, 2337, 2478, 2493], '531.90': [2186], '285.22': [1081], '715 ...

# %% [markdown]
# # repeat with a regular dictionary

# %%
icd9_patients = {}
#dictionary keyed by the code, then the value is the list of patients with that code

for p,c,l in icd9_data[:50]: #the three pieces in the tuple get separated into those variable names
    #print(p,c,l)
    if c in icd9_patients:
        icd9_patients[c].append(p)
    else:
        new_list = [p]
        icd9_patients[c] = new_list
    #print(icd9_patients)

# %%
import random
d,p = random.choice(icd9_patients_list)
print(d,len(p),sep="\n")
print(icd9_patients["V12.59"])
for d,p in icd9_patients.items():
    if "HX" in d:
        print(d,len(p))

# %%
assert_equals(len(icd9_patients["V12.59"]),5)
assert_equals(len(icd9_patients["572.2"]),12)

# %% [markdown]
# #### Loop through  `icd9_patients_list`
# 1. for each element in `icd9_patients_list` print the ICD9 label corresponding to the code and the number of patients with each diagnosis.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# ### How many diagnoses does each patient have?

# %%
patient_diagnoses = defaultdict(list)
# YOUR CODE HERE
raise NotImplementedError()

# %%
for p, d in patient_diagnoses_list:
    print(p)
    print(d) # replace with len(d)
    print("\n")

# %%
assert_equals(len(patient_diagnoses[2512]),49)
assert_equals(len(patient_diagnoses[353]),56)
assert_equals(len(patient_diagnoses_list[0][1]),125)
assert_equals(len(patient_diagnoses_list[45][1]),23)
