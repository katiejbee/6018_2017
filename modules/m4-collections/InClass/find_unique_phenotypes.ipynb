# %% [markdown]
# # Unique Phenotypes
#
# You have been given a file that consists of phenotypes that have been assigned to individual cardiology patients. The data was supposed to have been entered as a table with two columns per patient. The first column was to be a single, primary phenotype for a patient. The second column was to be a comma separated list of secondary phenotypes for that patient. Unfortunately, data entry did not follow this prescription and was inconsistent. Sometimes multiple phenotypes are provided in column one, sometimes a different delimiter than a comma is used.
#
# Your task is to provide an alphabetically sorted list of unique phenotypes encountered in the data. Missing values are denoted by an empty string and should **not** be treated as a phenotype.
#
# As a side note, the researcher responsible for this data would also like to know what delimiters were used in data entry.
#
# I have used Pandas to read the data in and convert it to a list for you to start with.

# %%
import pandas as pd

# %%
data = pd.read_excel("./create_uniq_phenotypes.xlsx", header=None)
print(data.columns)
data.head(20)
# Out:
# Int64Index([0, 1], dtype='int64')
#                                        0  \
# 0                                AS, BAV
# 1                 Capillary malformation
# 2                Congenital Heart Defect
# 3                Congenital Heart Defect
# 4                                    CHD
# 5                                    CHD
# 6                                    CHD
# 7                                    CHD
# 8                                    CHD
# 9                                    CHD
# 10                                   CHD
# 11                                   CHD
# 12                      CHD & Cardiology
# 13                        CHD/Cardiology
# 14                                   CHD
# 15                                   CHD
# 16  Congenital Heart Defect & Cardiology
# 17  Cardiology & Congenital Heart Defect
# 18  Congenital Heart Defect & Cardiology
# 19                            Cardiology
#
#                                                     1
# 0                                          Cardiology
# 1                                       Lymph F#69-01
# 2                                                 NaN
# 3                                               TAPVR
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12       AVC (balanced) subvalvar aortic fibrous ring
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                D-TGA, VSD muscular
# 17                                   L-TGA, PS, LV-PA
# 18  Tricupsid Atresia, D-TGA, Hypoplastic p-ventri...
# 19                                                NaN

# %%
data = [", ".join(d) for d in data.fillna("").values.tolist()]

# %%
data
# Out:
# ['AS, BAV, Cardiology',
#  'Capillary malformation, Lymph F#69-01',
#  'Congenital Heart Defect, ',
#  'Congenital Heart Defect, TAPVR',
#  'CHD, ',
#  'CHD, ',
#  'CHD, ',
#  'CHD, ',
#  'CHD, ',
#  'CHD, ',
#  'CHD, ',
#  'CHD, ',
#  'CHD & Cardiology, AVC (balanced) subvalvar aortic fibrous ring',
#  'CHD/Cardiology, ',
#  'CHD, ',
#  'CHD, ',
#  'Congenital Heart Defect & Cardiology, D-TGA, VSD muscular',
#  'Cardiology & Congenital Heart Defect, L-TGA, PS, LV-PA',
#  'Congenital Heart Defect & Cardiology, Tricupsid Atresia, D-TGA, Hypoplastic p-ventricle & aorta w/VSD',
#  'Cardiology, ',
#  'Congenital Heart Disease & Cardiology, HLHS',
#  'Cardiology, PA/IVS',
#  'Cardiology, ',
#  'Cardiology, ',
#  'Cardiology, ',
#  'Cardiology, ',
#  'Cardiology, ',
#  'Cardiology, ',
#  'Cardiology, ',
#  'Cardiology, ',
#  'Cardiology, ',
#  'Cardiology, ',
#  'Cardiology, Kawisaki',
#  'Cardiology, Hypoplastic left Heart Syndrome',
#  'Cardiology, ',
#  'Cardiology, ',
#  'Cardiology, Tetraology of fallot/PulmonaryArtresea',
#  'Cardiology, TOF',
#  'Cardiology, ',
#  'Cardiology, TAPVR',
#  'Cardiology, Transposition of the Great Arteries',
#  'Cardiology, Pulmonary Artresia,VSD',
#  'Cardiology, Tetrology of Fallot',
#  'Cardiology, Typoplastic left Heart syndrome',
#  'Cardiology, TOF ',
#  'Cardiology, Typoplastic left Heart Syndrome',
#  'Cardiology, Dextrocardia',
#  'Cardiology, ',
#  'Cardiology, Wolf Parkenson White Syndrome',
#  'Cardiology, Coarctation, secundum ASD, PDA, BAV',
#  'Cardiology, CA,BAV',
#  'Cardiology, long Qt syndrome',
#  'Cardiology, Wolf Parkinson White Syndrome',
#  'Cardiology, Tri Cupid Artresia',
#  'Cardiology, DTGA,VSD',
#  'Cardiology, ',
#  'Cardiology, ',
#  'Cardiology, BAV',
#  'Cardiology, COA',
#  'Cardiology, Pulmonary Stenosis',
#  'Cardiology, Ai Rheumatic Fever',
#  'Cardiology, VSD',
#  'Cardiology, See notes Section',
#  'Cardiology, COA,BAV',
#  'Cardiology, L-TGA,VSD',
#  'Cardiology, Hypoplastic Left Heart Syndrome',
#  'Cardiology, Tricuspid Artresia, COA',
#  'Cardiology, AS,Sub AS',
#  'Cardiology, BAV,COA',
#  'Cardiology, WPW',
#  'Cardiology, PA / I VS',
#  'Cardiology, AS',
#  'Cardiology, ',
#  'Cardiology, ',
#  'Cardiology, TGA',
#  'Cardiology, BAV',
#  'Cardiology, BAV,AI,AS',
#  'Cardiology, CHD,AS',
#  'Cardiology, HLHS,AS',
#  'Cardiology, PVA',
#  'Cardiology, BAV',
#  'Cardiology, PA,VSD',
#  'Cardiology, TGV',
#  'Cardiology, HLHS',
#  'Cardiology, HLHS,AS,MS',
#  'Cardiology, WPW',
#  'Cardiology, TAPVR',
#  'Cardiology, TGA,COA',
#  'Cardiology, D-TGA',
#  'Cardiology, AS,BAV',
#  'Cardiology, L-TGA',
#  'Cardiology, COA,AS',
#  'Cardiology, HLHS',
#  'Cardiology, COA',
#  'Cardiology, IAA: VSD',
#  'Cardiology, TGA',
#  'Cardiology, LSH',
#  'Cardiology, IAAJ VSD,Sub AS',
#  'Cardiology, BAV',
#  'Cardiology, TOF',
#  'Cardiology, AS/AI',
#  'Cardiology, COA,BAV',
#  'Cardiology, TA,TGA',
#  'Cardiology, COA',
#  'Cardiology, COA',
#  'Cardiology, COA',
#  'Cardiology, TAG,Mitral Artresia',
#  'Cardiology, TA, PS (valvar)',
#  'Cardiology, HLHS',
#  'Cardiology, DORV',
#  'Cardiology, D-TGA',
#  'Cardiology, HLHS',
#  'Cardiology, Truncus Type II , PA Stenosis',
#  'Cardiology, COA',
#  'Cardiology, HLHS',
#  'Cardiology, HCM',
#  'Cardiology, BAV, Mild PS (valvar)',
#  'Cardiology, HLHS, T-GA, PA (valvar w/VSD)',
#  'Cardiology, TGA, VSD',
#  'Cardiology, TA',
#  'Cardiology, PS',
#  'Cardiology, D-TGA',
#  'Cardiology, WPW',
#  'Cardiology, PA/IVS',
#  'Cardiology, HCM',
#  'Cardiology, COA',
#  'Cardiology, DORV',
#  'Cardiology, complete AV septal defect, balanced',
#  'Cardiology, COA',
#  'Cardiology, PH',
#  'Cardiology, ALCAPA, dilated cardiomyopathy',
#  'Cardiology, valvular AS/AI',
#  'Cardiology, COA, BAV',
#  'Cardiology, HLHS Variant',
#  'Cardiology, Tricuspid Atresia ,D-TGA VSD',
#  'Cardiology, Mild AS (valve)',
#  'Cardiology, DTGA,VSD',
#  'Cardiology, BAV',
#  'Cardiology, Ebstins',
#  'Cardiology, COA',
#  'Cardiology, COA, BAV',
#  'Cardiology, Truncus',
#  'Cardiology, COA, valvular aortic stenosis',
#  'Cardiology, AS/AI (valvular), BAV, COA',
#  'Cardiology, AS (Valve)',
#  'Cardiology, DORV, mitral atresia',
#  'Cardiology, inlet VSD, secundum ASD, moderate MI, DORV, MS, LV hypoplasia',
#  'Cardiology, PA, IVS, mild PS, Severe PI',
#  'Cardiology, TOF',
#  'Cardiology, TGA, pulmonary artresia valvar',
#  'Cardiology, BAV, AI, AS supravalvar',
#  'Cardiology, DILV w/left AV atresia, BAV, LTGA ASD "unrestrictive"',
#  'Cardiology, AI, AS',
#  'Cardiology, BAV, Valve AS',
#  'Cardiology, DTGA w/IVS, ASD, AI, PI',
#  'Cardiology, Valvar PS,PFO',
#  'Cardiology, COA w/hypoplasia, Transverse Arch, probable BAV, mid muscular VSD, PFO',
#  'Cardiology, ',
#  'Cardiology, ',
#  'Cardiology, Valvar PS, PDA',
#  'Cardiology, TGA',
#  'Cardiology, Secundum ASD, Ebstein Anamdy',
#  'Cardiology, WPW',
#  'Cardiology, DTGA',
#  'Cardiology, COA, BAV',
#  'Cardiology, MV prolapse, MR, PI, ALCAPA w/ Subsequent Myocardial Ischemia',
#  'Cardiology, Valve PS',
#  'Cardiology, Secundum ASD, Valve PS',
#  'Cardiology, TOF, Perimembranous VSD',
#  "Cardiology, Ebsteen's, TR, Secundum ASD",
#  'Cardiology, DORV w/ PA, PDA,, outlet VSD, Secundum ASD',
#  'Cardiology, HLHS, Mitral Atresia, Aorticatresia, PDA',
#  'Cardiology, HLHS',
#  'Cardiology, IAA type B, outlet VSD, secindum ASD, 22q11 deletion',
#  'Cardiology, Diated CM, MR',
#  'Cardiology, SVT',
#  'Cardiology, DTGA, Subpulmonary VSD, PDA double aortic arch/ Vasular ring',
#  'Cardiology, 22q11 deletion, TOF, ASD, PDA',
#  'Cardiology, A1,dilated aortic root, Marfan Syndrome',
#  'Cardiolgoy, WPW',
#  'Cardiology, DILV w/ l-,a;[psed great vessels. right sided AV valve',
#  'Cardiology, TOF, PA',
#  'Cardiology, ',
#  'Cardiology, PA/VSD (subaortic)',
#  'Cardiology, Secundum ASD',
#  'Cardiology, DTGA',
#  'Cardiology, Partial AVSD, Primum ASD, LSVC, Cortriatriaum',
#  'Cardiology, TOF/PA, PFO reverse PDA',
#  'Cardiology, COA, PJRT',
#  "Cardiology, Ebstein's",
#  'Cardiology, HLHS',
#  'Cardiology, ',
#  'Cardiology, Balanced AVSD, PDA',
#  'Cardiology, Primum ASD, Secundum ASD',
#  'Cardiology, SVT',
#  'Cardiology, Truncus Type 1, PFO, RAA, VSD',
#  'Cardiology, Valve AS',
#  'Cardiology, BAV, AS Valvar, AI',
#  'Cardiology, Valve PS, PDA',
#  'Cardiology, DORV, Sub AS, COA, VSD, MS',
#  'Cardiology, COA, BAV, PDA, Subaortic ridge',
#  'Cardiology, WPW',
#  'Cardiology, COA, BAV',
#  'Cardiology, TAPVR, PH',
#  'Cardiology, T21, Balanced AV canal, PH, inlet VSD, muscular VSD, Secundum ASD, Primum ASD',
#  'Cardiology, Valvar PS',
#  'Cardiology, Functional single left ventricle with right or tricuspid atresia, valvar, subvalvar severe PS, TGA (D), RAA',
#  'Cardiology, PFO, small aortic isthmus, COA',
#  'Cardiology, Tricuspid atresia w/normally related great vessels, secundum, ASD, muscular VSD',
#  'Cardiology, DTGA, muscular VSD, COA',
#  'Cardiology, Tricuspid atresia, DTGA, restrictive VSD, COA',
#  'Cardiology, BAV (As 2 degrees to BAV)',
#  'Cardiology, Valvar AS, valvar AI, MI (unknown)',
#  'Cardiology, Perimembranous VSD, LTGA w/ventricular inversion',
#  'Cardiology, Secundum ASD, WPW',
#  'Cardiology, subaortic membrane w/ mild left ventricular outflow tract obstruction, trivial AI & PI',
#  'Cardiology, secundum ASD, possible VSD noted in clinic notes but not on echo report',
#  'Cardiology, TOF, RAA',
#  'Cardiology, DORV, TGA, COA, AI, unknown type ASD',
#  'Cardiology, D-TGA',
#  'Cardiology, PAPVR, PFO, sinous venousus, ASD unknown type',
#  'Cardiology, COA, BAV, PDA',
#  'Cardiology, DTGA, PDA, muscular vs, perimembranous VSD',
#  'Cardiology, DTGA, (S.D.D)dextroposition',
#  'Cardiology, COA, SubAS',
#  'Cardiology, COA, perimembranous VSD',
#  'Cardiology, COA w/small transverse aortic arch, PDA, PI, muscular VSD',
#  'Cardiology, ',
#  'Cardiology, D-TGA',
#  'Cardiology, BAV',
#  'Cardiology, COA, dilated left ventricle',
#  'Cardiology, DORV, VT, KD',
#  'Cardiology, COA, BAV',
#  'Cardiology, TOF, RAA, mild PI, PDA',
#  'Cardiology, TOF',
#  'Cardiology, Tricuspid Stresea, Secundum ASD',
#  'Cardiology, Dysplastic VS, Ebstenoid Tricuspid Valve',
#  'Cardiology, BAV, PDA, valve AS, AI',
#  'Cardiology, PA/IVS, PDA, PFO, Tricuspid regurgitation',
#  'Cardiology, COA, BAV, PDA, PFO, 2 muscular VSDs',
#  'Cardiology, KD w/o coronary involvement',
#  'Cardiology, TOF, PDA, infracristal VSD, PS, Pulmonary paremembraneous valve stenosis',
#  'Cardiology, AR, valve AS',
#  'Cardiology, COA, BAV, permembraneous VSD, Trace AI',
#  'Cardiology, unbalanced AVSD, Primum & secundum, ASD, inlet VSD, heterotaxy-right, atrial isomerism, DORV, TAPVR',
#  'Cardiology, PA-IVS, PDA, Secundum ASD, PI',
#  'Cardiology, BAV, AI',
#  'Cardiology, COA',
#  'Cardiology, PDA, ostium secundum ASD',
#  'Cardiology, valvar PS, secundum ASD',
#  'Cardiology, D-TGA',
#  'Cardiology, Noonan Syndrome, Subvalvar, valvar, supravalvar PS, PI, fenestrated ASD',
#  'Cardiology, HLHS, aortic atresia, MS, secundum ASD',
#  'Cardiology, Trisomy 21, inlet VSD, Primum ASD, AV canal',
#  'Cardiology, Williams Syndrome, Supravalvar AS',
#  'Cardiology, COA',
#  'Cardiology, Valvular AS, BAV',
#  'Cardiology, COA, secundum ASD, BAV, muscular VSD, AI',
#  'Cardiology, COA, BAV, VSD (perimembranous), ASD (secundum) PDA',
#  'Cardiology, Valvar AS, BAV',
#  'Cardiology, BAV, AI, AS valvar',
#  'Cardiology, TA',
#  'Cardiology, I, L, LTGA, PS, outlet VSD, PA',
#  'Cardiology, KD w/coronary',
#  'Cardiology, Migraine w/possible PFO',
#  'Cardiology, WPW',
#  'Cardiology, AV canal (incomplete), primum & secundum ASD, valvar PS, clft mitral valve, endocardial cushion defect type abnormalities suggestion of PDA',
#  'Cardiology, secundum ASD (spontaneous closure by age foree)',
#  'Cardiology, Valve AS',
#  'Cardiology, COA',
#  "Cardiology, BAV, PPS, innocent murmur (still's type)",
#  'Cardiology, COA, muscular VSD',
#  'Cardiology, BAV, AS (valve)',
#  'Cardiology, DCM possibly 2to daunorubicin therapy',
#  'Cardiology, SVT-PJRT, SVT due to a concealed accessory connection',
#  'Cardiology, BAV, PDA, COA, muscular VSD, PFO complete Avanal',
#  'Cardiology, KD w/o coronary, muscular VSD, PDA',
#  'Cardiology, valve AS, COA, PDA',
#  'Cardiology, PDA',
#  'Cardiology, COA, muscular VSD, hx of PH',
#  'Cardiology, Intracardiac myxoma',
#  'Cardiology, RF, AI, MR',
#  'Cardiology, KD w/CI',
#  'Cardiology, PDA, AI, BAV',
#  'Cardiology, Latreal esomereson, PDA, PAPVR - 1psi lateral',
#  'Cardiology, PS (unknown type) SVT',
#  'Cardiology, DTGA, inlet VSD, COA, PDA, secundum ASD',
#  'Cardiology, BAV',
#  'Cardiology, Tric Atresia, Normally related great vessels, muscular VSD, secundum ASD, born w/out a sternum',
#  'Cardiology, L-TGA, tricupsid atresia, moderate PS (unknown type) restrictive PFO',
#  'Cardiology, HLHS',
#  'Cardiology, HLHS (aortic & mitral atresia)',
#  'Cardiology, Valvar AS, BAV',
#  'Cardiology, noncompaction LV cardiomyopathy, secundum ASD',
#  'Cardiology, DORV, malposed great vessels, interrupted IVC, valvar and subvalvar PS',
#  'Cardiology, D-TGA',
#  'Cardiology, PFO',
#  'Cardiology, D-TGA, muscular VSD, subvalvar PS',
#  'Cardiology, COA, BAV, perimembrous VSD',
#  'Cardiology, PFO',
#  'Cardiology, DILV with malposed great arteries and arch hypoplasia',
#  'Cardiology, KD no CI',
#  'Cardiology, S, L, L-TGA, inlet to outlet VSD',
#  'Cardiology, HLHS',
#  'Cardiology, Large VSD (almost single ventricle, essentially only trabecular septum at apex), small right ventricle and tricuspid valve, S/P PA band, PFO vs ASD',
#  'Cardiology, pulmonary atresia/VSD dextrocardia w/ abdominal & atrial situs solitus, right AV valve & right ventricular hypoplasia, non-restrictive outlet VSD (subaortic), pulmonary atresia, left aortic arch, secundum ASD',
#  'Cardiology, BAV',
#  'Cardiology, Pulmonary arteriovenous malformation',
#  'Cardiology, Aortic Atresia, VSD, COA',
#  'Cardiology, PDA, PFO',
#  'Cardiology, COA, VSD (perimebranous) LSVC BAV',
#  'Cardiology, HLHS',
#  'Cardiology, BAV',
#  'Cardiology, L-TGA, muscular VSD, COA',
#  'Cardiology, Ebsteins anomaly, hypoplastic pulmonary valve, ASD, non-compaction CM, pre excitation',
#  'Cardiology, Coarct',
#  'Cardiology, HLHS',
#  'Cardiology, HX ASD, VSD, CLEFT MV',
#  'Cardiology, BAV, COA, S/P stent',
#  'Cardiology, COA, AO, S/P repair, VS',
#  'Cardiology, PA, IVS, PDA',
#  'Cardiology, PA, IVS',
#  'Cardiology, CAVC S/P repair, L AV',
#  'Cardiology, P/O COA',
#  'Cardiology, COARCT, VSD',
#  'Cardiology, PH',
#  'Cardiology, ',
#  'Cardiology, AVSD',
#  'Cardiology, ',
#  'Cardiology, Tetralogy of Fallot',
#  'Cardiology, S/P AV Canal',
#  'Cardiology, ',
#  'Cardiology, BAV, COA',
#  'Cardiology, LVNC w/complete block',
#  'Cardiology, SND, CAVB S/P',
#  'Cardiology, AV Canal',
#  'Cardiology, BAV',
#  'Cardiology, HLHS S/P',
#  'Cardiology, DORV w/d-malposed, PA, VSD',
#  'Cardiology, HLHS, S/P Fontan',
#  'Cardiology, AS, BAV',
#  'Cardiology, IAA, unbalanced right dominant AV canal, large PDA, DKS',
#  'Cardiology, WPW,AVRT S/P Ablation',
#  'Cardiology, BAV',
#  'Cardiology, DILV',
#  'Cardiology, AVSD, DORV',
#  'Cardiology, SIP Coarct',
#  'Cardiology, HLHS, S/P Fontana',
#  'Cardiology, KD',
#  'Cardiology, Pulm Valve Atresia',
#  "Cardiology, COA, Ebstein's",
#  "Cardiology, Shone's Complex Variant",
#  'Cardiology, VSD',
#  'Cardiology, COA',
#  'Cardiology, BAV, COA',
#  'Cardiology, TOF',
#  'Cardiology, PA PVR',
#  'Cardiology, ',
#  'Cardiology, ',
#  'Cardiology, ',
#  'Cardiology, AS S/P Balloon',
#  'Cardiology, Hypoplastic aortic valve, LV non-compaction',
#  'Cardiology, ',
#  'Cardiology, SND, S/P, VSD, S/P COA',
#  'Cardiology, S/P COA',
#  'Cardiology, AS/AI',
#  'Cardiology, BAV',
#  'Cardiology, ',
#  'Cardiology, Pre-Glenn',
#  'Cardiology, AS',
#  'Cardiology, PAPVR',
#  'Cardiology, ',
#  'Cardiology, S/P Ross',
#  'Cardiology, COA',
#  'Cardiology, VSD, BAV',
#  'Cardiology, PDA, ASD/PFO',
#  'Cardiology, VSD',
#  'Cardiology, HLHS',
#  'Cardiology, AV Canal',
#  'Cardiology, DORV',
#  'Cardiology, TGA S/P, S/P VSD',
#  'Cardiology, ',
#  'Cardiology, BAV, AI',
#  'Cardiology, ASD/PFO',
#  'Cardiology, HLHS',
#  'Cardiology, COA',
#  'Cardiology, HLHS, BD Glenn',
#  'Cardiology, COA',
#  'Cardiology, AVSD, LVOTO',
#  'Cardiology, ',
#  'Cardiology, DORV',
#  'Cardiology, Dextrocardia Tricuspid Atresia',
#  'Cardiology, D-TGA',
#  'Cardiology, HLHS, D-TGA',
#  'Cardiology, ',
#  'Cardiology, BAV, AS/A1',
#  'Cardiology, HLHS',
#  'Cardiology, ',
#  'Cardiology, D-TGA',
#  'Cardiology, WPW',
#  'Cardiology, DORV,AVSD,PS',
#  'Cardiology, HLHS',
#  'Cardiology, HPLV',
#  'Cardiology, BAV',
#  'Cardiology, ',
#  'Cardiology, Aortic Valve',
#  'Cardiology, HCM',
#  'Cardiology, HLHS',
#  'Cardiology, COA',
#  'Cardiology, BAV',
#  'Cardiology, COA, HTN',
#  'Cardiology, BAV',
#  'Cardiology, LDS',
#  'Cardiology, BAV,AS,A1,COA',
#  'Cardiology, BAV',
#  'Cardiology, HLHS  (MS/AS)',
#  'Cardiology, ',
#  'Cardiology, ',
#  'Cardiology, TA',
#  'Cardiology, WPW',
#  'Cardiology, AS, Sub AS',
#  'Cardiology, PA, severly hypoplastic RV',
#  'Cardiology, ',
#  'Cardiology, TOF',
#  'Cardiology, D-TGA/PFO VSD',
#  'Cardiology, DTGA, VSD',
#  'Cardiology, L Atrial Isomerism',
#  'Cardiology, Single ventricle, PAPVR',
#  'Cardiology, A/O Stenosis, BAV',
#  'Cardiology, TOF',
#  'Cardiology, COA, BAV',
#  'Cardiology, ',
#  'Cardiology, ',
#  'Cardiology, VSD, ASD',
#  'Cardiology, ',
#  'Cardiology, D-TGA',
#  'Cardiology, TAPVR',
#  'Cardiology, Truncus Arteriosus',
#  'Cardiology, D-TGA, VSD, ASD',
#  'Cardiology, PA',
#  'Cardiology, HLHS',
#  'Cardiology, ',
#  'Cardiology, AVSD',
#  'Cardiology, ',
#  'Cardiology, DILV, Fontan',
#  'Cardiology, Tet.',
#  'Cardiology, AS',
#  'Cardiology, Unbalanced AV canal',
#  'Cardiology, AS',
#  'Cardiology, ASD, VSD',
#  'Cardiology, BAV',
#  'Cardiology, ',
#  'Cardiology, Tri atresia, D-TGA, VSD, Poss COA',
#  'Cardiology, BAV, COA, MVP',
#  'Cardiology, AV Canal',
#  'Cardiology, HLHS',
#  'Cardiology, VSD',
#  'Cardiology, HLHS',
#  'Cardiology, Coarctation, VSD',
#  'Cardiology, ',
#  'Cardiology, WPW',
#  'Cardiology, COA',
#  'Cardiology, SVT, WPW',
#  'Cardiology, BAV',
#  'Cardiology, LVOT',
#  'Cardiology, LVOT',
#  'Cardiology, LVOT',
#  'Cardiology, COA, BAV',
#  'Cardiology, LVOT',
#  'Cardiology, LVOT',
#  'Cardiology, LVOT',
#  'Cardiology, AS, Valvar& Dilated Descending Aorta',
#  'Cardiology, LVOT',
#  'Cardiology, COA',
#  'Cardiology, Pulm Atresia, Hypoplastic Tricuspid, Hypoplastic RV, PFO',
#  'Cardiology, VSD, COA',
#  'Cardiology, HLHS, COA',
#  'Cardiology, BAV',
#  'Cardiology, Heterotaxia, Polysplenia, ASD',
#  'Cardiology, ',
#  'Cardiology, AS, S/P, BA',
#  'Cardiology, ',
#  'Cardiology, BAV',
#  'Cardiology, ',
#  'Cardiology, TOF',
#  'Cardiology, BAV',
#  'Cardiology, P/O, COA',
#  'Cardiology, LV noncompaction',
#  'Cardiology, BAV, COA',
#  'Cardiology, COA',
#  'Cardiology, BAV, AS, HI, S/P, IAA, VSD',
#  'Cardiology, PDA, S/P',
#  'Cardiology, COA',
#  'Cardiology, ',
#  'Cardiology, ',
#  'Cardiology, BAV',
#  'Cardiology, ',
#  'Cardiology, ',
#  'Cardiology, ',
#  'Cardiology, BAV',
#  'Cardiology, ',
#  'Cardiology, ',
#  'Cardiology, ',
#  'Cardiology, ',
#  'Cardiology, HLHS',
#  'Cardiology, HLHS',
#  'Cardiology, DORV, Hypoplast arch, VSD',
#  'Cardiology, COA, BAV',
#  'Cardiology, D-TGA',
#  'Cardiology, COA',
#  'Cardiology, AS, AR',
#  'Cardiology, DORV, D-TGA',
#  'Cardiology, COA, BAV',
#  'Cardiology, COA',
#  'Cardiology, BAV, COA',
#  'Cardiology, COA, VSD',
#  'Cardiology, ',
#  'Cardiology, COA, BAV',
#  'Cardiology, BAV, COA',
#  'Cardiology, ',
#  'Cardiology, ',
#  'Cardiology, COA',
#  'Cardiology, COA',
#  'Cardiology, VSD, BAV',
#  'Cardiology, ',
#  'Cardiology, COA, BAV',
#  'Cardiology, ',
#  'Cardiology, HPLV',
#  'Cardiology, BAV, COA, VSD',
#  'Cardiology, COA',
#  'Cardiology, COA',
#  'Cardiology, BAV',
#  'Cardiology, COA, AS, BAV',
#  'Cardiology, ASD, VSD, COA',
#  'Cardiology, BAV',
#  'Cardiology, HPLHS',
#  'Cardiology, PA, IVS, HRRV, NF1',
#  'Cardiology, COA, BAV',
#  'Cardiology, COA, VSD',
#  'Cardiology, HLHS',
#  'Cardiology, COA, D-TGA',
#  'Cardiology, COA',
#  'Cardiology, ',
#  'Cardiology, BAV, AS',
#  'Cardiology, AVNRT',
#  'Cardiology, F/H, Aortic Aneurysm',
#  'Cardiology, VSD, ASD, COA',
#  'Cardiology, L-TGA',
#  'Cardiology, TGA',
#  'Cardiology, AS/AR',
#  'Cardiology, ',
#  'Cardiology, COA',
#  'Cardiology, TOF',
#  'Cardiology, HLHS',
#  'Cardiology, TOF',
#  'Cardiology, BAV, AS, PDA',
#  'Cardiology, LQT',
#  'Cardiology, HLHS',
#  'Cardiology, TAPVR',
#  'Cardiology, Non compaction, COA',
#  'Cardiology, Critical AS',
#  'Cardiology, TET',
#  'Cardiology, Tetrology of Fallot',
#  'Cardiology, DORV',
#  'Cardiology, VSD, BAV',
#  'Cardiology, HLHS',
#  'Cardiology, DORV',
#  'Cardiology, TAPVR',
#  'Cardiology, HLHS, Dextro, VSD, PS',
#  'Cardiology, BAV',
#  'Cardiology, ',
#  'Cardiology, Heterotaxy, Dextrocardia, L-TGA, TAPVR',
#  'Cardiology, TOF',
#  'Cardiology, TAPVR',
#  'Cardiology, ',
#  'Cardiology, ',
#  'Cardiology, VSD,COA,Biliary Atresia,Malrotation,Polysplemia',
#  'Cardiology, HLHS',
#  'Cardiology, ',
#  'Cardiology, HLHS',
#  'Cardiology, ',
#  'Cardiology, AET',
#  'Cardiology, TOF',
#  'Cardiology, TGA, PH',
#  'Cardiology, ',
#  'Cardiology, AV Canal, Hypoplastic L AW',
#  'Cardiology, DIRV',
#  'Cardiology, ',
#  'Cardiology, BAV,  COA',
#  'Cardiology, HLHS',
#  'Cardiology, Heterotaxy, Biliary Atresia, Polysplenia',
#  'Cardiology, HLHS, MV and AV atresia, PDA',
#  'Cardiology, COA, Hypoplastic',
#  'Cardiology, BAV',
#  'Cardiology, TOF',
#  'Cardiology, HLHS',
#  'Cardiology, BAV',
#  'Cardiology, ',
#  'Cardiology, HLHS',
#  'Cardiology, HLHS',
#  'Cardiology, HLHS',
#  'Cardiology, HLHS',
#  'Cardiology, Dextrocardia',
#  'Cardiology, HLHS',
#  'Cardiology, ',
#  'Cardiology, ',
#  'Cardiology, ASD, VSD, COA',
#  'Cardiology, HLHS',
#  'Cardiology, BAV',
#  'Cardiology, TOF',
#  'Cardiology, BAV',
#  'Cardiology, TGA',
#  'Cardiology, ',
#  'Cardiology, ',
#  'Cardiology, BAV',
#  'Cardiology, ',
#  'Cardiology, VSD',
#  'Cardiology, BAV',
#  'Cardiology, HLHS',
#  'Cardiology, COA',
#  'Cardiology, Sub AS',
#  'Cardiology, PDA',
#  'Cardiology, ',
#  'Cardiology, ',
#  'Cardiology/Adhoc, HLHS',
#  'Cardiology, ',
#  'Cardiology, HLHS',
#  'Cardiology, ',
#  'Cardiology, COA, BAV',
#  'Cardiology, ',
#  'Cardiology, ',
#  "Cardiology, Ebstein's ",
#  'Cardiology, ',
#  'Cardiology, ',
#  'Cardiology, TAPVR',
#  'Cardiology, Heterotaxy',
#  'Cardiology, Transposition of greater arteries',
#  'Cardiology, ',
#  'Cardiology, ',
#  'Cardiology, ',
#  'Cardiology, ',
#  'Cardiology, ',
#  'Cardiology, ',
#  'Cardiology, COA, BAV',
#  'Cardiology, ',
#  'Cardiology, ',
#  'Cardiology, ',
#  'Cardiology, ',
#  'Cardiology, HLHS',
#  'Cardiology, COA, BAV',
#  'Cardiology, BAV',
#  'Cardiology, ',
#  'Cardiology, HLHS',
#  'Cardiology, HLHS',
#  'Cardiology, sinus venosus ASD/PAPVR',
#  'Cardiology, truncas',
#  'Cardiology, Heterotaxy syndrome',
#  'Cardiology, HLHS',
#  'Cardiology, BAV',
#  'Cardiology, Tricuspid Atresia',
#  'Cardiology, ',
#  'Cardiology, ',
#  'Cardiology, ',
#  'Cardiology, HLHS',
#  'Cardiology, Coarctation',
#  'Cardiology, ',
#  'Cardiology, D-TGA',
#  'Cardiology, AS/AR',
#  'Cardiology, DORV,TGA',
#  'Cardiology, TGA, VSD, ASD',
#  'Cardiology, DORV',
#  'Cardiology, TGA',
#  'Cardiology, TET, VSD, Atresia',
#  'Cardiology, LVOT, L-TGA, Sub PS, VSD, Dextro, at 2 weeks',
#  'Cardiology, ',
#  'Cardiology, TAPVR',
#  'Cardiology, COA, BAV',
#  'Cardiology, HLHS',
#  'Cardiology, D-TGA',
#  'Cardiology, ',
#  'Cardiology, TGA',
#  'Cardiology, ',
#  'Cardiology, BAV',
#  'Cardiology, Dextrocardia, L-TGA',
#  'Cardiology, DORV',
#  'Cardiology, ',
#  'Cardiology, TOF',
#  'Cardiology, DORV, VSD, PS, TGA, PFO',
#  'Cardiology, WPW',
#  'Cardiology, TOF, 22Q11 Deletion Positive',
#  'Cardiology, HLHS',
#  'Cardiology, COA, VSD, ASD',
#  'Cardiology, TET',
#  'Cardiology, Truncus Arteriosus',
#  'Cardiology, Heterotaxy',
#  'Cardiology, heterotaxy',
#  'Cardiology, ASD, PFO',
#  'Cardiology, DORV, Secundum ASD',
#  'Cardiology, HLHS, COA',
#  'Cardiology, AS, Secundum ASD',
#  'Cardiology, Innocent murmur',
#  'Cardiology, ASD/Left atrial isomerism',
#  'Cardiology, HLHS, BAV, PFO, COA',
#  'Cardiology, D-TGA, VSD, ASD',
#  'Cardiology, HLHS, ASD, PDA',
#  'Cardiology, D-TGA, ASD, PDA ',
#  'Cardiology, TOF, Pulm Atresia, VSD',
#  'Cardiology, BAV',
#  'Cardiology, INT IVC, ASD, Omphaolcele, Duodenal ATR',
#  'Cardiology, DORV, PS, TGA',
#  'Cardiology, D-TGA, VSD',
#  'Cardiology, BAV',
#  'Cardiology, Malposed Great Arteries, DILV, ASD, VSD',
#  'Cardiology, BAV',
#  'Cardiology, DORV, VSD, PFO, COA',
#  'Cardiology, COA, BAV',
#  'Cardiology, AVSD',
#  'Cardiology, HLHS variant',
#  'Cardiology, HLHS, Heterotaxy, ASD',
#  'Cardiology, Dextrocardia',
#  'Cardiology, HLHS',
#  'Cardiology, TOF, Pulmonary Atresia',
#  'Cardiology, COA',
#  'Cardiology, Trisomy 21, AVSD',
#  'Cardiology, Partial AV canal, ASD',
#  'Cardiology, COA, Cortriatriatum',
#  'Cardiology, Tri Atresia, VSD, Bicuspid Pulmonary Valve, TGA',
#  'Cardiology, TAPVR',
#  'Cardiology/Lymph  #F48-01, PHACES Syndrome, BAV, VSD, PFO',
#  'Cardiology, Aortic Atresia, COA, PFO, VSD',
#  'Cardiology, TOF',
#  'Cardiology, TOF, VSD, PFO',
#  'Cardiology, tric atr, hyplas LV, VSD, ASD, PDA',
#  'Cardiology, TOF',
#  'Cardiology, COA, 45, X',
#  'Cardiology, BAV with aortic stenosis',
#  'Cardiology, CardiologyPartial AV canal, ASD, Cleft MV',
#  'Cardiology, secundum ASD, VSD, trisomy 21',
#  'Cardiology, TOF, VSD',
#  'Cardiology, BAV ',
#  'Cardiology, BAV, w/AS, PDA',
#  'Cardiology, Truncus arteriosis, VSD, ASD',
#  'Cardiology, VSD, 15q deletion',
#  'Cardiology, VSD',
#  'Cardiology, T21, partial AC canal defect, ASD, VSD',
#  'Cardiology, COA, non-compaction CM',
#  'Cardiology, WPW',
#  'Cardiology, ',
#  'Cardiology, Afib',
#  'Cardiology, HLHS',
#  'Cardiology, VSD',
#  'Cardiology, HLHS',
#  'Cardiology, T21, VSD, PDA',
#  'Cardiology, TOF',
#  'Cardiology, TGA',
#  'Cardiology, Unbalanced AV canal, LV hypoplasia,COA, PDA',
#  'Cardiology, BAV, AS',
#  'Cardiology, VSD, ASD',
#  'Cardiology, IAA',
#  'Cardiology, ',
#  'Cardiology, DILV, TGA',
#  'Cardiology, VSD,ASD,PDA',
#  'Cardiology, DORV, TGA',
#  'Cardiology, ',
#  'Cardiology, VSD, PDA',
#  'Cardiology, HLHS',
#  'Cardiology, COA',
#  'Cardiology, HLHS',
#  'Cardiology, ',
#  'Cardiology, ',
#  'Cardiology, D-TGA',
#  'Cardiology, TA',
#  'Cardiology, VSD, BAV, PDA',
#  'Cardiology, ',
#  'Cardiology, DTGA, PFO, PDA',
#  'Cardiology, PAPVR, Sinus Venousus, ASD',
#  "Cardiology, Ebstein's anomaly, A - Plutter",
#  'Cardiology, TOF',
#  'Cardiology, ',
#  'Cardiology, Bicuspid AV with AV stenosis',
#  'Cardiology, ',
#  'Cardiology, ',
#  'Cardiology, ',
#  'Cardiology, ',
#  'Cardiology, ',
#  'Cardiology, ',
#  'Cardiology, ',
#  'Cardiology, WPW',
#  'Cardiology, DORV',
#  'Cardiology, PA w/ VSD, PAA',
#  'Cardiology, Partial AVSD with ASD',
#  'Cardiology, TGA, VSD',
#  'Cardiology, Truncus Type1',
#  'Cardiology, SVT',
#  'Cardiology, DTGA, PFO',
#  'Cardiology, HLHS, ASD, PDA',
#  'Cardiology, COA, BAV, PFO',
#  "Cardiology, Ebstein's Anomaly, VSD",
#  'Cardiology, PFO, RVOT, Truncus',
#  'Cardiology, PFO, PDA, ASD, BAV',
#  'Cardiology, COA, BAV, PFO',
#  'Cardiology, DTGA, VSD, PDA, DORV',
#  'Cardiology, ASD, VSD, LVOT, AV Canal',
#  'Cardiology, BAV',
#  "Cardiology, AV Canal with Ebstein's Anomaly, ASD, VSD",
#  'Cardiology, Heterotaxy',
#  'Cardiology, DILV, d-TGA, with VSD',
#  'Cardiology, DORV, DTGA',
#  'Cardiology, ',
#  'Cardiology, HLH Variant, PDA, ASD',
#  'Cardiology, VSD',
#  'Cardiology, VSD, PDA',
#  'Cardiology, ',
#  'Cardiology, ',
#  'Cardiology, ',
#  'Cardiology, BAV',
#  'Cardiology, ',
#  'Cardiology, TET',
#  'Cardiology, VSD, Sub PS, PFO, PH',
#  'Cardiology, COA',
#  'Cardiology, PFO,COA,VSD, PDA, ACO Anterior',
#  'Cardiology, ',
#  'Cardiology, Heterotaxy, Dextrocardia',
#  'Cardiology, BAV',
#  'Cardiology, TOF, VSD',
#  'Cardiology, COA, Inlet VSD, Cleft Left AV, PDA, Hypertrophy',
#  'Cardiology, Innominate Artery',
#  'Cardiology , COA',
#  'Cardiology, TOF, T21',
#  'Cardiology, Large Secundom ASD',
#  'Cardiology, Heterotaxy',
#  'Cardiology, TZI, ASD, PDA',
#  'Cardiology, Aortic Dilation, MVP',
#  'Cardiology, PAPVR',
#  'Cardiology, ASD,PAPVR',
#  'Cardiology, Vascular Ring',
#  'Cardiology, Charge, PDA, Pulm Stenosis',
#  'Cardiology, AV Canal',
#  'Cardiology, WPW',
#  'Cardiology, BAV',
#  'Cardiology, ',
#  'Cardiology, ',
#  'Cardiology, ',
#  'Cardiology, ',
#  'Cardiology, TOF',
#  'Cardiology, BAV, COA',
#  'Cardiology, Tric Atresia, VSD',
#  'Cardiology, Truncus',
#  'Cardiology, Heterotaxy, Asplenia, DORV',
#  'Cardiology, DILV',
#  'Cardiology, COA, BAV',
#  'Cardiology, Truncus Type 1',
#  'Cardiology, Severe PS W/ Decreased RV Function',
#  'Cardiology, Fontan/ Tricuspid Atresia',
#  'Cardiology, BAV',
#  'Cardiology, BAV',
#  'Cardiology, TOF',
#  'Cardiology, HLHS, PDA',
#  'Cardiology, BAV',
#  'Cardiology, COA, DORV',
#  'Cardiology, ASD',
#  'Cardiology, HLHS',
#  'Cardiology, DORV, PA',
#  'Cardiology, TOF',
#  'Cardiology, COA, VSD',
#  'Cardiology, DORV, PA',
#  'Cardiology, TOF',
#  'Cardiology, WPW',
#  'Cardiology, ',
#  'Cardiology, HLHS',
#  'Adhoc/Vascular 002-01, ',
#  'Adhoc/Vascular# 003, ',
#  'Laterality, ',
#  'Laterality, Cardiology, TAPVR',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PFO, ',
#  'PH, Cardiology',
#  'Mirror Image, ',
#  'Adhoc/Venous Malformation, ',
#  'Adhoc/Venous Malformation, ',
#  'Adhoc/Vascular 001-01, ']

# %%
#alphabetical sorted list of unique phenotypes

#first let's get all the phenotypes out
#data is a list of strings and we want to split it by commas
phenotypes = []
for string in data:
    phenotypes.extend(string.split(",")) #put each new string into a list   
#print(phenotypes)

# %%
#preprocess data
#strip removes leading and trailing whitespaces
#left of the for loop is what we want to keep -- no whitespaces, put all in uppercase for later comparison in the set and sorting
#right of the for loop we have a boolean condition: only keep if true (empty string is false)
#could also use the remove method of a set
phenotypes = [p.strip().upper() for p in phenotypes if p]

# %%
#now, to find out which ones are unique use sets
phenotypes_set = set(phenotypes)

# %%
'' in phenotypes_set
# Out:
# False

# %%
help(plist.sort)
# Out:
# Help on built-in function sort:
#
# sort(...) method of builtins.list instance
#     L.sort(key=None, reverse=False) -> None -- stable sort *IN PLACE*

# %%
#key passes in a function to sort by
plist.sort(key = len, reverse=True)

#anonymous functions are defined using the lambda keyword
plist.sort(key = lambda x: x[-1], reverse=True)

# %%
plist
# Out:
# ['DCM POSSIBLY 2TO DAUNORUBICIN THERAPY',
#  'CONGENITAL HEART DISEASE & CARDIOLOGY',
#  'CONGENITAL HEART DEFECT & CARDIOLOGY',
#  'NONCOMPACTION LV CARDIOMYOPATHY',
#  "AV CANAL WITH EBSTEIN'S ANOMALY",
#  'DILATED CARDIOMYOPATHY',
#  'INNOMINATE ARTERY',
#  "EBSTEIN'S ANOMALY",
#  'EBSTEINS ANOMALY',
#  'CHD & CARDIOLOGY',
#  'KD W/O CORONARY',
#  'EBSTEIN ANAMDY',
#  'CHD/CARDIOLOGY',
#  'KD W/CORONARY',
#  'HYPERTROPHY',
#  'LATERALITY',
#  'HETEROTAXY',
#  'CARDIOLOGY',
#  'CARDIOLGOY',
#  'X',
#  'HYPOPLASTIC L AW',
#  'WPW',
#  'VSD (PERIMEBRANOUS) LSVC BAV',
#  'SEVERLY HYPOPLASTIC RV',
#  'HYPOPLASTIC RV',
#  'CLEFT LEFT AV',
#  'PROBABLE BAV',
#  'HYPLAS LV',
#  'CLEFT MV',
#  'L AV',
#  'HRRV',
#  'HPLV',
#  'DORV',
#  'DIRV',
#  'DILV',
#  'TGV',
#  'BAV',
#  'POSSIBLE VSD NOTED IN CLINIC NOTES BUT NOT ON ECHO REPORT',
#  'CARDIOLOGY & CONGENITAL HEART DEFECT',
#  'KD W/O CORONARY INVOLVEMENT',
#  'COMPLETE AV SEPTAL DEFECT',
#  "SHONE'S COMPLEX VARIANT",
#  'PARTIAL AC CANAL DEFECT',
#  'CONGENITAL HEART DEFECT',
#  'PS (UNKNOWN TYPE) SVT',
#  'TETROLOGY OF FALLOT',
#  'TETRALOGY OF FALLOT',
#  'DILATED AORTIC ROOT',
#  'HETEROTAXY-RIGHT',
#  'HLHS VARIANT',
#  'HLH VARIANT',
#  'SIP COARCT',
#  'S/P STENT',
#  'SVT-PJRT',
#  'COARCT',
#  'AVNRT',
#  'RVOT',
#  'PJRT',
#  'LVOT',
#  'TET',
#  'SVT',
#  'LQT',
#  'AET',
#  'VT',
#  'PULMONARY ATRESIA/VSD DEXTROCARDIA W/ ABDOMINAL & ATRIAL SITUS SOLITUS',
#  'TRICUSPID ATRESIA W/NORMALLY RELATED GREAT VESSELS',
#  'PULMONARY PAREMEMBRANEOUS VALVE STENOSIS',
#  'TRANSPOSITION OF THE GREAT ARTERIES',
#  'TRANSPOSITION OF GREATER ARTERIES',
#  'NORMALLY RELATED GREAT VESSELS',
#  'BICUSPID AV WITH AV STENOSIS',
#  'VALVULAR AORTIC STENOSIS',
#  'BAV WITH AORTIC STENOSIS',
#  'VALVAR AND SUBVALVAR PS',
#  'MALPOSED GREAT ARTERIES',
#  'MALPOSED GREAT VESSELS',
#  'SMALL AORTIC ISTHMUS',
#  'SUBVALVAR SEVERE PS',
#  'TRUNCUS ARTERIOSUS',
#  'TRUNCUS ARTERIOSIS',
#  'PULMONARY STENOSIS',
#  'SINOUS VENOUSUS',
#  '2 MUSCULAR VSDS',
#  'SUPRAVALVAR PS',
#  'SUPRAVALVAR AS',
#  'SINUS VENOUSUS',
#  'PULM STENOSIS',
#  'DYSPLASTIC VS',
#  'SUBVALVAR PS',
#  'A/O STENOSIS',
#  'VALVULAR AS',
#  'PA STENOSIS',
#  'MUSCULAR VS',
#  'CRITICAL AS',
#  'DTGA W/IVS',
#  'AT 2 WEEKS',
#  'VALVAR PS',
#  'VALVAR AS',
#  'PA / I VS',
#  "EBSTEIN'S",
#  "EBSTEEN'S",
#  'VALVE PS',
#  'VALVE AS',
#  'S/P ROSS',
#  'TRUNCUS',
#  'TRUNCAS',
#  'MILD PS',
#  'EBSTINS',
#  'SUB PS',
#  'SUB AS',
#  'PA/IVS',
#  'PA-IVS',
#  'SUBAS',
#  'HPLHS',
#  'W/AS',
#  'HLHS',
#  'PPS',
#  'LDS',
#  'IVS',
#  'DKS',
#  'VS',
#  'PS',
#  'MS',
#  'AS',
#  'S',
#  'PULMONARY ARTRESIA VALVAR',
#  'SINUS VENOSUS ASD/PAPVR',
#  'AI RHEUMATIC FEVER',
#  'INNOCENT MURMUR',
#  'CAVC S/P REPAIR',
#  'AS SUPRAVALVAR',
#  'VSD MUSCULAR',
#  'DUODENAL ATR',
#  'ACO ANTERIOR',
#  'A - PLUTTER',
#  'S/P REPAIR',
#  'SUBVALVAR',
#  'AS VALVAR',
#  'TRIC ATR',
#  'VALVAR',
#  'PA PVR',
#  'TAPVR',
#  'PAPVR',
#  'AS/AR',
#  'TR',
#  'MR',
#  'AR',
#  'HLHS S/P',
#  'CAVB S/P',
#  'TGA S/P',
#  'S/P',
#  'MVP',
#  'MODERATE PS (UNKNOWN TYPE) RESTRICTIVE PFO',
#  'MIGRAINE W/POSSIBLE PFO',
#  'ASD/PFO',
#  'DEXTRO',
#  'LVOTO',
#  'PFO',
#  'P/O',
#  'AO',
#  'SUBAORTIC MEMBRANE W/ MILD LEFT VENTRICULAR OUTFLOW TRACT OBSTRUCTION',
#  'SVT DUE TO A CONCEALED ACCESSORY CONNECTION',
#  'PULMONARY ARTERIOVENOUS MALFORMATION',
#  'SEVERE PS W/ DECREASED RV FUNCTION',
#  'LTGA W/VENTRICULAR INVERSION',
#  'ADHOC/VENOUS MALFORMATION',
#  'TRICUSPID REGURGITATION',
#  'CAPILLARY MALFORMATION',
#  '(S.D.D)DEXTROPOSITION',
#  'LATREAL ESOMERESON',
#  'SEE NOTES SECTION',
#  'LV NON-COMPACTION',
#  'AVRT S/P ABLATION',
#  'LV NONCOMPACTION',
#  'AORTIC DILATION',
#  'PRE EXCITATION',
#  'NON COMPACTION',
#  'AS S/P BALLOON',
#  '22Q11 DELETION',
#  '15Q DELETION',
#  'MALROTATION',
#  'COARCTATION',
#  'S/P FONTAN',
#  'PRE-GLENN',
#  'BD GLENN',
#  'FONTAN',
#  'HTN',
#  'ASD/LEFT ATRIAL ISOMERISM',
#  'BORN W/OUT A STERNUM',
#  'L ATRIAL ISOMERISM',
#  'PRIMUM & SECUNDUM',
#  'NON-COMPACTION CM',
#  'ATRIAL ISOMERISM',
#  'AORTIC ANEURYSM',
#  'CORTRIATRIATUM',
#  'CORTRIATRIAUM',
#  'DIATED CM',
#  'SECUNDUM',
#  'HCM',
#  'UNBALANCED RIGHT DOMINANT AV CANAL',
#  'CARDIOLOGYPARTIAL AV CANAL',
#  'PAPVR - 1PSI LATERAL',
#  'UNBALANCED AV CANAL',
#  'PFO COMPLETE AVANAL',
#  'BALANCED AV CANAL',
#  'PARTIAL AV CANAL',
#  'S/P AV CANAL',
#  'AV CANAL',
#  'L',
#  'LVNC W/COMPLETE BLOCK',
#  'TRUNCUS TYPE II',
#  'TRIVIAL AI & PI',
#  'VALVULAR AS/AI',
#  'MODERATE MI',
#  'VALVAR AI',
#  'SEVERE PI',
#  'TRACE AI',
#  'KD NO CI',
#  'KAWISAKI',
#  'MILD PI',
#  'KD W/CI',
#  'AS/AI',
#  'TZI',
#  'PI',
#  'HI',
#  'AI',
#  'I',
#  'COA W/SMALL TRANSVERSE AORTIC ARCH',
#  'LEFT AORTIC ARCH',
#  'TRANSVERSE ARCH',
#  'HYPOPLAST ARCH',
#  'HX OF PH',
#  'LSH',
#  'F/H',
#  'PH',
#  'AVC (BALANCED) SUBVALVAR AORTIC FIBROUS RING',
#  'PDA DOUBLE AORTIC ARCH/ VASULAR RING',
#  'VASCULAR RING',
#  'TAG',
#  'TOF',
#  'RF',
#  'A;[PSED GREAT VESSELS. RIGHT SIDED AV VALVE',
#  'SMALL RIGHT VENTRICLE AND TRICUSPID VALVE',
#  'LARGE VSD (ALMOST SINGLE VENTRICLE',
#  'TYPOPLASTIC LEFT HEART SYNDROME',
#  'HYPOPLASTIC LEFT HEART SYNDROME',
#  'WOLF PARKINSON WHITE SYNDROME',
#  'WOLF PARKENSON WHITE SYNDROME',
#  'HYPOPLASTIC PULMONARY VALVE',
#  'EBSTENOID TRICUSPID VALVE',
#  'HYPOPLASTIC AORTIC VALVE',
#  'BICUSPID PULMONARY VALVE',
#  '22Q11 DELETION POSITIVE',
#  'DILATED LEFT VENTRICLE',
#  'HETEROTAXY SYNDROME',
#  'WILLIAMS SYNDROME',
#  'CLFT MITRAL VALVE',
#  'SINGLE VENTRICLE',
#  'LONG QT SYNDROME',
#  'ASD UNKNOWN TYPE',
#  'SUBAORTIC RIDGE',
#  'PHACES SYNDROME',
#  'NOONAN SYNDROME',
#  'MARFAN SYNDROME',
#  'MIRROR IMAGE',
#  'AORTIC VALVE',
#  'OMPHAOLCELE',
#  'MV PROLAPSE',
#  'CHARGE',
#  'HYPOPLASTIC P-VENTRICLE & AORTA W/VSD',
#  'PRIMUM & SECUNDUM ASD',
#  'PARTIAL AVSD WITH ASD',
#  'HYPOPLASTIC TRICUSPID',
#  'OSTIUM SECUNDUM ASD',
#  'INLET TO OUTLET VSD',
#  'PERMEMBRANEOUS VSD',
#  'PERIMEMBRANOUS VSD',
#  'LARGE SECUNDOM ASD',
#  'DORV W/D-MALPOSED',
#  'UNKNOWN TYPE ASD',
#  'SUBPULMONARY VSD',
#  'PERIMEMBROUS VSD',
#  'MID MUSCULAR VSD',
#  'INFRACRISTAL VSD',
#  'UNBALANCED AVSD',
#  'RESTRICTIVE VSD',
#  'FENESTRATED ASD',
#  'D-TGA/PFO VSD',
#  'BALANCED AVSD',
#  'SECUNDUM ASD',
#  'SECINDUM ASD',
#  'PARTIAL AVSD',
#  'MUSCULAR VSD',
#  'S/P PA BAND',
#  'PRIMUM ASD',
#  'PFO VS ASD',
#  'OUTLET VSD',
#  'PA W/ VSD',
#  'INLET VSD',
#  'D-TGA VSD',
#  'WITH VSD',
#  'IAAJ VSD',
#  'IAA: VSD',
#  'BALANCED',
#  'S/P VSD',
#  'HX ASD',
#  'AVSD',
#  'VSD',
#  'SND',
#  'CHD',
#  'ASD',
#  'KD',
#  'CARDIOLOGY/ADHOC',
#  'INTERRUPTED IVC',
#  'HYPOPLASTIC',
#  'INT IVC',
#  'LSVC',
#  'IAA TYPE B',
#  'AFIB',
#  'FUNCTIONAL SINGLE LEFT VENTRICLE WITH RIGHT OR TRICUSPID ATRESIA',
#  'ENDOCARDIAL CUSHION DEFECT TYPE ABNORMALITIES SUGGESTION OF PDA',
#  'DILV WITH MALPOSED GREAT ARTERIES AND ARCH HYPOPLASIA',
#  'RIGHT AV VALVE & RIGHT VENTRICULAR HYPOPLASIA',
#  'ALCAPA W/ SUBSEQUENT MYOCARDIAL ISCHEMIA',
#  'TETRAOLOGY OF FALLOT/PULMONARYARTRESEA',
#  'VALVAR& DILATED DESCENDING AORTA',
#  'DEXTROCARDIA TRICUSPID ATRESIA',
#  'FONTAN/ TRICUSPID ATRESIA',
#  'DILV W/LEFT AV ATRESIA',
#  'INTRACARDIAC MYXOMA',
#  'TRICUSPID ARTRESIA',
#  'TRI CUPID ARTRESIA',
#  'PULMONARY ARTRESIA',
#  'PULM VALVE ATRESIA',
#  'ASD (SECUNDUM) PDA',
#  'TRICUSPID STRESEA',
#  'TRICUSPID ATRESIA',
#  'TRICUPSID ATRESIA',
#  'PULMONARY ATRESIA',
#  'MV AND AV ATRESIA',
#  'COA W/HYPOPLASIA',
#  'PFO REVERSE PDA',
#  'MITRAL ARTRESIA',
#  'BILIARY ATRESIA',
#  'MITRAL ATRESIA',
#  'AORTIC ATRESIA',
#  'LV HYPOPLASIA',
#  'AORTICATRESIA',
#  'TRIC ATRESIA',
#  'PULM ATRESIA',
#  'DEXTROCARDIA',
#  'TRI ATRESIA',
#  'S/P FONTANA',
#  'POLYSPLENIA',
#  'POLYSPLEMIA',
#  'HETEROTAXIA',
#  'DORV W/ PA',
#  'LARGE PDA',
#  'POSS COA',
#  'ASPLENIA',
#  'S/P COA',
#  'P/O COA',
#  'ATRESIA',
#  'TOF/PA',
#  'ALCAPA',
#  'LV-PA',
#  'L-TGA',
#  'D-TGA',
#  'T-GA',
#  'LTGA',
#  'DTGA',
#  'TGA',
#  'RAA',
#  'PVA',
#  'PDA',
#  'PAA',
#  'IAA',
#  'COA',
#  'TA',
#  'PA',
#  'CA',
#  'BA',
#  '45',
#  'ADHOC/VASCULAR# 003',
#  'CARDIOLOGY/LYMPH  #F48-01',
#  'ADHOC/VASCULAR 002-01',
#  'ADHOC/VASCULAR 001-01',
#  'TRUNCUS TYPE 1',
#  'TRUNCUS TYPE1',
#  'LYMPH F#69-01',
#  'TRISOMY 21',
#  'AS/A1',
#  'T21',
#  'NF1',
#  'A1',
#  'TET.',
#  'DILV W/ L-',
#  'SECUNDUM ASD (SPONTANEOUS CLOSURE BY AGE FOREE)',
#  'ESSENTIALLY ONLY TRABECULAR SEPTUM AT APEX)',
#  'NON-RESTRICTIVE OUTLET VSD (SUBAORTIC)',
#  "INNOCENT MURMUR (STILL'S TYPE)",
#  'HLHS (AORTIC & MITRAL ATRESIA)',
#  'BAV (AS 2 DEGREES TO BAV)',
#  'AV CANAL (INCOMPLETE)',
#  'VSD (PERIMEMBRANOUS)',
#  'PA/VSD (SUBAORTIC)',
#  'PA (VALVAR W/VSD)',
#  'MILD PS (VALVAR)',
#  'AS/AI (VALVULAR)',
#  'MILD AS (VALVE)',
#  'HLHS  (MS/AS)',
#  'MI (UNKNOWN)',
#  'PS (VALVAR)',
#  'AS (VALVE)',
#  'TGA (D)',
#  'LTGA ASD "UNRESTRICTIVE"']

# %%
#go back to a list so we can work with it
plist = list(phenotypes_set)
#sort it
plist.sort() #can also put reverse = True to sort the other way
#print(plist)

# %%
help(lambda)
# Out:
#   File "<ipython-input-63-9b4a285515f7>", line 1
#     help(lambda)
#                ^
# SyntaxError: invalid syntax
