# %%
import pymysql
import pandas as pd
import getpass
from textblob import TextBlob
import re

# %%
conn = pymysql.connect(host="mysql",
                       port=3306,user="jovyan",
                       passwd=getpass.getpass("Enter MySQL passwd for jovyan"),db='mimic2')
cursor = conn.cursor()
# Out:
# Enter MySQL passwd for jovyan········

# %% [markdown]
# ### Use Pandas and SQL to create a dataframe with the following:
# * subject_id
# * hospital admission id
# * text of the radiology report
# * Limit the number of reports to 10000

# %%
rad_data = \
pd.read_sql("""SELECT DISTINCT noteevents.subject_id, 
                      noteevents.hadm_id,
                      noteevents.text 
               FROM noteevents
               WHERE noteevents.category = 'RADIOLOGY_REPORT' LIMIT 5000""",conn)
rad_data.head(5)
# Out:
#    subject_id  hadm_id                                               text
# 0          56  28766.0  \n\n\n     DATE: [**2644-1-17**] 10:53 AM\n   ...
# 1          56  28766.0  \n\n\n     DATE: [**2644-1-17**] 10:53 AM\n   ...
# 2          56  28766.0  \n\n\n     DATE: [**2644-1-17**] 10:43 AM\n   ...
# 3          56  28766.0  \n\n\n     DATE: [**2644-1-17**] 6:37 AM\n    ...
# 4          56  28766.0  \n\n\n     DATE: [**2644-1-19**] 12:09 PM\n   ...

# %%
rad_data.shape
# Out:
# (5000, 3)

# %%
print(rad_data.iloc[20]["text"])
# Out:
#      DATE: [**3352-7-6**] 10:20 AM
#      CHEST (PORTABLE AP)                                             Clip # [**Clip Number (Radiology) 1631**]
#      Reason: fever- eval for infection
#      Admitting Diagnosis: NON-HODGKIN'S LYMPHOMIA\BONE MARROW TRANSPLANT
#      ______________________________________________________________________________
#      UNDERLYING MEDICAL CONDITION:
#       54 year old man with T-cell lymphoma, neutropenia
#      REASON FOR THIS EXAMINATION:
#       fever- eval for infection
#      ______________________________________________________________________________
#                                      FINAL REPORT
#      INDICATION:  Neutropenia and fever.
#
#      COMPARISON: [**6-23**], [**6-6**] and [**3352-6-3**].
#
#      CHEST AP PORTABLE RADIOGRAPH:  The cardiac, mediastinal and hilar contours are
#      unremarkable.  The left lung is clear.  There is a somewhat well circumscribed
#      opacity immediately overlying the catheter which runs along the lateral right
#      upper hemithorax.  No definite pulmonary infiltrates or effusions.  The
#      osseous structures are unremarkable.  The right internal jugular central
#      venous catheter tip extends to the distal SVC.  No pneumothorax.
#
#      IMPRESSION:
#      1)  There is a somewhat well-circumscribed but subtle opacity immediately
#      adjacent to the external portion of the catheter overlying the right upper
#      lobe.  This may be related to the catheter itself but it is difficult to
#      exclude an underlying opacity in this region.  Correlation with physical exam
#      recommended.

# %% [markdown]
# ### Write a function that returns true or false depending on whether the report contains an impression section
#
# #### Hints
#
# * Not every report will have an impression section
# * "INTERPRETATION:" and "CONCLUSIONS:" might be synonyms for "IMPRESSION:"

# %%
def count_impression(report): #student solution
    for word in report.split():
        if word == "IMPRESSION:" or word == "INTERPRETATION:" or word == "CONCLUSIONS:":
            return True
    return False

# %%
def count_impression2(report): #Brian's solution is faster
    headings = ["IMPRESSION:", "INTERPRETATION:", "CONCLUSIONS:"]
    for h in headings:
        if h in report:
            return True
    return False

# %%
sum([count_impression(report) for report in rad_data["text"]])
# Out:
# 4042

# %% [markdown]
# ### Write a function that returns the impression section of a report

# %%
#we assume the impression section is the last section
#if no impression section, return whole report

def get_impression(report):
    headings = ["IMPRESSION:", "INTERPRETATION:", "CONCLUSIONS:"]
    for h in headings:
        if h in report:
            return report[report.find(h):]
    return report

# %%
get_impression(rad_data.iloc[20]["text"])
# Out:
# 'IMPRESSION:\n     1)  There is a somewhat well-circumscribed but subtle opacity immediately\n     adjacent to the external portion of the catheter overlying the right upper\n     lobe.  This may be related to the catheter itself but it is difficult to\n     exclude an underlying opacity in this region.  Correlation with physical exam\n     recommended.\n\n'

# %% [markdown]
# ### Define Regular expressions for data cleansing
#
# We have a lot of patterns that are unique and don't convey meaningful information
#
# * De-identified names, dates, etc.
#     * `[**Clip Number (Radiology) 12569**]`
#     * `[**Hospital 12568**]`
#     * `[**Last Name (NamePattern4) 337**]`
#     * `[**First Name8 (NamePattern2) 12565**]`
#     * `[**Last Name (NamePattern1) 12566**]`
# * Separators  (e.g. `__________________`)
#
# ### Split into groups and write and test regular expressions to capture these patterns
# * Write a regular expression to replace dates in the reports with ``[**DATE**]``
# * Write a regular expression to replace times in the reports with ``[**TIME**]``
# * Write a regular expression to replaces digits with "d", (e.g. "43 cc" would become "dd cm")

# %%
#write a regular expression to capture [**Last Name (NamePattern4) 337**]
last_name=re.compile(r"""\[\*\*Last Name \(NamePattern\d+\) [0-9]*\*\*\]""")

# %%
date=re.compile(r"""((?P<month>[A-Z][a-z]{2,}(\.)?) (?P<day>[0-9]{1,2}))""")
last_name=re.compile(r"""(\[\*\*Last Name \((NamePattern|STitle)(\d+)?\) [0-9]*\*\*\])""")
clip = re.compile(r"""\[\*\*Clip Number \(Radiology\) \d+\*\*]""")
date2 = re.compile(r"""DATE: \[\*\*\d+-\d+-\d+\*\*]""")
hospital=re.compile(r"""(\[\*\*Hospital \d+\*\*\*\])""")
unders = re.compile(r"""_{2,}""") #recognize two or more underscores

age2 = re.compile(r"""(?P<age>[0-9]+)(-|\s)y(ear(s)?|\.)(-|\s)?o(ld|\.)""")
age3 = re.compile(r"""\bage(d)? (?P<age>[0-9]+)""")
digits = re.compile(r"""\d""")
def age_in_decades(m):
    age = int(m.group("age"))
    
    return "[** Age in %ss**]"%(int(age/10)*10,)

age_in_decades(next(age2.finditer("74-year-old")))
#tmp = re.sub(age2, age_in_decades, re.sub(age3, age_in_decades, report_txt))
# Out:
# '[** Age in 70s**]'

# %% [markdown]
# #### Hints
#
# * Look at some sample reports to see what dates and times look like in the reports
# * What order would you need to apply the regular expressions?

# %%
def preprocess(report):
    return digits.sub("d",
                      unders.sub("\n", 
                                 hospital.sub("HOSPITAL", 
                                              date2.sub("DATE", 
                                                        clip.sub("CLIP", 
                                                                 last_name.sub("LASTNAME", report))))))

# %%
for i in range(10):
    print(preprocess(rad_data.iloc[i]['text']))
    print("*"*42,"\n\n")
# Out:
#      DATE dd:dd AM
#      MR HEAD W & W/O CONTRAST; MR CONTRAST GADOLIN                   Clip # CLIP
#      Reason: R ICB and HX brain mets - eval - also with DWI for CVA Do MR
#       Contrast: MAGNEVIST Amt: dd
#
#
#      UNDERLYING MEDICAL CONDITION:
#       [**Age over dd **] year old woman with lung CA- mets to brain
#      REASON FOR THIS EXAMINATION:
#       R ICB and HX brain mets - eval - also with DWI for CVA Do MRI both with and
#       without contast please
#
#
#                                      FINAL REPORT
#      EXAMINATION:  MRI of the brain with and without gadolinium.
#
#      INDICATION:  [**Age over dd **] year old woman with lung cancer and right intracranial bleed
#      and history of brain metastases.  Please evaluate for acute infarct.
#
#      TECHNIQUE:  Multiplanar Td and Td-weighted images of the brain with gadolinium
#      according to standard departmental protocol.  No prior study for comparison.
#
#      FINDINGS:  On diffusion-weighted images there is a small area of restricted
#      diffusion along the falx within the left occipitotemporal lobe.  It is also
#      bright on FLAIR-weighted images and may represent a subacute infarct. Clinical
#      correlation is recommended.  On gradient echo images there is a large area of
#      intraparenchymal hemorrhage within the right parietal lobe and left thalamus
#      which following administration of gadolinium reveals ring-enhancing lesions.
#      These are suspicious for hemorrhagic metastases given the patient's history.
#      Additional ring-enhancing lesions throughout the supra- and infratentorial
#      compartments are visualized.  There is a moderate amount of peritumoral edema
#      involving the right parietal lobe lesion in addition to a second right
#      parietal lesion along the falx high in the vertex.  The other areas of
#      metastases reveal a minimal amount of peritumoral edema.
#
#
#
# ******************************************
#
#
#
#
#
#      DATE dd:dd AM
#      MR HEAD W & W/O CONTRAST; MR CONTRAST GADOLIN                   Clip # CLIP
#      Reason: R ICB and HX brain mets - eval - also with DWI for CVA Do MR
#       Contrast: MAGNEVIST Amt: dd
#
#
#      UNDERLYING MEDICAL CONDITION:
#       [**Age over dd **] year old woman with lung CA- mets to brain
#      REASON FOR THIS EXAMINATION:
#       R ICB and HX brain mets - eval - also with DWI for CVA Do MRI both with and
#       without contast please
#
#
#                                      FINAL REPORT
#      EXAMINATION:  MRI of the brain with and without gadolinium.
#
#      INDICATION:  [**Age over dd **] year old woman with lung cancer and right intracranial bleed
#      and history of brain metastases.  Please evaluate for acute infarct.
#
#      TECHNIQUE:  Multiplanar Td and Td-weighted images of the brain with gadolinium
#      according to standard departmental protocol.  No prior study for comparison.
#
#      FINDINGS:  On diffusion-weighted images there is a small area of restricted
#      diffusion along the falx within the left occipitotemporal lobe.  It is also
#      bright on FLAIR-weighted images and may represent a subacute infarct. Clinical
#      correlation is recommended.  On gradient echo images there is a large area of
#      intraparenchymal hemorrhage within the right parietal lobe and left thalamus
#      which following administration of gadolinium reveals ring-enhancing lesions.
#      These are suspicious for hemorrhagic metastases given the patient's history.
#      Additional ring-enhancing lesions throughout the supra- and infratentorial
#      compartments are visualized.  There is a moderate amount of peritumoral edema
#      involving the right parietal lobe lesion in addition to a second right
#      parietal lesion along the falx high in the vertex.  The other areas of
#      metastases reveal a minimal amount of peritumoral edema.
#
#
#
# ******************************************
#
#
#
#
#
#      DATE dd:dd AM
#      CT HEAD W/O CONTRAST                                            Clip # CLIP
#      Reason: ? stability of bleed
#      Admitting Diagnosis: HEAD BLEED
#
#
#      UNDERLYING MEDICAL CONDITION:
#       [**Age over dd **] year old woman with ? hemorragic mass
#      REASON FOR THIS EXAMINATION:
#       ? stability of bleed
#      No contraindications for IV contrast
#
#
#                                      FINAL REPORT  (REVISED)
#      HISTORY:  [**Age over dd **] year-old woman with a history of metastatic lung cancer to the
#      brain.  Question hemorrhagic mass.  Question stability of bleed.
#
#      COMPARISON:  Head CT from [**Hospital ddddd**] Hospital dated [**dddd-d-dd**].
#
#      TECHNIQUE:  Noncontrast head CT.
#
#      FINDINGS:  Compared to the prior days study, there is stable appearance of the
#      right parietal intraparenchymal hemorrhage with surrounding edema.  At the
#      superior margin of the parenchymal hemorrhage there is a rounded heterogeneous
#      focus which could represent a metastatic lesion.  An additional dmm hyperdense
#      focus, possibly hemorrhage, is noted in the posteromedial margin of the left
#      thalamus, with surroundng edema.  Low-attenuation foci seen in both basal
#      ganglia and insular regions are consistent with chronic lacunar infarcts.
#      There is no shift of midline structures.  The ventricles are stable in
#      appearance.  The osseous and soft tissue structures are unremarkable.
#
#      IMPRESSION:  Stable appearance of right parietal lobe and left thalamic
#      hemorrhages, which are concerning for hemorrhagic metastasis in this patient
#      with known metastatic lung carcinoma to the brain.
#
#
#
#
# ******************************************
#
#
#
#
#
#      DATE d:dd AM
#      CHEST (PORTABLE AP)                                             Clip # CLIP
#      Reason: NGT placement
#      Admitting Diagnosis: HEAD BLEED
#
#
#      UNDERLYING MEDICAL CONDITION:
#       [**Age over dd **] year old woman with SAH
#      REASON FOR THIS EXAMINATION:
#       NGT placement
#
#
#                                      FINAL REPORT
#      INDICATION:  A [**Age over dd **]-year-old woman with SAH.  Nasogastric tube placement.
#
#      TECHNIQUE:  Portable AP chest radiograph.
#
#      There is no previous chest radiograph for comparison.
#
#      FINDINGS:
#
#      The patient is status post median sternotomy.  Scoliosis is noted.  The
#      patient is rotated.
#
#      Note is made of mild cardiomegaly.  Note is made of rounded opacity overlying
#      the left hilum, which probably representing aspiration pneumonia; however,
#      left hilar mass cannot be totally excluded.  Mild CHF is noted.  No
#      pneumothorax is noted.  Nasogastric tube is coursing down below the left
#      hemidiaphragm.
#
#      IMPRESSION:
#
#      Cardiomegaly and mild CHF.  Nasogastric tube as described above.  Rounded
#      opacity overlying the left hilum, which probably representing aspiration
#      pneumonia; however, left hilar mass cannot be totally excluded.  Please
#      confirm resolution by repeated chest x-ray after treatment, and if the lesion
#      persists, please evaluate by CT scan.
#
#      The information is communicated with the referring physician, LASTNAME. [**First Named (NamePatternd) ddddd**] LASTNAME
#      by telephone in the morning of [**dddd-d-dd**].
#
#
#
# ******************************************
#
#
#
#
#
#      DATE dd:dd PM
#      CHEST (PORTABLE AP)                                             Clip # CLIP
#      Reason: aspiration pna?
#      Admitting Diagnosis: HEAD BLEED
#
#
#      UNDERLYING MEDICAL CONDITION:
#        [**Age over dd **] year old woman with ICH and nmoe with increased secretions
#
#      REASON FOR THIS EXAMINATION:
#       aspiration pna?
#
#
#                                      FINAL REPORT
#      This is a portable semierect chest that is dated [**dddd-d-dd**] compared to
#      [**dddd-d-dd**].
#
#      CLINICAL INDICATION:  Question aspiration pneumonia.
#
#      Nasogastric tube terminates below the diaphragm.  The cardiac silhouette
#      appears enlarged, but stable.  There is a large mass-like opacity overlying
#      the left hilum, which has slightly lobulated margins.  This measures about d
#      cm in greatest diameter.  Bilateral pleural effusions are noted, moderate on
#      the left and small on the right.  No pneumothorax is identified.
#
#      As compared to the previous study, alveolar opacities adjacent to the
#      perihilar mass have resolved.
#
#      IMPRESSION:
#
#      Marked improvement in left perihilar alveolar process with residual
#      well-marginated mass-like opacity, concerning for neoplasm.  This could be
#      initially confirmed with PA and lateral chest radiographs, but CT may be
#      considered for more complete characterization.  Findings communicated to
#      clinical service caring for the patient.
#
#
#
# ******************************************
#
#
#
#
#
#      DATE d:dd AM
#      CHEST (PORTABLE AP)                                             Clip # CLIP
#      Reason: r/o chf
#
#
#      UNDERLYING MEDICAL CONDITION:
#       dd year old man with sob, hx of chf
#      REASON FOR THIS EXAMINATION:
#       r/o chf
#
#
#                                      FINAL REPORT
#      INDICATION: Shortness of breath.
#
#      COMPARISON: [**dddd-d-dd**].
#
#      CHEST, AP PORTABLE RADIOGRAPH: There is stable moderate cardiomegaly in a
#      patient s/p CABG. There are multiple sternal wires which again appear
#      disrupted. There is mild to moderate pulmonary vascular redistribution and
#      hazy illdefined opacity obscuring the left cardiac silhouette. Tiny nodule in
#      the right upper lobe is unchanged. There is either a tiny nodule in the
#      lingula vs. vessel on end. The osseous structures are unremarkable.
#
#      IMPRESSION: Stable cardiomegaly with pulmonary vascular redistribution and new
#      lingular opacity. This could either represent pneumonia vs. asymmetric
#      pulmonary edema.
#
#
# ******************************************
#
#
#
#
#
#      DATE dd:dd AM
#      CHEST (PORTABLE AP)                                             Clip # CLIP
#      Reason: dd yo M with CHF and possible pna, now with acute worsening
#
#
#      UNDERLYING MEDICAL CONDITION:
#       dd year old man with sob, hx of chf, cad s/p CABG
#      REASON FOR THIS EXAMINATION:
#       dd yo M with CHF and possible pna, now with acute worsening of SOB and
#       increasing Od requirement, eval for worsening failure, new infiltrates or pulm
#       process
#
#
#                                      FINAL REPORT
#      PORTABLE CHEST:
#
#      CLINICAL INDICATION:  Worsening shortness of breath and oxygen requirement.
#
#      Comparison is made to prior chest radiographs of [**dddd-d-dd**] and [**d-dd**], dddd.
#
#      The heart is enlarged but stable in size.  There is persistent upper zone
#      vascular redistribution and perihilar haziness.  Additionally, there is an
#      area of increased opacity in the lingula which obscures the left heart border.
#      Note is made of disruption and malalignment of the sternal wires which is
#      unchanged dating back to [**dddd-d-dd**].
#
#      IMPRESSION:
#      d)  Confluent lingular opacity concerning for pneumonia.  When the patient's
#      condition permits, more complete evaluation with standard PA and lateral chest
#      radiographs is recommended.
#      d)  Mild congestive heart failure pattern.
#      d)  Malalignment and disruption of multiple sternal wires which appears to be
#      chronic.  This may be due to a chronic sternal dehiscence.
#
#
# ******************************************
#
#
#
#
#
#      DATE d:dd AM
#      CT HEAD W/O CONTRAST                                            Clip # CLIP
#      Reason: Please r/o bleed - pt has been ruled in for MI and is on hep
#      Admitting Diagnosis: CONGESTIVE HEART FAILURE
#
#
#      UNDERLYING MEDICAL CONDITION:
#       dd year old man w/ CAD, s/p CABG, CHF, COPD, IDDM, presenting with NSTEMI.
#      REASON FOR THIS EXAMINATION:
#       Please r/o bleed - pt has been ruled in for MI and is on heparin drip, but he
#       is experiencing some confusion and his Hct dropped from dd --> dd.  Please do
#       STAT Head CT if possible, b/c we need to know if we should stop the heparin.
#      CONTRAINDICATIONS for IV CONTRAST:
#       h/o IDDM, borderline Cr
#
#
#                                      FINAL REPORT  (REVISED)
#      INDICATION:  Confusion and hematocrit drop while on Heparin.
#
#      TECHNIQUE:  CT head without contrast.
#
#      COMPARISONS: CT head of [**dddd-d-dd**].
#
#      FINDINGS:  There is no intraparenchymal or extra axial hemorrhage. There is no
#      shift of normally midline structures or mass effect. There has been no
#      interval change in the appearance of the brain since the prior scan. There is
#      again demonstrated extensive atherosclerotic calcifications within the
#      cavernous portions of the internal carotid arteries bilaterally. The
#      surrounding osseous and visualized paranasal sinuses are unremarkable.
#
#      IMPRESSION:  No intracranial hemorrhage or mass effect.
#
#
#
# ******************************************
#
#
#
#
#
#      DATE d:dd PM
#      CT ABDOMEN W/O CONTRAST; CT PELVIS W/O CONTRAST                 Clip # CLIP
#      Reason: r/o bleed
#      Admitting Diagnosis: CONGESTIVE HEART FAILURE
#
#
#      UNDERLYING MEDICAL CONDITION:
#       dd year old man with CAD, s/p CABG, HTN, CHF, COPD here in hospital for cath on
#       Monday now with acute Hct drop from dd - dd - dd overnight.
#      REASON FOR THIS EXAMINATION:
#       r/o bleed
#      CONTRAINDICATIONS for IV CONTRAST:
#       h/o diabetes
#
#
#                                      FINAL REPORT
#      HISTORY:  dd y/o man status post CABG and acute drop in hematocrit.
#
#      TECHNIQUE: Axial images of the abdomen and pelvis were obtained without IV
#      contrast.
#
#      COMPARISONS: Not available.
#
#      CT ABDOMEN W/O CONTRAST:  Lung bases demonstrate patchy opacity in the region
#      of the lingula. There is no pleural effusion. The liver appears unremarkable
#      without focal abnormality.  There are several small gallstones noted within
#      the gallbladder.  The pancreas, spleen, adrenal glands, and right kidney
#      appear unremarkable.  There is a small punctate calcification noted within the
#      mid pole of the left kidney which could represent a small renal stone. There
#      is no evidence of hydronephrosis.  Visualized large and small bowel loops
#      appear unremarkable. There is no significant mesenteric or retroperitoneal
#      lymphadenopathy.  There is no free air or free fluid within the abdomen.
#
#      CT PELVIS W/O CONTRAST:  The prostate is slight enlarged. The urinary bladder
#      and rectum appear unremarkable.  There is no pelvic lymphadenopathy or pelvic
#      free fluid.
#
#      BONE WINDOWS demonstrate no evidence of suspicious lytic or blastic lesions.
#
#      IMPRESSION:
#
#      d) No evidence of retroperitoneal hemorrhage.
#      d) Cholelithiasis without evidence of cholecystitis.
#      d) Lingular infiltrate and pneumonia should be considered in the appropriate
#      clinical setting.
#      d) There is a small subcentimeter stone within the left kidney without
#      evidence of hydronephrosis.
#
#
# ******************************************
#
#
#
#
#
#      DATE d:dd PM
#      CT ABDOMEN W/O CONTRAST; CT PELVIS W/O CONTRAST                 Clip # CLIP
#      Reason: r/o bleed
#      Admitting Diagnosis: CONGESTIVE HEART FAILURE
#
#
#      UNDERLYING MEDICAL CONDITION:
#       dd year old man with CAD, s/p CABG, HTN, CHF, COPD here in hospital for cath on
#       Monday now with acute Hct drop from dd - dd - dd overnight.
#      REASON FOR THIS EXAMINATION:
#       r/o bleed
#      CONTRAINDICATIONS for IV CONTRAST:
#       h/o diabetes
#
#
#                                      FINAL REPORT
#      HISTORY:  dd y/o man status post CABG and acute drop in hematocrit.
#
#      TECHNIQUE: Axial images of the abdomen and pelvis were obtained without IV
#      contrast.
#
#      COMPARISONS: Not available.
#
#      CT ABDOMEN W/O CONTRAST:  Lung bases demonstrate patchy opacity in the region
#      of the lingula. There is no pleural effusion. The liver appears unremarkable
#      without focal abnormality.  There are several small gallstones noted within
#      the gallbladder.  The pancreas, spleen, adrenal glands, and right kidney
#      appear unremarkable.  There is a small punctate calcification noted within the
#      mid pole of the left kidney which could represent a small renal stone. There
#      is no evidence of hydronephrosis.  Visualized large and small bowel loops
#      appear unremarkable. There is no significant mesenteric or retroperitoneal
#      lymphadenopathy.  There is no free air or free fluid within the abdomen.
#
#      CT PELVIS W/O CONTRAST:  The prostate is slight enlarged. The urinary bladder
#      and rectum appear unremarkable.  There is no pelvic lymphadenopathy or pelvic
#      free fluid.
#
#      BONE WINDOWS demonstrate no evidence of suspicious lytic or blastic lesions.
#
#      IMPRESSION:
#
#      d) No evidence of retroperitoneal hemorrhage.
#      d) Cholelithiasis without evidence of cholecystitis.
#      d) Lingular infiltrate and pneumonia should be considered in the appropriate
#      clinical setting.
#      d) There is a small subcentimeter stone within the left kidney without
#      evidence of hydronephrosis.
#
#
# ******************************************

# %% [markdown]
# ### You can use the Pandas `iloc` method to grab specific reports

# %%
print(rad_data.iloc[0]["text"])

# %%
print(rad_data.iloc[0]["text"])

# %% [markdown]
# ### Create a new column named "impression" for storing just the impression portion of the report

# %%
#take our impression sections, clean them up, and put into the dataframe as a new column
rad_data["impression"] = \
rad_data.apply(lambda row: preprocess(get_impression(row["text"])).lower(), axis=1)

# %%
rad_data.head()
# Out:
#    subject_id  hadm_id                                               text  \
# 0          56  28766.0  \n\n\n     DATE: [**2644-1-17**] 10:53 AM\n   ...
# 1          56  28766.0  \n\n\n     DATE: [**2644-1-17**] 10:53 AM\n   ...
# 2          56  28766.0  \n\n\n     DATE: [**2644-1-17**] 10:43 AM\n   ...
# 3          56  28766.0  \n\n\n     DATE: [**2644-1-17**] 6:37 AM\n    ...
# 4          56  28766.0  \n\n\n     DATE: [**2644-1-19**] 12:09 PM\n   ...
#
#                                           impression
# 0  \n\n\n     date 10:53 am\n     mr head w & w/o...
# 1  \n\n\n     date 10:53 am\n     mr head w & w/o...
# 2  impression:  stable appearance of right pariet...
# 3  impression:\n     \n     cardiomegaly and mild...
# 4  impression:\n     \n     marked improvement in...

# %%
print(rad_data.iloc[20]["impression"])

# %% [markdown]
# ### How many unique words occur in the corpus?
#
# #### Hint
#
# 1. Use TextBlob
# 1. Put all the reports into a single string
#
# #### I got 8658

# %%
#" ".join(rad_data["impression"])

# %%
#!python -m textblob.download_corpora
blob = TextBlob(" ".join(rad_data["impression"]))
unique_impression_words = set(blob.words)
len(unique_impression_words)

#pass TextBlob a string and it gets the words for us
#" " is the delimiter for join -- so we make one big string with empty string between
#set for uniqueness

#Brian gets 7402 and apparently he is right and we are wrong
# Out:
# 8485

# %%
unique_impression_words
# Out:
# {'centra',
#  'ea',
#  '2915-9-2',
#  'pain',
#  '78-year-odl',
#  'pronounced',
#  'handed',
#  '2:11',
#  't12',
#  '9:28',
#  'should',
#  'regard',
#  'symmetry',
#  'lefet',
#  'caring',
#  '1947',
#  'top',
#  'hemidiaphgram',
#  '143',
#  'bradycardia',
#  'panniculitis',
#  '2271',
#  'does',
#  'underperfusion',
#  'nondependent',
#  'mmp',
#  'lesion',
#  'towards',
#  'results',
#  'cxrs',
#  'barely',
#  'rhonchi',
#  'jp',
#  'soluble',
#  'ear',
#  'created',
#  'would',
#  'outlined',
#  'undergoing',
#  '225',
#  'endograft',
#  'rewire',
#  'consult',
#  'detail',
#  'pseudoaneurysmal',
#  'overload',
#  'supratentorial',
#  '3350-10-18',
#  'cub',
#  '8:10',
#  'recto-sigmoid',
#  '2847-6-29',
#  '172',
#  'tolerating',
#  '10292',
#  'obliterates',
#  'leftclip',
#  'coming',
#  'represents',
#  '12:24',
#  'lacunar',
#  '87',
#  'lobar',
#  'patient',
#  'moderate',
#  'ruq',
#  'flowing',
#  'story',
#  '2617-10-24',
#  'overall',
#  '2962-10-19',
#  '2798-11-3',
#  'optimal',
#  'bp',
#  'acetabular',
#  'cardiopulm',
#  'post-tpa',
#  'hyper-echoic',
#  'intr',
#  '442',
#  'pulm',
#  'elastic',
#  '6:16',
#  'intraperitoneal',
#  'iliofemoral',
#  'ab',
#  '160',
#  'recovery',
#  'tenderness',
#  'staples',
#  'non-contrast',
#  'nkg',
#  '3233-9-20',
#  'calves',
#  '2915-8-24',
#  'structure',
#  '7:20',
#  'third',
#  'name9',
#  'hyperflexion',
#  'contraindications',
#  'now',
#  'feding',
#  '87-year-old',
#  'stripping',
#  'segment',
#  'mediansternotomy',
#  '10:45',
#  'failed',
#  '11-20',
#  'sq',
#  'hole',
#  'wand',
#  '9:41',
#  'aberrant',
#  'accommodate',
#  '71-year-old',
#  'malignan',
#  '774',
#  'enterocolitis',
#  '11/28',
#  '7-25',
#  'apposition',
#  '32',
#  'bulges',
#  'administered',
#  '11:25',
#  'peeling',
#  'oriented',
#  'hypodensity',
#  'actual',
#  'invading',
#  'hemicolectomy',
#  'superior',
#  'imaging',
#  'intrahepatic/extrahepatic',
#  '12:14',
#  '7:08',
#  '5:08',
#  'omniflush',
#  'modality',
#  'incident',
#  'fifth',
#  'temps',
#  'locking',
#  '5-27',
#  'film',
#  'portovenous',
#  '2513-2-4',
#  'mdct',
#  'leaking',
#  'sbe',
#  'gangrene',
#  'balloon',
#  'ankylosing',
#  'blead',
#  '14:20',
#  'als',
#  'tip',
#  'curve',
#  'earlier',
#  'congestion',
#  '1pm',
#  'ng-tube',
#  '11-1',
#  'en',
#  'acidosis',
#  'orientation',
#  '3074-5-7',
#  'l4-l5',
#  'limit',
#  'pa/lateral',
#  '77yr',
#  'abdominal',
#  'cns',
#  'air/sbft',
#  'plethora',
#  'aneurysm',
#  'principal',
#  '2501-11-19',
#  'tree',
#  'three-dimensional',
#  'tract',
#  'cauda',
#  'icb',
#  'supplying',
#  '11:50',
#  '1-14',
#  'collateral',
#  '2293',
#  'amt',
#  '3034-6-13',
#  'flare',
#  'intervals',
#  '8-18',
#  '716',
#  '3082-1-12',
#  'circumferential',
#  'mid-to-upper',
#  '3334-9-30',
#  'neurosurgical',
#  'lamina',
#  'start',
#  '3:41',
#  'transcriptional',
#  'para',
#  'inflitrate',
#  '2948-9-24',
#  'completion',
#  'dr',
#  '4:34',
#  'ne',
#  'nuclei',
#  '11-week-old',
#  'bandage',
#  'prevertebral',
#  'determine',
#  'pneumotorax',
#  'sterile',
#  'intratrochanteric',
#  'fatty',
#  'unusual',
#  'zilver',
#  'o',
#  'pelvis',
#  'ventricle',
#  'becomes',
#  'cervicomedullary',
#  'hip',
#  'erosive',
#  'appreciably',
#  'coned',
#  'replace',
#  '0.32',
#  'c5',
#  'ivh',
#  'single',
#  'accompanying',
#  '6:24',
#  'important',
#  '3353-1-11',
#  'acom',
#  'follow-through',
#  '2559-3-24',
#  'meningeal',
#  'pet-ct',
#  'svc/right',
#  '8119',
#  'subarticular',
#  '8th',
#  'lll',
#  '2b',
#  'away',
#  'inversion',
#  'tracheal',
#  '7:57',
#  'brachio',
#  'shine',
#  'neuropathic',
#  'column',
#  'thrombus',
#  'context',
#  'it',
#  '12-13',
#  '4:57',
#  'metastasis',
#  'ports',
#  'preogression',
#  '12513',
#  '3344-11-17',
#  'sesha',
#  'added',
#  'babygram',
#  'tubular',
#  'reduction',
#  'watershed',
#  'ureterovesical',
#  'proposed',
#  'cleft',
#  '8-11',
#  'persists',
#  'angoplast',
#  'arches',
#  'base',
#  'visualization',
#  '6:34',
#  'dual',
#  'stataus',
#  'adenomyomatosis',
#  't',
#  '10/1',
#  'effusion',
#  'subcarinal',
#  '10:26',
#  'significnt',
#  'unstable',
#  'biliary',
#  'calcification',
#  'well',
#  'vault',
#  'hypotension-fever',
#  'together',
#  'angiomas',
#  'blockages',
#  'subchondral',
#  'hallux',
#  'smh',
#  'fields',
#  '15030',
#  'accumulation',
#  'spinous',
#  'stroke',
#  'probably',
#  'ccu',
#  'midesophagus',
#  '2817-4-20',
#  'arteriosis',
#  '13163',
#  'let',
#  'provider',
#  'dampened',
#  'levels',
#  '8:22',
#  'sclerosis',
#  'ileus/obstruction',
#  'ethmoid',
#  'gastrostomy',
#  'ulcer',
#  'amputations',
#  'superifical',
#  '2610-4-23',
#  'causing',
#  'blockade',
#  'attempt-related',
#  'medullary',
#  'retro',
#  'be',
#  'airways',
#  'redemonstrated',
#  'thecal',
#  'proximal/mid',
#  'subclav',
#  '7:56',
#  'quite',
#  'endo-tracheal',
#  'vws',
#  'inconclusive',
#  '6:14',
#  'portable',
#  'microperforation',
#  'p/w',
#  'since',
#  '1-26',
#  'increases',
#  'arteriography',
#  'verify',
#  'frontal',
#  'core',
#  'follow-up',
#  'acut',
#  'supervised',
#  'nonetheless',
#  'could',
#  '2513-2-10',
#  'similiar',
#  'obviously',
#  '1:58',
#  'proportion',
#  'asthma',
#  'conversion',
#  'conspicuity',
#  'cabgx1',
#  '2528-2-18',
#  'mvmt',
#  '4-30',
#  'else',
#  'midcervical',
#  '12921',
#  'e',
#  '5.2',
#  '3-11',
#  'she',
#  '3422-11-20',
#  '5:24',
#  'distally',
#  'metaphysis',
#  'anesthesiologist',
#  'tibiofemoral',
#  'general',
#  'distant',
#  '2.1',
#  'impaction',
#  'hfo',
#  'dilator',
#  'atn',
#  'duodenal',
#  'effort',
#  'n-j',
#  '06:06',
#  'hyaline',
#  'radiolucencies',
#  'recent',
#  'requests',
#  '3268-12-26',
#  '4495',
#  '25-50',
#  'ureters',
#  'ptx',
#  'thinned',
#  'along',
#  '60-69',
#  'alignment',
#  'hiatal',
#  '3354-2-8',
#  '12:36',
#  'need',
#  'seventh',
#  'aspiration/dysphasia',
#  '3981',
#  'tissues',
#  '8:54',
#  'reperesent',
#  'avulsion',
#  'progressively',
#  'amplitudes',
#  'noting',
#  'presesent',
#  '120',
#  'cm/second',
#  'bulkiness',
#  'extrinsic',
#  'persistently',
#  'roundedimpression',
#  'healed',
#  'choroid',
#  '545',
#  'collaterals',
#  'tympany',
#  'prep',
#  'retropulsion',
#  '57',
#  'host',
#  'influenza',
#  'produce',
#  'wedging',
#  'reassessment',
#  '5:21',
#  'lymphomia\\bone',
#  'stablility',
#  'cephalic',
#  'condyles',
#  '2806-11-27',
#  'perfusion/splenic',
#  'resuscitation',
#  '75898',
#  '9:51',
#  'status',
#  'e/f',
#  '3233-10-4',
#  'ud',
#  'transit',
#  '7298',
#  'rds',
#  'different',
#  'dopplers',
#  'dhs',
#  'revealing',
#  'deposit',
#  '6.8',
#  'phalanx',
#  'hodgkin',
#  'someone',
#  '2-17',
#  'acquisition',
#  'wall-to',
#  '6:30',
#  'bifrontal',
#  '4:01',
#  '4:03',
#  '0.28',
#  'trach/vent',
#  'identifies',
#  'demylenation',
#  'performing',
#  'pelvic',
#  'type',
#  'cavo-atrial',
#  'cast',
#  'tethering',
#  'roof',
#  'parallel',
#  '1811',
#  'branching',
#  'non-propulsive',
#  '3052-10-28',
#  'c5-7',
#  'whether',
#  'saphenofemoral',
#  'perilymphatic',
#  'planes',
#  'questions',
#  'mid-femur',
#  'abscess',
#  'likley',
#  'tenosynovitis',
#  'transforaminal',
#  '331',
#  'patch',
#  'abcess',
#  '7:27',
#  'anechoic',
#  'crests',
#  'pm',
#  'blood',
#  'muscle',
#  'supraglottitis',
#  '2709-7-11',
#  'bacteremic',
#  '180',
#  '2806-10-17',
#  '11:00',
#  'troponins',
#  'bleeds',
#  'rest',
#  'centimeters',
#  'sounds/aspiration',
#  '2689-3-29',
#  '7:55',
#  '16:44',
#  'thymus',
#  'interrogated',
#  'mtp',
#  'nonmyositis',
#  '6:35',
#  '3128-5-31',
#  'scar',
#  '865',
#  'overlies',
#  '11:04',
#  '12:58',
#  '2558-4-26',
#  '0.43',
#  'border',
#  'b/l',
#  'sectional',
#  '12042',
#  'perihilar',
#  '3344-12-22',
#  'hilar/paraspinal',
#  'anterolisthesis',
#  'artery/vein',
#  'invaluable',
#  'come',
#  '2.6',
#  'an',
#  '9:22',
#  'metallic',
#  'downsizing',
#  'int/shth',
#  'concomitant',
#  'produced',
#  'dictate',
#  '3352-9-26',
#  'instruments',
#  'thinning',
#  '9:49',
#  'fungal',
#  'insuff/exsufflator',
#  'questional',
#  'requesting',
#  '2806-12-18',
#  'reason',
#  'dementia',
#  'c1892',
#  'subdural',
#  'reached',
#  '2:50',
#  'relating',
#  'correlated',
#  '10-15',
#  '3451-12-30',
#  'consists',
#  'lobes',
#  'slit-like',
#  'will',
#  '2:38',
#  'epigastrium',
#  'punctures',
#  'ridges',
#  '82-year-old',
#  'iv',
#  'lap',
#  'units',
#  'accummulation',
#  'pain\\cardiac',
#  'urogram',
#  '3-6',
#  'ending',
#  '2806-11-3',
#  'vrs',
#  'confirmatory',
#  'attention',
#  'cystic',
#  '2512-12-13',
#  'clerotic',
#  'heterotopic',
#  'addition',
#  'sequential',
#  'islands',
#  '3591',
#  'fistulogram/sinogram',
#  'sizeable',
#  'afp',
#  'sinusitis',
#  '2806-10-27',
#  'punctate',
#  'gastrografin',
#  '6.1',
#  'positional',
#  '579',
#  'pachymeningeal',
#  '3286-8-5',
#  '1652',
#  'whole',
#  'overling',
#  '12:48',
#  'firm',
#  'cisterns',
#  '10/3302',
#  '12614',
#  'c1',
#  'omental',
#  'evalute',
#  '5:49',
#  'anomalies',
#  'rehabilitation',
#  'reflective',
#  'double',
#  'bringing',
#  'collected',
#  'worsened',
#  'dup',
#  'total',
#  '3480-4-15',
#  'angulation',
#  'irregular',
#  'stat',
#  'trach',
#  'contours',
#  'demonstrate',
#  'diaphragms',
#  '3156-3-4',
#  'adhesion',
#  'persist',
#  'dorsalis',
#  '4.3-cm',
#  'flow-limiting',
#  'continuos',
#  '11:47',
#  'isolated',
#  '16:35',
#  '3131-11-28',
#  'comprehensive',
#  'burkitts',
#  'thus',
#  'wave',
#  'ordering',
#  'fibrillation',
#  'sequences',
#  'bland',
#  'cholecysitis',
#  'another',
#  '2909-11-21',
#  '2951-9-3',
#  'impairment',
#  'foreign',
#  'local',
#  'abnormalities',
#  'craniotomy',
#  'basis',
#  'named',
#  'exophytically',
#  'consolidated',
#  '2761-8-16',
#  '3095-8-1',
#  '5:28',
#  '2502-4-4',
#  'orogastric',
#  'daily',
#  '7-french',
#  'code',
#  '2-28',
#  'ingestion',
#  'viral',
#  'decub',
#  'loc',
#  'biopsies',
#  '7.4',
#  'atherosclerosis',
#  'past',
#  'ischemia/infarction',
#  'tachycardia',
#  'subpectoral',
#  '3:44',
#  'im',
#  'cellular',
#  'cont',
#  'fullness',
#  'thoracic',
#  '1669',
#  'ductus',
#  '446',
#  'faintly',
#  'pacer/defibrillator',
#  'withdrawn',
#  'terminate',
#  'prior',
#  '0.21',
#  'significantly',
#  'mra',
#  '121/5/03',
#  'request',
#  '3354-3-3',
#  'hypothermic',
#  'higher',
#  'obscured',
#  'femer',
#  '11:35',
#  '12:01',
#  '1949',
#  'egd',
#  'nerve',
#  'bubbles',
#  'pulmonray',
#  'lacular',
#  'rule/out',
#  'hypodense',
#  'warranted',
#  '9:30',
#  'representative',
#  'thigh',
#  '2:55',
#  '2686-9-16',
#  'later',
#  'blob',
#  '75625',
#  'nonphysiologic',
#  'tibia/fibula',
#  '455',
#  '7-1283',
#  '3:49',
#  'reading',
#  '2806-10-15',
#  '7494',
#  'requirements',
#  '693',
#  'disclosed',
#  '3063-3-4',
#  'hepatficejejunostomy',
#  'transplanted',
#  '83',
#  'ectatic',
#  'echo',
#  'hypodensities',
#  '0.22',
#  'symptom',
#  '6:13',
#  '2/5/5',
#  '2512-9-3',
#  'dual-lumen',
#  '2951-8-24',
#  'carefully',
#  '3139-3-20',
#  'etiology',
#  'overt',
#  'admitted',
#  'tlc',
#  '11:56',
#  'pca',
#  '4:43',
#  '74s',
#  '12:55',
#  '74',
#  'pharnyx',
#  'air',
#  '3128-8-6',
#  '13:44',
#  '4:19',
#  'orthopedic',
#  '12:52',
#  'desaturation',
#  'family',
#  'lies',
#  '3344-12-24',
#  'atelectases',
#  '2554-7-16',
#  '3-cm',
#  'oxygenation',
#  'origins',
#  'diseas',
#  '1.9',
#  '9-11',
#  'infratentorial',
#  '1918',
#  'circulation',
#  'paraaortic',
#  '3970',
#  'courses',
#  'peripheral',
#  'relayed',
#  'respiratory',
#  'convex',
#  '3082-1-8',
#  'needles',
#  'hyperinflated',
#  'massive',
#  'nonconvulsive',
#  '3099-11-4',
#  '10:10',
#  'desaturating',
#  'obstructed',
#  'c/o',
#  '1-1',
#  'a1',
#  'post-surgical',
#  'diltation',
#  '03/06',
#  'reversal',
#  '547',
#  'plantar',
#  '2-25',
#  'atelectasis/collapse',
#  'semiovale',
#  'cri',
#  'guide',
#  'provided',
#  'hrs',
#  'magnevist',
#  'atheromatous',
#  '12:22',
#  '2501-4-7',
#  't1-weighted',
#  '6:00am',
#  'name6',
#  'month',
#  'organisms',
#  'intestinal',
#  'thank',
#  'labrum',
#  'march',
#  'revision',
#  'quadrants',
#  'mottled',
#  '2-20',
#  'cardiomegaly',
#  'fluids',
#  'unchanged',
#  '2574-8-12',
#  'decrease',
#  'pattern1',
#  '6.5',
#  '5-4',
#  'transdermally',
#  '1360',
#  'decreased',
#  'y/o',
#  'into',
#  'cough',
#  'extreme',
#  'areation',
#  'discitis',
#  'confirmed',
#  '55m',
#  '3.9',
#  'fistulous',
#  'usual',
#  'carcinoma',
#  '10272',
#  '12:05',
#  'parotids',
#  'separate',
#  'pneumonic',
#  'account',
#  'visceral',
#  'burden',
#  'ill-defined',
#  'explore',
#  'embolus',
#  'infiltrate/atelectasis',
#  'postr-pyloric',
#  'apices',
#  '2729',
#  'post',
#  'min',
#  'coarse',
#  '2951-8-31',
#  '10-27',
#  'cerebral',
#  'impingement',
#  'ampulla',
#  'enzymes',
#  'cvvh',
#  'recanalized',
#  'bony',
#  'electively',
#  'lymphatic',
#  'time',
#  'thickening/effusions',
#  'how',
#  'jejunum',
#  '3253-5-29',
#  'passes',
#  'multilumen',
#  'suboptimal',
#  'tracheobronchomalacic',
#  'pull-through',
#  'metal',
#  'upward',
#  'woman',
#  'laminectomies',
#  'blind-ending',
#  'common',
#  'suture',
#  'suggesting',
#  'symmetric',
#  'excluding',
#  'hyperperfusion',
#  'regular',
#  'needle',
#  '90276',
#  'sole',
#  '1:45',
#  'cea',
#  'kyphosis',
#  'decision',
#  '10:28',
#  'respect',
#  'heels',
#  'initial',
#  'sides',
#  'frog',
#  'interstitial',
#  '3-3',
#  'leptomeningeal',
#  'preclude',
#  'replaces',
#  'once',
#  '4:37',
#  'signfiicant',
#  'intracranial',
#  '2:35',
#  'subsegmental',
#  'radial',
#  'toxicity',
#  'angioma',
#  'vicarious',
#  'pvc',
#  '5:07',
#  'left-sided',
#  'mild',
#  'monitor',
#  '2948-9-27',
#  'disuse',
#  'cord',
#  'vomiting',
#  'conspicuous',
#  'during',
#  'volving',
#  'nourishment',
#  'larger',
#  'locale',
#  '3094-1-23',
#  '78-year-old',
#  '9:08',
#  'chest/mediastinum',
#  'adenocarcinoma',
#  'communicated',
#  'radiological',
#  'gone',
#  '3474-12-11',
#  'require',
#  '1203',
#  'ai',
#  'contain',
#  "tf's",
#  'axillary',
#  'arota',
#  'occipital',
#  'check/repo',
#  'question',
#  'discrepancy',
#  'momentarily',
#  'improved',
#  'gbm',
#  'fibroids',
#  'activity',
#  'dilatations',
#  'alignment/hardware',
#  'incr',
#  'perinephric',
#  ...}

# %%
from collections import Counter

c = Counter(blob.words)
c.most_common()
# Out:
# [('the', 15148),
#  ('of', 9815),
#  ('and', 5570),
#  ('is', 4910),
#  ('with', 4789),
#  ('in', 4376),
#  ('impression', 4153),
#  ('right', 3518),
#  ('to', 3401),
#  ('no', 3237),
#  ('left', 2927),
#  ('clip', 2794),
#  ('for', 2643),
#  ('a', 2599),
#  ('reason', 2189),
#  ('there', 2057),
#  ('contrast', 1982),
#  ('chest', 1970),
#  ('ct', 1902),
#  ('1', 1754),
#  ('this', 1723),
#  ('2', 1596),
#  ('date', 1555),
#  ('report', 1533),
#  ('tube', 1473),
#  ('final', 1473),
#  ('at', 1460),
#  ('was', 1427),
#  ('pleural', 1403),
#  ('are', 1374),
#  ('on', 1357),
#  ('evidence', 1277),
#  ('or', 1230),
#  ('small', 1186),
#  ('placement', 1070),
#  ('artery', 1040),
#  ('be', 1013),
#  ('examination', 976),
#  ('3', 954),
#  ('bilateral', 930),
#  ('as', 906),
#  ('effusion', 905),
#  ('pm', 903),
#  ('within', 897),
#  ('catheter', 885),
#  ('lower', 882),
#  ('over', 879),
#  ('diagnosis', 879),
#  ('lobe', 864),
#  ('pulmonary', 863),
#  ('pneumothorax', 854),
#  ('interval', 852),
#  ('admitting', 824),
#  ('underlying', 821),
#  ('study', 817),
#  ('ap', 815),
#  ('line', 809),
#  ('findings', 798),
#  ('not', 791),
#  ('tip', 749),
#  ('lung', 748),
#  ('seen', 740),
#  ('medical', 736),
#  ('from', 734),
#  ('which', 716),
#  ('condition', 715),
#  ('prior', 712),
#  ('old', 696),
#  ('portable', 685),
#  ('edema', 669),
#  ('am', 668),
#  ('year', 664),
#  ('cont', 653),
#  ('change', 642),
#  ('effusions', 634),
#  ('patient', 633),
#  ('s/p', 630),
#  ('atelectasis', 627),
#  ('abdomen', 623),
#  ('an', 610),
#  ('w/o', 601),
#  ('were', 587),
#  ('name', 569),
#  ('pelvis', 564),
#  ('unchanged', 561),
#  ('amt', 560),
#  ('vein', 551),
#  ('compared', 545),
#  ('has', 543),
#  ('pneumonia', 538),
#  ('disease', 536),
#  ('w/contrast', 536),
#  ('new', 528),
#  ('cm', 512),
#  ('please', 508),
#  ('by', 496),
#  ('upper', 493),
#  ('stable', 492),
#  ('significant', 490),
#  ('likely', 488),
#  ('fluid', 484),
#  ('lastname', 463),
#  ('liver', 461),
#  ('4', 459),
#  ('view', 449),
#  ('above', 449),
#  ('size', 447),
#  ('man', 447),
#  ('history', 445),
#  ('appearance', 443),
#  ('may', 437),
#  ('position', 429),
#  ('optiray', 426),
#  ('now', 423),
#  ('normal', 421),
#  ('consistent', 421),
#  ('mild', 409),
#  ('mass', 408),
#  ('failure', 408),
#  ('large', 407),
#  ('acute', 405),
#  ('bowel', 404),
#  ('identified', 402),
#  ('without', 400),
#  ('these', 396),
#  ('multiple', 395),
#  ('heart', 395),
#  ('evaluate', 391),
#  ('distal', 385),
#  ('first', 383),
#  ('increased', 372),
#  ('but', 368),
#  ('moderate', 361),
#  ('due', 361),
#  ('dr', 347),
#  ('indication', 341),
#  ('previous', 341),
#  ('anterior', 341),
#  ('successful', 339),
#  ('comparison', 334),
#  ('w', 334),
#  ('could', 333),
#  ('into', 332),
#  ('present', 332),
#  ('since', 331),
#  ('hepatic', 328),
#  ('fracture', 325),
#  ('eval', 318),
#  ('5', 318),
#  ('mr', 314),
#  ('hemorrhage', 311),
#  ('represent', 309),
#  ('amount', 306),
#  ('persistent', 302),
#  ('opacity', 302),
#  ('been', 299),
#  ('clinical', 298),
#  ('both', 298),
#  ('post', 298),
#  ('proximal', 298),
#  ('ascites', 294),
#  ('performed', 292),
#  ('biliary', 289),
#  ('status', 289),
#  ('consolidation', 288),
#  ('changes', 287),
#  ('venous', 287),
#  ('can', 286),
#  ('air', 284),
#  ("'s", 284),
#  ('abdominal', 282),
#  ('posterior', 282),
#  ('flow', 282),
#  ('film', 281),
#  ('images', 281),
#  ('picc', 281),
#  ('woman', 280),
#  ('through', 280),
#  ('stomach', 279),
#  ('chf', 277),
#  ('level', 274),
#  ('noted', 273),
#  ('described', 269),
#  ('opacities', 267),
#  ('region', 267),
#  ('svc', 265),
#  ('vascular', 263),
#  ('diffuse', 262),
#  ('exam', 260),
#  ('head', 259),
#  ('also', 258),
#  ('patent', 257),
#  ('central', 257),
#  ('last', 257),
#  ('r/o', 254),
#  ('wall', 249),
#  ('placed', 248),
#  ('worsening', 248),
#  ('field', 247),
#  ('discussed', 243),
#  ('however', 243),
#  ('single', 242),
#  ('assess', 242),
#  ('internal', 240),
#  ('lesion', 238),
#  ('well', 236),
#  ('after', 233),
#  ('stenosis', 233),
#  ('than', 231),
#  ('associated', 227),
#  ('free', 222),
#  ('thoracic', 222),
#  ('renal', 219),
#  ('focal', 219),
#  ('subclavian', 218),
#  ('obstruction', 218),
#  ('previously', 218),
#  ('excluded', 217),
#  ('again', 217),
#  ('obtained', 216),
#  ('lesions', 215),
#  ('spinal', 215),
#  ('recommended', 215),
#  ('two', 213),
#  ('arteries', 212),
#  ('that', 211),
#  ('lateral', 211),
#  ('slight', 209),
#  ('base', 209),
#  ('most', 208),
#  ('extensive', 208),
#  ('superior', 207),
#  ('vertebral', 207),
#  ('tips', 203),
#  ('area', 201),
#  ('ng', 200),
#  ('portal', 200),
#  ('time', 198),
#  ('brain', 197),
#  ('aspiration', 196),
#  ('limited', 196),
#  ('process', 195),
#  ('common', 195),
#  ('metastatic', 194),
#  ('increase', 193),
#  ('its', 192),
#  ('other', 191),
#  ('improvement', 191),
#  ('bibasilar', 191),
#  ('same', 190),
#  ('slightly', 189),
#  ('technique', 189),
#  ('mediastinal', 189),
#  ('jugular', 188),
#  ('iv', 187),
#  ('femoral', 187),
#  ('150', 186),
#  ('lungs', 186),
#  ('drainage', 186),
#  ('nonionic', 184),
#  ('radiograph', 184),
#  ('150cc', 184),
#  ('possible', 184),
#  ('it', 183),
#  ('procedure', 182),
#  ('french', 181),
#  ('thickening', 181),
#  ('collection', 180),
#  ('mm', 179),
#  ('tubes', 176),
#  ('abd', 176),
#  ('endotracheal', 176),
#  ('c', 176),
#  ('junction', 176),
#  ('stent', 174),
#  ('approximately', 174),
#  ('congestive', 173),
#  ('some', 172),
#  ('hematoma', 172),
#  ('place', 171),
#  ('spine', 170),
#  ('evaluation', 170),
#  ('unremarkable', 170),
#  ('segmental', 167),
#  ('if', 167),
#  ('dilatation', 167),
#  ('more', 166),
#  ('recent', 166),
#  ('gastric', 166),
#  ('mesenteric', 166),
#  ('ij', 166),
#  ('patchy', 166),
#  ('un', 165),
#  ('service', 164),
#  ('low', 164),
#  ('carina', 164),
#  ('definite', 163),
#  ('removal', 163),
#  ('bleed', 162),
#  ('aorta', 161),
#  ('aortic', 161),
#  ('scan', 161),
#  ('areas', 160),
#  ('emphysema', 159),
#  ('cardiac', 159),
#  ('colon', 156),
#  ('6', 156),
#  ('further', 156),
#  ('cardiomegaly', 155),
#  ('filling', 155),
#  ('day', 154),
#  ('otherwise', 153),
#  ('left-sided', 153),
#  ('given', 153),
#  ('enhancement', 153),
#  ('compression', 152),
#  ('greater', 152),
#  ('satisfactory', 151),
#  ('up', 151),
#  ('stitle', 151),
#  ('doctor', 151),
#  ('abscess', 150),
#  ('physician', 149),
#  ('initial', 149),
#  ('mid', 149),
#  ('abnormal', 149),
#  ('embolization', 148),
#  ('extending', 147),
#  ('chronic', 146),
#  ('duct', 146),
#  ('subcutaneous', 145),
#  ('along', 143),
#  ('made', 143),
#  ('wire', 143),
#  ('severe', 142),
#  ('density', 142),
#  ('loops', 142),
#  ('sepsis', 142),
#  ('interstitial', 141),
#  ('carotid', 141),
#  ('nasogastric', 140),
#  ('et', 140),
#  ('pain', 139),
#  ('check', 139),
#  ('gallbladder', 138),
#  ('visualized', 138),
#  ('kidney', 137),
#  ('out', 137),
#  ('port', 136),
#  ('lines', 136),
#  ('intracranial', 136),
#  ('side', 135),
#  ('appears', 135),
#  ('results', 134),
#  ('one', 134),
#  ('frontal', 134),
#  ('nodules', 134),
#  ('feeding', 134),
#  ('conclusion', 134),
#  ('mri', 134),
#  ('main', 133),
#  ('portion', 133),
#  ('non', 131),
#  ('telephone/fax', 130),
#  ('right-sided', 130),
#  ('ultrasound', 130),
#  ('basilar', 129),
#  ('via', 128),
#  ('use', 128),
#  ('partial', 128),
#  ('mra', 127),
#  ('then', 127),
#  ('veins', 127),
#  ('ready', 127),
#  ('adjacent', 127),
#  ('have', 126),
#  ('correlation', 126),
#  ('earlier', 125),
#  ('name8', 124),
#  ('secondary', 124),
#  ('celiac', 123),
#  ('ptx', 122),
#  ('advanced', 122),
#  ('involving', 122),
#  ('occlusion', 122),
#  ('extremity', 122),
#  ('signal', 121),
#  ('lymphadenopathy', 121),
#  ('lymphoma', 121),
#  ('supine', 121),
#  ('probably', 120),
#  ('following', 120),
#  ('arm', 120),
#  ('tiny', 119),
#  ('improved', 119),
#  ('soft', 119),
#  ('radiology', 118),
#  ('probable', 118),
#  ('imaging', 117),
#  ('body', 117),
#  ('subdural', 116),
#  ('namepattern2', 115),
#  ('sheath', 115),
#  ('when', 115),
#  ('less', 115),
#  ('retrocardiac', 114),
#  ('decreased', 114),
#  ('location', 114),
#  ('only', 114),
#  ('several', 114),
#  ('aneurysm', 113),
#  ('intrahepatic', 113),
#  ('x', 113),
#  ('retroperitoneal', 113),
#  ('gas', 113),
#  ('middle', 113),
#  ('minimal', 113),
#  ('coils', 112),
#  ('cava', 112),
#  ('apical', 112),
#  ('vena', 112),
#  ('finding', 112),
#  ('infiltrate', 112),
#  ('vessels', 112),
#  ('pre', 112),
#  ('tumor', 112),
#  ('tissue', 111),
#  ('pa', 111),
#  ('clear', 111),
#  ('decrease', 110),
#  ('fractures', 110),
#  ('bilaterally', 110),
#  ('resolution', 110),
#  ('demonstrated', 110),
#  ('needle', 109),
#  ('progression', 109),
#  ('iliac', 108),
#  ('narrowing', 107),
#  ('related', 107),
#  ('hours', 107),
#  ('shunt', 107),
#  ('100cc', 107),
#  ('36', 107),
#  ('injury', 106),
#  ('pelvic', 106),
#  ('ionic', 106),
#  ('enlarged', 106),
#  ('known', 106),
#  ('views', 105),
#  ('kidneys', 105),
#  ('representing', 105),
#  ('lymph', 105),
#  ('should', 104),
#  ('degree', 104),
#  ('infection', 104),
#  ('distinct', 103),
#  ('reconstruction', 103),
#  ('contribution', 102),
#  ('dilated', 101),
#  ('removed', 101),
#  ('additional', 101),
#  ('although', 101),
#  ('major', 101),
#  ('pt', 101),
#  ('would', 100),
#  ('remains', 100),
#  ('quadrant', 100),
#  ('graft', 100),
#  ('suggest', 99),
#  ('59', 99),
#  ('pericardial', 98),
#  ('tibial', 98),
#  ('residual', 98),
#  ('100', 98),
#  ('changed', 98),
#  ('levels', 97),
#  ('lobes', 97),
#  ('significantly', 97),
#  ('vs', 97),
#  ('throughout', 97),
#  ('thrombus', 97),
#  ('8', 97),
#  ('multifocal', 97),
#  ('continued', 97),
#  ('below', 96),
#  ('pancreas', 96),
#  ('note', 96),
#  ('midline', 96),
#  ('10', 96),
#  ('brachial', 96),
#  ('ett', 96),
#  ('procedural', 96),
#  ('passed', 96),
#  ('magnevist', 95),
#  ('atrium', 94),
#  ('wires', 94),
#  ('infectious', 93),
#  ('aspect', 93),
#  ('loculated', 93),
#  ('jejunum', 92),
#  ('lumbar', 92),
#  ('a.m', 92),
#  ('appear', 91),
#  ('followup', 91),
#  ('inferior', 91),
#  ('infarction', 90),
#  ('cta', 90),
#  ('cirrhosis', 90),
#  ('between', 90),
#  ('degenerative', 90),
#  ('arterial', 90),
#  ('bleeding', 89),
#  ('balloon', 89),
#  ('effect', 89),
#  ('opacification', 89),
#  ('copd', 89),
#  ('increasing', 88),
#  ('segment', 88),
#  ('duodenum', 88),
#  ('neck', 88),
#  ('infarct', 88),
#  ('coronary', 88),
#  ('diaphragm', 88),
#  ('angioplasty', 87),
#  ('suggestive', 86),
#  ('t9', 86),
#  ('versus', 86),
#  ('volume', 86),
#  ('swan-ganz', 86),
#  ('fever', 86),
#  ('collections', 85),
#  ('marked', 85),
#  ('positioning', 85),
#  ('nodule', 85),
#  ('cancer', 84),
#  ('77', 84),
#  ('fistula', 84),
#  ('represents', 83),
#  ('appropriate', 83),
#  ('drain', 83),
#  ('material', 83),
#  ('complete', 82),
#  ('studies', 82),
#  ('prominent', 82),
#  ('measuring', 82),
#  ('r', 82),
#  ('l', 82),
#  ('any', 81),
#  ('m.d', 81),
#  ('primary', 81),
#  ('multiplanar', 81),
#  ('clinically', 81),
#  ('spleen', 81),
#  ('fx', 80),
#  ('partially', 80),
#  ('76', 80),
#  ('av', 80),
#  ('radiologist', 79),
#  ('good', 79),
#  ('possibly', 79),
#  ('hip', 78),
#  ('intubated', 78),
#  ('access', 78),
#  ('elevated', 78),
#  ('bladder', 78),
#  ('attenuation', 78),
#  ('tract', 77),
#  ('metastasis', 77),
#  ('splenic', 77),
#  ('blood', 77),
#  ('end', 77),
#  ('foot', 77),
#  ('inflammatory', 77),
#  ('layering', 77),
#  ('dialysis', 76),
#  ('namepattern1', 76),
#  ('40', 75),
#  ('cerebral', 75),
#  ('t1', 75),
#  ('parietal', 75),
#  ('just', 75),
#  ('foci', 74),
#  ('collapse', 74),
#  ('cc', 74),
#  ('under', 74),
#  ('external', 73),
#  ('motion', 73),
#  ('cord', 73),
#  ('stranding', 73),
#  ('dated', 73),
#  ('peg', 73),
#  ('85', 73),
#  ('space', 73),
#  ('terminates', 73),
#  ('overall', 72),
#  ('surgical', 72),
#  ('near', 72),
#  ('pna', 71),
#  ('follow', 71),
#  ('abnormality', 71),
#  ('lumen', 71),
#  ('demonstrates', 70),
#  ('structures', 70),
#  ('trauma', 70),
#  ('incl', 70),
#  ('cabg', 70),
#  ('supply', 70),
#  ('standard', 69),
#  ('sided', 69),
#  ('tracheostomy', 69),
#  ('62', 69),
#  ('development', 69),
#  ('team', 69),
#  ('measures', 69),
#  ('site', 69),
#  ('t10', 69),
#  ('oral', 68),
#  ('overlying', 68),
#  ('masses', 68),
#  ('reconstructions', 68),
#  ('concerning', 67),
#  ('found', 67),
#  ('adrenal', 67),
#  ('difficult', 67),
#  ('hydronephrosis', 67),
#  ('branch', 67),
#  ('inf', 67),
#  ('metastases', 66),
#  ('perforation', 66),
#  ('7', 66),
#  ('bronchus', 66),
#  ('lat', 66),
#  ('p.m', 66),
#  ('14', 66),
#  ('axial', 66),
#  ('nodes', 66),
#  ('guidance', 66),
#  ('infiltrates', 66),
#  ('zone', 66),
#  ('bile', 66),
#  ('different', 65),
#  ('guid', 65),
#  ('patency', 65),
#  ('particles', 65),
#  ('differential', 65),
#  ('communicated', 65),
#  ('nonspecific', 65),
#  ('improving', 65),
#  ('bypass', 65),
#  ('interpretation', 64),
#  ('surrounding', 64),
#  ('presence', 64),
#  ('confirm', 64),
#  ('see', 64),
#  ('guided', 64),
#  ('varices', 64),
#  ('exclude', 64),
#  ('either', 64),
#  ('c1769', 64),
#  ('79', 64),
#  ('and/or', 64),
#  ('cyst', 64),
#  ('bone', 64),
#  ('sob', 64),
#  ('shift', 64),
#  ('enlargement', 64),
#  ('calcification', 63),
#  ('68', 63),
#  ('contraindications', 62),
#  ('abnormalities', 62),
#  ('pattern', 62),
#  ('parenchymal', 62),
#  ('namepattern4', 62),
#  ('mediastinum', 62),
#  ('initials', 62),
#  ('cervical', 62),
#  ('somewhat', 62),
#  ('recons', 62),
#  ('cysts', 61),
#  ('pigtail', 61),
#  ('image', 61),
#  ('perc', 61),
#  ('anastomosis', 61),
#  ('x-ray', 61),
#  ('second', 61),
#  ('order', 61),
#  ('including', 61),
#  ('had', 61),
#  ('white', 61),
#  ('pancreatic', 60),
#  ('respiratory', 60),
#  ('origin', 60),
#  ('very', 60),
#  ('setting', 60),
#  ('enhancing', 60),
#  ('fall', 60),
#  ('superimposed', 60),
#  ('pressure', 60),
#  ('ductal', 60),
#  ('films', 60),
#  ('variceal', 60),
#  ('50', 60),
#  ('pancreatitis', 60),
#  ('highly', 60),
#  ('cholecystitis', 59),
#  ('limits', 59),
#  ('ngt', 59),
#  ('administration', 58),
#  ('suspicious', 58),
#  ('four', 58),
#  ('medial', 58),
#  ('ca', 58),
#  ('vasculature', 57),
#  ('completely', 57),
#  ('popliteal', 57),
#  ('i', 57),
#  ('nodular', 57),
#  ('catheters', 57),
#  ('thrombosis', 57),
#  ('consult', 56),
#  ('75', 56),
#  ('infarcts', 56),
#  ('sagittal', 56),
#  ('radiographs', 56),
#  ('call', 56),
#  ('c1887', 56),
#  ('least', 56),
#  ('guiding', 56),
#  ('inf/perf', 56),
#  ('rib', 56),
#  ('showed', 56),
#  ('ventricle', 55),
#  ('ventricular', 55),
#  ('follow-up', 55),
#  ('occipital', 55),
#  ('t2', 55),
#  ('do', 55),
#  ('dvt', 55),
#  ('epidural', 55),
#  ('ischemia', 55),
#  ('exacerbation', 55),
#  ('possibility', 55),
#  ('hernia', 55),
#  ('preliminary', 55),
#  ('fluoroscopic', 55),
#  ('today', 55),
#  ('gadolin', 55),
#  ('silhouette', 54),
#  ('babygram', 54),
#  ('used', 54),
#  ('biopsy', 54),
#  ('etiology', 54),
#  ('t5', 54),
#  ('located', 54),
#  ('fluoro', 54),
#  ('calcifications', 54),
#  ('paracentesis', 54),
#  ('bases', 54),
#  ('intraabdominal', 54),
#  ('basilic', 54),
#  ('shows', 54),
#  ('system', 54),
#  ('pseudoaneurysm', 54),
#  ('included', 54),
#  ('node', 54),
#  ('o.r', 54),
#  ('available', 53),
#  ('around', 53),
#  ('osseous', 53),
#  ('gradient', 53),
#  ('reviewed', 53),
#  ('transcription', 53),
#  ('mailed', 53),
#  ('better', 53),
#  ('surgery', 53),
#  ('superficial', 53),
#  ('considered', 53),
#  ('overload', 52),
#  ('distally', 52),
#  ('using', 52),
#  ('aeration', 52),
#  ('hilar', 52),
#  ('among', 52),
#  ('studied', 52),
#  ('intravenous', 52),
#  ('sternal', 52),
#  ('apparent', 52),
#  ('telephone', 52),
#  ('number', 52),
#  ('matter', 52),
#  ('remain', 52),
#  ('airspace', 52),
#  ('volumes', 52),
#  ('s', 52),
#  ('pva', 51),
#  ('hear', 51),
#  ('guide', 51),
#  ('suggesting', 51),
#  ('velocities', 51),
#  ('cardiopulmonary', 51),
#  ("it's", 51),
#  ('repeat', 51),
#  ('radline', 51),
#  ('orginate', 51),
#  ('carried', 51),
#  ('listen', 51),
#  ('embolizable', 51),
#  ('before', 51),
#  ('t5/6', 51),
#  ('embolism', 50),
#  ('stricture', 50),
#  ('loop', 50),
#  ('hospital', 50),
#  ('gadolinium', 50),
#  ('infant', 50),
#  ('herniation', 50),
#  ('though', 50),
#  ('concern', 50),
#  ('diffusion', 50),
#  ('overlies', 49),
#  ('approved', 49),
#  ('focus', 49),
#  ('sch', 49),
#  ('9', 49),
#  ('show', 49),
#  ('high', 49),
#  ('allowing', 48),
#  ('extravasation', 48),
#  ('deep', 48),
#  ('stroke', 48),
#  ('extension', 48),
#  ('perihilar', 48),
#  ('apex', 48),
#  ('moderately', 48),
#  ('beyond', 48),
#  ('calcified', 48),
#  ('per', 48),
#  ('name4', 48),
#  ('about', 48),
#  ('three', 48),
#  ('rectum', 48),
#  ('fields', 47),
#  ('embolus', 47),
#  ('positioned', 47),
#  ('hemithorax', 47),
#  ('asymmetric', 47),
#  ('short', 47),
#  ('early', 47),
#  ('joint', 47),
#  ('cerebellar', 47),
#  ('cv', 47),
#  ('demonstrate', 47),
#  ('irregular', 46),
#  ('peripheral', 46),
#  ('basal', 46),
#  ('axillary', 46),
#  ('artifact', 46),
#  ('cholelithiasis', 46),
#  ('dissection', 46),
#  ('terminating', 46),
#  ('injection', 46),
#  ('inferiorly', 46),
#  ('swelling', 46),
#  ('predominantly', 46),
#  ('temporal', 45),
#  ('gastrointestinal', 45),
#  ('injected', 45),
#  ('outflow', 45),
#  ('series', 45),
#  ('followed', 45),
#  ('sinus', 45),
#  ('vessel', 45),
#  ('addendum', 45),
#  ('conray', 45),
#  ('fr', 45),
#  ('upright', 45),
#  ('treatment', 45),
#  ('distribution', 45),
#  ('congestion', 44),
#  ('addition', 44),
#  ('intubation', 44),
#  ('atherosclerotic', 44),
#  ('during', 44),
#  ('disc', 44),
#  ('breath', 44),
#  ('helpful', 44),
#  ('diameter', 44),
#  ('f/u', 44),
#  ('name13', 44),
#  ('postoperative', 44),
#  ('brachiocephalic', 44),
#  ('immediately', 44),
#  ('all', 44),
#  ('back', 44),
#  ('subarachnoid', 44),
#  ('83', 43),
#  ('osteomyelitis', 43),
#  ('loss', 43),
#  ('arch', 43),
#  ('cell', 43),
#  ('canal', 43),
#  ('detected', 43),
#  ('recommend', 43),
#  ('esophagus', 43),
#  ('involvement', 43),
#  ('gastrojejunostomy', 43),
#  ('infusion', 43),
#  ('pe', 43),
#  ('traumatic', 43),
#  ('yo', 43),
#  ('intra-abdominal', 43),
#  ('nature', 43),
#  ('worrisome', 43),
#  ('still', 43),
#  ('attempt', 43),
#  ('total', 43),
#  ('30', 42),
#  ('pathology', 42),
#  ('need', 42),
#  ('projects', 42),
#  ('transjugular', 42),
#  ('trachea', 42),
#  ('51', 42),
#  ('days', 42),
#  ('angle', 42),
#  ('hemidiaphragm', 42),
#  ('similar', 42),
#  ('cath', 42),
#  ('complications', 42),
#  ('5-french', 42),
#  ('reduction', 41),
#  ('consolidations', 41),
#  ('84', 41),
#  ('internal-external', 41),
#  ('bodies', 41),
#  ('prominence', 41),
#  ('ards', 41),
#  ('defect', 41),
#  ('newborn', 41),
#  ('knee', 41),
#  ('codes', 41),
#  ('needs', 41),
#  ('shortness', 41),
#  ('thoracentesis', 41),
#  ('cpt', 41),
#  ('replacement', 41),
#  ('branches', 41),
#  ('cystic', 41),
#  ('alveolar', 41),
#  ('relatively', 41),
#  ('administered', 40),
#  ('rule', 40),
#  ('tunneled', 40),
#  ('tissues', 40),
#  ('worsened', 40),
#  ('protocol', 40),
#  ('include', 40),
#  ('elbow', 40),
#  ('source', 40),
#  ('esophageal', 40),
#  ('too', 40),
#  ('radiographic', 40),
#  ('taken', 40),
#  ('sigmoid', 40),
#  ('female', 40),
#  ('dictation', 40),
#  ('w/iv', 40),
#  ('percutaneous', 40),
#  ('anasarca', 40),
#  ('occluded', 40),
#  ('simple', 40),
#  ('pole', 39),
#  ('comment', 39),
#  ('name11', 39),
#  ('pattern1', 39),
#  ('differences', 39),
#  ('portosystemic', 39),
#  ('doppler', 39),
#  ('fossa', 39),
#  ('hypoxia', 39),
#  ('information', 39),
#  ('markedly', 39),
#  ('myocardial', 39),
#  ('gi', 39),
#  ('ileus', 38),
#  ('extent', 38),
#  ('persists', 38),
#  ('atrophy', 38),
#  ('5-mm', 38),
#  ('hypotension', 38),
#  ('linear', 38),
#  ('unit', 38),
#  ('appreciated', 38),
#  ('characterize', 38),
#  ('ivc', 38),
#  ('indicated', 38),
#  ('intraperitoneal', 37),
#  ('third', 37),
#  ('hypodensity', 37),
#  ('median', 37),
#  ...]

# %%
#essentially meaningless words are called stopwords
#usually remove these before you continue with creating vectors

from gensim.parsing.preprocessing import STOPWORDS
STOPWORDS
#gensim is not specific to medical text...
#it removes no, which is bad for medical text e.g. "no [bad thing]"
#can't use a generic stopword list
# Out:
# frozenset({'a',
#            'about',
#            'above',
#            'across',
#            'after',
#            'afterwards',
#            'again',
#            'against',
#            'all',
#            'almost',
#            'alone',
#            'along',
#            'already',
#            'also',
#            'although',
#            'always',
#            'am',
#            'among',
#            'amongst',
#            'amoungst',
#            'amount',
#            'an',
#            'and',
#            'another',
#            'any',
#            'anyhow',
#            'anyone',
#            'anything',
#            'anyway',
#            'anywhere',
#            'are',
#            'around',
#            'as',
#            'at',
#            'back',
#            'be',
#            'became',
#            'because',
#            'become',
#            'becomes',
#            'becoming',
#            'been',
#            'before',
#            'beforehand',
#            'behind',
#            'being',
#            'below',
#            'beside',
#            'besides',
#            'between',
#            'beyond',
#            'bill',
#            'both',
#            'bottom',
#            'but',
#            'by',
#            'call',
#            'can',
#            'cannot',
#            'cant',
#            'co',
#            'computer',
#            'con',
#            'could',
#            'couldnt',
#            'cry',
#            'de',
#            'describe',
#            'detail',
#            'did',
#            'didn',
#            'do',
#            'does',
#            'doesn',
#            'doing',
#            'don',
#            'done',
#            'down',
#            'due',
#            'during',
#            'each',
#            'eg',
#            'eight',
#            'either',
#            'eleven',
#            'else',
#            'elsewhere',
#            'empty',
#            'enough',
#            'etc',
#            'even',
#            'ever',
#            'every',
#            'everyone',
#            'everything',
#            'everywhere',
#            'except',
#            'few',
#            'fifteen',
#            'fify',
#            'fill',
#            'find',
#            'fire',
#            'first',
#            'five',
#            'for',
#            'former',
#            'formerly',
#            'forty',
#            'found',
#            'four',
#            'from',
#            'front',
#            'full',
#            'further',
#            'get',
#            'give',
#            'go',
#            'had',
#            'has',
#            'hasnt',
#            'have',
#            'he',
#            'hence',
#            'her',
#            'here',
#            'hereafter',
#            'hereby',
#            'herein',
#            'hereupon',
#            'hers',
#            'herself',
#            'him',
#            'himself',
#            'his',
#            'how',
#            'however',
#            'hundred',
#            'i',
#            'ie',
#            'if',
#            'in',
#            'inc',
#            'indeed',
#            'interest',
#            'into',
#            'is',
#            'it',
#            'its',
#            'itself',
#            'just',
#            'keep',
#            'kg',
#            'km',
#            'last',
#            'latter',
#            'latterly',
#            'least',
#            'less',
#            'ltd',
#            'made',
#            'make',
#            'many',
#            'may',
#            'me',
#            'meanwhile',
#            'might',
#            'mill',
#            'mine',
#            'more',
#            'moreover',
#            'most',
#            'mostly',
#            'move',
#            'much',
#            'must',
#            'my',
#            'myself',
#            'name',
#            'namely',
#            'neither',
#            'never',
#            'nevertheless',
#            'next',
#            'nine',
#            'no',
#            'nobody',
#            'none',
#            'noone',
#            'nor',
#            'not',
#            'nothing',
#            'now',
#            'nowhere',
#            'of',
#            'off',
#            'often',
#            'on',
#            'once',
#            'one',
#            'only',
#            'onto',
#            'or',
#            'other',
#            'others',
#            'otherwise',
#            'our',
#            'ours',
#            'ourselves',
#            'out',
#            'over',
#            'own',
#            'part',
#            'per',
#            'perhaps',
#            'please',
#            'put',
#            'quite',
#            'rather',
#            're',
#            'really',
#            'regarding',
#            'same',
#            'say',
#            'see',
#            'seem',
#            'seemed',
#            'seeming',
#            'seems',
#            'serious',
#            'several',
#            'she',
#            'should',
#            'show',
#            'side',
#            'since',
#            'sincere',
#            'six',
#            'sixty',
#            'so',
#            'some',
#            'somehow',
#            'someone',
#            'something',
#            'sometime',
#            'sometimes',
#            'somewhere',
#            'still',
#            'such',
#            'system',
#            'take',
#            'ten',
#            'than',
#            'that',
#            'the',
#            'their',
#            'them',
#            'themselves',
#            'then',
#            'thence',
#            'there',
#            'thereafter',
#            'thereby',
#            'therefore',
#            'therein',
#            'thereupon',
#            'these',
#            'they',
#            'thick',
#            'thin',
#            'third',
#            'this',
#            'those',
#            'though',
#            'three',
#            'through',
#            'throughout',
#            'thru',
#            'thus',
#            'to',
#            'together',
#            'too',
#            'top',
#            'toward',
#            'towards',
#            'twelve',
#            'twenty',
#            'two',
#            'un',
#            'under',
#            'unless',
#            'until',
#            'up',
#            'upon',
#            'us',
#            'used',
#            'using',
#            'various',
#            'very',
#            'via',
#            'was',
#            'we',
#            'well',
#            'were',
#            'what',
#            'whatever',
#            'when',
#            'whence',
#            'whenever',
#            'where',
#            'whereafter',
#            'whereas',
#            'whereby',
#            'wherein',
#            'whereupon',
#            'wherever',
#            'whether',
#            'which',
#            'while',
#            'whither',
#            'who',
#            'whoever',
#            'whole',
#            'whom',
#            'whose',
#            'why',
#            'will',
#            'with',
#            'within',
#            'without',
#            'would',
#            'yet',
#            'you',
#            'your',
#            'yours',
#            'yourself',
#            'yourselves'})

# %%
my_stop_words = frozenset(["a", "am", "an", "and", "are", "as", "at", "be", "for", "is", "the", "is", "of", "which", ])

# %% [markdown]
# ## Create a single string with all the reports
#
# #### Hints, etc.
# * Use List Comprehension
# * Use string joins
# * Iterate over the rows of the data frame

# %% [markdown]
# ### Define a vector space for the radiology corpus
#
# #### Hints
#
# 1. How would you build a corpus from words only occuring more than N times?

# %% [markdown]
# ### Create a new column named `"impression no stops"` where [stop words](https://en.wikipedia.org/wiki/Stop_words) have been dropped from the impression
#
# * The gensim package has stop words defined (``from gensim.parsing.preprocessing import STOPWORDS``
#
# #### Hints
# 1. Do you agree with dropping all the stop words?
# 1. How could we create a new stopwords frozen set absent the terms we wan't to keep (double negative?)
# 1. You could use a regular expressions substitution or token the report first and operate on the list of words.

# %%
rad_data["impression no stops"] = \
rad_data.apply(lambda row: \
               " ".join([word for word in row["impression"].split() if word not in my_stop_words]), axis=1)

# %%
rad_data.iloc[0]["impression"]
# Out:
# "\n\n\n     date 10:53 am\n     mr head w & w/o contrast; mr contrast gadolin                   clip # clip\n     reason: r icb and hx brain mets - eval - also with dwi for cva do mr\n      contrast: magnevist amt: 15\n     \n\n     underlying medical condition:\n      [**age over 90 **] year old woman with lung ca- mets to brain                                   \n     reason for this examination:\n      r icb and hx brain mets - eval - also with dwi for cva do mri both with and \n      without contast please\n     \n\n                                     final report\n     examination:  mri of the brain with and without gadolinium.\n     \n     indication:  [**age over 90 **] year old woman with lung cancer and right intracranial bleed\n     and history of brain metastases.  please evaluate for acute infarct.\n     \n     technique:  multiplanar t1 and t2-weighted images of the brain with gadolinium\n     according to standard departmental protocol.  no prior study for comparison.\n     \n     findings:  on diffusion-weighted images there is a small area of restricted\n     diffusion along the falx within the left occipitotemporal lobe.  it is also\n     bright on flair-weighted images and may represent a subacute infarct. clinical\n     correlation is recommended.  on gradient echo images there is a large area of\n     intraparenchymal hemorrhage within the right parietal lobe and left thalamus\n     which following administration of gadolinium reveals ring-enhancing lesions.\n     these are suspicious for hemorrhagic metastases given the patient's history.\n     additional ring-enhancing lesions throughout the supra- and infratentorial\n     compartments are visualized.  there is a moderate amount of peritumoral edema\n     involving the right parietal lobe lesion in addition to a second right\n     parietal lesion along the falx high in the vertex.  the other areas of\n     metastases reveal a minimal amount of peritumoral edema.\n     \n\n"

# %%
rad_data.iloc[0]["impression no stops"]
# Out:
# "date 10:53 mr head w & w/o contrast; mr contrast gadolin clip # clip reason: r icb hx brain mets - eval - also with dwi cva do mr contrast: magnevist amt: 15 underlying medical condition: [**age over 90 **] year old woman with lung ca- mets to brain reason this examination: r icb hx brain mets - eval - also with dwi cva do mri both with without contast please final report examination: mri brain with without gadolinium. indication: [**age over 90 **] year old woman with lung cancer right intracranial bleed history brain metastases. please evaluate acute infarct. technique: multiplanar t1 t2-weighted images brain with gadolinium according to standard departmental protocol. no prior study comparison. findings: on diffusion-weighted images there small area restricted diffusion along falx within left occipitotemporal lobe. it also bright on flair-weighted images may represent subacute infarct. clinical correlation recommended. on gradient echo images there large area intraparenchymal hemorrhage within right parietal lobe left thalamus following administration gadolinium reveals ring-enhancing lesions. these suspicious hemorrhagic metastases given patient's history. additional ring-enhancing lesions throughout supra- infratentorial compartments visualized. there moderate amount peritumoral edema involving right parietal lobe lesion in addition to second right parietal lesion along falx high in vertex. other areas metastases reveal minimal amount peritumoral edema."

# %% [markdown]
# ### What are the unique words in our vocabulary?

# %%
unique_impression_words = set(TextBlob(" ".join(rad_data["impression no stops"])).words)

# %% [markdown]
# ### We'll create a vocabulary with `zip` and `dict`

# %%
word_map = dict(zip(unique_impression_words,range(len(unique_impression_words))))

# %%
len(word_map)
# Out:
# 8479

# %%
word_map
# Out:
# {'75625': 743,
#  'centra': 0,
#  'variant': 7028,
#  'ea': 1,
#  'silhouette': 4267,
#  'oral': 4268,
#  'pseudo-obstruction': 4269,
#  'perforated': 8187,
#  'workup': 5650,
#  '2915-9-2': 2,
#  'pain': 3,
#  'part': 4271,
#  '78-year-odl': 4,
#  'sachs': 4273,
#  'tomorrow': 4274,
#  'regarding': 7763,
#  'pronounced': 5,
#  'handed': 6,
#  't12': 8,
#  '3:52': 4276,
#  'flouroscopic': 4277,
#  '9:28': 9,
#  'should': 10,
#  'regard': 11,
#  'stones/sludge/cbd': 5558,
#  'symmetry': 12,
#  'unfolded': 4278,
#  'lefet': 13,
#  '141': 4279,
#  'fluctuating': 4280,
#  'caring': 14,
#  '2558-5-25': 4281,
#  '1947': 15,
#  'top': 16,
#  '143': 18,
#  'making': 7765,
#  'abnormally': 4283,
#  'bradycardia': 19,
#  'porta': 4270,
#  'panniculitis': 20,
#  '258': 4287,
#  '2271': 21,
#  'does': 22,
#  'underperfusion': 23,
#  'nondependent': 24,
#  'thrombosis': 3536,
#  'mmp': 25,
#  'lesion': 26,
#  'towards': 27,
#  'ipf': 4288,
#  'cxrs': 29,
#  'corresponding': 4289,
#  'west': 2756,
#  'jp': 32,
#  'soluble': 33,
#  'ct': 4293,
#  'marker': 7032,
#  'transfixing': 1218,
#  'february': 4272,
#  '2-5': 4295,
#  '13:00': 4296,
#  '12:49': 4298,
#  '7:39': 4300,
#  'ear': 34,
#  'created': 35,
#  'serial': 7034,
#  'would': 36,
#  'prosthesis': 4302,
#  "n't": 4303,
#  'undergoing': 38,
#  '225': 39,
#  'endograft': 40,
#  'r-sided': 4305,
#  'rewire': 41,
#  '2520-7-25': 4307,
#  'consult': 42,
#  'pva': 4308,
#  'uninterpretable': 4309,
#  'detail': 43,
#  'pseudoaneurysmal': 44,
#  '12:09': 2276,
#  'pyeloric': 5656,
#  'overload': 45,
#  'inch': 5928,
#  'supratentorial': 46,
#  '3350-10-18': 47,
#  'reviewed': 6331,
#  'cub': 48,
#  '8:10': 49,
#  'recto-sigmoid': 50,
#  '2847-6-29': 51,
#  '172': 52,
#  'tolerating': 53,
#  '1341': 2068,
#  '10292': 54,
#  'plct': 4977,
#  'obliterates': 55,
#  'conjunction': 4312,
#  '2915-7-12': 4313,
#  'entering': 4314,
#  'convexities': 5658,
#  'leftclip': 56,
#  'coming': 57,
#  'extremities': 7038,
#  '12:24': 59,
#  '3:45': 4315,
#  '87': 61,
#  'lobar': 62,
#  'patient': 63,
#  '5-8': 4317,
#  'infrahilar': 4318,
#  'representa': 5659,
#  'gentleman': 4319,
#  'moderate': 64,
#  'characterize': 7040,
#  'ir': 4321,
#  'interfissural': 4322,
#  'ruq': 65,
#  'radii': 4323,
#  'vena': 8145,
#  '1/2': 6953,
#  'story': 67,
#  '2617-10-24': 68,
#  'overall': 69,
#  '2798-11-3': 71,
#  'bp': 73,
#  'temporal-parietal': 4324,
#  '2847-4-22': 4325,
#  '3131-12-3': 4326,
#  'acetabular': 74,
#  'thrive': 5661,
#  'ps': 4327,
#  'multiple': 4328,
#  'clinical': 4329,
#  'auscultory': 5125,
#  'cardiopulm': 75,
#  'wants': 7773,
#  'post-tpa': 76,
#  'hyper-echoic': 77,
#  'intr': 78,
#  'haste': 4333,
#  '442': 79,
#  'tf': 5665,
#  'paramedian': 4334,
#  'pulm': 80,
#  '3131-5-13': 4335,
#  'aware': 4336,
#  'name': 4337,
#  '6:16': 82,
#  'intraperitoneal': 83,
#  'iliofemoral': 84,
#  'ab': 85,
#  'complication': 4338,
#  '160': 86,
#  'tenderness': 88,
#  'improvement/resolution': 7725,
#  'succesful': 4339,
#  '6-cm': 4340,
#  'fevers': 4341,
#  'staples': 89,
#  '3233-9-20': 92,
#  'nkg': 91,
#  'abutting': 2321,
#  'solitary': 4343,
#  'structure': 95,
#  'post-pyloric': 4344,
#  'tuberosity': 4345,
#  'spatial': 4346,
#  '7:20': 96,
#  'hyperflexion': 99,
#  'name9': 98,
#  'crackles': 4348,
#  'contraindications': 100,
#  'alone': 1394,
#  'increasing': 4349,
#  'spaces': 4350,
#  'redemonstrates': 4351,
#  'ratios': 4352,
#  'hypoalbuminemic': 4353,
#  'ant.plan': 4354,
#  'now': 101,
#  'contacting': 7050,
#  'feding': 102,
#  '12-26': 4356,
#  '87-year-old': 103,
#  'measure': 5503,
#  '8:11': 4282,
#  'cr': 7463,
#  'hemidiaphgram': 17,
#  'stripping': 104,
#  'segment': 105,
#  'pole': 4357,
#  'mediansternotomy': 106,
#  'mid/central': 2775,
#  '10:45': 107,
#  'failed': 108,
#  'sq': 110,
#  '10:14': 4360,
#  'wand': 112,
#  'le': 4361,
#  '9:41': 113,
#  'aberrant': 114,
#  'scan': 8368,
#  'accommodate': 115,
#  '71-year-old': 116,
#  'probe': 7779,
#  'adajcent': 4364,
#  'malignan': 117,
#  'mildly': 7326,
#  '774': 118,
#  '3345-1-3': 4285,
#  'soft-tissue': 4365,
#  'enterocolitis': 119,
#  '11/28': 120,
#  '10.6': 4367,
#  '7-25': 121,
#  '3095-8-13': 4286,
#  'apposition': 122,
#  '32': 123,
#  '3:36': 7781,
#  'administered': 125,
#  '11:25': 126,
#  'peeling': 127,
#  'oriented': 128,
#  'width': 5847,
#  'locule': 4369,
#  'diminishes': 7257,
#  '2pm': 2605,
#  'pet': 4370,
#  'electronically': 4371,
#  'hypodensity': 129,
#  'aspiration': 4372,
#  'pacer': 4373,
#  'injury': 4375,
#  'fl': 8428,
#  'actual': 130,
#  'invading': 131,
#  'one': 4377,
#  'hemicolectomy': 132,
#  'query': 4379,
#  'superior': 133,
#  'aspirated': 4381,
#  'imaging': 134,
#  'helical': 6344,
#  'intrahepatic/extrahepatic': 135,
#  'determined': 6346,
#  'grafting': 4383,
#  '12:14': 136,
#  '7:08': 137,
#  '5:08': 138,
#  'omniflush': 139,
#  'effective': 4384,
#  'modality': 140,
#  'incident': 141,
#  'popliteal/tibial': 6360,
#  'peak': 4386,
#  'over': 4387,
#  'fifth': 142,
#  'temps': 143,
#  'character': 4388,
#  'extrapontine': 4389,
#  'atlantoaxial': 4390,
#  'intermedius': 4391,
#  'locking': 144,
#  'atherosclerosis': 696,
#  'barely': 30,
#  '5-27': 145,
#  'film': 146,
#  'portovenous': 147,
#  'post-procedure': 7786,
#  '3082-1-18': 4393,
#  'ascitis': 4394,
#  'mdct': 149,
#  '11:46': 3549,
#  'ankylosis': 6348,
#  '2816-10-26': 4396,
#  'leaking': 150,
#  'sbe': 151,
#  '1999': 4397,
#  'gangrene': 152,
#  'tubes': 4398,
#  'ankylosing': 154,
#  'blead': 155,
#  'output': 4292,
#  'little': 4399,
#  'flouroscopy': 4400,
#  'rule': 4401,
#  'two-lumen': 4294,
#  '14:20': 156,
#  'als': 157,
#  'tip': 158,
#  'curve': 159,
#  'earlier': 160,
#  'uncomplicated': 4403,
#  'congestion': 161,
#  '1.06': 4404,
#  'vigorous': 5686,
#  '1pm': 162,
#  'ng-tube': 163,
#  '11-1': 164,
#  'en': 165,
#  'microcoils': 4405,
#  'name10': 6522,
#  'acidosis': 166,
#  'shadow': 4407,
#  'orientation': 167,
#  '12:54': 4408,
#  '3074-5-7': 168,
#  'graded': 4410,
#  'l4-l5': 169,
#  'neurosurgery': 7561,
#  'coughing': 4411,
#  'pa/lateral': 171,
#  'severely': 4414,
#  'effu': 6341,
#  '70s': 4297,
#  'antral/pyloric': 4415,
#  '9:58': 8314,
#  'streaky': 4416,
#  '2806-12-21': 4418,
#  'im': 702,
#  'x4': 4420,
#  'subclavian': 4421,
#  'implant': 4423,
#  'air/sbft': 175,
#  'becasue': 4299,
#  '75': 4424,
#  'plethora': 176,
#  'aneurysm': 177,
#  '2512-3-15': 6355,
#  'here': 4425,
#  '2501-11-19': 179,
#  'tree': 180,
#  'hepatitis': 2089,
#  'three-dimensional': 181,
#  '9:03': 4426,
#  'tract': 182,
#  '3251-5-6': 4427,
#  'assess': 4428,
#  'cellular': 703,
#  'cauda': 183,
#  '2-cm': 4301,
#  '55cc': 4997,
#  'artifacts': 6540,
#  '2815-11-28': 5692,
#  'reoccurred': 4432,
#  'l4-5': 2191,
#  'hemorrahge': 4433,
#  '121': 4434,
#  'icb': 184,
#  'int.shth': 4435,
#  'coiled': 4436,
#  'five': 4438,
#  '11:50': 186,
#  '1-14': 187,
#  'mid-svc': 4440,
#  '5-25': 6502,
#  '11242': 4441,
#  '2816-8-30': 4442,
#  'collateral': 188,
#  '2293': 189,
#  'postion': 4443,
#  'refused': 7792,
#  'cistern': 4444,
#  'outlined': 37,
#  'amt': 190,
#  'trending': 4060,
#  'loculation': 4445,
#  '3034-6-13': 191,
#  'below-knee': 7908,
#  'flare': 192,
#  'intervals': 193,
#  '1.1': 4447,
#  '8-18': 194,
#  'retrospect': 4448,
#  'orbit': 5694,
#  '716': 195,
#  '3082-1-12': 196,
#  'circumferential': 197,
#  'mid-to-upper': 198,
#  '4-french': 4451,
#  'cephalus': 4452,
#  '3334-9-30': 199,
#  '8-13': 4453,
#  'neurosurgical': 200,
#  'fullness': 705,
#  'lamina': 201,
#  'thoracic': 706,
#  'start': 202,
#  'named': 678,
#  'gram': 4455,
#  'longitudinal': 4559,
#  'allowed': 4456,
#  'transcriptional': 204,
#  'para': 205,
#  'arms': 4457,
#  '75962': 4458,
#  'temporo-occipital': 4459,
#  'inflitrate': 206,
#  'introducer': 8172,
#  '2948-9-24': 207,
#  '3055-5-28': 4460,
#  'duodenum': 7064,
#  'completion': 208,
#  'dr': 209,
#  '3976': 4461,
#  '4:34': 210,
#  'lactate': 4462,
#  'nuclei': 212,
#  '11-week-old': 213,
#  'saphenous': 4463,
#  'fundus': 4464,
#  'prevertebral': 215,
#  'salvageable': 2796,
#  '642': 3562,
#  '3331170': 4466,
#  'determine': 216,
#  'pneumotorax': 217,
#  'sterile': 218,
#  'intratrochanteric': 219,
#  'atrium': 4469,
#  'fatty': 220,
#  'o': 223,
#  'zilver': 222,
#  'pelvis': 224,
#  'becomes': 226,
#  'c7': 4475,
#  'extent': 4476,
#  'sudden': 7067,
#  'by': 4479,
#  'cervicomedullary': 227,
#  'hip': 228,
#  'erosive': 229,
#  'appreciably': 230,
#  'coned': 231,
#  'replace': 232,
#  'predominance': 4481,
#  'unknown': 3568,
#  'aortoenteric': 4482,
#  '0.32': 233,
#  'c5': 234,
#  'ivh': 235,
#  'single': 236,
#  'avg': 1723,
#  'pacer/defibrillator': 711,
#  'accompanying': 237,
#  'extravasation': 4485,
#  'important': 239,
#  'reformats': 7502,
#  'oropharynx': 4486,
#  'acom': 241,
#  '3109-6-16': 5604,
#  'follow-through': 242,
#  '2559-3-24': 243,
#  'meningeal': 244,
#  'intact': 4487,
#  'infectious': 4488,
#  'unerupted': 5662,
#  'intraventricular': 4489,
#  'pet-ct': 245,
#  'svc/right': 246,
#  '8119': 247,
#  'subarticular': 248,
#  '0.27': 4495,
#  'lll': 250,
#  '6:51': 2103,
#  '2b': 251,
#  '2141': 8319,
#  'affecting': 4497,
#  'ardsnet': 4498,
#  'asymmetrical': 4342,
#  'peribronchovascular': 4499,
#  'away': 252,
#  'persistant': 4501,
#  'orifice': 4502,
#  '1:00': 4503,
#  'inversion': 253,
#  'tracheal': 254,
#  'efussion': 4504,
#  'yellow': 8040,
#  '7:57': 255,
#  'brachio': 256,
#  'shine': 257,
#  're': 4505,
#  '2567-1-22': 4507,
#  'neuropathic': 258,
#  'peripancreatic': 8306,
#  'column': 259,
#  'thrombus': 260,
#  'context': 261,
#  'it': 262,
#  'enteric': 2806,
#  'radio-opaque': 7803,
#  '2587': 4510,
#  'posteroinferior': 4511,
#  'encircling': 7857,
#  'post-removal': 4512,
#  'supplies': 4513,
#  'placment': 4514,
#  '12-13': 263,
#  '4:59': 4516,
#  'due': 4517,
#  'sideholes': 4310,
#  '180cc': 4518,
#  '4:57': 264,
#  'lines': 6684,
#  'metastasis': 265,
#  '5-18': 4521,
#  'preogression': 267,
#  '12513': 268,
#  'tendon': 4522,
#  '12-5': 4523,
#  '3344-11-17': 269,
#  '2:36': 4524,
#  'articulation': 7071,
#  'sesha': 270,
#  'added': 271,
#  '9:44': 4526,
#  '92': 6318,
#  'svc': 4527,
#  'babygram': 272,
#  'tubular': 273,
#  'reduction': 274,
#  'watershed': 275,
#  'ureterovesical': 276,
#  'proposed': 277,
#  '1.2': 4530,
#  'cleft': 278,
#  'request': 719,
#  '8-11': 279,
#  'persists': 280,
#  'lipohemarthrosis': 7808,
#  '4527': 4537,
#  'angoplast': 281,
#  'arches': 282,
#  'base': 283,
#  'identified': 4539,
#  'insular': 4311,
#  '22nd': 4540,
#  'visualization': 284,
#  'stataus': 287,
#  'dual': 286,
#  'upstream': 4541,
#  'therapeutic': 1419,
#  'adenomyomatosis': 288,
#  'mellitus': 6376,
#  't': 289,
#  '5:40': 8248,
#  '10/1': 290,
#  'effusion': 291,
#  'subcarinal': 292,
#  '6278': 7810,
#  '10:26': 293,
#  'significnt': 294,
#  'unstable': 295,
#  '1:08': 3580,
#  'lidocaine': 4545,
#  '10:40': 6983,
#  'biliary': 296,
#  '8:02': 4546,
#  '3.5': 4771,
#  'calcification': 297,
#  '47': 1423,
#  'well': 298,
#  'vault': 299,
#  '1:55': 4549,
#  'obscured': 723,
#  '8-12': 4551,
#  '10:07': 4552,
#  'control': 7075,
#  'getting': 4553,
#  '150cc': 7074,
#  'minor': 4554,
#  'after': 4555,
#  'hypotension-fever': 300,
#  '2989': 4556,
#  '9:40am': 4557,
#  'together': 301,
#  '3183-8-20': 4560,
#  'represents': 58,
#  'angiomas': 302,
#  '2951-10-18': 4562,
#  '12:34': 1427,
#  'tunneled': 4563,
#  'blockages': 303,
#  'calcific': 4564,
#  'subchondral': 304,
#  'hallux': 305,
#  'smh': 306,
#  'dry': 4565,
#  'gave': 4566,
#  'fields': 307,
#  'cm-long': 4567,
#  '5:26': 4568,
#  '15030': 308,
#  'accumulation': 309,
#  'contracted': 4569,
#  'spinous': 310,
#  'stroke': 311,
#  'probably': 312,
#  'ccu': 313,
#  '2817-4-20': 315,
#  'haze': 4570,
#  'arteriosis': 316,
#  '3430-3-8': 4571,
#  'deployed': 7813,
#  '13163': 317,
#  '5:10': 4572,
#  'let': 318,
#  'superadded': 4573,
#  'telephone/fax': 4574,
#  'repositioning': 6498,
#  'chest': 4575,
#  'mid-subclavian': 4576,
#  'lesions': 4577,
#  '10908': 4578,
#  '7:24': 5714,
#  '1.0': 5857,
#  'oblique': 4579,
#  'provider': 319,
#  '12:59': 2115,
#  'consolidations': 4581,
#  'torso': 4316,
#  'levels': 321,
#  '8:22': 322,
#  'sclerosis': 323,
#  'moderate-to': 6384,
#  'obstructive': 4583,
#  'malpositioning': 4584,
#  'cholangitis': 4585,
#  'ileus/obstruction': 324,
#  '3477-12-10': 7371,
#  'tender': 4587,
#  'colectomy': 4588,
#  'gastrostomy': 326,
#  'infarcts': 4590,
#  'versusimited': 4591,
#  'spike': 4592,
#  'addendum': 7084,
#  '3289-2-8': 5716,
#  'consolidation/atelectasis': 3582,
#  'unnamed': 4593,
#  'descent': 4594,
#  '533': 5918,
#  'severe': 4595,
#  'ulcer': 327,
#  'amputations': 328,
#  '7974': 4596,
#  'superifical': 329,
#  'osteonecrosis': 2117,
#  '2610-4-23': 330,
#  'connection': 4597,
#  'gastrojejunal': 4598,
#  'causing': 331,
#  'blockade': 332,
#  'o-g': 2815,
#  'attempt-related': 333,
#  'acromion': 4600,
#  'hypoalbuminemia': 4601,
#  'medullary': 334,
#  'hydropneum': 4320,
#  'retro': 335,
#  'develops': 4604,
#  'airways': 336,
#  'diminished': 4605,
#  'redemonstrated': 337,
#  'thecal': 338,
#  'tach': 4607,
#  'adverse': 5730,
#  'proximal/mid': 339,
#  'lbo': 4609,
#  'congestive': 6388,
#  'subclav': 340,
#  'hypodense': 734,
#  'accounted': 4610,
#  'allergic': 3482,
#  'interest': 5989,
#  'warranted': 735,
#  'shadows': 2850,
#  'bypass': 5556,
#  '636': 3995,
#  '6:09': 4612,
#  'evaluating': 4613,
#  '7:56': 341,
#  'quite': 342,
#  'endo-tracheal': 343,
#  '3-22': 4617,
#  'vws': 344,
#  'flowing': 66,
#  'inconclusive': 345,
#  '6:14': 346,
#  'nares': 4618,
#  'portable': 347,
#  'move': 7332,
#  'runs': 4619,
#  'microperforation': 348,
#  '11:27': 4620,
#  'since': 350,
#  'aided': 4621,
#  '1-26': 351,
#  'increases': 352,
#  'arteriography': 353,
#  'verify': 354,
#  'representative': 737,
#  'frontal': 355,
#  'core': 356,
#  'none': 7090,
#  'splenectomy': 4624,
#  'follow-up': 357,
#  'reccommended': 4625,
#  'angiodynamic': 4626,
#  'creatine': 4627,
#  'involved': 4628,
#  'pathology': 4629,
#  'acut': 358,
#  'supervised': 359,
#  'vertebrobasilar': 4630,
#  'plate': 4631,
#  'effn': 6396,
#  'patent': 4632,
#  'discusse': 8309,
#  'obl': 4633,
#  '2962-10-19': 70,
#  '11-4': 1170,
#  'hospital': 6960,
#  'consisting': 4634,
#  '6mm': 4635,
#  'diagnosed': 4636,
#  '8:08': 4637,
#  'laying': 7207,
#  'nonetheless': 360,
#  'optimal': 72,
#  'namepattern2': 4638,
#  'nrb': 8308,
#  'obtained': 4639,
#  '2513-2-10': 362,
#  'uncertain': 4641,
#  'achieve': 5722,
#  '4:09': 4642,
#  'obviously': 364,
#  'likelihood': 4643,
#  '3354-2-19': 4644,
#  'pneu': 4645,
#  '2:30': 6423,
#  '1:58': 365,
#  'suction': 4646,
#  "add'l": 4647,
#  'plane': 3469,
#  'proportion': 366,
#  'cage': 4648,
#  'position': 4649,
#  '54cm': 6805,
#  'conversion': 368,
#  'conspicuity': 369,
#  '2528-2-18': 371,
#  'mvmt': 372,
#  '4-30': 373,
#  'onset': 4651,
#  '7:53': 6759,
#  'else': 374,
#  'tertiary': 4652,
#  '55': 4653,
#  'accounting': 4654,
#  'intravas': 6649,
#  'anteriorly': 8208,
#  'arterie': 4655,
#  'midcervical': 375,
#  'scapulae': 4656,
#  'kinked': 7822,
#  '12921': 376,
#  'e': 377,
#  '5.2': 378,
#  '3-11': 379,
#  '3422-11-20': 381,
#  'l5': 4658,
#  'precarinal': 4659,
#  'enters': 4660,
#  '3475-3-22': 4661,
#  '5:24': 382,
#  'distally': 383,
#  'metaphysis': 384,
#  'bleeding': 4662,
#  'anesthesiologist': 385,
#  'tibiofemoral': 386,
#  'general': 387,
#  '2.1': 389,
#  'graft/sda': 4664,
#  'used': 4665,
#  '122': 4666,
#  '3407-3-21': 4667,
#  'hyperdynamic': 4668,
#  'successive': 2296,
#  '9:11': 4672,
#  'impaction': 390,
#  'hfo': 391,
#  'dilator': 392,
#  'duodenal': 394,
#  'small': 4673,
#  'statlock': 4674,
#  'happened': 4675,
#  'defined': 4676,
#  'seems': 4677,
#  'effort': 395,
#  'n-j': 396,
#  'angiogram': 4678,
#  'manifested': 4679,
#  'forms': 4680,
#  '06:06': 397,
#  'hyaline': 398,
#  'radiolucencies': 399,
#  'free': 4332,
#  'blade': 7980,
#  'recent': 400,
#  'required': 1441,
#  'cysts': 4683,
#  'available': 4684,
#  'requests': 401,
#  'transverse': 4686,
#  '3268-12-26': 402,
#  'spine': 5150,
#  '25-50': 404,
#  'placement/fluid': 5030,
#  'ureters': 405,
#  'specified': 2052,
#  'orders': 4688,
#  'desired': 4689,
#  'ptx': 406,
#  'fracture\\cath': 5607,
#  'visibility': 4690,
#  '1230': 4691,
#  'thinned': 407,
#  'along': 408,
#  '5:17': 4692,
#  'significantly-enlarged': 4693,
#  'non-coronary': 4694,
#  '7th': 4695,
#  'motor': 7100,
#  'intravenously': 7572,
#  'uti': 4696,
#  '60-69': 409,
#  'alignment': 410,
#  'hiatal': 411,
#  'placed': 7799,
#  '3354-2-8': 412,
#  '12:36': 413,
#  'need': 414,
#  'seventh': 415,
#  '24m': 6713,
#  'akinesis': 4701,
#  '3109-8-20': 7099,
#  'aspiration/dysphasia': 416,
#  '3981': 417,
#  'tissues': 418,
#  '7:49': 4702,
#  '8:54': 419,
#  'w/o': 4703,
#  'reperesent': 420,
#  'ue': 4704,
#  'mr': 4705,
#  '2645-3-20': 4706,
#  'avulsion': 421,
#  'progressively': 422,
#  'vii': 6409,
#  'then': 7372,
#  'amplitudes': 423,
#  'noting': 424,
#  'off': 4708,
#  'presesent': 425,
#  'flair-weighted': 4710,
#  '120': 426,
#  'bulkiness': 428,
#  'extrinsic': 429,
#  'details': 4712,
#  '1.3': 6410,
#  'persistently': 430,
#  'roundedimpression': 431,
#  'colon.just': 4714,
#  'demineralization': 4715,
#  'choroid': 433,
#  '545': 434,
#  'dictating': 6989,
#  'collaterals': 435,
#  'resolve': 6412,
#  'fluoroscopy': 4717,
#  'tympany': 436,
#  'complications': 4718,
#  '12:57': 4995,
#  'opacified': 7607,
#  'duplex': 6413,
#  'prep': 437,
#  'tourniquet': 7640,
#  '7:38': 4720,
#  'retropulsion': 438,
#  'elastic': 81,
#  '57': 439,
#  'simply': 7730,
#  'fracture': 8377,
#  '6-16': 2136,
#  '3295-12-1': 8280,
#  'initially': 1448,
#  'host': 440,
#  'feasible': 4723,
#  'unobstructed': 4725,
#  'influenza': 441,
#  'expla': 4726,
#  'cong': 4727,
#  '7mm': 4728,
#  '2:02': 4730,
#  'produce': 442,
#  'stabilized': 4731,
#  'reassessment': 444,
#  '2645-3-4': 4732,
#  'retrocrural': 4733,
#  '11:23': 4734,
#  'esophagogastrectomy': 4735,
#  '11:48': 4736,
#  '5:21': 445,
#  'cephalic': 448,
#  'stablility': 447,
#  'colons': 4737,
#  '2806-11-27': 450,
#  'perfusion/splenic': 451,
#  'hydropneumothorax': 8299,
#  'recovery': 87,
#  '1942': 4738,
#  'resuscitation': 452,
#  'serviceclip': 7840,
#  '75898': 453,
#  '3-31': 6083,
#  '9:51': 454,
#  'fenestrated': 4739,
#  'out': 7201,
#  '1-25': 7841,
#  '3480-5-18': 4740,
#  '12-9': 4741,
#  'shortness': 7105,
#  'overinflated': 4742,
#  'status': 455,
#  'e/f': 456,
#  'ud': 458,
#  '7298': 460,
#  'neuro': 4744,
#  'different': 462,
#  'dopplers': 463,
#  'femoris': 4745,
#  '5:02': 4746,
#  'infe': 4747,
#  '11:26': 4748,
#  'n/v': 4749,
#  '2502-7-18': 4750,
#  'dhs': 464,
#  'revealing': 465,
#  '4:08': 4751,
#  'cholecystectomy': 4752,
#  '5:14': 4753,
#  'deposit': 466,
#  '6.8': 467,
#  'trifurcation': 4755,
#  'compression': 5740,
#  'phalanx': 468,
#  'non-contrast': 90,
#  'post-radiation': 2843,
#  'immune': 4757,
#  'venography': 2144,
#  'minimal': 6715,
#  'guidewire': 7845,
#  'someone': 470,
#  'flank': 4758,
#  '3.5cm': 7846,
#  '2915-8-24': 94,
#  '2-17': 471,
#  '4-6': 4760,
#  'acquisition': 472,
#  'divisions': 6963,
#  '76f': 4761,
#  '2806-10-16': 3606,
#  '0.47': 4762,
#  'ectatic': 759,
#  'wall-to': 473,
#  'hypodensities': 761,
#  'appearance': 4764,
#  'leg': 7902,
#  'bifrontal': 475,
#  '4:01': 476,
#  '3:39': 4766,
#  '4:03': 477,
#  '0.28': 478,
#  'coursing': 5044,
#  'trach/vent': 479,
#  'appoximately': 6399,
#  'demylenation': 481,
#  'atrial': 4768,
#  'performing': 482,
#  'granulomatous': 4769,
#  'pelvic': 483,
#  'consolidative': 4772,
#  'tethering': 487,
#  'cast': 486,
#  'roof': 488,
#  '2649-5-29': 3608,
#  ...}

# %% [markdown]
# ### Save for use in our next notebook

# %%
import gzip
import pickle

with open("rad_data.pickle.gz", "wb") as f0:
    pickle.dump(rad_data, f0)

# %%
with open("rad_vocabulary.pickle.gz", "wb") as f0:
    pickle.dump(word_map, f0)
