# %% [markdown]
# # Phrases
#
# So far we have only thought in terms of single words: "lower", "lobe", "University", "of", "Utah". But in reality often times multiple words form one unit of thought: "University of Utah". Our word vectors will do a better job of representing our text if we fist recognize these phrases. We are going to use the [gensim](https://radimrehurek.com/gensim/models/phrases.html) package to detect and transform these phrases.
#
# For example, the sentence, "I am a faculty member in the departments of Biomedical Informatics and Radiology and Imaging Sciences at the University of Utah." would be transformed to "I am a faculty member in the departments of Biomedical_Informatics and Radiology_and_Imaging_Sciences at the University_of_Utah."
#
# "Biomedical_Informatics is an example of a **bigram phrase** and "University_of_Utah" is a **trigram phrase**. I guess "Radiology_and_Imaging_Sciences" is a quadgram phrase, but we will likely not try to detect phrases that long.

# %% [markdown]
# # Using the Gensim Phrases Module

# %%
# %matplotlib inline

# %%
from nose.tools import assert_almost_equal, assert_true, assert_equal, assert_raises
from numbers import Number

# %% [markdown]
# ## Upgrade to the latest version of gensim

# %%
#!conda install gensim -y

# %%
import pymysql
import pandas as pd
import getpass
from textblob import TextBlob
import re
from gensim.models.phrases import Phraser, Phrases
from IPython.display import clear_output, display, HTML
import pickle
import gzip
import seaborn as sns
from collections import Counter

# %%
import gensim
gensim.__version__
# Out:
# '3.1.0'

# %%
with open("rad_data.pickle.gz", "rb") as f0:
    rad_data = pickle.load(f0)
rad_data.head()
# Out:
#    subject_id  hadm_id                                               text  \
# 0          56  28766.0  \n\n\n     DATE: [**2644-1-17**] 10:53 AM\n   ...
# 1          56  28766.0  \n\n\n     DATE: [**2644-1-17**] 10:43 AM\n   ...
# 2          56  28766.0  \n\n\n     DATE: [**2644-1-17**] 6:37 AM\n    ...
# 3          56  28766.0  \n\n\n     DATE: [**2644-1-19**] 12:09 PM\n   ...
# 4          37  18052.0  \n\n\n     DATE: [**3264-8-14**] 6:06 AM\n    ...
#
#                                           impression  \
# 0  \n\n\n     date dd:dd am\n     mr head w & w/o...
# 1  impression:  stable appearance of right pariet...
# 2  impression:\n     \n     cardiomegaly and mild...
# 3  impression:\n     \n     marked improvement in...
# 4  impression: stable cardiomegaly with pulmonary...
#
#                                  impression no stops
# 0  date dd:dd mr head w & w/o contrast; mr contra...
# 1  impression: stable appearance right parietal l...
# 2  impression: cardiomegaly mild chf. nasogastric...
# 3  impression: marked improvement in left perihil...
# 4  impression: stable cardiomegaly with pulmonary...

# %%
with open("rad_vocabulary.pickle.gz", "rb") as f0:
    word_map = pickle.load(f0)

# %% [markdown]
# ## Let's recompute the impression column but don't convert to lowercase first

# %%
rad_data["impression"] = \
rad_data.apply(lambda row: get_impression(row["text"]), axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-ac952361ae1d> in <module>()
# ----> 1 rad_data["impression"] = rad_data.apply(lambda row: get_impression(row["text"]), axis=1)
#
# /opt/conda/lib/python3.5/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4150                     if reduce is None:
#    4151                         reduce = True
# -> 4152                     return self._apply_standard(f, axis, reduce=reduce)
#    4153             else:
#    4154                 return self._apply_broadcast(f, axis)
#
# /opt/conda/lib/python3.5/site-packages/pandas/core/frame.py in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4246             try:
#    4247                 for i, v in enumerate(series_gen):
# -> 4248                     results[i] = func(v)
#    4249                     keys.append(v.name)
#    4250             except Exception as e:
#
# <ipython-input-15-ac952361ae1d> in <lambda>(row)
# ----> 1 rad_data["impression"] = rad_data.apply(lambda row: get_impression(row["text"]), axis=1)
#
# NameError: ("name 'get_impression' is not defined", 'occurred at index 0')

# %%
rad_data.shape

# %% [markdown]
# ## What are our most common words
# ### Hint: use a `Counter` and `most_common`

# %% [markdown]
# ### Write a function to pre-process our text
#
# * Lower case?
# * Digits?
# * Strip dates/times?
# * stop words?

# %% [markdown]
# ### But first, write unit tests to test whether `preprocess` is functioning correctly
# #### Then write functionality to pass tests
#
# You might want to use the `strings` module

# %%
import string
string.ascii_uppercase
# Out:
# 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
date=re.compile(r"""((?P<month>[A-Z][a-z]{2,}(\.)?) (?P<day>[0-9]{1,2}))""")
last_name=re.compile(r"""(\[\*\*Last Name \((NamePattern|STitle)(\d+)?\) [0-9]*\*\*\])""")
clip = re.compile(r"""\[\*\*Clip Number \(Radiology\) \d+\*\*\]""")
date2 = re.compile(r"""DATE\: \[\*\*\d+-\d+-\d+\*\*\]""")
hospital=re.compile(r"""(\[\*\*Hospital \d+\*\*\])""")
unders = re.compile(r"""_{2,}""")

age2 = re.compile(r"""(?P<age>[0-9]+)(-|\s)y(ear(s)?|\.)(-|\s)?o(ld|\.)""")
age3 = re.compile(r"""\bage(d)? (?P<age>[0-9]+)""")
digits = re.compile(r"""\d""")
def age_in_decades(m):
    age = int(m.group("age"))
    
    return "[** Age in %ss**]"%(int(age/10)*10,)

age_in_decades(next(age2.finditer("74-year-old")))
# Out:
# '[** Age in 70s**]'

# %%
def preprocess(report):
    return digits.sub("d",unders.sub("\n",
               hospital.sub("HOSPITAL", 
                            date2.sub("DATE", 
                                      clip.sub("CLIP", 
                                               last_name.sub("LASTNAME", report))))))

# %%
def preprocess(txt):
    return txt.lower()

# %% [markdown]
# ## Do we return a string

# %%
assert_true(type(preprocess("my name"))== str)

# %% [markdown]
# ## Do we remove what we intend to?

# %%
assert_equal(
    set(string.ascii_uppercase).intersection(preprocess("The patient's name is Oscar Wilde.")), set([]))

# %%
assert_equal()

# %% [markdown]
# ### Use our `preprocess` function to create a new column "clean_impression"

# %%
rad_data["clean_impression_no_stops"] = \
rad_data.apply(lambda row: preprocess(row["impression no stops"]), axis = 1)
rad_data.head(5)
# Out:
#    subject_id  hadm_id                                               text  \
# 0          56  28766.0  \n\n\n     DATE: [**2644-1-17**] 10:53 AM\n   ...
# 1          56  28766.0  \n\n\n     DATE: [**2644-1-17**] 10:43 AM\n   ...
# 2          56  28766.0  \n\n\n     DATE: [**2644-1-17**] 6:37 AM\n    ...
# 3          56  28766.0  \n\n\n     DATE: [**2644-1-19**] 12:09 PM\n   ...
# 4          37  18052.0  \n\n\n     DATE: [**3264-8-14**] 6:06 AM\n    ...
#
#                                           impression  \
# 0  \n\n\n     date dd:dd am\n     mr head w & w/o...
# 1  impression:  stable appearance of right pariet...
# 2  impression:\n     \n     cardiomegaly and mild...
# 3  impression:\n     \n     marked improvement in...
# 4  impression: stable cardiomegaly with pulmonary...
#
#                                  impression no stops  \
# 0  date dd:dd mr head w & w/o contrast; mr contra...
# 1  impression: stable appearance right parietal l...
# 2  impression: cardiomegaly mild chf. nasogastric...
# 3  impression: marked improvement in left perihil...
# 4  impression: stable cardiomegaly with pulmonary...
#
#                            clean_impression_no_stops
# 0  date dd:dd mr head w & w/o contrast; mr contra...
# 1  impression: stable appearance right parietal l...
# 2  impression: cardiomegaly mild chf. nasogastric...
# 3  impression: marked improvement in left perihil...
# 4  impression: stable cardiomegaly with pulmonary...

# %% [markdown]
# ## Create a TextBlob from all the text in `rad_data["clean_impression"]`

# %%
blob = TextBlob(preprocess(" ".join(rad_data["clean_impression_no_stops"])))

#words = blob.words is slower because TextBlob hasn't computed anything until you ask for it

# %% [markdown]
# ## Write a function `train_phrases` that will train bigram and trigram detectors
#
# * We want to be able to ignore common terms in our phrase detection
# * We want to be able to specify the minimum number of occurences in our text to be considered a phrase
# * Return a dictionary of detectors

# %% [markdown]
# ### Write unit tests to determine whether `train_phrases` is working as expected

# %%
def train_phrases(blob, common_terms=None, min_count=5):
    sentences = [s.words for s in blob.sentences] #a phrase won't go outside a sentence boundary
                                                  #a list of lists of words
    if common_terms == None:
        common_terms = []
    phrases = Phrases(sentences, common_terms=common_terms, #don't let this interrupt the count 
                      min_count=min_count)
    bigram = Phraser(phrases)
    trigram = Phrases(bigram[sentences])
    
    return {"bigram":bigram, "trigram":trigram}

# %%
common_terms = ["of", "with", "without", "and", "or", "the", "a"]
generators = train_phrases(blob, common_terms=common_terms, min_count=5)

# %% [markdown]
# ### Write a function that takes a `TextBlob` instance and phrase generators and returns a string of text
# #### Unit tests first

# %%
def get_phrased_text(blob, generators):
    #must iterate across sentences
    return " ".join([w for s in blob.sentences for w in generators["trigram"][generators["bigram"][s.tokens]] ])

# %%
get_phrased_text(TextBlob("There is a mass in the left lower lobe, a 2.0 cm bvbs."), 
                generators)
# Out:
# /opt/conda/lib/python3.5/site-packages/gensim/models/phrases.py:431: UserWarning: For a faster implementation, use the gensim.models.phrases.Phraser class
#   warnings.warn("For a faster implementation, use the gensim.models.phrases.Phraser class")
# 'There is a mass in the left_lower_lobe'

# %%
TextBlob("There is a mass in the left lower lobe, a 2.0 cm bvbs.").tokens
# Out:
# WordList(['There', 'is', 'a', 'mass', 'in', 'the', 'left', 'lower', 'lobe', ',', 'a', '2.0', 'cm', 'bvbs', '.'])

# %%
assert_true()

# %%
assert_true()

# %%
phrased_txt = get_phrased_text(blob, generators)
# Out:
# /opt/conda/lib/python3.5/site-packages/gensim/models/phrases.py:431: UserWarning: For a faster implementation, use the gensim.models.phrases.Phraser class
#   warnings.warn("For a faster implementation, use the gensim.models.phrases.Phraser class")

# %% [markdown]
# ## What phrases did we detect?

# %%
found_phrases = set([w for w in TextBlob(phrased_txt).words if "_" in w])
print(len(found_phrases))
# Out:
# 2233

# %%
found_phrases
# Out:
# {'check_line_placement',
#  'r/o_pe',
#  'not_completely',
#  'central_venous_line',
#  'common_carotid',
#  'same_date',
#  'linear_atelectasis',
#  'tubes_remain',
#  'hip_fx',
#  'heart_enlarged',
#  'interval_improvement_in',
#  'standard_placement',
#  'gated_images',
#  'date_mailed',
#  'subcutaneous_edema',
#  'anterior_tibial_artery',
#  'ld_vertebral',
#  'ct_guided',
#  'low_lung',
#  'tube_coiled',
#  'one_view_portable',
#  'feeding_tube_placement',
#  'central_venous_catheter',
#  'fatty_infiltration',
#  'bone_destruction',
#  'd-d_cm',
#  'intrahepatic_ductal_dilatation',
#  'small_bowel_obstruction',
#  'supine_positioning',
#  'septum_pellucidum',
#  'has_been',
#  'it_unclear',
#  'abdomen_pelvis',
#  'could_reflect',
#  'bilateral_pulmonary_nodules',
#  'more_prominent',
#  'once_again',
#  'asymmetric_pulmonary_edema',
#  'dd_pm_date_mailed',
#  'well_visualized',
#  'sinus_disease',
#  'no_significant_change_since',
#  'bowel_ischemia',
#  'pa_cath',
#  'improvement_in',
#  'lateral_aspect',
#  'gated_wall_motion_images',
#  'may_helpful',
#  'bilateral_layering_pleural_effusions',
#  'dd.d_cm',
#  'level_ge_junction',
#  'brain_atrophy',
#  'upper_zone_redistribution',
#  'ap_radiograph',
#  'abnormal_uptake',
#  'catheter_terminates',
#  'comminuted_fracture',
#  'ejection_fraction',
#  'contrast_enhancement',
#  'in_satisfactory_position',
#  'thoracic_lumbar_spine',
#  'cava_right_atrium',
#  'should_advanced',
#  'midline_structures',
#  'subclavian_central_venous_catheter',
#  'field_view',
#  'slight_interval_increase_in',
#  'tip_projects',
#  'cta_abd',
#  'further_details',
#  'refer_to',
#  'pulmonary_vasculature',
#  'eval_pulm',
#  'thickened_gallbladder_wall',
#  'pleural_plaques',
#  'within_stomach',
#  'to_previous_study',
#  'atelectasis_versus',
#  'stable_cardiomegaly',
#  'not_included',
#  'improved_aeration',
#  'urine_output',
#  'spinal_stenosis',
#  'more_complete_assessment',
#  'altered_mental_status',
#  'ddd_cm/second',
#  'diagnostic_abnormality',
#  'conray_amt',
#  'not_well',
#  'esophageal_ca/sda_underlying_medical',
#  'left_ventricular_cavity_size',
#  'most_likely_represents',
#  'final_report_portable',
#  'head_w',
#  'chest_radiographs',
#  'not_well_visualized',
#  'call_radiology_listen_line',
#  'wires_incl',
#  'superior_cavoatrial_junction',
#  'inflammatory_change',
#  'again_note_made',
#  'portal_venous',
#  'multiple_pulmonary_nodules',
#  'pleural_fluid',
#  'status_post_cabg',
#  'not_changed',
#  'intraperitoneal_gas',
#  'new_onset',
#  'slightly_decreased',
#  'external_iliac',
#  'placement_x',
#  'associated_compressive',
#  'underlying_emphysema',
#  'supine_only',
#  'gj_tube',
#  'restricted_diffusion',
#  'left_retrocardiac_opacity',
#  'dd_year_old_male',
#  'distended_gallbladder',
#  'stenosis_origin',
#  'dddcc_final_report',
#  'cm_above_carina',
#  'distinct_procedural',
#  'minutes_fluoro',
#  'dr_lastname',
#  'several_days',
#  'basilar_opacities',
#  'almost_complete',
#  'ett_ngt',
#  'likely_related',
#  'ng_tube_extends_below',
#  'hepatic_veins',
#  'abnormal_fdg',
#  'views_skeleton',
#  'single_ap',
#  'lung_fields',
#  'no_contraindications_iv_contrast',
#  'technically_limited',
#  'large_small_bowel',
#  'incl_inf',
#  'please_perform',
#  'popliteal_vein',
#  'swan_ganz',
#  'clinically_indicated',
#  'were_taken',
#  'osseous_metastases',
#  'differential_diagnosis',
#  'short_interval',
#  'lower_lobe',
#  'slightly_smaller',
#  'plain_film',
#  'followed_by',
#  'coronary_artery_disease\\coronary_artery',
#  'picc_line_placment_sch',
#  'earlier_same_day',
#  'tumor_burden',
#  'claudication/sda_underlying_medical_condition',
#  'in_diameter',
#  'extends_below_diaphragm',
#  'passes_into',
#  'by_same',
#  'transition_point',
#  'multiplanar_reconstructions',
#  'internal_jugular_central_venous',
#  'please_check',
#  'abd_w',
#  'bowel_perforation',
#  'any_evidence',
#  'j_tube',
#  'mr_contrast_gadolin',
#  'low_attenuation',
#  'cord_compression',
#  'right_subclavian',
#  'has_not_changed',
#  'consistent_with',
#  'was_informed',
#  'aortic_stenosis',
#  'doppler_ultrasound',
#  'thoracic_lumbar',
#  'small_pleural_effusions',
#  'free_intraperitoneal_gas',
#  'in_good_position',
#  'acute_infarct',
#  'underlying_infection',
#  'cervical_spine',
#  'distal_common_bile',
#  'main_bronchus',
#  'note_that',
#  'previous_examination',
#  'pa_lateral',
#  'increase_in_size',
#  'lung_nodules',
#  'tip_swan-ganz_catheter_overlies',
#  'inflammatory_changes',
#  'osseous_structures',
#  'report_these_findings',
#  'dd_minutes_prior',
#  'dd_yo',
#  'bypass_graft',
#  'was_confirmed',
#  'mild_congestive_heart_failure',
#  'evidence_diverticulitis',
#  'were_communicated',
#  'no_evidence',
#  'portable_supine',
#  'dd_pm_mr_head',
#  'informed_consent',
#  'in_situ',
#  'enlarged_cardiac',
#  'earlier_today',
#  'overlies_region',
#  'no_evidence_pneumothorax',
#  'attenuation_lesions',
#  'distal_radius',
#  'feeding_tube',
#  'leptomeningeal_enhancement',
#  'ground-glass_opacity',
#  'no_acute_intracranial',
#  'myocardial_perfusion',
#  'lung_expansion',
#  'concerning_metastatic',
#  'were_relayed',
#  'heart_failure',
#  'elevated_creatinine-dehydration_underlying_medical',
#  'small_amount_ascites',
#  'follow_up_recommended',
#  'mid_lung_zone',
#  'air_fluid_levels',
#  'approximately_d.d_cm_above',
#  'low_density',
#  'mediastinal_lymph_nodes',
#  'distal_end_feeding_tube',
#  'worse_than',
#  'measuring_up_to',
#  'airspace_opacities',
#  'territorial_infarction',
#  'pulmonary_artery_catheter',
#  'same_day',
#  'common_hepatic',
#  'worsening_congestive',
#  'spinal_cord',
#  'moderate_sized',
#  'common_carotid_artery',
#  'from_prior_day',
#  'more_confluent',
#  'partially_reversible',
#  'sagittal_coronal',
#  'acute_intracranial',
#  'large_bowel',
#  'was_provided',
#  's/p_hepatico',
#  'shift_normally_midline_structures',
#  'moderate_amount_ascites',
#  'normal_wall_motion',
#  'recommended_to_exclude',
#  'us_abd',
#  'compression_fractures',
#  'without_complication',
#  'wall_thickening',
#  'resp_distress',
#  'erect_ap',
#  'likely_secondary_to',
#  'referring_physician',
#  'diffuse_bilateral',
#  'status_epilepticus',
#  'abnormal_signal',
#  'bowel_loops',
#  'without_evidence_diverticulitis',
#  'portable_chest_x-ray',
#  'mucosal_thickening',
#  'patchy_atelectasis',
#  'combined_alveolar_interstitial_pattern',
#  'previous_study_earlier_same',
#  'passed_through',
#  'compared_with_previous',
#  'contrast_reason',
#  'from_d.dd_cm',
#  'pulmonary_infiltrates',
#  'films_submitted',
#  'more_optimal_placement',
#  'partial_obstruction',
#  'portal_vein_patent',
#  'td_signal',
#  'upper_pole',
#  'bypass_surgery',
#  'depending_on',
#  'dd_minutes',
#  'has_worsened',
#  'lungs_clear',
#  'peroneal_artery',
#  'significant_change',
#  'comparison_made_to',
#  'dd_hours',
#  'stress_perfusion_images_reveal',
#  'further_evaluation',
#  'increased_tracer',
#  'involving_inferior',
#  'pulmonary_embolus',
#  'representing_atelectasis',
#  'that_may_represent',
#  'hours_earlier',
#  'underlying_pneumonia_can',
#  's/p_r',
#  'not_definitively',
#  'has_resolved',
#  'lobe_atelectasis/consolidation',
#  'myocardial_infarction',
#  'interval_worsening',
#  'compatible_with',
#  'second_portion_duodenum',
#  'known_history',
#  'chest_reviewed_compared_with_previous',
#  'dd_pm',
#  'no_evidence_pulmonary_embolism',
#  'lung_bases',
#  'compared_to_prior',
#  'in_standard_placements',
#  'tracer_uptake',
#  'common_hepatic_duct',
#  'satisfactory_positioning',
#  'ekg_changes',
#  'high_grade',
#  'common_femoral_artery',
#  'under_diaphragm',
#  'lobe_collapse',
#  'findings_called_to',
#  'bibasilar_opacities',
#  'repeat_radiograph',
#  'tunneled_dialysis',
#  'inferior_myocardial',
#  'subdural_collections',
#  'mra_circle',
#  'volume_overload',
#  'suv_d.d',
#  'secondary_to',
#  'passes_below',
#  'metatarsal_level',
#  'to_ensure',
#  'obtained_with_thallium-ddd',
#  'x_d.d',
#  'again_seen',
#  'could_secondary_to',
#  'from_carina',
#  'interstitial_pulmonary_edema',
#  'renal_cell',
#  'biliary_drainage_catheter',
#  'arm_swelling',
#  'left_base',
#  'representing_combination',
#  'no_significant',
#  'recommended_further',
#  'spinal_canal',
#  'ductal_dilatation',
#  'lungs_grossly_clear',
#  'loops_bowel',
#  'ett_placement',
#  'worsening_pulmonary_edema',
#  'coronary_artery_disease',
#  'throughout_abdomen',
#  'day_earlier',
#  'clinical_correlation_requested',
#  'ct_dddcc_nonionic_contrast',
#  'slight_increase_in',
#  'ap_film',
#  'than_on',
#  'heart_border',
#  'since_prior_film',
#  'dd_y/o',
#  'main_stem_bronchus',
#  'dd_pm_babygram_chest',
#  'd.dd_cm',
#  'unable_to',
#  'cardiac_failure',
#  'carotid_stenosis',
#  'heart_top_normal',
#  'r/o_pneumothorax',
#  'cystic_structure',
#  'previous_ct',
#  'pelvis_w/o',
#  'mild_interstitial_edema',
#  'clinical_service_caring_patient',
#  'can_not_entirely_excluded',
#  'right_upper_lobe',
#  'changed_from',
#  'distal_stomach',
#  'right_middle_cerebral_artery',
#  'sternal_dehiscence',
#  'right_upper_quadrant',
#  'fractures_seen',
#  'mr_head',
#  'recurrent_ptx_reason_this',
#  'main_stem',
#  'lungs_show',
#  'artery_bypass',
#  'uncertain_etiology',
#  'physician_lastname',
#  'difficult_to_assess',
#  'rule_out',
#  'pneumonia_can_not_excluded',
#  'occlusive_disease',
#  'without_any',
#  'incidentally_noted',
#  'od_sats',
#  'chest_tubes',
#  'retained_contrast',
#  'change_from_prior',
#  'film_history',
#  'blood_products',
#  'interval_placement',
#  'pericholecystic_fluid',
#  'been_withdrawn',
#  'via_telephone',
#  'interstitial_alveolar_opacities',
#  'infant_with',
#  'mild_cardiomegaly',
#  'further_assessment',
#  'after_treatment',
#  'dd_pm_ct_abdomen',
#  'left-sided_pleural_effusion',
#  'can_not_ruled_out',
#  'gastrointestinal_bleed_underlying_medical',
#  'fluid_levels',
#  'was_not',
#  'earlier_same_date',
#  'ground_glass_opacities',
#  'cvl_placement',
#  'humeral_head',
#  'please_place',
#  'no_definite',
#  'has_been_removed',
#  'unknown_primary',
#  'combination_atelectasis',
#  'time_study',
#  'porta_hepatis',
#  's/p_intubation',
#  'standard_position',
#  'calcified_pleural_plaques',
#  'gadolinium_enhanced',
#  'supine_portable',
#  'local_anesthesia',
#  'right_subclavian_central',
#  'mass_effect',
#  'no_pneumothorax',
#  'these_results_were_discussed',
#  'after_administration',
#  'celiac_axis',
#  'since_recent',
#  'abd_tenderness',
#  'posterior_tibial',
#  'surrounding_edema',
#  'd.d_x_d.d_cm',
#  'size_top',
#  'both_lower_lobes',
#  'extends_below',
#  'common_external',
#  'bony_metastatic',
#  'single_frontal',
#  'glass_opacities',
#  'lymphangitic_spread',
#  'throughout_colon',
#  'soft_tissue_density',
#  'small_amount_fluid',
#  'interval_improvement',
#  'no_other',
#  'biliary_system',
#  'main_pulmonary',
#  'interstitial_markings',
#  'peripheral_vascular_disease',
#  'subacute_infarction',
#  'no_evidence_dvt',
#  'on_either_side',
#  'gallbladder_wall_edema',
#  'parietal_lobe',
#  'lines_described',
#  'cardiopulmonary_disease',
#  'could_performed',
#  'chronic_microvascular',
#  'right_subclavian_line',
#  'major_vascular',
#  'ddcc_final',
#  'bibasilar_atelectases',
#  'evaluate_lung_expansion',
#  'congestive_failure',
#  'tip_projects_over',
#  'lung_volumes_lower',
#  'sided_pleural_effusion',
#  'stab_wound',
#  'renal_arteries',
#  'vascular_congestion',
#  'portable_chest_radiograph',
#  'next_previous',
#  'cardiac_silhouette',
#  'renal_transplant',
#  'normally_midline',
#  'underlying_medical_condition',
#  'developing_pneumonia',
#  'discussed_with',
#  'ij_line',
#  'distal_svc',
#  'peg_tube',
#  'lv_enlargement',
#  'chest_fluoro',
#  'pls_assess',
#  'limited_study',
#  'lower_lung_zone',
#  'dd_year_old_woman',
#  'more_likely',
#  'multi-procedure_same_day',
#  'layering_pleural',
#  'without_definite_evidence',
#  'water_seal',
#  'pulmonary_arterial_hypertension',
#  'likely_due_to',
#  'clinical_details',
#  'due_to_patient_motion',
#  'optimal_placement',
#  'oral_contrast',
#  'final_report_history',
#  'single_ap_portable',
#  'lateral_wall',
#  'immediately_after',
#  'delayed_images',
#  'corresponding_to',
#  'jugular_approach',
#  'clip_reason',
#  'lumbar_spine',
#  'lower_lobe_atelectasis',
#  'please_refer_to',
#  'upper_abdomen',
#  'interval_changes',
#  'perihilar_haziness',
#  'liver_biopsy',
#  'body_habitus',
#  'non_ionic',
#  'perfusion_defects',
#  'bowel_obstruction',
#  'enterocutaneous_fistula',
#  'motor_vehicle_accident\\injuries',
#  'bilateral_subdural_hematomas',
#  'time_dictation',
#  'aortic_valve',
#  'et_tube_tip',
#  'frontal_chest_radiograph',
#  'please_eval_interval_change',
#  'final_report_clinical_indication',
#  'without_evidence',
#  'septic_emboli',
#  'right_lung_base',
#  'has_been_advanced',
#  'severe_degenerative_changes',
#  'name_patternd',
#  'respiratory_motion',
#  'dddcc_non_ionic_contrast',
#  'bone_scan',
#  'mild_pulmonary',
#  'was_notified',
#  'satisfactory_positions',
#  'interstitial_lung',
#  'clinical_correlation_recommended',
#  'remains_in_place',
#  'was_advanced',
#  'please_page',
#  'admitting_diagnosis',
#  'posterior_branch',
#  'pulmonary_nodule',
#  'pulmonary_fibrosis',
#  'more_sensitive',
#  'if_any',
#  'spinal_canal_stenosis',
#  'cm_long',
#  'lung_zone',
#  'slight_decrease',
#  'immediately_following',
#  'lung_apices',
#  'hemodialysis_catheter',
#  'probably_represents',
#  'below_diaphragm',
#  'most_likely_due_to',
#  'findings_suggestive',
#  'in_addition',
#  'during_procedure',
#  'probably_due_to',
#  'please_note',
#  'tubes_lines',
#  'fluoro_time_was_used',
#  'study_performed',
#  'per_second',
#  'in_o.r',
#  'partial_resolution',
#  'no_appreciable',
#  'costophrenic_angle',
#  'interval_change',
#  'other_lines_tubes',
#  'vascular_redistribution',
#  'following_intravenous',
#  'tissue_mass',
#  'obtained_with_thallium',
#  'line_placement',
#  'inf_cdddd',
#  'please_evaluate',
#  'please_evaluate_interval_change',
#  'slight_increase',
#  'feeding_tube_overlies',
#  'cardiac_arrest',
#  'osseous_metastatic',
#  'to_ed_dashboard',
#  'medial_aspect',
#  'mildly_enlarged',
#  'ge_junction',
#  'dd-year-old_woman',
#  'telemetry_underlying_medical_condition',
#  'magnevist_amt',
#  'clinical_information',
#  'post_thoracentesis',
#  'was_passed',
#  'degraded_by',
#  'gi_bleeding',
#  'joint_effusion',
#  'compression_fracture',
#  'these_results',
#  'previously_described',
#  'volume_loss',
#  'superior_vena_cava',
#  'ventricular_pacer',
#  'renal_ultrasound',
#  'intra-abdominal_ascites',
#  'aortic_valve_replacement',
#  'compared_to_prior_study',
#  'continues_to',
#  'vertebral_bodies',
#  'interval_development',
#  'evaluate_lung_fields',
#  'extremely_limited',
#  'clinical_team',
#  'may_reflect',
#  'change_since_prior_study',
#  'near_complete',
#  'soft_tissue_mass',
#  'clinical_correlation_advised',
#  'due_to',
#  'acute_cholecystitis',
#  'adjacent_atelectasis',
#  'multifocal_pneumonia',
#  'bilateral_carotid',
#  'satisfactory_position',
#  'hepatic_duct',
#  'within_normal_limits',
#  'soft_tissue_swelling',
#  'd.d_x',
#  'occlusive_thrombus',
#  'two_hours',
#  'defect_involving',
#  'has_decreased',
#  'vein_thrombosis',
#  'sided_effusion',
#  'loops_small_bowel',
#  'subclavian_central',
#  'left_lower_lobe',
#  'dd_cm_total',
#  'severe_emphysema',
#  'distal_esophagus',
#  'from_prior',
#  'proximal_portion',
#  'difficult_to',
#  'eval_ngt',
#  'most_likely_representing',
#  'this_examination',
#  'bilateral_layering',
#  'vasogenic_edema',
#  'see_comment',
#  's/p_fall',
#  'fracture_or_dislocation',
#  'gastric_fundus',
#  'pa_lateral_chest',
#  'major_tributaries',
#  'interval_progression',
#  'moderately_severe',
#  'two_days',
#  'intracranial_hemorrhage',
#  'adjacent_to',
#  'hazy_opacity',
#  'sepsis_field_view',
#  'evaluate_progression',
#  'has_been_partially',
#  'yo_m',
#  'infant_with_increasing',
#  'alveolar_opacities',
#  'pulse_volume',
#  'history_lung_cancer',
#  'chest_tubes_remain',
#  'should_withdrawn',
#  'overlies_proximal',
#  'asymmetric_pulmonary',
#  'dedicated_pa_lateral',
#  'smaller_than',
#  'chest_wall',
#  'foci_abnormally',
#  'brain_imaging_was_obtained',
#  'ct_abdomen_w/o_contrast',
#  'cirrhotic_liver',
#  'cavity_size',
#  'retrocardiac_atelectasis',
#  'alveolar_interstitial',
#  'rapid_afib',
#  'limited_study_due_to',
#  'view_chest',
#  'located_within',
#  'underlying_collapse_and/or',
#  'passes_below_diaphragm_out',
#  'most_recent',
#  'femoral_artery',
#  'l_ij',
#  'cecum_not',
#  'images_were',
#  'was_obtained',
#  'fluid_collections',
#  'patent_tips',
#  'relate_to',
#  'lower_quadrant',
#  'on_current_exam',
#  'now_s/p',
#  'without_radiologist_present',
#  'mediastinal_hematoma',
#  'popliteal_artery',
#  'staff_caring',
#  'head_trauma',
#  'most_likely_represent',
#  'portal_vein',
#  'alveolar_infiltrates',
#  'raises_possibility',
#  'body_stomach',
#  'amount_ascites',
#  'extensive_subcutaneous',
#  'findings_consistent_with',
#  'hepatic_encephalopathy',
#  'pneumonic_consolidation',
#  'consult_service',
#  'level_thoracic_inlet',
#  'in_appropriate_clinical',
#  'joint_space',
#  'multiplanar_reformatted',
#  'retroperitoneal_bleed',
#  'terminating_in',
#  'significant_stenosis',
#  'ct_chest',
#  'increased_opacity',
#  'low_attenuation_lesions',
#  'renal_cyst',
#  'clinical_service',
#  'metastatic_disease',
#  'tdd_vertebral_body',
#  'assess_interval_change',
#  'measures_d.d_x_d.d',
#  'atelectatic_changes',
#  'liver_lesions',
#  'anterior_posterior',
#  'bilateral_pleural_effusion',
#  'likely_related_to',
#  'sg_catheter',
#  'ogt_placement',
#  'may_represent',
#  'images_demonstrate',
#  'line_ready_use',
#  'check_position',
#  'hiatal_hernia',
#  'please_confirm',
#  'brachial_vein',
#  'chest_portable_ap',
#  'cardiac_enlargement',
#  'basilic_veins',
#  'left_kidney',
#  'mid_lung',
#  'again_noted',
#  'total_length',
#  'left_ventricular',
#  'project_over',
#  'mra_brain_w/o_contrast',
#  'essentially_unchanged',
#  'large_hiatal_hernia',
#  'portable_chest',
#  'abdominal_pain',
#  'perfusion_defect',
#  'post-surgical_changes',
#  'dobhoff_tube',
#  'antecubital_fossa',
#  'focal_opacity',
#  'interval_reduction',
#  'could_represent_either',
#  'lateral_ventricle',
#  'dd_ct_head',
#  'possibly_due_to',
#  'dobhoff_placement',
#  'intraventricular_hemorrhage',
#  'stable_appearance',
#  'lower_pole',
#  'when_patient',
#  'vascular_calcifications',
#  'extending_from',
#  'apical_pleural_thickening',
#  'right_internal_jugular',
#  'chronic_lung',
#  'noted_above',
#  'prior_film',
#  'this_could',
#  'year_old_woman',
#  'gastroesophageal_junction',
#  'greater_saphenous',
#  'cyberknife_protocol',
#  'vertebral_artery',
#  'ligament_treitz',
#  'compared_to',
#  'guid_wires',
#  'could_related_to',
#  'rib_fractures',
#  'line_ready',
#  'stomach_out_view',
#  'copd_exacerbation_underlying_medical',
#  'please_assess',
#  'fluoro_without_radiologist_in_o.r',
#  'internal_carotid_artery',
#  'coiled_in',
#  'tortuosity_thoracic_aorta',
#  'please_assess_interval_change',
#  's/p_trach',
#  'airspace_disease',
#  'physiologic_uptake_seen',
#  'evidence_intestinal',
#  'catheter_projects_over',
#  'post_cabg',
#  'retroperitoneal_hemorrhage',
#  'dd_yom',
#  'av_fistula',
#  'on_same_day',
#  'medical_record',
#  'patient_has_had',
#  'please_check_position',
#  'since_previous',
#  'left_subclavian_catheter',
#  'pleural_effusions',
#  'increased_interstitial',
#  'dens_fracture',
#  'likely_represents',
#  'time_interpretation',
#  'upper_lobe',
#  'ett_pulled_back',
#  'bilateral_pulmonary',
#  'in_standard_position',
#  'above_carina',
#  'free_intraperitoneal_air',
#  'proximal_svc',
#  'tibial_plateau',
#  'did_not',
#  'last_name',
#  'been_removed',
#  'sternal_wire',
#  'examination_please',
#  'brain_imaging',
#  'ng_tube_coiled',
#  'r/o_mets',
#  'ij_central_line',
#  'may_relate',
#  'ld_ld',
#  'may_helpful_to',
#  'double_lumen',
#  'weighted_images',
#  'pls_assess_interval_change',
#  'thecal_sac',
#  'patent_measuring_from',
#  'evidence_acute',
#  'described_above',
#  'mediastinal_lymph',
#  'recurrent_ptx',
#  'slight_interval_improvement_in',
#  'm_s/p',
#  'no_evidence_bowel_obstruction',
#  'stable_appearance_brain',
#  'has_been_placed',
#  'endotracheal_tube',
#  'one_day',
#  'outflow_tract',
#  'metastatic_lesions',
#  'ill-defined_opacity',
#  'complicated_by',
#  'obtained_with_tc-ddm',
#  'ed_dashboard',
#  'given_patient',
#  'admitted_with_pna_large',
#  'lobe_liver',
#  'rightward_shift',
#  'copd_exacerbation',
#  'results_were',
#  'mid_trachea',
#  'team_time',
#  'dd_year_old',
#  'clinical_concern',
#  'were_acquired',
#  'hypercarbic_respiratory_failure',
#  'fluoroscopic_guidance',
#  'bilateral_pleural',
#  'air_space',
#  'differential_diagnosis_includes',
#  'somewhat_more',
#  'otherwise_unremarkable',
#  'its_tip',
#  'optimal_position',
#  'maximum_suv',
#  'mild_chf',
#  'underlying_infectious_process',
#  'not_visualized',
#  'superimposed_pneumonia',
#  'ct_scan',
#  'distal_end_not_included',
#  'not_significantly',
#  'abdominal_distention',
#  'carotid_artery',
#  'these_findings',
#  'main_portal_vein',
#  'cell_carcinoma',
#  'resp_failure',
#  'ap_lateral_views',
#  'aortic_arch',
#  'diffuse_alveolar',
#  'approximately_d.d_cm',
#  'since_previous_study',
#  'images_skeleton',
#  'tib/fib_ap',
#  'pa_catheter',
#  'cm_per_second',
#  'glenohumeral_joint',
#  'compressive_atelectasis',
#  'aortic_aneurysm',
#  'apical_pleural',
#  'descending_thoracic',
#  'periventricular_white_matter',
#  'do_not',
#  'was_discussed_with',
#  'left_ventricular_enlargement',
#  'if_warranted',
#  "'s_symptoms",
#  'c-spine_fracture_underlying_medical',
#  'pulmonary_arterial',
#  'vascular_catheter',
#  'interstitial_opacities',
#  'w/contrast_ct_dddcc_nonionic',
#  'iliac_arteries',
#  'when_compared',
#  'previously_demonstrated',
#  'may_related',
#  'pvd_s/p',
#  'two_views',
#  'lateral_decubitus',
#  'r/o_abscess',
#  'bilateral_pleural_effusions',
#  'rather_than',
#  'no_significant_change',
#  'interval_decrease',
#  'ap_upright',
#  'does_not',
#  'tips_patency',
#  'bilateral_air_space',
#  'single_portable',
#  'aneurysmal_dilatation',
#  'hepatic_encephalopathy_underlying_medical',
#  'concerning_metastatic_disease',
#  'mild_pulmonary_edema',
#  'fluid_status',
#  'ddd_cm/sec',
#  'basilar_atelectasis',
#  'stated_above',
#  'less_likely',
#  'bony_metastases',
#  'tip_swan-ganz_catheter',
#  'disease\\cath_underlying',
#  'these_areas',
#  'radiograph_chest_reviewed',
#  'was_administered',
#  'aplastic_anemia',
#  'focal_consolidation',
#  'bone_lesions',
#  'eval_ptx',
#  'ct_abdomen_w/contrast',
#  'brachiocephalic_vein',
#  'anterior_posterior_circulation',
#  'on_hfov',
#  'by_telephone',
#  'cephalic_basilic',
#  'deep_venous_thrombosis',
#  'sheath_was',
#  'basilar_opacity',
#  'intrahepatic_biliary',
#  'red_blood',
#  'variceal_bleed',
#  'focal_consolidations',
#  'cardiac_mediastinal',
#  'please_correlate_clinically',
#  'ct_abd',
#  'frontal_temporal',
#  'dd_pm_chest_fluoro',
#  'liver_parenchyma',
#  'active_bleeding',
#  ...}

# %% [markdown]
# ### How often did each phrase occur?

# %%
from collections import Counter

# %%
phrased_blob = TextBlob(phrased_txt)

# %%
counter = Counter(phrased_blob.words)
counter.most_common(20) #d are our numbers
# Out:
# [('d', 5619),
#  ('impression', 4096),
#  ('with', 3492),
#  ('in', 3027),
#  ('right', 2403),
#  ('dd', 2144),
#  ('left', 1946),
#  ('there', 1650),
#  ('clip', 1309),
#  ('date', 1242),
#  ('to', 1102),
#  ('no', 1078),
#  ('clip_reason', 1039),
#  ('chest', 1031),
#  ('on', 996),
#  ('or', 983),
#  ('reason_this_examination', 740),
#  ('admitting_diagnosis', 704),
#  ('this', 664),
#  ('within', 646)]

# %%
word_map_phrases = dict(zip(counter.keys(), range(len(counter))))

# %%
counted_phrases = Counter([w for w in phrased_blob.words if "_" in w])
counted_phrases
# Out:
# Counter({'check_line_placement': 11,
#          'r/o_pe': 9,
#          'central_venous_line': 28,
#          'common_carotid': 3,
#          'same_date': 11,
#          'lower_lobe_consolidation': 22,
#          'linear_atelectasis': 16,
#          'tubes_remain': 2,
#          'hip_fx': 9,
#          'heart_enlarged': 10,
#          'interval_improvement_in': 28,
#          'standard_placement': 2,
#          'gated_images': 1,
#          'not_completely': 6,
#          'date_mailed': 20,
#          "paget_'s_disease": 8,
#          'subcutaneous_edema': 7,
#          'proximal_jejunum': 17,
#          'anterior_tibial_artery': 8,
#          'ld_vertebral': 3,
#          'ct_guided': 11,
#          'fractures_identified': 9,
#          'low_lung': 1,
#          'tube_coiled': 2,
#          'feeding_tube_placement': 42,
#          'central_venous_catheter': 32,
#          'fatty_infiltration': 6,
#          'brachial_vein': 21,
#          'bone_destruction': 9,
#          'd-d_cm': 13,
#          'intrahepatic_ductal_dilatation': 8,
#          'small_bowel_obstruction': 18,
#          'supine_positioning': 7,
#          'septum_pellucidum': 6,
#          'cm_from': 18,
#          'has_been': 64,
#          'it_unclear': 8,
#          'abdomen_pelvis': 30,
#          'could_reflect': 10,
#          'bilateral_pulmonary_nodules': 8,
#          'more_prominent': 7,
#          'once_again': 6,
#          'asymmetric_pulmonary_edema': 21,
#          'dd_pm_date_mailed': 60,
#          'sinus_disease': 9,
#          'bowel_ischemia': 6,
#          'pa_cath': 6,
#          'improvement_in': 44,
#          'gated_wall_motion_images': 10,
#          'may_helpful': 19,
#          'bilateral_layering_pleural_effusions': 15,
#          'dd.d_cm': 8,
#          'level_ge_junction': 8,
#          'brain_atrophy': 13,
#          'upper_zone_redistribution': 19,
#          'ap_radiograph': 14,
#          'catheter_terminates': 14,
#          'comminuted_fracture': 6,
#          'ejection_fraction': 6,
#          'contrast_enhancement': 11,
#          'thoracic_lumbar_spine': 6,
#          'cava_right_atrium': 6,
#          'should_advanced': 11,
#          'midline_structures': 2,
#          'subclavian_central_venous_catheter': 1,
#          'field_view': 132,
#          'slight_interval_increase_in': 10,
#          'tip_projects': 2,
#          'cta_abd': 1,
#          'further_details': 7,
#          'refer_to': 3,
#          'pulmonary_vasculature': 11,
#          'eval_pulm': 4,
#          'thickened_gallbladder_wall': 6,
#          'within_stomach': 22,
#          'atelectasis_versus': 12,
#          'stable_cardiomegaly': 13,
#          'not_included': 11,
#          'urine_output': 9,
#          'spinal_stenosis': 10,
#          'more_complete_assessment': 8,
#          'altered_mental_status': 6,
#          'ddd_cm/second': 6,
#          'project_over': 11,
#          'diagnostic_abnormality': 6,
#          'conray_amt': 11,
#          'not_well': 13,
#          'esophageal_ca/sda_underlying_medical': 7,
#          'head_w': 1,
#          'most_likely_represents': 12,
#          'final_report_portable': 63,
#          'large_hiatal_hernia': 7,
#          'chest_radiographs': 17,
#          'not_well_visualized': 10,
#          'call_radiology_listen_line': 80,
#          'wires_incl': 4,
#          'superior_cavoatrial_junction': 8,
#          'inflammatory_change': 8,
#          'multiple_pulmonary_nodules': 9,
#          'pleural_fluid': 33,
#          'status_post_cabg': 12,
#          'not_changed': 5,
#          'intraperitoneal_gas': 3,
#          'dd_pm_cta_chest': 25,
#          'one_view_portable': 1,
#          'cardiomediastinal_silhouette_stable': 8,
#          'ganz_catheter': 1,
#          'new_onset': 10,
#          'slightly_decreased': 14,
#          'placement_x': 12,
#          'associated_compressive': 6,
#          'underlying_emphysema': 9,
#          'supine_only': 10,
#          'gj_tube': 10,
#          'restricted_diffusion': 14,
#          'left_retrocardiac_opacity': 37,
#          'dd_year_old_male': 8,
#          'distended_gallbladder': 6,
#          'stenosis_origin': 6,
#          'dddcc_final_report': 8,
#          'clinical_concern': 17,
#          'cm_above_carina': 5,
#          'distinct_procedural': 37,
#          'minutes_fluoro': 1,
#          'several_days': 4,
#          'basilar_opacities': 7,
#          'almost_complete': 6,
#          'due_to_lack': 3,
#          'ett_ngt': 3,
#          'likely_related': 1,
#          'ng_tube_extends_below': 14,
#          'hepatic_veins': 20,
#          'abnormal_fdg': 7,
#          'views_skeleton': 9,
#          'single_ap': 48,
#          'lung_fields': 42,
#          'no_contraindications_iv_contrast': 31,
#          'technically_limited': 7,
#          'large_small_bowel': 9,
#          'incl_inf': 2,
#          'please_perform': 6,
#          'popliteal_vein': 10,
#          'swan_ganz': 6,
#          'clinically_indicated': 1,
#          'were_taken': 7,
#          'osseous_metastases': 10,
#          'differential_diagnosis': 25,
#          'short_interval': 10,
#          'lower_lobe': 155,
#          'plain_film': 10,
#          'od_sats': 7,
#          'located_within': 9,
#          'followed_by': 13,
#          'picc_line_placment_sch': 11,
#          'tumor_burden': 6,
#          'claudication/sda_underlying_medical_condition': 9,
#          'in_diameter': 16,
#          'extends_below_diaphragm': 1,
#          'passes_into': 1,
#          'interval_decrease_in': 27,
#          'by_same': 37,
#          'multiplanar_reconstructions': 10,
#          'internal_jugular_central_venous': 5,
#          'abd_w': 3,
#          'film_history': 20,
#          'bowel_perforation': 8,
#          'any_evidence': 9,
#          'j_tube': 8,
#          'mr_contrast_gadolin': 28,
#          'low_attenuation': 21,
#          'most_recent': 5,
#          'cord_compression': 12,
#          'has_not_changed': 9,
#          'consistent_with': 329,
#          'was_informed': 7,
#          'aortic_stenosis': 10,
#          'doppler_ultrasound': 7,
#          'thoracic_lumbar': 1,
#          'small_pleural_effusions': 32,
#          'free_intraperitoneal_gas': 9,
#          'in_good_position': 35,
#          'ultrasound_guided': 8,
#          'acute_infarct': 17,
#          'underlying_infection': 9,
#          'cervical_spine': 31,
#          'distal_common_bile': 8,
#          'stable_appearance': 92,
#          'main_bronchus': 12,
#          'note_that': 1,
#          'previous_examination': 8,
#          'pa_lateral': 22,
#          'increase_in_size': 15,
#          'lung_nodules': 13,
#          'tip_swan-ganz_catheter_overlies': 6,
#          'osseous_structures': 18,
#          'report_these_findings': 9,
#          'dd_minutes_prior': 18,
#          'dd_yo': 35,
#          'bypass_graft': 9,
#          'was_confirmed': 6,
#          'mild_congestive_heart_failure': 33,
#          'evidence_diverticulitis': 4,
#          'urinary_bladder': 8,
#          'were_communicated': 1,
#          'portable_supine': 22,
#          'informed_consent': 1,
#          'dd_pm_mr_head': 26,
#          'in_situ': 10,
#          'enlarged_cardiac': 1,
#          'earlier_today': 9,
#          'overlies_region': 3,
#          'no_evidence_pneumothorax': 125,
#          'attenuation_lesions': 1,
#          'distal_radius': 9,
#          'feeding_tube': 117,
#          'by_different': 36,
#          'lung_expansion': 6,
#          'myocardial_perfusion': 23,
#          'no_acute_intracranial': 35,
#          'concerning_metastatic': 2,
#          'were_relayed': 3,
#          'heart_failure': 39,
#          'please_evaluate_interval_change': 16,
#          'elevated_creatinine-dehydration_underlying_medical': 12,
#          'small_amount_ascites': 25,
#          'follow_up_recommended': 10,
#          'air_fluid_levels': 8,
#          'mild_cardiomegaly': 20,
#          'approximately_d.d_cm_above': 12,
#          'mediastinal_lymph_nodes': 6,
#          'worse_than': 7,
#          'measuring_up_to': 15,
#          'airspace_opacities': 18,
#          'territorial_infarction': 5,
#          'pulmonary_artery_catheter': 15,
#          'same_day': 22,
#          'common_hepatic': 4,
#          'worsening_congestive': 1,
#          'spinal_cord': 22,
#          'moderate_sized': 22,
#          'common_carotid_artery': 6,
#          'from_prior_day': 8,
#          'more_confluent': 12,
#          'partially_reversible': 7,
#          'sagittal_coronal': 6,
#          'acute_intracranial': 1,
#          'reference_exam': 14,
#          'this_time': 21,
#          'large_bowel': 10,
#          'was_provided': 11,
#          's/p_hepatico': 8,
#          'shift_normally_midline_structures': 24,
#          'moderate_amount_ascites': 6,
#          'well_visualized': 1,
#          'normal_wall_motion': 6,
#          'recommended_to_exclude': 6,
#          'no_significant_change_since': 22,
#          'compression_fractures': 8,
#          'gastrointestinal_bleed_underlying_medical': 10,
#          'without_complication': 7,
#          'ng_tube': 221,
#          'wall_thickening': 34,
#          'biliary_tree': 12,
#          'resp_distress': 9,
#          'erect_ap': 7,
#          'likely_secondary_to': 20,
#          'referring_physician': 13,
#          'status_epilepticus': 8,
#          'no_appreciable_change': 13,
#          'abnormal_signal': 7,
#          'bowel_loops': 9,
#          'without_evidence_diverticulitis': 8,
#          'portable_chest_x-ray': 7,
#          'mucosal_thickening': 14,
#          'lateral_aspect': 13,
#          'patchy_atelectasis': 16,
#          'combined_alveolar_interstitial_pattern': 6,
#          'iv_contrast': 32,
#          'previous_study_earlier_same': 7,
#          'passed_through': 5,
#          'contrast_reason': 17,
#          'from_d.dd_cm': 6,
#          'pulmonary_infiltrates': 9,
#          'films_submitted': 7,
#          'more_optimal_placement': 6,
#          'portal_vein_patent': 5,
#          'td_signal': 16,
#          'bypass_surgery': 7,
#          'depending_on': 6,
#          'has_worsened': 15,
#          'lungs_clear': 24,
#          'ground_glass_opacity': 9,
#          'peroneal_artery': 6,
#          'significant_change': 9,
#          'comparison_made_to': 57,
#          'dd_hours': 29,
#          'appears_normal': 12,
#          'stress_perfusion_images_reveal': 7,
#          'further_evaluation': 54,
#          'increased_tracer': 3,
#          'involving_inferior': 4,
#          'pulmonary_embolus': 32,
#          'representing_atelectasis': 10,
#          'that_may_represent': 10,
#          'hours_earlier': 28,
#          'underlying_pneumonia_can': 7,
#          's/p_r': 14,
#          'myocardial_infarction': 4,
#          'lobe_atelectasis/consolidation': 1,
#          'interval_worsening': 25,
#          'compatible_with': 17,
#          'second_portion_duodenum': 6,
#          'known_history': 5,
#          'portal_veins': 7,
#          'degenerative_changes': 40,
#          'chest_reviewed_compared_with_previous': 2,
#          'dd_pm': 445,
#          'no_evidence_pulmonary_embolism': 17,
#          'lung_bases': 32,
#          'compared_to_prior': 30,
#          'in_standard_placements': 17,
#          'tracer_uptake': 14,
#          'satisfactory_positioning': 20,
#          'ekg_changes': 7,
#          'high_grade': 10,
#          'common_femoral_artery': 11,
#          'has_been_removed': 30,
#          'lobe_collapse': 8,
#          'findings_called_to': 7,
#          'bibasilar_opacities': 17,
#          'interval_resolution': 21,
#          'prior_study': 96,
#          'repeat_radiograph': 8,
#          'tunneled_dialysis': 1,
#          'inferior_myocardial': 13,
#          'cyberknife_protocol': 8,
#          'subdural_collections': 6,
#          'abnormal_uptake': 6,
#          'mra_circle': 7,
#          's/p_intubation': 25,
#          'volume_overload': 22,
#          'suv_d.d': 12,
#          'secondary_to': 61,
#          'passes_below': 1,
#          'metatarsal_level': 7,
#          'to_ensure': 9,
#          'obtained_with_thallium-ddd': 7,
#          'x_d.d': 4,
#          'again_seen': 50,
#          'could_secondary_to': 4,
#          'from_carina': 9,
#          'interstitial_pulmonary_edema': 26,
#          'renal_cell': 3,
#          'biliary_drainage_catheter': 7,
#          'arm_swelling': 6,
#          'left_base': 54,
#          'representing_combination': 1,
#          'no_significant': 47,
#          'recommended_further': 4,
#          'spinal_canal': 18,
#          'ductal_dilatation': 13,
#          'minimally_displaced': 6,
#          'lungs_grossly_clear': 7,
#          'ett_placement': 26,
#          'worsening_pulmonary_edema': 16,
#          'throughout_abdomen': 7,
#          'day_earlier': 6,
#          'clinical_correlation_requested': 8,
#          'ct_dddcc_nonionic_contrast': 84,
#          'slight_increase_in': 32,
#          'ap_film': 23,
#          'than_on': 17,
#          'since_prior_film': 9,
#          'dd_y/o': 6,
#          'dd_pm_babygram_chest': 6,
#          'abnormal_enhancement': 11,
#          'unable_to': 14,
#          'normal_route_tracer_excretion': 13,
#          'cardiac_failure': 38,
#          'carotid_stenosis': 14,
#          'heart_top_normal': 6,
#          'r/o_pneumothorax': 18,
#          'cystic_structure': 6,
#          'previous_ct': 7,
#          'in_satisfactory_position': 81,
#          'mild_interstitial_edema': 11,
#          'clinical_service_caring_patient': 6,
#          'can_not_entirely_excluded': 13,
#          'right_upper_lobe': 97,
#          'distal_stomach': 11,
#          'right_middle_cerebral_artery': 6,
#          'sternal_dehiscence': 7,
#          'right_upper_quadrant': 41,
#          'fractures_seen': 8,
#          'mr_head': 11,
#          'recurrent_ptx_reason_this': 8,
#          'main_stem': 3,
#          'right_ij': 45,
#          'artery_bypass': 6,
#          'uncertain_etiology': 6,
#          'physician_lastname': 2,
#          'difficult_to_assess': 7,
#          'rule_out': 31,
#          'occlusive_disease': 8,
#          'without_any': 10,
#          'incidentally_noted': 6,
#          'chest_tubes': 43,
#          'retained_contrast': 18,
#          'change_from_prior': 4,
#          'blood_products': 10,
#          'interval_placement': 63,
#          'been_withdrawn': 1,
#          'via_telephone': 6,
#          'interstitial_alveolar_opacities': 3,
#          'celiac_axis': 10,
#          'infant_with': 26,
#          'further_assessment': 7,
#          'after_treatment': 10,
#          'dd_pm_ct_abdomen': 44,
#          'left-sided_pleural_effusion': 31,
#          'can_not_ruled_out': 6,
#          'fluid_levels': 2,
#          'was_not': 33,
#          'earlier_same_date': 6,
#          'ground_glass_opacities': 7,
#          'cvl_placement': 13,
#          'humeral_head': 9,
#          'please_place': 20,
#          'no_definite': 87,
#          'unknown_primary': 9,
#          'combination_atelectasis': 8,
#          'time_study': 10,
#          'terminates_in': 42,
#          'porta_hepatis': 10,
#          'standard_position': 4,
#          'calcified_pleural_plaques': 11,
#          'gadolinium_enhanced': 6,
#          'supine_portable': 2,
#          'local_anesthesia': 10,
#          'right_subclavian_central': 17,
#          'increased_density': 19,
#          'mass_effect': 75,
#          'no_pneumothorax': 419,
#          'these_results_were_discussed': 12,
#          'after_administration': 9,
#          'pleural_plaques': 1,
#          'please_correlate_clinically': 14,
#          'since_recent': 8,
#          'free_intraabdominal_air': 6,
#          'abd_tenderness': 6,
#          'posterior_tibial': 7,
#          'surrounding_edema': 11,
#          'to_previous_study': 4,
#          'd.d_x_d.d_cm': 13,
#          'both_lower_lobes': 13,
#          'valve_replacement': 3,
#          'extends_below': 1,
#          'again_demonstrated': 11,
#          'common_external': 5,
#          'bony_metastatic': 6,
#          'single_frontal': 10,
#          'glass_opacities': 1,
#          'size_top': 1,
#          'lymphangitic_spread': 6,
#          'throughout_colon': 11,
#          'small_amount_fluid': 9,
#          'interval_improvement': 17,
#          'no_other': 58,
#          'biliary_system': 9,
#          'peripheral_vascular_disease': 7,
#          'interstitial_markings': 9,
#          'intrahepatic_biliary_dilatation': 6,
#          'subacute_infarction': 7,
#          'no_evidence_dvt': 23,
#          'on_either_side': 7,
#          'gallbladder_wall_edema': 9,
#          'parietal_lobe': 19,
#          'cardiopulmonary_disease': 1,
#          'could_performed': 23,
#          'chronic_microvascular': 12,
#          'improved_aeration': 22,
#          'right_subclavian_line': 24,
#          'motor_vehicle': 3,
#          'major_vascular': 10,
#          'ddcc_final': 10,
#          'bibasilar_atelectases': 16,
#          'congestive_failure': 13,
#          'tip_projects_over': 10,
#          'diagnostic_abnormalities': 7,
#          'lung_volumes_lower': 7,
#          'sided_pleural_effusion': 8,
#          'renal_arteries': 9,
#          'vascular_congestion': 16,
#          'portable_chest_radiograph': 5,
#          'next_previous': 6,
#          'normally_midline': 4,
#          'underlying_medical_condition': 564,
#          'developing_pneumonia': 11,
#          'discussed_with': 47,
#          'av_fistula': 25,
#          'ij_line': 4,
#          'medical_record': 3,
#          'distal_svc': 40,
#          'lv_enlargement': 7,
#          'chest_fluoro': 4,
#          'limited_study': 15,
#          'lower_lung_zone': 14,
#          'dd_year_old_woman': 261,
#          'more_likely': 11,
#          'layering_pleural': 7,
#          'water_seal': 3,
#          'pulmonary_arterial_hypertension': 7,
#          'likely_due_to': 39,
#          'clinical_details': 10,
#          'bilateral_alveolar': 16,
#          'due_to_patient_motion': 4,
#          'soft_tissue_density': 11,
#          'optimal_placement': 4,
#          'oral_contrast': 25,
#          'final_report_history': 167,
#          'single_ap_portable': 17,
#          'patient_has_had': 13,
#          'lateral_wall': 9,
#          'immediately_after': 7,
#          'delayed_images': 10,
#          'corresponding_to': 11,
#          'left_subclavian_catheter': 12,
#          'jugular_approach': 2,
#          'right_main_stem': 22,
#          'clip_reason': 1039,
#          'pleural_effusions': 104,
#          'lumbar_spine': 36,
#          'lower_lobe_atelectasis': 20,
#          'please_refer_to': 10,
#          'tracheostomy_tube': 55,
#          'upper_abdomen': 18,
#          'interval_changes': 17,
#          'perihilar_haziness': 21,
#          'liver_biopsy': 7,
#          'left-sided_picc': 5,
#          'body_habitus': 12,
#          'non_ionic': 1,
#          'perfusion_defects': 5,
#          'bowel_obstruction': 10,
#          'enterocutaneous_fistula': 14,
#          'motor_vehicle_accident\\injuries': 6,
#          'bilateral_subdural_hematomas': 9,
#          'time_dictation': 21,
#          'aortic_valve': 3,
#          'likely_represents': 30,
#          'et_tube_tip': 20,
#          'frontal_chest_radiograph': 6,
#          'please_eval_interval_change': 19,
#          'main_pulmonary': 4,
#          'left_ventricular_cavity_size': 8,
#          'final_report_clinical_indication': 12,
#          'without_evidence': 64,
#          'septic_emboli': 7,
#          'right_lung_base': 59,
#          'has_been_advanced': 7,
#          'severe_degenerative_changes': 6,
#          'name_patternd': 38,
#          'respiratory_motion': 10,
#          'satisfactory_positions': 6,
#          'bone_scan': 23,
#          'mild_pulmonary': 11,
#          'was_notified': 10,
#          'interstitial_lung': 5,
#          'clinical_correlation_recommended': 27,
#          'lines_described': 1,
#          'remains_in_place': 22,
#          'was_advanced': 12,
#          'please_page': 10,
#          'admitting_diagnosis': 704,
#          'posterior_branch': 6,
#          'pulmonary_nodule': 12,
#          'pulmonary_fibrosis': 6,
#          'more_sensitive': 12,
#          'if_any': 9,
#          'spinal_canal_stenosis': 8,
#          'cm_long': 5,
#          'lung_zone': 3,
#          'slight_decrease': 2,
#          'immediately_following': 7,
#          'lung_apices': 12,
#          'hemodialysis_catheter': 11,
#          'probably_represents': 6,
#          'below_diaphragm': 20,
#          'most_likely_due_to': 15,
#          'findings_suggestive': 12,
#          'in_addition': 28,
#          'during_procedure': 6,
#          'probably_due_to': 15,
#          'please_note': 3,
#          'tubes_lines': 18,
#          'fluoro_time_was_used': 9,
#          'study_performed': 13,
#          'per_second': 2,
#          'in_o.r': 31,
#          'partial_resolution': 7,
#          'no_appreciable': 14,
#          'costophrenic_angle': 19,
#          'vascular_redistribution': 6,
#          'following_intravenous': 13,
#          'tissue_mass': 1,
#          'free_intraperitoneal_air': 15,
#          'obtained_with_thallium': 6,
#          'line_placement': 139,
#          'inf_cdddd': 2,
#          'please_evaluate': 60,
#          'slight_increase': 2,
#          'feeding_tube_overlies': 3,
#          'cardiac_arrest': 12,
#          'to_ed_dashboard': 9,
#          'medial_aspect': 9,
#          'mildly_enlarged': 6,
#          'ge_junction': 26,
#          'dd-year-old_woman': 29,
#          'telemetry_underlying_medical_condition': 11,
#          'magnevist_amt': 59,
#          'again_note_made': 8,
#          'post_thoracentesis': 2,
#          'evaluate_lung_expansion': 8,
#          'was_passed': 5,
#          'gi_bleeding': 7,
#          'joint_effusion': 11,
#          'compression_fracture': 19,
#          'these_results': 10,
#          'previously_described': 22,
#          'right_subclavian': 38,
#          'volume_loss': 28,
#          'superior_vena_cava': 63,
#          'ventricular_pacer': 3,
#          'renal_ultrasound': 9,
#          'aortic_valve_replacement': 6,
#          'continues_to': 9,
#          'vertebral_bodies': 24,
#          'interval_development': 42,
#          'extremely_limited': 10,
#          'clinical_team': 9,
#          'may_reflect': 20,
#          'stab_wound': 6,
#          'change_since_prior_study': 7,
#          'near_complete': 10,
#          'dorsalis_pedis': 15,
#          'soft_tissue_mass': 9,
#          'clinical_correlation_advised': 7,
#          'due_to': 118,
#          'acute_cholecystitis': 9,
#          'vascular_territorial': 2,
#          'multifocal_pneumonia': 34,
#          'bilateral_carotid': 7,
#          'satisfactory_position': 22,
#          'hepatic_duct': 14,
#          'soft_tissue_swelling': 14,
#          'd.d_x': 2,
#          'occlusive_thrombus': 6,
#          'greater_than_right': 2,
#          'defect_involving': 7,
#          'has_decreased': 17,
#          'vein_thrombosis': 6,
#          'sided_effusion': 5,
#          'loops_small_bowel': 13,
#          'subclavian_central': 1,
#          'further_evaluated': 9,
#          'dd_cm_total': 7,
#          'increased_opacity': 23,
#          'severe_emphysema': 9,
#          'from_prior': 20,
#          'proximal_portion': 8,
#          'eval_ngt': 6,
#          'cardiac_silhouette': 30,
#          'pericholecystic_fluid': 18,
#          'most_likely_representing': 13,
#          'may_helpful_to': 12,
#          'this_examination': 6,
#          'bilateral_layering': 4,
#          'vasogenic_edema': 13,
#          'see_comment': 3,
#          'intra_or': 4,
#          'fracture_or_dislocation': 17,
#          'gastric_fundus': 8,
#          'pa_lateral_chest': 18,
#          'external_iliac': 8,
#          'major_tributaries': 6,
#          'interval_progression': 16,
#          'moderately_severe': 10,
#          'two_days': 9,
#          'intracranial_hemorrhage': 27,
#          'gallbladder_wall': 8,
#          'adjacent_to': 51,
#          'hazy_opacity': 6,
#          'sepsis_field_view': 10,
#          'yo_m': 2,
#          'has_been_partially': 8,
#          'infant_with_increasing': 6,
#          'history_lung_cancer': 2,
#          'pulse_volume': 3,
#          'chest_tubes_remain': 9,
#          'should_withdrawn': 7,
#          'overlies_proximal': 6,
#          'asymmetric_pulmonary': 1,
#          'dedicated_pa_lateral': 8,
#          'bowel_gas': 10,
#          'smaller_than': 5,
#          'chest_wall': 29,
#          'foci_abnormally': 6,
#          'ct_abdomen_w/o_contrast': 30,
#          'cirrhotic_liver': 15,
#          'cavity_size': 6,
#          'retrocardiac_atelectasis': 9,
#          'rapid_afib': 6,
#          'limited_study_due_to': 12,
#          'view_chest': 28,
#          'underlying_collapse_and/or': 6,
#          'passes_below_diaphragm_out': 8,
#          'femoral_artery': 4,
#          'l_ij': 9,
#          'cecum_not': 6,
#          'images_were': 17,
#          'was_obtained': 32,
#          'fluid_collections': 30,
#          'patent_tips': 19,
#          'pericardial_effusion': 45,
#          'changed_from': 2,
#          'relate_to': 2,
#          'lower_quadrant': 8,
#          'on_current_exam': 6,
#          'now_s/p': 29,
#          'without_radiologist_present': 6,
#          'mediastinal_hematoma': 10,
#          'popliteal_artery': 12,
#          'stable_appearance_brain': 7,
#          'staff_caring': 2,
#          'peg_tube': 10,
#          'head_trauma': 8,
#          'most_likely_represent': 6,
#          'portal_vein': 40,
#          'limited_due_to': 10,
#          'pls_assess': 1,
#          'alveolar_infiltrates': 6,
#          'raises_possibility': 8,
#          'amount_ascites': 6,
#          'dr_lastname': 1,
#          'extensive_subcutaneous': 3,
#          'findings_consistent_with': 58,
#          'hepatic_encephalopathy': 15,
#          'one_day': 2,
#          'level_thoracic_inlet': 8,
#          'in_appropriate_clinical': 22,
#          'joint_space': 7,
#          'multiplanar_reformatted': 7,
#          'retroperitoneal_bleed': 15,
#          'terminating_in': 43,
#          'significant_stenosis': 7,
#          'ct_chest': 66,
#          'low_attenuation_lesions': 6,
#          'renal_cyst': 6,
#          'clinical_service': 7,
#          'tdd_vertebral_body': 7,
#          'assess_interval_change': 19,
#          'atelectatic_changes': 15,
#          'liver_lesions': 17,
#          'multi-procedure_same_day': 7,
#          'anterior_posterior': 5,
#          'bilateral_pleural_effusion': 23,
#          'likely_related_to': 18,
#          'sg_catheter': 17,
#          'ogt_placement': 14,
#          'may_represent': 126,
#          'images_demonstrate': 8,
#          'portal_venous': 12,
#          'line_ready_use': 16,
#          'check_position': 13,
#          'without_definite_evidence': 6,
#          'hiatal_hernia': 9,
#          'please_confirm': 8,
#          'chest_portable_ap': 2,
#          'cardiac_enlargement': 15,
#          'basilic_veins': 1,
#          'left_kidney': 45,
#          'mid_lung': 7,
#          'again_noted': 41,
#          'total_length': 2,
#          'left_ventricular': 28,
#          'mra_brain_w/o_contrast': 13,
#          'essentially_unchanged': 21,
#          'portable_chest': 18,
#          'abdominal_pain': 32,
#          'perfusion_defect': 11,
#          'post-surgical_changes': 6,
#          'dobhoff_tube': 11,
#          'antecubital_fossa': 6,
#          'interval_reduction': 6,
#          'could_represent_either': 7,
#          'paranasal_sinuses': 8,
#          'lateral_ventricle': 20,
#          'may_related_to': 18,
#          'dd_ct_head': 23,
#          'possibly_due_to': 11,
#          'dobhoff_placement': 9,
#          'intraventricular_hemorrhage': 9,
#          'when_patient': 14,
#          'lower_pole': 14,
#          'extending_from': 18,
#          'apical_pleural_thickening': 9,
#          'right_internal_jugular': 66,
#          'mastoid_air_cells': 6,
#          'noted_above': 17,
#          'copd_exacerbation': 14,
#          'prior_film': 11,
#          'previous_exam': 11,
#          'this_could': 31,
#          'year_old_woman': 11,
#          'gastroesophageal_junction': 7,
#          'greater_saphenous': 5,
#          'air_bronchograms': 8,
#          'vertebral_artery': 20,
#          'ligament_treitz': 8,
#          'compared_to': 245,
#          'vein_mapping': 9,
#          'guid_wires': 2,
#          'could_related_to': 6,
#          'rib_fractures': 12,
#          'line_ready': 4,
#          'stomach_out_view': 8,
#          'copd_exacerbation_underlying_medical': 36,
#          'please_assess': 39,
#          'fluoro_without_radiologist_in_o.r': 8,
#          'internal_carotid_artery': 25,
#          'coiled_in': 22,
#          'tortuosity_thoracic_aorta': 7,
#          'distal_end_not_included': 10,
#          'please_assess_interval_change': 9,
#          's/p_trach': 6,
#          'airspace_disease': 12,
#          'physiologic_uptake_seen': 7,
#          'evidence_intestinal': 2,
#          'catheter_projects_over': 4,
#          'post_cabg': 1,
#          'retroperitoneal_hemorrhage': 6,
#          'dd_yom': 12,
#          'hilar_contours': 5,
#          'on_same_day': 12,
#          'please_check_position': 8,
#          'since_previous': 12,
#          'increased_interstitial': 6,
#          'dens_fracture': 6,
#          'time_interpretation': 26,
#          'ett_pulled_back': 6,
#          'upper_lobe': 61,
#          'plmt_clip': 1,
#          'bilateral_pulmonary': 25,
#          'in_standard_position': 10,
#          'above_carina': 14,
#          'proximal_svc': 10,
#          'tibial_plateau': 8,
#          'did_not': 8,
#          'last_name': 70,
#          'been_removed': 2,
#          'sternal_wire': 6,
#          'examination_please': 1,
#          'slightly_smaller': 9,
#          'brain_imaging': 3,
#          'ng_tube_coiled': 8,
#          'r/o_mets': 6,
#          'ij_central_line': 6,
#          'may_relate': 2,
#          'internal_carotid_arteries': 6,
#          'ld_ld': 5,
#          'double_lumen': 6,
#          'weighted_images': 6,
#          'pls_assess_interval_change': 7,
#          'thecal_sac': 10,
#          'patent_measuring_from': 1,
#          'otherwise_unremarkable': 11,
#          'evidence_acute': 9,
#          'described_above': 76,
#          'mediastinal_lymph': 3,
#          'recurrent_ptx': 5,
#          'slight_interval_improvement_in': 11,
#          'm_s/p': 10,
#          'no_evidence_bowel_obstruction': 9,
#          'has_been_placed': 17,
#          'endotracheal_tube': 201,
#          'outflow_tract': 4,
#          'torso_ct': 7,
#          'metastatic_lesions': 14,
#          'resting_perfusion_images_were': 18,
#          'ill-defined_opacity': 7,
#          'complicated_by': 7,
#          'obtained_with_tc-ddm': 4,
#          'ed_dashboard': 1,
#          'w/iv_contrast': 12,
#          'given_patient': 13,
#          'admitted_with_pna_large': 7,
#          'lobe_liver': 31,
#          'rightward_shift': 8,
#          'results_were': 20,
#          'coronary_artery_disease\\coronary_artery': 10,
#          'mid_trachea': 7,
#          'team_time': 6,
#          'dd_year_old': 14,
#          'were_acquired': 9,
#          'hypercarbic_respiratory_failure': 6,
#          'fluoroscopic_guidance': 7,
#          'bilateral_pleural': 7,
#          'air_space': 15,
#          'differential_diagnosis_includes': 11,
#          'somewhat_more': 7,
#          'optimal_position': 6,
#          'its_tip': 12,
#          'perc_g/g-j_tube_plmt': 7,
#          'maximum_suv': 8,
#          'mild_chf': 46,
#          'pneumonic_consolidation': 9,
#          'earlier_same_day': 21,
#          'underlying_infectious_process': 9,
#          'not_visualized': 26,
#          'superimposed_pneumonia': 13,
#          'not_significantly': 2,
#          'abdominal_distention': 8,
#          'these_findings': 90,
#          'cell_carcinoma': 1,
#          'ct_scan': 74,
#          'ap_lateral_views': 9,
#          'aortic_arch': 17,
#          'diffuse_alveolar': 10,
#          'approximately_d.d_cm': 8,
#          'since_previous_study': 16,
#          'occipital_lobe': 11,
#          'images_skeleton': 6,
#          'most_likely': 37,
#          'tib/fib_ap': 1,
#          'pa_catheter': 33,
#          'cm_per_second': 6,
#          'glenohumeral_joint': 7,
#          'renal_transplant': 7,
#          'carotid_artery': 4,
#          'retrocardiac_opacification': 9,
#          'aortic_aneurysm': 8,
#          'apical_pleural': 10,
#          'descending_thoracic': 8,
#          'main_portal_vein': 9,
#          'periventricular_white_matter': 13,
#          'resp_failure': 8,
#          'do_not': 15,
#          'was_discussed_with': 14,
#          'left_ventricular_enlargement': 9,
#          'if_warranted': 5,
#          'pulmonary_arterial': 6,
#          'vascular_catheter': 27,
#          'intracranial_hemorrhage_or': 9,
#          'infected_icd': 8,
#          'w/contrast_ct_dddcc_nonionic': 1,
#          'iliac_arteries': 9,
#          'when_compared': 9,
#          'better_evaluated': 7,
#          'previously_demonstrated': 19,
#          'may_related': 1,
#          'pvd_s/p': 6,
#          'lateral_decubitus': 7,
#          'r/o_abscess': 9,
#          'bilateral_pleural_effusions': 278,
#          'rather_than': 12,
#          'ap_upright': 5,
#          'tips_patency': 8,
#          'ap_chest': 136,
#          'bilateral_air_space': 9,
#          'hepatic_encephalopathy_underlying_medical': 7,
#          'concerning_metastatic_disease': 6,
#          'mild_pulmonary_edema': 65,
#          'fluid_status': 15,
#          'ddd_cm/sec': 8,
#          'basilar_atelectasis': 33,
#          'stated_above': 6,
#          'disease\\cath_underlying': 8,
#          'these_areas': 7,
#          'radiograph_chest_reviewed': 17,
#          'was_administered': 14,
#          'focal_consolidation': 17,
#          'bone_lesions': 8,
#          'eval_ptx': 6,
#          'ct_abdomen_w/contrast': 39,
#          'brachiocephalic_vein': 30,
#          'by_telephone': 24,
#          'cephalic_basilic': 6,
#          'deep_venous_thrombosis': 5,
#          'sheath_was': 10,
#          'red_blood': 10,
#          'transition_point': 6,
#          'variceal_bleed': 8,
#          'focal_consolidations': 10,
#          'interval_change': 98,
#          'ct_abd': 33,
#          'frontal_temporal': 1,
#          'dd_pm_chest_fluoro': 10,
#          'liver_parenchyma': 6,
#          'active_bleeding': 7,
#          'please_check': 8,
#          ...})

# %%
list(counted_phrases.most_common())[-500:]
# Out:
# [('extensive_degenerative_changes', 6),
#  ('innominate_vein', 6),
#  ('stenosis_origin', 6),
#  ('should_pulled_back', 6),
#  ('vascular_redistribution', 6),
#  ('last_cxr', 6),
#  ('obtained_with_thallium', 6),
#  ('mildly_enlarged', 6),
#  ('degraded_by', 6),
#  ('detailed_above', 6),
#  ('intra-abdominal_ascites', 6),
#  ('operative_report', 6),
#  ('pulmonary_arteries', 6),
#  ('stab_wound', 6),
#  ('single-lumen_picc', 6),
#  ('r/o_mets', 6),
#  ('two_hours', 6),
#  ('ij_line_placement', 6),
#  ('double_lumen', 6),
#  ('this_examination', 6),
#  ('major_tributaries', 6),
#  ('hazy_opacity', 6),
#  ('evaluate_progression', 6),
#  ('infant_with_increasing', 6),
#  ('dth_rib', 6),
#  ('overlies_proximal', 6),
#  ('foci_abnormally', 6),
#  ('cavity_size', 6),
#  ('flow_signal', 6),
#  ('femoral_vein', 6),
#  ('cecum_not', 6),
#  ('inguinal_region', 6),
#  ('distended_gallbladder', 6),
#  ('esophageal_cancer', 6),
#  ('mra_neck', 6),
#  ('without_radiologist_present', 6),
#  ('chest_compared_to', 6),
#  ('brain_imaging_was_obtained', 6),
#  ('alveolar_infiltrates', 6),
#  ('amount_ascites', 6),
#  ('low_attenuation_lesions', 6),
#  ('renal_cyst', 6),
#  ('grossly_clear', 6),
#  ('without_definite_evidence', 6),
#  ('small_amount_free_fluid', 6),
#  ('antecubital_fossa', 6),
#  ('combined_alveolar_interstitial_pattern', 6),
#  ('on_current_exam', 6),
#  ('could_related_to', 6),
#  ('av_fistulogram', 6),
#  ('flow_velocities', 6),
#  ('would_include', 6),
#  ('retroperitoneal_hemorrhage', 6),
#  ('post-pyloric_feeding_tube', 6),
#  ('dens_fracture', 6),
#  ('ett_pulled_back', 6),
#  ('multilevel_degenerative', 6),
#  ('sternal_wire', 6),
#  ('duplex_dopp_abd/pel', 6),
#  ('ij_central_line', 6),
#  ('weighted_images', 6),
#  ('junction_superior_vena', 6),
#  ('evidence_osteomyelitis', 6),
#  ('team_time', 6),
#  ('hypercarbic_respiratory_failure', 6),
#  ('internal_carotid_arteries', 6),
#  ('images_skeleton', 6),
#  ('cm_per_second', 6),
#  ('left-sided_picc_line', 6),
#  ('pvd_s/p', 6),
#  ('previously_placed', 6),
#  ('most_likely_represent', 6),
#  ('concerning_metastatic_disease', 6),
#  ('tip_swan-ganz_catheter_projects', 6),
#  ('stated_above', 6),
#  ('anterior_posterior_projections', 6),
#  ('resting_perfusion', 6),
#  ('cephalic_basilic', 6),
#  ('vein_thrombosis', 6),
#  ('transition_point', 6),
#  ('bypass_graft/sda', 6),
#  ('interstitial_abnormality', 6),
#  ('compressive_atelectasis', 6),
#  ('free_intraabdominal_air', 6),
#  ('venous_approach', 6),
#  ('projects_over_svc', 6),
#  ('can_not_rule_out', 6),
#  ('intracranial_mass', 6),
#  ('it_difficult_to', 6),
#  ('post_intubation', 6),
#  ('posterior_circulation', 6),
#  ('hepatopetal_flow', 6),
#  ('rapid_afib', 6),
#  ('pt_had', 6),
#  ('marked_increase_in', 6),
#  ('dd_y/o', 6),
#  ('td_weighted', 6),
#  ('free_gas', 6),
#  ('colon_ca', 6),
#  ('markedly_enlarged', 6),
#  ('upper_lungs_clear', 6),
#  ('nasogastric_tube_passes_into', 6),
#  ('pulmonary_arterial', 6),
#  ('limits_evaluation', 6),
#  ('s/p_avr', 6),
#  ('was_prepped_draped', 6),
#  ('technical_differences', 6),
#  ('ddth_rib', 6),
#  ('small_vessel_ischemic', 6),
#  ('probably_represents', 6),
#  ('hilar_lymphadenopathy', 6),
#  ('central_airways', 6),
#  ('not_changed', 5),
#  ('diverticulosis_without', 5),
#  ('cm_above_carina', 5),
#  ('without_evidence_cholecystitis', 5),
#  ('interstitial_pattern', 5),
#  ('brain_with_gadolinium', 5),
#  ('internal_jugular_central_venous', 5),
#  ('ct_guidance', 5),
#  ('completely_excluded', 5),
#  ('was_passed', 5),
#  ('deep_venous_thrombosis', 5),
#  ('discussed_with_clinical', 5),
#  ('contraindications_iv', 5),
#  ('passed_through', 5),
#  ('portal_vein_patent', 5),
#  ('known_history', 5),
#  ('lower_lung_zones', 5),
#  ('ld_ld', 5),
#  ('to_determine', 5),
#  ('lines_tubes_described_above', 5),
#  ('portable_chest_radiograph', 5),
#  ('discussed_with_referring', 5),
#  ('hilar_contours', 5),
#  ('myocardial_infarction_underlying_medical', 5),
#  ('perfusion_defects', 5),
#  ('common_external', 5),
#  ('acute_cardiopulmonary_disease', 5),
#  ('interstitial_lung', 5),
#  ('cm_long', 5),
#  ('deep_venous', 5),
#  ('current_study', 5),
#  ('previous_studies', 5),
#  ('internal_carotid', 5),
#  ('carotid_arteries', 5),
#  ('sided_effusion', 5),
#  ('was_sent', 5),
#  ('smaller_than', 5),
#  ('most_recent', 5),
#  ('ap_upright', 5),
#  ('veins_patent', 5),
#  ('on_hfov', 5),
#  ('gastrointestinal_bleed', 5),
#  ('anterior_posterior', 5),
#  ('dipyridamole_administration', 5),
#  ('greater_saphenous', 5),
#  ('jugular_line', 5),
#  ('left-sided_picc', 5),
#  ('recurrent_ptx', 5),
#  ('wall_trachea', 5),
#  ('arterial_venous', 5),
#  ('territorial_infarction', 5),
#  ('if_warranted', 5),
#  ('mr_head_w/o_contrast', 5),
#  ('mild_congestive', 5),
#  ('lung_base', 5),
#  ('cardiopulmonary_process', 5),
#  ('upper_quadrant', 5),
#  ('post_operative', 5),
#  ('new_areas', 5),
#  ('subdural_fluid_collections', 5),
#  ('loops_small', 4),
#  ('roux-en-y_hepaticojejunostomy', 4),
#  ('normal_size', 4),
#  ('eval_pulm', 4),
#  ('wires_incl', 4),
#  ('intra_or', 4),
#  ('several_days', 4),
#  ('change_from_prior', 4),
#  ('jugular_cv_line', 4),
#  ('evidence_diverticulitis', 4),
#  ('myocardial_infarction', 4),
#  ('common_hepatic', 4),
#  ('involving_inferior', 4),
#  ('due_to_patient_motion', 4),
#  ('standard_position', 4),
#  ('tibial_artery', 4),
#  ('could_secondary_to', 4),
#  ('team_caring', 4),
#  ('recommended_further', 4),
#  ('d.dd_cm', 4),
#  ('amount_free', 4),
#  ('outflow_tract', 4),
#  ('to_previous_study', 4),
#  ('catheter_projects_over', 4),
#  ('main_pulmonary', 4),
#  ('normally_midline', 4),
#  ('ij_line', 4),
#  ('chest_fluoro', 4),
#  ('cm_transverse', 4),
#  ('superior_mesenteric', 4),
#  ('optimal_placement', 4),
#  ('superior_vena', 4),
#  ('resting_images', 4),
#  ('ill_defined', 4),
#  ('ascites_mark', 4),
#  ('in_standard_placement', 4),
#  ('eval_pneumo', 4),
#  ('bilateral_layering', 4),
#  ('cdddd_guid', 4),
#  ('femoral_artery', 4),
#  ('could_advanced', 4),
#  ('days_earlier', 4),
#  ('in_standard', 4),
#  ('td_td', 4),
#  ('line_ready', 4),
#  ('year_old', 4),
#  ('obtained_with_tc-ddm', 4),
#  ('external_carotid', 4),
#  ('carotid_artery', 4),
#  ('ground_glass', 4),
#  ('hilar_lymph', 4),
#  ('ct_head', 4),
#  ('x_d.d', 4),
#  ('present_throughout', 4),
#  ('included_on', 4),
#  ('cerebral_hemispheres', 4),
#  ('abdomen_w/o', 4),
#  ('lateral_views', 4),
#  ('jugular_vein', 4),
#  ('common_carotid', 3),
#  ('ld_vertebral', 3),
#  ('lower_lobe_atelectasis/consolidation', 3),
#  ('was_paged', 3),
#  ('refer_to', 3),
#  ('intraperitoneal_gas', 3),
#  ('x_ray', 3),
#  ('study_yesterday', 3),
#  ('increased_fdg', 3),
#  ('these_findings_time_dictation', 3),
#  ('dedicated_pa', 3),
#  ('overlies_region', 3),
#  ('were_relayed', 3),
#  ('increased_tracer', 3),
#  ('complete_resolution', 3),
#  ('renal_cell', 3),
#  ('aortic_valve', 3),
#  ('overt_chf', 3),
#  ('radiograph_dated', 3),
#  ('biliary_ductal', 3),
#  ('radiograph_compared', 3),
#  ('main_stem', 3),
#  ('been_interval', 3),
#  ('interstitial_alveolar_opacities', 3),
#  ('were_called', 3),
#  ('ett_ngt', 3),
#  ('perfusion_images', 3),
#  ('water_seal', 3),
#  ('ap_film_history', 3),
#  ('not_definitively', 3),
#  ('lung_zone', 3),
#  ('superficial_femoral', 3),
#  ('please_note', 3),
#  ('feeding_tube_overlies', 3),
#  ('diffusion_weighted', 3),
#  ('ventricular_pacer', 3),
#  ('failure_pattern', 3),
#  ('arteries_bilaterally', 3),
#  ('lower_lobe_collapse', 3),
#  ('see_comment', 3),
#  ('more_complete', 3),
#  ('service_caring', 3),
#  ('pulse_volume', 3),
#  ('acute_cardiopulmonary_process', 3),
#  ('abd_w', 3),
#  ('extensive_subcutaneous', 3),
#  ('atelectasis_vs', 3),
#  ('due_to_lack', 3),
#  ('significantly_changed', 3),
#  ('under_fluoroscopic', 3),
#  ('medical_record', 3),
#  ('motor_vehicle', 3),
#  ('brain_imaging', 3),
#  ('jugular_iv', 3),
#  ('mediastinal_lymph', 3),
#  ('patchy_air_space', 3),
#  ('contrast_enhanced', 3),
#  ('mesenteric_artery', 3),
#  ('bibasilar_patchy', 3),
#  ('acute_intracranial_hemorrhage', 3),
#  ('evidence_hydronephrosis', 3),
#  ('tube_removal', 3),
#  ('sagittal_td', 3),
#  ('abnormally_increased', 3),
#  ('extensive_degenerative', 3),
#  ('valve_replacement', 3),
#  ('attending_review', 3),
#  ('were_communicated_to', 3),
#  ('eval_interval_change', 3),
#  ('dd_year', 3),
#  ('process_can', 3),
#  ('following_completion', 2),
#  ('tubes_remain', 2),
#  ('tube_coiled', 2),
#  ('were_conveyed', 2),
#  ('midline_structures', 2),
#  ('tip_projects', 2),
#  ('chest_radiograph_compared_to', 2),
#  ('definite_evidence', 2),
#  ('inf_cdddd', 2),
#  ('appropriate_clinical', 2),
#  ('slight_increase', 2),
#  ('incl_inf', 2),
#  ('neutropenic_fever', 2),
#  ('images_reveal', 2),
#  ('stress_perfusion', 2),
#  ('concerning_metastatic', 2),
#  ('fluoro_time', 2),
#  ('babygram_chest', 2),
#  ('not_significantly', 2),
#  ('top_normal', 2),
#  ('chest_reviewed_compared_with_previous', 2),
#  ('intrahepatic_ductal', 2),
#  ('intraperitoneal_air', 2),
#  ('fdg_activity', 2),
#  ('standard_placement', 2),
#  ('consent_was', 2),
#  ('no_evidence_intra', 2),
#  ('physician_lastname', 2),
#  ('fluid_levels', 2),
#  ('supine_portable', 2),
#  ('saphenous_vein', 2),
#  ('vascular_territorial', 2),
#  ('greater_than_right', 2),
#  ('jugular_approach', 2),
#  ('compared_with_previous', 2),
#  ('radiographic_evidence', 2),
#  ('slight_decrease', 2),
#  ('per_second', 2),
#  ('pneumonia_can', 2),
#  ('under_diaphragm', 2),
#  ('post_thoracentesis', 2),
#  ('yo_m', 2),
#  ('history_lung_cancer', 2),
#  ('crf_amyloidosis', 2),
#  ('changed_from', 2),
#  ('relate_to', 2),
#  ('radiographic_appearance', 2),
#  ('by_motion', 2),
#  ('chest_portable_ap', 2),
#  ('total_length', 2),
#  ('jugular_central', 2),
#  ('air_cells', 2),
#  ('guid_wires', 2),
#  ('warranted_clinically', 2),
#  ('not_changed_significantly', 2),
#  ('vena_cava', 2),
#  ('evidence_intestinal', 2),
#  ('man_with_cad', 2),
#  ('other_significant', 2),
#  ('been_removed', 2),
#  ('c-spine_fracture', 2),
#  ('may_relate', 2),
#  ('one_day', 2),
#  ('d.d_x', 2),
#  ('spread_tumor', 2),
#  ('approximately_d.d', 2),
#  ('cardiopulmonary_abnormality', 2),
#  ('dd_a.m', 2),
#  ('lung_expansion_on_hfov', 2),
#  ('staff_caring', 2),
#  ('fluoro_without_radiologist', 2),
#  ('dddcc_non_ionic_contrast', 2),
#  ('venous_system', 2),
#  ('not_clearly', 2),
#  ('and/or_consolidation', 2),
#  ('studies_available', 2),
#  ('considered_if', 2),
#  ('admitted_with_pna', 2),
#  ('clip_clip', 2),
#  ('may_related', 1),
#  ('low_lung', 1),
#  ('free_intraperitoneal', 1),
#  ('gated_images', 1),
#  ('right-sided_picc', 1),
#  ('subclavian_central_venous_catheter', 1),
#  ('prior_studies_available_comparison', 1),
#  ('one_view_portable', 1),
#  ('were_communicated', 1),
#  ('minutes_fluoro', 1),
#  ('after_dipyridamole', 1),
#  ('now_w', 1),
#  ('likely_related', 1),
#  ('history_trauma', 1),
#  ('current_exam', 1),
#  ('normal_limits', 1),
#  ('attenuation_lesions', 1),
#  ('clinically_indicated', 1),
#  ('extends_below_diaphragm', 1),
#  ('passes_into', 1),
#  ('thoracic_lumbar', 1),
#  ('lower_lobe_collapse/consolidation', 1),
#  ('been_withdrawn', 1),
#  ('unclear_whether', 1),
#  ('note_that', 1),
#  ('lobe_atelectasis', 1),
#  ('informed_consent', 1),
#  ('enlarged_cardiac', 1),
#  ('osseous_metastatic', 1),
#  ('worsening_congestive', 1),
#  ('acute_intracranial', 1),
#  ('lungs_grossly', 1),
#  ('old_man_s/p', 1),
#  ('lobe_atelectasis/consolidation', 1),
#  ('d.dd_cm_near', 1),
#  ('venous_thrombosis', 1),
#  ('tunneled_dialysis', 1),
#  ('glass_opacities', 1),
#  ('passes_below', 1),
#  ('history_cabg', 1),
#  ('volume_recordings', 1),
#  ('middle_lobe', 1),
#  ('extending_below', 1),
#  ('subclavian_cv', 1),
#  ('spleen_pancreas', 1),
#  ('discussed_with_ordering', 1),
#  ('not_ruled', 1),
#  ('jugular_cv', 1),
#  ('been_placed', 1),
#  ('non_ionic', 1),
#  ('old_man', 1),
#  ('cta_abd', 1),
#  ('post_cabg', 1),
#  ('woman_s/p', 1),
#  ('head_w', 1),
#  ('prepped_draped', 1),
#  ('severe_degenerative', 1),
#  ('extends_below', 1),
#  ('size_top', 1),
#  ('changed_since', 1),
#  ('cardiopulmonary_disease', 1),
#  ('note_added', 1),
#  ('main_pa', 1),
#  ('ganz_catheter', 1),
#  ('preliminary_results', 1),
#  ('portable_single_view', 1),
#  ('superior_vena_cava_ready', 1),
#  ('tissue_mass', 1),
#  ('pleural_plaques', 1),
#  ('subclavian_central', 1),
#  ('findings_discussed_with_dr', 1),
#  ('bladder_visualized', 1),
#  ('head_ct_scan', 1),
#  ('has_had', 1),
#  ('abdomen_supine', 1),
#  ('asymmetric_pulmonary', 1),
#  ('elevated_creatinine-dehydration', 1),
#  ('reconstructions_multiplanar', 1),
#  ('possibly_due', 1),
#  ('basilic_veins', 1),
#  ('other_changes', 1),
#  ('consult_service', 1),
#  ('lines_described', 1),
#  ('year_old_man_with_cad', 1),
#  ('alveolar_interstitial', 1),
#  ('entirely_excluded', 1),
#  ('examination_please', 1),
#  ('dr_lastname', 1),
#  ('patent_measuring_from', 1),
#  ('ventricular_ejection', 1),
#  ('cm_above', 1),
#  ('ed_dashboard', 1),
#  ('contours_stable', 1),
#  ('edema_has_improved', 1),
#  ('passes_into_stomach_out', 1),
#  ('plmt_clip', 1),
#  ('interval_decrease', 1),
#  ('cell_carcinoma', 1),
#  ('tib/fib_ap', 1),
#  ('representing_combination', 1),
#  ('adrenal_gland', 1),
#  ('w/contrast_ct_dddcc_nonionic', 1),
#  ('posterior_cerebral', 1),
#  ('tubes_remain_in_place', 1),
#  ('congestive_heart', 1),
#  ('frontal_temporal', 1),
#  ('well_visualized', 1),
#  ('fluoroscopically_guided', 1),
#  ('clearly_visualized', 1),
#  ('findings_consistent', 1),
#  ('wedge_compression', 1),
#  ('calculated_from', 1),
#  ("'s_symptoms", 1),
#  ('pa_lat', 1),
#  ('pelvis_w/o', 1),
#  ('pls_assess', 1),
#  ('if_clinically', 1),
#  ('ventricular_enlargement', 1),
#  ('right-sided_pleural', 1)]

# %%
for phrase, count in list(counted_phrases.items())[:100]:
    print("%s\t%03d"%(phrase.ljust(40),count))

# %% [markdown]
# ## Create a word vector vocabulary using only words and phrases that occur more than N times
# ### How to choose N?

# %% [markdown]
# ### What is our vocabulary from phrased_txt (how many unqiue words)?
#
# Why use `TextBlob.words` instead of just `phrased_txt.split()`?
#
# #### why is `phrased_blob = TextBlob(phrased_txt)` fast and `print(len(set(phrased_blob.words)))` slow?

# %%
phrased_blob = TextBlob(phrased_txt)

# %%
print(len(set(phrased_blob.words)))

# %%
sns.distplot([c[1] for c in phrased_blob_count if c[1] > 500])

# %%
len([w for w in lcounted_phrases if w[1]>10])

# %%
vwords = [w for w in lcounted_phrases if w[1]>100 and w[0] not in stop_words]

# %%
len(vwords)

# %% [markdown]
# ### Determining Similarity Between Reports
# * CXR vs CT vs MR

# %%
rad_data[rad_data["text"].str.contains("MRI")]

# %% [markdown]
# ## Create a Report Browser

# %%
num_reports = rad_data.shape[0]
while True:
    try:
        i = int(input("Enter a number between 0 and %d. otherwise to quit"%num_reports))
        clear_output()

        if i < 0 or i >=num_reports:
            break
        txt = TextBlob(rd.sub("""d""", rad_data.iloc[i]['text'].strip().lower()))
        display(HTML("<>%s</p>"%" ".join(trigram_generator[bigram_generator[txt.tokens]])))
        
    except ValueError:
        break

# %%
type(txt)

# %% [markdown]
# ## Wrangling Doesn't Always Do What You Want
#
# >technique : multiplanar_td and td-weighted_images of the brain with gadolinium_according to standard departmental protocol .
