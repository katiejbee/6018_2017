# %%
import pymysql
import pandas as pd
import getpass
from textblob import TextBlob
import re
from collections import Counter

# %%
conn = pymysql.connect(host="mysql",
                       port=3306,user="jovyan",
                       passwd=getpass.getpass("Enter MySQL passwd for jovyan"),db='mimic2')
cursor = conn.cursor()
# Out:
# Enter MySQL passwd for jovyan········

# %% [markdown]
# ### Use Pandas and SQL to create a dataframe with the following:
# * subject_id
# * hospital admission id
# * text of the radiology report
# * Limit the number of reports to 10000

# %%
rad_data = \
pd.read_sql("""SELECT DISTINCT noteevents.subject_id, 
                      noteevents.hadm_id,
                      noteevents.text 
               FROM noteevents
               WHERE noteevents.category = 'RADIOLOGY_REPORT' LIMIT 5000""",conn)
rad_data.head(5)
# Out:
#    subject_id  hadm_id                                               text
# 0          56  28766.0  \n\n\n     DATE: [**2644-1-17**] 10:53 AM\n   ...
# 1          56  28766.0  \n\n\n     DATE: [**2644-1-17**] 10:43 AM\n   ...
# 2          56  28766.0  \n\n\n     DATE: [**2644-1-17**] 6:37 AM\n    ...
# 3          56  28766.0  \n\n\n     DATE: [**2644-1-19**] 12:09 PM\n   ...
# 4          37  18052.0  \n\n\n     DATE: [**3264-8-14**] 6:06 AM\n    ...

# %%
rad_data.shape
# Out:
# (5000, 3)

# %%
print(rad_data.iloc[20]["text"])
# Out:
#      DATE: [**3352-7-10**] 1:35 PM
#      CHEST (PORTABLE AP)                                             Clip # [**Clip Number (Radiology) 1633**]
#      Reason: Neutropenic fever, day +10 s/p bmt
#      Admitting Diagnosis: NON-HODGKIN'S LYMPHOMIA\BONE MARROW TRANSPLANT
#      ______________________________________________________________________________
#      UNDERLYING MEDICAL CONDITION:
#         54 year old man with NHL here for auto BMT
#      REASON FOR THIS EXAMINATION:
#       Neutropenic fever, day +10 s/p bmt
#      ______________________________________________________________________________
#                                      FINAL REPORT
#      INDICATIONS:  10 days post BMT, ? pneumonia.
#
#      PORTABLE AP CHEST:  Comparison is made to the prior study from [**3352-7-6**]. Exam
#      remains unchanged from previous study. No new infiltrate is seen. No pleural
#      effusions are seen.  The right hemithorax catheter is again seen and remains
#      unchanged from previous exam. The right IJ central venous catheter is again
#      seen and remains unchanged from previous study.
#
#      IMPRESSION: No acute change from previous exam.

# %% [markdown]
# ### Write a function that returns true or false depending on whether the report contains an impression section
#
# #### Hints
#
# * Not every report will have an impression section
# * "INTERPRETATION:" and "CONCLUSIONS:" might be synonyms for "IMPRESSION:"

# %%
def count_impression(report):
    for word in report.split():
        if word == "INTERPRETATION:" or word == "CONCLUSIONS:" or word == "IMPRESSION:":
            return True
        pass
    pass

# %%
def count_impression2(report):
    headings = ["INTERPRETATION:", "CONCLUSIONS:", "IMPRESSION:"]
    for h in headings:
        if h in report:
            return True
    
    return False

# %%
# %timeit count_impression2(rad_data.iloc[0]["text"])
# Out:
# 284 µs ± 4.91 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %timeit count_impression(rad_data.iloc[0]["text"])
# Out:
# 359 µs ± 4.17 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
sum([count_impression(report) for report in rad_data["text"]])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-02d961b7dfb1> in <module>()
# ----> 1 sum([count_impression(report) for report in rad_data["text"]])
#
# TypeError: unsupported operand type(s) for +: 'int' and 'NoneType'

# %% [markdown]
# ### Write a function that returns the impression section of a report

# %%
def get_impression(report):
    headings = ["INTERPRETATION:", "CONCLUSIONS:", "IMPRESSION:"]
    for h in headings:
        if h in report:
            return report[report.find(h):]
    
    return report

# %%
get_impression(rad_data.iloc[20]["text"])
# Out:
# 'IMPRESSION: No acute change from previous exam.\n\n'

# %% [markdown]
# ### Define Regular expressions for data cleansing
#
# We have a lot of patterns that are unique and don't convey meaningful information
#
# * De-identified names, dates, etc.
#     * `[**Clip Number (Radiology) 12569**]`
#     * `DATE: [**3352-7-10**] `
#     * `[**Hospital 12568**]`
#     * `[**Last Name (NamePattern4) 337**]`
#     * `[**First Name8 (NamePattern2) 12565**]`
#     * `[**Last Name (NamePattern1) 12566**]`
# * Separators  (e.g. `__________________`)
#
# ### Split into groups and write and test regular expressions to capture these patterns
# * Write a regular expression to replace dates in the reports with ``[**DATE**]``
# * Write a regular expression to replace times in the reports with ``[**TIME**]``
# * Write a regular expression to replaces digits with "d", (e.g. "43 cc" would become "dd cm")

# %%
date=re.compile(r"""((?P<month>[A-Z][a-z]{2,}(\.)?) (?P<day>[0-9]{1,2}))""")
last_name=re.compile(r"""(\[\*\*Last Name \((NamePattern|STitle)(\d+)?\) [0-9]*\*\*\])""")
clip = re.compile(r"""\[\*\*Clip Number \(Radiology\) \d+\*\*\]""")
date2 = re.compile(r"""DATE\: \[\*\*\d+-\d+-\d+\*\*\]""")
hospital=re.compile(r"""(\[\*\*Hospital \d+\*\*\])""")
unders = re.compile(r"""_{2,}""")

age2 = re.compile(r"""(?P<age>[0-9]+)(-|\s)y(ear(s)?|\.)(-|\s)?o(ld|\.)""")
age3 = re.compile(r"""\bage(d)? (?P<age>[0-9]+)""")
digits = re.compile(r"""\d""")
def age_in_decades(m):
    age = int(m.group("age"))
    
    return "[** Age in %ss**]"%(int(age/10)*10,)

age_in_decades(next(age2.finditer("74-year-old")))
#tmp = re.sub(age2, age_in_decades, re.sub(age3, age_in_decades, report_txt))
# Out:
# '[** Age in 70s**]'

# %%
unders.findall(rad_data.iloc[20]["text"])
# Out:
# ['______________________________________________________________________________',
#  '______________________________________________________________________________']

# %%
hospital.findall("""Dr. [**Last Name (STitle) 13    * `[**Hospital 12568**]`
927**] and Dr. [**Last Name (STitle) 13928**] on""")
# Out:
# ['[**Hospital 12568**]']

# %%
clip.findall("""BONE SCAN                                                       Clip # [**Clip Number (Radiology) 13926**]""")
# Out:
# ['[**Clip Number (Radiology) 13926**]']

# %%
date2.findall("""DATE: [**3352-7-10**]""")
# Out:
# ['DATE: [**3352-7-10**]']

# %% [markdown]
# #### Hints
#
# * Look at some sample reports to see what dates and times look like in the reports
# * What order would you need to apply the regular expressions?

# %%
def preprocess(report):
    return digits.sub("d",unders.sub("\n",
               hospital.sub("HOSPITAL", 
                            date2.sub("DATE", 
                                      clip.sub("CLIP", 
                                               last_name.sub("LASTNAME", report))))))

# %%
for i in range(10):
    print(preprocess(rad_data.iloc[i]['text']))
    print("*"*42,"\n\n")
# Out:
#      DATE dd:dd AM
#      MR HEAD W & W/O CONTRAST; MR CONTRAST GADOLIN                   Clip # CLIP
#      Reason: R ICB and HX brain mets - eval - also with DWI for CVA Do MR
#       Contrast: MAGNEVIST Amt: dd
#
#
#      UNDERLYING MEDICAL CONDITION:
#       [**Age over dd **] year old woman with lung CA- mets to brain
#      REASON FOR THIS EXAMINATION:
#       R ICB and HX brain mets - eval - also with DWI for CVA Do MRI both with and
#       without contast please
#
#
#                                      FINAL REPORT
#      EXAMINATION:  MRI of the brain with and without gadolinium.
#
#      INDICATION:  [**Age over dd **] year old woman with lung cancer and right intracranial bleed
#      and history of brain metastases.  Please evaluate for acute infarct.
#
#      TECHNIQUE:  Multiplanar Td and Td-weighted images of the brain with gadolinium
#      according to standard departmental protocol.  No prior study for comparison.
#
#      FINDINGS:  On diffusion-weighted images there is a small area of restricted
#      diffusion along the falx within the left occipitotemporal lobe.  It is also
#      bright on FLAIR-weighted images and may represent a subacute infarct. Clinical
#      correlation is recommended.  On gradient echo images there is a large area of
#      intraparenchymal hemorrhage within the right parietal lobe and left thalamus
#      which following administration of gadolinium reveals ring-enhancing lesions.
#      These are suspicious for hemorrhagic metastases given the patient's history.
#      Additional ring-enhancing lesions throughout the supra- and infratentorial
#      compartments are visualized.  There is a moderate amount of peritumoral edema
#      involving the right parietal lobe lesion in addition to a second right
#      parietal lesion along the falx high in the vertex.  The other areas of
#      metastases reveal a minimal amount of peritumoral edema.
#
#
#
# ******************************************
#
#
#
#
#
#      DATE dd:dd AM
#      CT HEAD W/O CONTRAST                                            Clip # CLIP
#      Reason: ? stability of bleed
#      Admitting Diagnosis: HEAD BLEED
#
#
#      UNDERLYING MEDICAL CONDITION:
#       [**Age over dd **] year old woman with ? hemorragic mass
#      REASON FOR THIS EXAMINATION:
#       ? stability of bleed
#      No contraindications for IV contrast
#
#
#                                      FINAL REPORT  (REVISED)
#      HISTORY:  [**Age over dd **] year-old woman with a history of metastatic lung cancer to the
#      brain.  Question hemorrhagic mass.  Question stability of bleed.
#
#      COMPARISON:  Head CT from HOSPITAL Hospital dated [**dddd-d-dd**].
#
#      TECHNIQUE:  Noncontrast head CT.
#
#      FINDINGS:  Compared to the prior days study, there is stable appearance of the
#      right parietal intraparenchymal hemorrhage with surrounding edema.  At the
#      superior margin of the parenchymal hemorrhage there is a rounded heterogeneous
#      focus which could represent a metastatic lesion.  An additional dmm hyperdense
#      focus, possibly hemorrhage, is noted in the posteromedial margin of the left
#      thalamus, with surroundng edema.  Low-attenuation foci seen in both basal
#      ganglia and insular regions are consistent with chronic lacunar infarcts.
#      There is no shift of midline structures.  The ventricles are stable in
#      appearance.  The osseous and soft tissue structures are unremarkable.
#
#      IMPRESSION:  Stable appearance of right parietal lobe and left thalamic
#      hemorrhages, which are concerning for hemorrhagic metastasis in this patient
#      with known metastatic lung carcinoma to the brain.
#
#
#
#
# ******************************************
#
#
#
#
#
#      DATE d:dd AM
#      CHEST (PORTABLE AP)                                             Clip # CLIP
#      Reason: NGT placement
#      Admitting Diagnosis: HEAD BLEED
#
#
#      UNDERLYING MEDICAL CONDITION:
#       [**Age over dd **] year old woman with SAH
#      REASON FOR THIS EXAMINATION:
#       NGT placement
#
#
#                                      FINAL REPORT
#      INDICATION:  A [**Age over dd **]-year-old woman with SAH.  Nasogastric tube placement.
#
#      TECHNIQUE:  Portable AP chest radiograph.
#
#      There is no previous chest radiograph for comparison.
#
#      FINDINGS:
#
#      The patient is status post median sternotomy.  Scoliosis is noted.  The
#      patient is rotated.
#
#      Note is made of mild cardiomegaly.  Note is made of rounded opacity overlying
#      the left hilum, which probably representing aspiration pneumonia; however,
#      left hilar mass cannot be totally excluded.  Mild CHF is noted.  No
#      pneumothorax is noted.  Nasogastric tube is coursing down below the left
#      hemidiaphragm.
#
#      IMPRESSION:
#
#      Cardiomegaly and mild CHF.  Nasogastric tube as described above.  Rounded
#      opacity overlying the left hilum, which probably representing aspiration
#      pneumonia; however, left hilar mass cannot be totally excluded.  Please
#      confirm resolution by repeated chest x-ray after treatment, and if the lesion
#      persists, please evaluate by CT scan.
#
#      The information is communicated with the referring physician, LASTNAME. [**First Named (NamePatternd) ddddd**] LASTNAME
#      by telephone in the morning of [**dddd-d-dd**].
#
#
#
# ******************************************
#
#
#
#
#
#      DATE dd:dd PM
#      CHEST (PORTABLE AP)                                             Clip # CLIP
#      Reason: aspiration pna?
#      Admitting Diagnosis: HEAD BLEED
#
#
#      UNDERLYING MEDICAL CONDITION:
#        [**Age over dd **] year old woman with ICH and nmoe with increased secretions
#
#      REASON FOR THIS EXAMINATION:
#       aspiration pna?
#
#
#                                      FINAL REPORT
#      This is a portable semierect chest that is dated [**dddd-d-dd**] compared to
#      [**dddd-d-dd**].
#
#      CLINICAL INDICATION:  Question aspiration pneumonia.
#
#      Nasogastric tube terminates below the diaphragm.  The cardiac silhouette
#      appears enlarged, but stable.  There is a large mass-like opacity overlying
#      the left hilum, which has slightly lobulated margins.  This measures about d
#      cm in greatest diameter.  Bilateral pleural effusions are noted, moderate on
#      the left and small on the right.  No pneumothorax is identified.
#
#      As compared to the previous study, alveolar opacities adjacent to the
#      perihilar mass have resolved.
#
#      IMPRESSION:
#
#      Marked improvement in left perihilar alveolar process with residual
#      well-marginated mass-like opacity, concerning for neoplasm.  This could be
#      initially confirmed with PA and lateral chest radiographs, but CT may be
#      considered for more complete characterization.  Findings communicated to
#      clinical service caring for the patient.
#
#
#
# ******************************************
#
#
#
#
#
#      DATE d:dd AM
#      CHEST (PORTABLE AP)                                             Clip # CLIP
#      Reason: r/o chf
#
#
#      UNDERLYING MEDICAL CONDITION:
#       dd year old man with sob, hx of chf
#      REASON FOR THIS EXAMINATION:
#       r/o chf
#
#
#                                      FINAL REPORT
#      INDICATION: Shortness of breath.
#
#      COMPARISON: [**dddd-d-dd**].
#
#      CHEST, AP PORTABLE RADIOGRAPH: There is stable moderate cardiomegaly in a
#      patient s/p CABG. There are multiple sternal wires which again appear
#      disrupted. There is mild to moderate pulmonary vascular redistribution and
#      hazy illdefined opacity obscuring the left cardiac silhouette. Tiny nodule in
#      the right upper lobe is unchanged. There is either a tiny nodule in the
#      lingula vs. vessel on end. The osseous structures are unremarkable.
#
#      IMPRESSION: Stable cardiomegaly with pulmonary vascular redistribution and new
#      lingular opacity. This could either represent pneumonia vs. asymmetric
#      pulmonary edema.
#
#
# ******************************************
#
#
#
#
#
#      DATE dd:dd AM
#      CHEST (PORTABLE AP)                                             Clip # CLIP
#      Reason: dd yo M with CHF and possible pna, now with acute worsening
#
#
#      UNDERLYING MEDICAL CONDITION:
#       dd year old man with sob, hx of chf, cad s/p CABG
#      REASON FOR THIS EXAMINATION:
#       dd yo M with CHF and possible pna, now with acute worsening of SOB and
#       increasing Od requirement, eval for worsening failure, new infiltrates or pulm
#       process
#
#
#                                      FINAL REPORT
#      PORTABLE CHEST:
#
#      CLINICAL INDICATION:  Worsening shortness of breath and oxygen requirement.
#
#      Comparison is made to prior chest radiographs of [**dddd-d-dd**] and [**d-dd**], dddd.
#
#      The heart is enlarged but stable in size.  There is persistent upper zone
#      vascular redistribution and perihilar haziness.  Additionally, there is an
#      area of increased opacity in the lingula which obscures the left heart border.
#      Note is made of disruption and malalignment of the sternal wires which is
#      unchanged dating back to [**dddd-d-dd**].
#
#      IMPRESSION:
#      d)  Confluent lingular opacity concerning for pneumonia.  When the patient's
#      condition permits, more complete evaluation with standard PA and lateral chest
#      radiographs is recommended.
#      d)  Mild congestive heart failure pattern.
#      d)  Malalignment and disruption of multiple sternal wires which appears to be
#      chronic.  This may be due to a chronic sternal dehiscence.
#
#
# ******************************************
#
#
#
#
#
#      DATE d:dd AM
#      CT HEAD W/O CONTRAST                                            Clip # CLIP
#      Reason: Please r/o bleed - pt has been ruled in for MI and is on hep
#      Admitting Diagnosis: CONGESTIVE HEART FAILURE
#
#
#      UNDERLYING MEDICAL CONDITION:
#       dd year old man w/ CAD, s/p CABG, CHF, COPD, IDDM, presenting with NSTEMI.
#      REASON FOR THIS EXAMINATION:
#       Please r/o bleed - pt has been ruled in for MI and is on heparin drip, but he
#       is experiencing some confusion and his Hct dropped from dd --> dd.  Please do
#       STAT Head CT if possible, b/c we need to know if we should stop the heparin.
#      CONTRAINDICATIONS for IV CONTRAST:
#       h/o IDDM, borderline Cr
#
#
#                                      FINAL REPORT  (REVISED)
#      INDICATION:  Confusion and hematocrit drop while on Heparin.
#
#      TECHNIQUE:  CT head without contrast.
#
#      COMPARISONS: CT head of [**dddd-d-dd**].
#
#      FINDINGS:  There is no intraparenchymal or extra axial hemorrhage. There is no
#      shift of normally midline structures or mass effect. There has been no
#      interval change in the appearance of the brain since the prior scan. There is
#      again demonstrated extensive atherosclerotic calcifications within the
#      cavernous portions of the internal carotid arteries bilaterally. The
#      surrounding osseous and visualized paranasal sinuses are unremarkable.
#
#      IMPRESSION:  No intracranial hemorrhage or mass effect.
#
#
#
# ******************************************
#
#
#
#
#
#      DATE d:dd PM
#      CT ABDOMEN W/O CONTRAST; CT PELVIS W/O CONTRAST                 Clip # CLIP
#      Reason: r/o bleed
#      Admitting Diagnosis: CONGESTIVE HEART FAILURE
#
#
#      UNDERLYING MEDICAL CONDITION:
#       dd year old man with CAD, s/p CABG, HTN, CHF, COPD here in hospital for cath on
#       Monday now with acute Hct drop from dd - dd - dd overnight.
#      REASON FOR THIS EXAMINATION:
#       r/o bleed
#      CONTRAINDICATIONS for IV CONTRAST:
#       h/o diabetes
#
#
#                                      FINAL REPORT
#      HISTORY:  dd y/o man status post CABG and acute drop in hematocrit.
#
#      TECHNIQUE: Axial images of the abdomen and pelvis were obtained without IV
#      contrast.
#
#      COMPARISONS: Not available.
#
#      CT ABDOMEN W/O CONTRAST:  Lung bases demonstrate patchy opacity in the region
#      of the lingula. There is no pleural effusion. The liver appears unremarkable
#      without focal abnormality.  There are several small gallstones noted within
#      the gallbladder.  The pancreas, spleen, adrenal glands, and right kidney
#      appear unremarkable.  There is a small punctate calcification noted within the
#      mid pole of the left kidney which could represent a small renal stone. There
#      is no evidence of hydronephrosis.  Visualized large and small bowel loops
#      appear unremarkable. There is no significant mesenteric or retroperitoneal
#      lymphadenopathy.  There is no free air or free fluid within the abdomen.
#
#      CT PELVIS W/O CONTRAST:  The prostate is slight enlarged. The urinary bladder
#      and rectum appear unremarkable.  There is no pelvic lymphadenopathy or pelvic
#      free fluid.
#
#      BONE WINDOWS demonstrate no evidence of suspicious lytic or blastic lesions.
#
#      IMPRESSION:
#
#      d) No evidence of retroperitoneal hemorrhage.
#      d) Cholelithiasis without evidence of cholecystitis.
#      d) Lingular infiltrate and pneumonia should be considered in the appropriate
#      clinical setting.
#      d) There is a small subcentimeter stone within the left kidney without
#      evidence of hydronephrosis.
#
#
# ******************************************
#
#
#
#
#
#      DATE d:dd PM
#      CHEST (PORTABLE AP)                                             Clip # CLIP
#      Reason: dd yo M CHF, SOB
#      Admitting Diagnosis: CONGESTIVE HEART FAILURE
#
#
#      UNDERLYING MEDICAL CONDITION:
#         dd year old man with sob, hx of chf, cad s/p CABG
#
#      REASON FOR THIS EXAMINATION:
#       dd yo M CHF, SOB
#
#
#                                      FINAL REPORT
#      INDICATION:  Shortness of breath with history of CHF and CAD.
#
#      Comparison [**dddd-d-dd**].
#
#      FINDINGS:  Patient is status post CABG and multiple sternal wires appear
#      fractured, not changed since the previous exam.  Cardiac and mediastinal
#      contours are also unchanged.  Pulmonary vasculature is indistinct, and there
#      remains vague increased density in the lingula.  No appreciable effusion.  No
#      pneumothorax.
#
#      IMPRESSION:
#      d. Persistence of interval slight worsening of degree of patchy opacity within
#      the lingula.  Continued follow up is recommended to exclude pneumonia.
#      d. Persistent mild CHF.
#
#
# ******************************************
#
#
#
#
#
#      DATE d:dd PM
#      CHEST (PORTABLE AP)                                             Clip # CLIP
#      Reason: for ng tube placement
#      Admitting Diagnosis: CONGESTIVE HEART FAILURE
#
#
#      UNDERLYING MEDICAL CONDITION:
#          dd year old man with sob, hx of chf, cad s/p CABG
#
#      REASON FOR THIS EXAMINATION:
#       for ng tube placement
#
#
#                                      FINAL REPORT
#      PORTABLE AP CHEST:
#
#      INDICATION:  NGT placement.
#
#      COMPARISON:  Earlier, same day.
#
#      FINDINGS:  Since the previous exam, a NGT has been placed, with tip just below
#      the diaphragm.  Multiple sideholes are above the diaphragm, and the tube
#      should be advanced several inches.  No appreciable change is seen within the
#      remainder of the chest.
#
#
# ******************************************

# %% [markdown]
# ### You can use the Pandas `iloc` method to grab specific reports

# %%
print(rad_data.iloc[0]["text"])
# Out:
#      DATE: [**2644-1-17**] 10:53 AM
#      MR HEAD W & W/O CONTRAST; MR CONTRAST GADOLIN                   Clip # [**Clip Number (Radiology) 12569**]
#      Reason: R ICB and HX brain mets - eval - also with DWI for CVA Do MR
#       Contrast: MAGNEVIST Amt: 15
#      ______________________________________________________________________________
#      UNDERLYING MEDICAL CONDITION:
#       [**Age over 90 **] year old woman with lung CA- mets to brain
#      REASON FOR THIS EXAMINATION:
#       R ICB and HX brain mets - eval - also with DWI for CVA Do MRI both with and
#       without contast please
#      ______________________________________________________________________________
#                                      FINAL REPORT
#      EXAMINATION:  MRI of the brain with and without gadolinium.
#
#      INDICATION:  [**Age over 90 **] year old woman with lung cancer and right intracranial bleed
#      and history of brain metastases.  Please evaluate for acute infarct.
#
#      TECHNIQUE:  Multiplanar T1 and T2-weighted images of the brain with gadolinium
#      according to standard departmental protocol.  No prior study for comparison.
#
#      FINDINGS:  On diffusion-weighted images there is a small area of restricted
#      diffusion along the falx within the left occipitotemporal lobe.  It is also
#      bright on FLAIR-weighted images and may represent a subacute infarct. Clinical
#      correlation is recommended.  On gradient echo images there is a large area of
#      intraparenchymal hemorrhage within the right parietal lobe and left thalamus
#      which following administration of gadolinium reveals ring-enhancing lesions.
#      These are suspicious for hemorrhagic metastases given the patient's history.
#      Additional ring-enhancing lesions throughout the supra- and infratentorial
#      compartments are visualized.  There is a moderate amount of peritumoral edema
#      involving the right parietal lobe lesion in addition to a second right
#      parietal lesion along the falx high in the vertex.  The other areas of
#      metastases reveal a minimal amount of peritumoral edema.

# %%
print(rad_data.iloc[0]["text"])
# Out:
#      DATE: [**2644-1-17**] 10:53 AM
#      MR HEAD W & W/O CONTRAST; MR CONTRAST GADOLIN                   Clip # [**Clip Number (Radiology) 12569**]
#      Reason: R ICB and HX brain mets - eval - also with DWI for CVA Do MR
#       Contrast: MAGNEVIST Amt: 15
#      ______________________________________________________________________________
#      UNDERLYING MEDICAL CONDITION:
#       [**Age over 90 **] year old woman with lung CA- mets to brain
#      REASON FOR THIS EXAMINATION:
#       R ICB and HX brain mets - eval - also with DWI for CVA Do MRI both with and
#       without contast please
#      ______________________________________________________________________________
#                                      FINAL REPORT
#      EXAMINATION:  MRI of the brain with and without gadolinium.
#
#      INDICATION:  [**Age over 90 **] year old woman with lung cancer and right intracranial bleed
#      and history of brain metastases.  Please evaluate for acute infarct.
#
#      TECHNIQUE:  Multiplanar T1 and T2-weighted images of the brain with gadolinium
#      according to standard departmental protocol.  No prior study for comparison.
#
#      FINDINGS:  On diffusion-weighted images there is a small area of restricted
#      diffusion along the falx within the left occipitotemporal lobe.  It is also
#      bright on FLAIR-weighted images and may represent a subacute infarct. Clinical
#      correlation is recommended.  On gradient echo images there is a large area of
#      intraparenchymal hemorrhage within the right parietal lobe and left thalamus
#      which following administration of gadolinium reveals ring-enhancing lesions.
#      These are suspicious for hemorrhagic metastases given the patient's history.
#      Additional ring-enhancing lesions throughout the supra- and infratentorial
#      compartments are visualized.  There is a moderate amount of peritumoral edema
#      involving the right parietal lobe lesion in addition to a second right
#      parietal lesion along the falx high in the vertex.  The other areas of
#      metastases reveal a minimal amount of peritumoral edema.

# %% [markdown]
# ### Create a new column named "impression" for storing just the impression portion of the report

# %%
rad_data["impression"] = \
rad_data.apply(lambda row: preprocess(get_impression(row["text"])).lower(), axis=1)

# %%
rad_data.head()
# Out:
#    subject_id  hadm_id                                               text  \
# 0          56  28766.0  \n\n\n     DATE: [**2644-1-17**] 10:53 AM\n   ...
# 1          56  28766.0  \n\n\n     DATE: [**2644-1-17**] 10:43 AM\n   ...
# 2          56  28766.0  \n\n\n     DATE: [**2644-1-17**] 6:37 AM\n    ...
# 3          56  28766.0  \n\n\n     DATE: [**2644-1-19**] 12:09 PM\n   ...
# 4          37  18052.0  \n\n\n     DATE: [**3264-8-14**] 6:06 AM\n    ...
#
#                                           impression
# 0  \n\n\n     date dd:dd am\n     mr head w & w/o...
# 1  impression:  stable appearance of right pariet...
# 2  impression:\n     \n     cardiomegaly and mild...
# 3  impression:\n     \n     marked improvement in...
# 4  impression: stable cardiomegaly with pulmonary...

# %%
print(rad_data.iloc[20]["impression"])
# Out:
# impression: no acute change from previous exam.

# %% [markdown]
# ### How many unique words occur in the corpus?
#
# #### Hint
#
# 1. Use TextBlob
# 1. Put all the reports into a single string
#
# #### I got 8658

# %%
#" ".join(rad_data["impression"])

# %%
blob = TextBlob(" ".join(rad_data["impression"]))
unique_impression_words = set(blob.words)
print(len(unique_impression_words))
# Out:
# 7402

# %%
c = Counter(blob.words)
c.most_common()
# Out:
# [('the', 11920),
#  ('of', 8221),
#  ('d', 5718),
#  ('and', 4548),
#  ('is', 4467),
#  ('with', 4256),
#  ('impression', 4096),
#  ('in', 4087),
#  ('dd', 3800),
#  ('right', 3218),
#  ('no', 3184),
#  ('left', 2783),
#  ('to', 2764),
#  ('for', 2465),
#  ('clip', 2367),
#  ('a', 2061),
#  ('chest', 2025),
#  ('reason', 2014),
#  ('there', 1824),
#  ('this', 1650),
#  ('tube', 1548),
#  ('pleural', 1451),
#  ('date', 1339),
#  ('report', 1294),
#  ('final', 1225),
#  ('evidence', 1210),
#  ('are', 1199),
#  ('at', 1187),
#  ('on', 1138),
#  ('ct', 1113),
#  ('contrast', 1096),
#  ('or', 1083),
#  ('placement', 1025),
#  ('examination', 1008),
#  ('be', 988),
#  ('small', 978),
#  ('bilateral', 974),
#  ('pulmonary', 966),
#  ('pneumothorax', 949),
#  ('effusion', 942),
#  ('ap', 925),
#  ('underlying', 902),
#  ('lower', 895),
#  ('lobe', 864),
#  ('lung', 847),
#  ('interval', 843),
#  ('line', 839),
#  ('portable', 819),
#  ('medical', 809),
#  ('study', 788),
#  ('findings', 775),
#  ('condition', 773),
#  ('pm', 767),
#  ('prior', 762),
#  ('diagnosis', 749),
#  ('change', 744),
#  ('tip', 743),
#  ('old', 741),
#  ('edema', 736),
#  ('within', 725),
#  ('not', 725),
#  ('year', 706),
#  ('admitting', 704),
#  ('as', 696),
#  ('was', 693),
#  ('atelectasis', 680),
#  ('effusions', 649),
#  ('s/p', 647),
#  ('catheter', 641),
#  ('pneumonia', 610),
#  ('am', 595),
#  ('which', 587),
#  ('seen', 587),
#  ('unchanged', 583),
#  ('over', 581),
#  ('from', 579),
#  ('patient', 546),
#  ('has', 535),
#  ('new', 523),
#  ('compared', 516),
#  ('please', 514),
#  ('upper', 497),
#  ('dddd-d-dd', 494),
#  ('position', 474),
#  ('history', 471),
#  ('failure', 470),
#  ('stable', 468),
#  ('man', 466),
#  ('likely', 461),
#  ('cm', 458),
#  ('artery', 456),
#  ('ddd', 455),
#  ('abdomen', 455),
#  ('mild', 448),
#  ('lastname', 447),
#  ('appearance', 443),
#  ('name', 439),
#  ('heart', 438),
#  ('an', 438),
#  ('may', 430),
#  ('disease', 426),
#  ('size', 424),
#  ('above', 418),
#  ('consistent', 414),
#  ('were', 408),
#  ('increased', 408),
#  ('w/o', 401),
#  ('acute', 400),
#  ('significant', 398),
#  ('view', 396),
#  ('normal', 394),
#  ('cont', 380),
#  ('chf', 372),
#  ('fluid', 371),
#  ('evaluate', 370),
#  ('opacity', 366),
#  ('first', 366),
#  ('now', 364),
#  ('by', 359),
#  ('but', 359),
#  ('since', 353),
#  ('indication', 351),
#  ('comparison', 350),
#  ('eval', 344),
#  ('vein', 342),
#  ('these', 340),
#  ('persistent', 339),
#  ('been', 336),
#  ('identified', 334),
#  ('consolidation', 330),
#  ('without', 330),
#  ('film', 326),
#  ('moderate', 321),
#  ('large', 316),
#  ('woman', 313),
#  ('images', 311),
#  ('could', 311),
#  ('post', 309),
#  ('distal', 308),
#  ('liver', 306),
#  ('dr', 305),
#  ('pelvis', 304),
#  ('mass', 304),
#  ('opacities', 300),
#  ('hemorrhage', 296),
#  ('status', 296),
#  ('can', 295),
#  ('previous', 294),
#  ('dddd', 290),
#  ('represent', 288),
#  ('due', 287),
#  ('single', 282),
#  ('multiple', 280),
#  ('changes', 279),
#  ('fracture', 276),
#  ('region', 273),
#  ('present', 273),
#  ('clinical', 271),
#  ('central', 270),
#  ('amt', 266),
#  ('stomach', 265),
#  ('bowel', 264),
#  ('assess', 264),
#  ('air', 262),
#  ('subclavian', 261),
#  ('worsening', 261),
#  ('ng', 260),
#  ('noted', 259),
#  ('lateral', 252),
#  ('diffuse', 249),
#  ('namepatternd', 242),
#  ('w', 239),
#  ('svc', 237),
#  ('w/contrast', 235),
#  ('exam', 234),
#  ('proximal', 232),
#  ('base', 231),
#  ('wall', 229),
#  ('excluded', 229),
#  ('also', 228),
#  ('picc', 227),
#  ('venous', 227),
#  ('d.d', 224),
#  ('radiograph', 223),
#  ('slight', 222),
#  ('r/o', 221),
#  ('named', 220),
#  ('endotracheal', 218),
#  ('level', 217),
#  ('dddd-dd-dd', 217),
#  ('than', 216),
#  ('ascites', 211),
#  ('obtained', 210),
#  ('dddd-d-d', 209),
#  ('both', 209),
#  ('head', 208),
#  ('congestive', 207),
#  ('slightly', 204),
#  ('interstitial', 204),
#  ('bibasilar', 202),
#  ('that', 202),
#  ('vascular', 202),
#  ('lungs', 201),
#  ('discussed', 201),
#  ('recommended', 201),
#  ("'s", 201),
#  ('optiray', 200),
#  ('posterior', 199),
#  ('carina', 199),
#  ('performed', 198),
#  ('mr', 198),
#  ('ij', 196),
#  ('again', 196),
#  ('however', 195),
#  ('feeding', 194),
#  ('cardiomegaly', 192),
#  ('aspiration', 192),
#  ('satisfactory', 192),
#  ('focal', 191),
#  ('process', 190),
#  ('limited', 189),
#  ('obstruction', 189),
#  ('time', 188),
#  ('tubes', 187),
#  ('renal', 186),
#  ('jugular', 184),
#  ('patchy', 184),
#  ('described', 184),
#  ('well', 181),
#  ('lesion', 180),
#  ('associated', 179),
#  ('last', 178),
#  ('telephone/fax', 177),
#  ('improvement', 177),
#  ('flow', 177),
#  ('if', 177),
#  ('internal', 177),
#  ('cardiac', 177),
#  ('other', 175),
#  ('et', 175),
#  ('increase', 173),
#  ('evaluation', 172),
#  ('into', 170),
#  ('mid', 170),
#  ('extensive', 170),
#  ('most', 169),
#  ('amount', 169),
#  ('abdominal', 169),
#  ('brain', 168),
#  ('recent', 167),
#  ('radiology', 167),
#  ('metastatic', 167),
#  ('after', 165),
#  ('possible', 165),
#  ('previously', 165),
#  ('area', 165),
#  ('lines', 165),
#  ('free', 163),
#  ('approximately', 163),
#  ('hepatic', 162),
#  ('more', 162),
#  ('some', 161),
#  ('hematoma', 161),
#  ('nasogastric', 161),
#  ('anterior', 160),
#  ('thoracic', 160),
#  ('junction', 158),
#  ('patent', 156),
#  ('dddcc', 155),
#  ('two', 155),
#  ('d-dd', 154),
#  ('mediastinal', 154),
#  ('scan', 153),
#  ('lesions', 153),
#  ('thickening', 153),
#  ('chronic', 152),
#  ('field', 152),
#  ('technique', 150),
#  ('low', 150),
#  ('infiltrate', 149),
#  ('further', 149),
#  ('otherwise', 149),
#  ('made', 148),
#  ('stenosis', 148),
#  ('pa', 147),
#  ('successful', 146),
#  ('through', 145),
#  ('emphysema', 145),
#  ('improved', 144),
#  ('spine', 143),
#  ('superior', 143),
#  ('retrocardiac', 142),
#  ('ddddd', 142),
#  ('biliary', 141),
#  ('its', 141),
#  ('greater', 140),
#  ('one', 140),
#  ('results', 140),
#  ('intracranial', 140),
#  ('place', 140),
#  ('areas', 139),
#  ('it', 138),
#  ('service', 138),
#  ('appears', 138),
#  ('supine', 138),
#  ('visualized', 138),
#  ('definite', 137),
#  ('apical', 137),
#  ('frontal', 137),
#  ('ett', 136),
#  ('have', 134),
#  ('femoral', 133),
#  ('iv', 133),
#  ('main', 133),
#  ('same', 133),
#  ('probably', 132),
#  ('subdural', 132),
#  ('earlier', 131),
#  ('check', 131),
#  ('pain', 129),
#  ('collection', 129),
#  ('abnormal', 128),
#  ('vertebral', 127),
#  ('infection', 127),
#  ('probable', 126),
#  ('up', 126),
#  ('m.d', 126),
#  ('placed', 126),
#  ('adjacent', 126),
#  ('gallbladder', 125),
#  ('body', 124),
#  ('given', 123),
#  ('severe', 123),
#  ('left-sided', 123),
#  ('day', 122),
#  ('right-sided', 121),
#  ('doctor', 121),
#  ('density', 120),
#  ('removal', 118),
#  ('swan-ganz', 118),
#  ('interpretation', 118),
#  ('c', 118),
#  ('colon', 117),
#  ('port', 117),
#  ('views', 117),
#  ('gas', 116),
#  ('bleed', 115),
#  ('abd', 115),
#  ('soft', 114),
#  ('arteries', 114),
#  ('volume', 114),
#  ('ptx', 114),
#  ('sepsis', 113),
#  ('inferior', 111),
#  ('td', 111),
#  ('along', 111),
#  ('kidney', 110),
#  ('basilar', 110),
#  ('portion', 110),
#  ('continued', 109),
#  ('subcutaneous', 109),
#  ('known', 109),
#  ('decreased', 109),
#  ('mm', 109),
#  ('physician', 109),
#  ('un', 109),
#  ('note', 107),
#  ('aortic', 107),
#  ('opacification', 107),
#  ('common', 107),
#  ('enhancement', 107),
#  ('extremity', 107),
#  ('enlarged', 106),
#  ('ventricular', 106),
#  ('remains', 106),
#  ('secondary', 106),
#  ('location', 105),
#  ('clear', 105),
#  ('carotid', 105),
#  ('ultrasound', 105),
#  ('unremarkable', 105),
#  ('stitle', 103),
#  ('mri', 102),
#  ('effect', 102),
#  ('related', 102),
#  ('tracer', 102),
#  ('degenerative', 102),
#  ('resolution', 102),
#  ('perfusion', 102),
#  ('involving', 102),
#  ('conclusion', 102),
#  ('middle', 101),
#  ('correlation', 101),
#  ('increasing', 101),
#  ('bilaterally', 101),
#  ('nodules', 101),
#  ('portal', 101),
#  ('tissue', 101),
#  ('hours', 100),
#  ('stent', 100),
#  ('atrium', 99),
#  ('side', 99),
#  ('minimal', 99),
#  ('vs', 99),
#  ('copd', 98),
#  ('imaging', 98),
#  ('changed', 98),
#  ('terminates', 98),
#  ('representing', 98),
#  ('demonstrated', 98),
#  ('dilatation', 98),
#  ('decrease', 97),
#  ('blood', 97),
#  ('although', 97),
#  ('progression', 97),
#  ('marked', 96),
#  ('initial', 96),
#  ('tumor', 96),
#  ('when', 96),
#  ('clinically', 95),
#  ('positioning', 95),
#  ('only', 95),
#  ('would', 95),
#  ('should', 95),
#  ('multifocal', 95),
#  ('residual', 95),
#  ('suggest', 94),
#  ('compression', 94),
#  ('fever', 94),
#  ('uptake', 93),
#  ('extending', 92),
#  ('duct', 92),
#  ('infiltrates', 92),
#  ('tracheostomy', 91),
#  ('following', 91),
#  ('degree', 91),
#  ('tips', 91),
#  ('dilated', 91),
#  ('overlying', 91),
#  ('diaphragm', 90),
#  ('aorta', 90),
#  ('collapse', 90),
#  ('show', 90),
#  ('below', 90),
#  ('motion', 89),
#  ('finding', 89),
#  ('r', 89),
#  ('signal', 88),
#  ('less', 88),
#  ('zone', 88),
#  ('call', 87),
#  ('ngt', 87),
#  ('preliminary', 87),
#  ('metastases', 87),
#  ('pattern', 87),
#  ('drainage', 86),
#  ('nonionic', 86),
#  ('wire', 86),
#  ('dd-year-old', 86),
#  ('quadrant', 85),
#  ('consult', 85),
#  ('a.m', 85),
#  ('lobes', 85),
#  ('possibly', 85),
#  ('complete', 84),
#  ('versus', 84),
#  ('throughout', 84),
#  ('space', 84),
#  ('significantly', 84),
#  ('improving', 84),
#  ('spinal', 84),
#  ('veins', 84),
#  ('vena', 83),
#  ('out', 83),
#  ('layering', 83),
#  ('neck', 82),
#  ('alveolar', 82),
#  ('respiratory', 82),
#  ('intubated', 82),
#  ('cancer', 82),
#  ('follow', 81),
#  ('loculated', 81),
#  ('mailed', 81),
#  ('transcription', 81),
#  ('lymph', 81),
#  ('radline', 80),
#  ('pericardial', 80),
#  ('infectious', 80),
#  ('listen', 80),
#  ('tiny', 80),
#  ('abscess', 80),
#  ('hear', 80),
#  ('l', 79),
#  ('via', 79),
#  ('mra', 79),
#  ('bone', 79),
#  ('cava', 79),
#  ('followup', 79),
#  ('pre', 79),
#  ('pna', 79),
#  ('infarction', 78),
#  ('overall', 78),
#  ('removed', 78),
#  ('loops', 78),
#  ('approved', 78),
#  ('midline', 78),
#  ('appropriate', 78),
#  ('retroperitoneal', 78),
#  ('fractures', 77),
#  ('standard', 77),
#  ('dddd-dd-d', 77),
#  ('films', 76),
#  ('advanced', 76),
#  ('sided', 75),
#  ('abnormality', 75),
#  ('several', 75),
#  ('procedure', 75),
#  ('suggestive', 75),
#  ('bronchus', 75),
#  ('pt', 75),
#  ('non', 75),
#  ('hip', 74),
#  ('x', 74),
#  ('appear', 74),
#  ('parenchymal', 74),
#  ('foci', 73),
#  ('cirrhosis', 73),
#  ('sob', 73),
#  ('trauma', 72),
#  ('studies', 72),
#  ('intubation', 72),
#  ('fall', 72),
#  ('enlargement', 72),
#  ('shows', 72),
#  ('overload', 71),
#  ('dated', 71),
#  ('structures', 71),
#  ('nodule', 71),
#  ('concerning', 70),
#  ('cerebral', 70),
#  ('surgical', 70),
#  ('see', 70),
#  ('dvt', 70),
#  ('gastric', 70),
#  ('volumes', 70),
#  ('narrowing', 70),
#  ('cta', 69),
#  ('abnormalities', 69),
#  ('infarct', 69),
#  ('superimposed', 69),
#  ('represents', 69),
#  ('cardiopulmonary', 69),
#  ('dd-dd', 69),
#  ('aspect', 69),
#  ('any', 69),
#  ('lat', 69),
#  ('asymmetric', 69),
#  ('radiographs', 68),
#  ('cabg', 68),
#  ('repeat', 68),
#  ('p.m', 67),
#  ('communicated', 67),
#  ('hydronephrosis', 67),
#  ('mediastinum', 66),
#  ('x-ray', 66),
#  ('kidneys', 66),
#  ('d-d', 66),
#  ('lumbar', 66),
#  ('included', 66),
#  ('osteomyelitis', 66),
#  ('bladder', 66),
#  ('elevated', 66),
#  ('development', 66),
#  ('radiologist', 65),
#  ('confirm', 65),
#  ('end', 64),
#  ('coronary', 64),
#  ('shift', 64),
#  ('prominent', 64),
#  ('and/or', 64),
#  ('activity', 63),
#  ('somewhat', 63),
#  ('difficult', 63),
#  ('lymphadenopathy', 63),
#  ('near', 63),
#  ('demonstrate', 63),
#  ('partially', 63),
#  ('measuring', 63),
#  ('available', 63),
#  ('fdg', 62),
#  ('occlusion', 62),
#  ('partial', 62),
#  ('bases', 62),
#  ('perihilar', 62),
#  ('site', 62),
#  ('terminating', 62),
#  ('apex', 61),
#  ('ionic', 61),
#  ('number', 61),
#  ('arterial', 61),
#  ('image', 61),
#  ('setting', 61),
#  ('injury', 60),
#  ('ards', 60),
#  ('namedd', 60),
#  ('defect', 60),
#  ('fluoro', 60),
#  ('metastasis', 60),
#  ('joint', 60),
#  ('good', 59),
#  ('minutes', 59),
#  ('cervical', 59),
#  ('ca', 59),
#  ('differential', 59),
#  ('demonstrates', 59),
#  ('magnevist', 59),
#  ('fistula', 59),
#  ('french', 59),
#  ('silhouette', 59),
#  ('exclude', 58),
#  ('either', 58),
#  ('helpful', 58),
#  ('duodenum', 58),
#  ('exacerbation', 58),
#  ('cv', 58),
#  ('fx', 58),
#  ('focus', 58),
#  ('radiographic', 57),
#  ('under', 57),
#  ('bile', 57),
#  ('resting', 57),
#  ('mesenteric', 57),
#  ('collections', 57),
#  ('use', 56),
#  ('overlies', 56),
#  ('allowing', 56),
#  ('white', 56),
#  ('loss', 56),
#  ('back', 56),
#  ('cholecystitis', 56),
#  ('aeration', 56),
#  ('ventricle', 56),
#  ('considered', 55),
#  ('limits', 55),
#  ('myocardial', 55),
#  ('better', 55),
#  ('tibial', 55),
#  ('initials', 55),
#  ('additional', 54),
#  ('cd', 54),
#  ('nkg', 54),
#  ('lymphoma', 54),
#  ('parietal', 53),
#  ('osseous', 53),
#  ('fields', 53),
#  ('thrombus', 53),
#  ('hilar', 53),
#  ('aneurysm', 53),
#  ('possibility', 53),
#  ('hemithorax', 53),
#  ('shoulder', 53),
#  ('ld', 53),
#  ('today', 52),
#  ('early', 52),
#  ('bleeding', 52),
#  ('hypoxia', 52),
#  ('pelvic', 52),
#  ('hemidiaphragm', 52),
#  ('bypass', 52),
#  ('ready', 52),
#  ('located', 52),
#  ('very', 52),
#  ('masses', 51),
#  ('iliac', 51),
#  ('rib', 51),
#  ('consolidations', 51),
#  ('pancreas', 51),
#  ('ankle', 51),
#  ('inflammatory', 51),
#  ('breath', 51),
#  ('distribution', 51),
#  ('foot', 51),
#  ('upright', 51),
#  ('remain', 51),
#  ('high', 51),
#  ('attenuation', 50),
#  ('recons', 50),
#  ('suggesting', 50),
#  ('including', 50),
#  ('lumen', 50),
#  ('balloon', 50),
#  ('linear', 49),
#  ('calcifications', 49),
#  ('arm', 49),
#  ('reviewed', 49),
#  ('calcified', 48),
#  ('nodes', 48),
#  ('shortness', 48),
#  ('dictation', 48),
#  ('enhancing', 48),
#  ('indicated', 48),
#  ('just', 48),
#  ('d.dd', 48),
#  ('assessment', 48),
#  ('basal', 47),
#  ('medial', 47),
#  ('sinus', 47),
#  ('still', 47),
#  ('nodular', 47),
#  ('coiled', 47),
#  ('peg', 47),
#  ('congestion', 46),
#  ('dialysis', 46),
#  ('airspace', 46),
#  ('multiplanar', 46),
#  ('herniation', 46),
#  ('least', 46),
#  ('do', 46),
#  ('all', 46),
#  ('subarachnoid', 46),
#  ('pulled', 46),
#  ('adrenal', 45),
#  ('presence', 45),
#  ('cyst', 45),
#  ('different', 45),
#  ('similar', 45),
#  ('second', 45),
#  ('matter', 45),
#  ('trachea', 45),
#  ('babygram', 45),
#  ('combination', 45),
#  ('needle', 45),
#  ('days', 45),
#  ('measures', 45),
#  ('cavity', 45),
#  ('concern', 44),
#  ('brachial', 44),
#  ('node', 44),
#  ('embolism', 44),
#  ('gated', 44),
#  ('had', 44),
#  ('apparent', 44),
#  ('detected', 44),
#  ('smaller', 44),
#  ('recommend', 44),
#  ('esophagus', 44),
#  ('nonspecific', 44),
#  ('brachiocephalic', 44),
#  ('projects', 43),
#  ('correlate', 43),
#  ('protocol', 43),
#  ('intravenous', 43),
#  ('though', 43),
#  ('vessels', 43),
#  ('team', 43),
#  ('hospital', 43),
#  ('surrounding', 43),
#  ('o.r', 42),
#  ('before', 42),
#  ('tract', 42),
#  ('distinct', 42),
#  ('cath', 42),
#  ('cord', 42),
#  ('infant', 42),
#  ('intrahepatic', 42),
#  ('telephone', 42),
#  ('pancreatic', 42),
#  ('administration', 42),
#  ('worsened', 41),
#  ('ischemia', 41),
#  ('axial', 41),
#  ('injection', 41),
#  ('vessel', 41),
#  ('oral', 41),
#  ('levels', 41),
#  ('differences', 41),
#  ('fraction', 41),
#  ('biopsy', 41),
#  ('infarcts', 41),
#  ('ejection', 41),
#  ('repositioning', 41),
#  ('ercp', 41),
#  ('calcification', 41),
#  ('deep', 41),
#  ('thrombosis', 40),
#  ('cerebellar', 40),
#  ('segment', 40),
#  ('reflect', 40),
#  ('component', 40),
#  ('extent', 40),
#  ('yo', 40),
#  ('procedural', 40),
#  ('major', 40),
#  ('caring', 40),
#  ('md', 40),
#  ('evaluated', 40),
#  ('inlet', 40),
#  ('intraperitoneal', 40),
#  ('etiology', 40),
#  ('three', 40),
#  ('distention', 39),
#  ('record', 39),
#  ('reconstruction', 39),
#  ('epidural', 39),
#  ('tissues', 39),
#  ('peripheral', 39),
#  ('system', 39),
#  ('ileus', 39),
#  ('superficial', 39),
#  ('sternotomy', 39),
#  ('between', 39),
#  ('positioned', 39),
#  ('follow-up', 38),
#  ('age', 38),
#  ('stranding', 38),
#  ('ductal', 38),
#  ('patternd', 38),
#  ('cell', 38),
#  ('recurrent', 38),
#  ('include', 38),
#  ('swan', 38),
#  ('bony', 38),
#  ('postoperative', 38),
#  ('gi', 38),
#  ('i', 37),
#  ('west', 37),
#  ('material', 37),
#  ('perforation', 37),
#  ('persists', 37),
#  ('sheath', 37),
#  ('current', 37),
#  ('thoracentesis', 37),
#  ('fluoroscopic', 37),
#  ('stress', 37),
#  ('spleen', 37),
#  ('sternal', 37),
#  ('graft', 37),
#  ('moderately', 37),
#  ('av', 37),
#  ('hernia', 37),
#  ('rule', 37),
#  ('about', 36),
#  ('predominantly', 36),
#  ('cholelithiasis', 36),
#  ('contraindications', 36),
#  ('stem', 36),
#  ('then', 36),
#  ('delayed', 36),
#  ('paracentesis', 36),
#  ('question', 36),
#  ('canal', 36),
#  ('extension', 36),
#  ('diffusion', 36),
#  ('hypotension', 36),
#  ('popliteal', 36),
#  ('patency', 36),
#  ('jejunum', 35),
#  ('swelling', 35),
#  ('groin', 35),
#  ('suggested', 35),
#  ('normally', 35),
#  ('during', 35),
#  ('occipital', 35),
#  ('ge', 35),
#  ('distended', 35),
#  ('surgery', 35),
#  ('access', 35),
#  ('pathology', 35),
#  ('primary', 35),
#  ('vasculature', 35),
#  ('yesterday', 35),
#  ('contours', 35),
#  ('scarring', 35),
#  ('costophrenic', 34),
#  ('fundus', 34),
#  ('pe', 34),
#  ('pigtail', 34),
#  ('lead', 34),
#  ('embolus', 34),
#  ('cystic', 34),
#  ('doppler', 34),
#  ('needs', 34),
#  ('cvl', 34),
#  ('artifact', 34),
#  ('external', 34),
#  ('does', 34),
#  ('newborn', 34),
#  ('appreciable', 34),
#  ('cysts', 33),
#  ('basilic', 33),
#  ('fissure', 33),
#  ('essentially', 33),
#  ('cc', 33),
#  ('cxr', 33),
#  ('suggests', 33),
#  ('c-spine', 33),
#  ('dislocation', 33),
#  ('relatively', 33),
#  ('short', 33),
#  ('shunt', 33),
#  ('completely', 33),
#  ('collapse/consolidation', 33),
#  ('prominence', 33),
#  ('bodies', 33),
#  ('markings', 33),
#  ('remaining', 33),
#  ('gadolinium', 33),
#  ('temporal', 33),
#  ('dd-d', 33),
#  ('redistribution', 33),
#  ('stroke', 32),
#  ('guidance', 32),
#  ('information', 32),
#  ('encephalopathy', 32),
#  ('tachypnea', 32),
#  ('injected', 32),
#  ('dissection', 32),
#  ('od', 32),
#  ('worrisome', 32),
#  ('diagnostic', 32),
#  ('intestinal', 32),
#  ('atelectasis/consolidation', 32),
#  ('extends', 32),
#  ('mildly', 32),
#  ('grossly', 32),
#  ('celiac', 32),
#  ('axillary', 32),
#  ('developing', 31),
#  ('knee', 31),
#  ('too', 31),
#  ('includes', 31),
#  ('filling', 31),
#  ('atrial', 31),
#  ('hydrocephalus', 31),
#  ('median', 31),
#  ('involvement', 31),
#  ('sagittal', 31),
#  ('provided', 30),
#  ('uncertain', 30),
#  ('stone', 30),
#  ('overt', 30),
#  ('angle', 30),
#  ('fibrosis', 30),
#  ('defects', 30),
#  ('splenic', 30),
#  ('guided', 30),
#  ('worse', 30),
#  ('pancreatitis', 30),
#  ('segmental', 30),
#  ('female', 30),
#  ('suspicious', 30),
#  ('minor', 30),
#  ('treatment', 30),
#  ('addendum', 30),
#  ('rectum', 29),
#  ('cavoatrial', 29),
#  ('us', 29),
#  ('such', 29),
#  ('withdrawn', 29),
#  ('femur', 29),
#  ('cbd', 29),
#  ('atrophy', 29),
#  ('anasarca', 29),
#  ('suboptimal', 29),
#  ('sinuses', 29),
#  ('indicating', 29),
#  ('densities', 29),
#  ('expected', 29),
#  ('asthma', 29),
#  ('s', 28),
#  ('sigmoid', 28),
#  ('subacute', 28),
#  ('gadolin', 28),
#  ('series', 28),
#  ('humerus', 28),
#  ('intraparenchymal', 28),
#  ('beyond', 28),
#  ('massive', 28),
#  ('pole', 28),
#  ('diameter', 28),
#  ('ends', 28),
#  ('confluent', 28),
#  ('unit', 28),
#  ('velocities', 28),
#  ('markedly', 28),
#  ('engorgement', 28),
#  ('regions', 28),
#  ('hx', 28),
#  ('used', 28),
#  ('pacemaker', 28),
#  ('suv', 28),
#  ('called', 28),
#  ('tdd', 28),
#  ('addition', 28),
#  ('comment', 28),
#  ('malignancy', 28),
#  ('calculated', 27),
#  ('entirely', 27),
#  ('dobhoff', 27),
#  ('urinary', 27),
#  ...]

# %%
unique_impression_words
# Out:
# {'infiltrative',
#  'embolized',
#  'hypoxic',
#  'caking',
#  'gyrus',
#  'tendon',
#  'exact',
#  'wider',
#  'esophagogram',
#  'unstable',
#  'visualizing',
#  'complicated',
#  'fibrotic',
#  'linear',
#  'discussion',
#  'urologists',
#  'conus',
#  'intrapelvic',
#  'pneumoperitoneum',
#  'relayed',
#  'increase/development',
#  'microvenous',
#  'organisms',
#  'consolidation',
#  'discrete',
#  'derived',
#  'use',
#  'rightclip',
#  'wheezing',
#  'rectum',
#  'steps',
#  'posterofrontal',
#  'd-dimer',
#  'sg',
#  'csru',
#  'diverticulosis',
#  'gave',
#  'g/j',
#  'vertical',
#  'approaching',
#  'ray',
#  'reformatted',
#  'good',
#  'o.r',
#  'reverses',
#  'labeled',
#  'observed',
#  'dish',
#  'aneurysms',
#  'give',
#  'termination',
#  'breathing',
#  'updated',
#  'compartments',
#  'cxrs',
#  'obscures',
#  'reformats',
#  'effussion',
#  'gasless',
#  'underinflated',
#  'lock',
#  'sutured',
#  'barely',
#  'uncal',
#  'presented',
#  'edema',
#  'aliasing',
#  'comparison',
#  'reactive',
#  'plate',
#  'huberon',
#  'e.g',
#  'fu',
#  'atheromatous',
#  'delineated',
#  'overlies',
#  'which',
#  'bicarb',
#  'guidewire',
#  'complete',
#  'openings',
#  'eg',
#  'passage',
#  'gtt',
#  'wall-to',
#  'disseminated',
#  'surface',
#  'osteolytic',
#  'atelectasis/consolidation/effusion',
#  'non-obstructing',
#  'w/u',
#  'after',
#  'plaques',
#  'lower',
#  'ascites',
#  'disida',
#  'basilic',
#  'weighted',
#  'overlapping',
#  'drop-out',
#  'lbp',
#  'pair',
#  'projects',
#  'processes',
#  'chb',
#  'ramus',
#  'granulomatous',
#  'bilatera',
#  'dressing',
#  'dm',
#  'carinal',
#  'simple-appearing',
#  'obstructive/cholecystitis',
#  'interparenchymal',
#  'greatest',
#  'instructed',
#  'intbation',
#  'nonspecfic',
#  'pancolitis',
#  'repaired',
#  'felt',
#  't',
#  'retro',
#  'mental',
#  'abrupt',
#  'straight',
#  'cause',
#  'caused',
#  'fistulogram',
#  'sternum',
#  'free',
#  'air/sbft',
#  'repair',
#  'camera',
#  'dnd/drd',
#  'drained',
#  'lopressor',
#  'w/contrast',
#  'auscultory',
#  'convenience',
#  'refluxing',
#  'describes',
#  'acquisition',
#  'testicular',
#  'atrium',
#  'endolumenal',
#  'fitulogram',
#  'd-mm',
#  'rectus',
#  'placememt',
#  'mtp',
#  'non-aggressive',
#  'suggest',
#  'attending',
#  'radiologistclip',
#  'throat',
#  'blunt',
#  'adhesions',
#  'obvious',
#  'feeding',
#  'fundus',
#  'iliac',
#  'nephrologist',
#  'salvageabl',
#  'diffrence',
#  'mixd',
#  'stroke',
#  'picc',
#  'shunting',
#  'made',
#  'creatin',
#  'descending',
#  'object',
#  'makes',
#  'uneventful',
#  'modality',
#  'j',
#  'ischemia',
#  'effusion/pna',
#  'transudative',
#  'neoplasm',
#  'initiation',
#  'dual-chamber',
#  'spiculated',
#  'vertebral',
#  'outlining',
#  'rigid',
#  'pushed',
#  'tiube',
#  'transtentorial',
#  'drop-off',
#  'ect',
#  'thrombosis',
#  'osteoblastic',
#  'siza',
#  'temporary',
#  'flow',
#  'spectral',
#  'uncerwent',
#  'discuseed',
#  'switched',
#  'bm',
#  'mayi',
#  'apex',
#  'incisional',
#  'tub',
#  'sdh',
#  'indicate',
#  'sma',
#  'ingestion',
#  'form',
#  'upon',
#  'spurring',
#  'punctuate',
#  'hydrocele',
#  'featureless',
#  'embo',
#  'scalpel',
#  're-expansion',
#  'projected',
#  'compressing',
#  'esophagram',
#  'conducted',
#  'patterns',
#  'diaphyseal',
#  'creatinine-dehydration',
#  'did',
#  'calcified',
#  'transaminitis',
#  'lungs',
#  'ards',
#  'sized',
#  'iac',
#  'asssss',
#  'the',
#  'cannulation',
#  'shift',
#  'l.central',
#  'confluent',
#  'symmetry',
#  'orthopedic',
#  'cradiac',
#  'chemo',
#  'exclusion',
#  'electronically',
#  'reimaging',
#  'porta',
#  'fistula/graft',
#  'traverses',
#  'while',
#  'abut',
#  'hemoconcentration',
#  'aspergillosis',
#  'decompression',
#  'heb',
#  'ddcc',
#  'pathologist',
#  'para-aortic',
#  'projectional',
#  'mapping',
#  'ground',
#  'mediastinitis',
#  'alveolar',
#  'ddd.d',
#  'technically-successful',
#  'sighted',
#  'lasix',
#  'brachiocephalic/svc',
#  'continuing',
#  'backed',
#  'each',
#  'terminate',
#  'mostly',
#  'sided',
#  'temporo-occipital',
#  'midway',
#  'mid-body',
#  'leiomyosarcoma',
#  'non-enhanced',
#  'cd',
#  'trauma',
#  'sixteen',
#  'loss',
#  'uncertain',
#  'cerebral',
#  'concentration',
#  'brought',
#  'dysplasia',
#  'multiforme',
#  'carinii',
#  'axial',
#  'fem-dp',
#  'was',
#  'temporooccipital',
#  'fasc',
#  'stenotic',
#  'stopped',
#  'prostheses',
#  'obl',
#  'necrosis',
#  'us',
#  'osh',
#  'kyphosis.liklet',
#  'explained',
#  'septum',
#  'pca',
#  'definition',
#  'isprobably',
#  'supra',
#  'block',
#  'd-day-old',
#  'anteriorly',
#  'evidenced',
#  'hypoalbuminemic',
#  'secured',
#  'earlier',
#  'turned',
#  'opague',
#  'interfissural',
#  'campus',
#  'pacing',
#  'dd.d',
#  'post-biopsy',
#  'hemorrhages',
#  'wet',
#  'pyelonephritis',
#  'angled',
#  'mid-line',
#  'rotoablation',
#  'lumbar',
#  'mr-angio',
#  'i',
#  'malleolus',
#  'paracentecis',
#  'conoslidation',
#  'calcaneal',
#  'view',
#  'hepatectomy',
#  'extermity',
#  'field-of-view',
#  'echoic',
#  'greater',
#  'nature',
#  'fasciitis',
#  'attempted',
#  'conferred',
#  'consolidated',
#  'uptake',
#  'rapidly',
#  'symptom',
#  'about',
#  'obstructive',
#  'nonocclusive',
#  'inf',
#  'interspace',
#  'consists',
#  'spaceo',
#  'evacuations',
#  'evolution',
#  'scanner',
#  'hida',
#  'methicillin',
#  'cricopharyngeal',
#  'difficulties',
#  'tbili',
#  'stably',
#  'backflow',
#  'traced',
#  'yet',
#  'project',
#  'valves',
#  'new',
#  'xrt',
#  'hrs',
#  'edema/effusions/atelectasis/consolidations',
#  'needles',
#  'west',
#  'd-fu',
#  'request',
#  'herself',
#  'hemithoraces',
#  'obviously',
#  'dd-year-odl',
#  'witnessed',
#  'loculations',
#  'thecal',
#  'round',
#  'loop',
#  'floor',
#  'prandial',
#  'g/gj',
#  'epilepticus',
#  'brachiocephalic',
#  'hemothorax',
#  'become',
#  'withdrawn',
#  'mellitus',
#  'arthrocentesis',
#  'lll',
#  'andcardioversion',
#  'physicianclip',
#  'greek',
#  'trigger',
#  'hiv/aids',
#  'urosepsis',
#  'leukemia/lymphoma',
#  'melas',
#  'confirmed',
#  'ic',
#  'thank',
#  'include',
#  'lefet',
#  'tourniquet',
#  'attenuation',
#  'chf/hydrostatic',
#  'achieved',
#  'found',
#  'sludge-filled',
#  'nodes',
#  'n-j',
#  'unable',
#  'paraspinal',
#  'stroke-need',
#  'bones',
#  'high',
#  'versusimited',
#  'uniform',
#  'bowels',
#  'guidance',
#  'oxymetry',
#  'getting',
#  'dmz',
#  'spect',
#  'premature',
#  'divided',
#  'continues',
#  'loc',
#  'non-filling',
#  'silicone',
#  'immediate',
#  'hyper-aeration',
#  'definite',
#  'daily',
#  'abx',
#  'essentially',
#  'pharmacologic',
#  'precisely',
#  'prevous',
#  'reval',
#  'immunocompromised',
#  'past',
#  'fluid-filled',
#  'intr',
#  'lbo',
#  'recurred',
#  'gtube',
#  'delective',
#  'low-pressure',
#  'preprocedural',
#  'cardiomegaly',
#  'echogenicity',
#  'manner',
#  'ptt',
#  'time-out',
#  'allegedly',
#  'discomfort',
#  'hyperintense',
#  'tachy.lymphoma.r/o',
#  'pre-procedural',
#  'emptied',
#  'well-demonstrated',
#  'sterily',
#  'fungal',
#  'gangrene',
#  'harvested',
#  'rapidity',
#  'three-month',
#  'fractured',
#  'recurs',
#  'pseudoaneurys',
#  'pre-medicated',
#  'radiosurgery',
#  'likewise',
#  'afixed',
#  'fluorodeoxyglucose',
#  'megacolon',
#  'tail',
#  'duodenal',
#  'posituion',
#  'presence',
#  'fanconi',
#  'abnormality/displacement',
#  'hemodynamic',
#  'nonhealing',
#  'triple',
#  'corpus',
#  'rehabilitation',
#  'lad',
#  'omniflush',
#  'diagnosed',
#  'consider',
#  'intraarterial',
#  'opaque',
#  'eight',
#  'aortogram',
#  'pericardiocentesis',
#  'persistence',
#  'cessation',
#  'invading',
#  'tomorrow',
#  'scout',
#  'tls',
#  'placment',
#  'invested',
#  'gone',
#  'failing',
#  'thyroid',
#  'beeper',
#  'sizes',
#  'therapy',
#  'forearm',
#  'transversearium',
#  'pbstruction',
#  'phases',
#  'peritumoral',
#  'overtly',
#  'nonperistalting',
#  'appropiate',
#  'rd',
#  'placement/fluid',
#  'chest/upper',
#  'pullback',
#  'azm',
#  'myopathy',
#  'desiccated',
#  'ple',
#  'observable',
#  'hydropneumothorax',
#  'clinically',
#  'adverse',
#  'change',
#  'uk',
#  'reintubation-evaluate',
#  'ugi',
#  'measuring',
#  'frontal/temporal',
#  'osseous',
#  'excrete',
#  'shower',
#  'incl',
#  'ratios',
#  'cyberknife',
#  'aerated',
#  'distress',
#  'uniformally',
#  'gall',
#  'tachypenia',
#  'retrograde',
#  'supplies',
#  'putamen',
#  'one',
#  'intraureteral',
#  'spontaneous',
#  'calves',
#  'pe.thrombus',
#  'series',
#  'd/dddd',
#  'presesent',
#  'essential',
#  'microcoils',
#  'administered',
#  'rehab',
#  'abnormality',
#  'dialysis',
#  'prominant',
#  'emphysematous',
#  'ej',
#  'implies',
#  'non-perfusion',
#  'ivorlewis',
#  'enlarged',
#  'technique',
#  'pneumomediastinum',
#  'mic',
#  'diaphoresis',
#  'hiatus',
#  'esophagogastric',
#  'little',
#  'noticed',
#  'vent',
#  'cutting',
#  'ep',
#  'capped',
#  'nephrogram',
#  'slit-like',
#  'cyst',
#  'vein-hepatic',
#  'reoccurred',
#  'purple',
#  'reveals',
#  'a-fib',
#  'rostral',
#  'pectus',
#  'diaphram',
#  'endplate',
#  'flank',
#  'esrd/n/v',
#  'component',
#  'tracing',
#  'plan',
#  'dobhoff',
#  'tachycardia',
#  'dwi',
#  'tr',
#  'stir',
#  'sphenois',
#  'intermedius',
#  'broncial',
#  'umbrella',
#  'pcn',
#  'nearby',
#  'mra',
#  'astemi',
#  'intra-tips',
#  'record',
#  'dif',
#  'responsiveness',
#  'distortion',
#  'pvr',
#  'comparable',
#  'lobulated',
#  'weakness',
#  'atelectatic',
#  'scanned',
#  'tuft',
#  'brachial',
#  'bms',
#  'march',
#  'technique/findings',
#  'in',
#  'w/dobhoff',
#  'heterotopic',
#  'intervals',
#  'periosseous',
#  'prevascular',
#  'v-cath',
#  'open',
#  'malplacement',
#  'requirements.acute',
#  'db',
#  'mets',
#  'airspace',
#  'different',
#  'abnromality',
#  'reconstruct',
#  'hemtome',
#  'asbestosis',
#  'jugular',
#  'superimposition',
#  'likel',
#  'appendicitis',
#  'signs',
#  'bulbi',
#  'closed',
#  'versus',
#  'lymphoms',
#  'myocardium',
#  'possibly',
#  'a-gram',
#  'solution',
#  'ea',
#  'undermined',
#  'localization',
#  'reforming',
#  'shortly',
#  'three-vessel',
#  'llq',
#  'relation',
#  'paraaortic',
#  'processing',
#  'consolidations',
#  'clonic',
#  'non-mobile',
#  'flow-limiting',
#  'persisting',
#  'lvier',
#  'atelectiasis',
#  'resistive',
#  'issued',
#  'interperitoneal',
#  'oriented',
#  'aspiration/pneumonia',
#  'superomedial',
#  'atelectasis/aspiration',
#  'l-sided',
#  'brewing',
#  'postop',
#  'communicated',
#  'recordings',
#  'avr/mvr/tvrepair',
#  'targeted',
#  'gastroparesis',
#  'subtle',
#  'underexposed',
#  'acromiohumeral',
#  'cd-d',
#  'culture',
#  'subsegmental',
#  'year-old',
#  'fissures',
#  'physiology',
#  'visualied',
#  'prbcs',
#  'infrahepatic',
#  'directed',
#  'confusion',
#  'metaphyseal',
#  'apposition',
#  'tacks',
#  'offset',
#  'instrumentation',
#  'labrum',
#  'syndrome',
#  'deferens',
#  'o.k',
#  'apart',
#  'noninvasive',
#  'attemts',
#  'differentiation',
#  'worried',
#  'intracavitary/intracystic',
#  'safely',
#  'to',
#  'mid-thigh',
#  'anasarcic',
#  'mild/small',
#  'cpt',
#  'allows',
#  'ptc',
#  'protion',
#  'multiplanar',
#  'urinary',
#  'stranding',
#  'tracheostomy',
#  'precluding',
#  'ac',
#  'interface',
#  'tachycardic',
#  'mva',
#  'subtentorial',
#  'multislice',
#  'consult',
#  'achieve',
#  'aureus',
#  'ventricular',
#  'fair',
#  'multiple',
#  'aortogramclip',
#  'post-removal',
#  'dmm',
#  'sincedd/dd',
#  'methotrexate',
#  'possible',
#  'staff',
#  'perc',
#  'visipaque',
#  'opacity',
#  'increases',
#  'albumin',
#  'volving',
#  'approximate',
#  'similar',
#  'avg',
#  'lobar',
#  'expiration',
#  'pancreas',
#  'information',
#  'claudication/sda',
#  'examinations',
#  'extending',
#  'candidiasis',
#  'paged',
#  'additional',
#  'fracture',
#  'commenced',
#  'vigorous',
#  'regression',
#  'sinus',
#  'occurring',
#  'headed',
#  'unusually',
#  'swan-ganz-type',
#  'retrospect',
#  'anomaly',
#  'catheters',
#  'detailed',
#  'vats/decortication',
#  'notify',
#  'treitz/proximal',
#  'cxr',
#  'segments',
#  'ongoing',
#  'mucomist',
#  'fluoro-guided',
#  'ductal',
#  'likelihood',
#  'per',
#  'hiatal',
#  'interest',
#  'once',
#  'ai',
#  'majro',
#  'suprarenal',
#  'width',
#  'wth',
#  'appreciate',
#  'non-specifcic',
#  'ala',
#  'intiation',
#  'transcatheter',
#  'melena',
#  'them',
#  'usually',
#  'si',
#  'position',
#  'circumscribed',
#  'urethra',
#  'creatine',
#  'aaa',
#  'centered',
#  'sd',
#  'sites',
#  'microatelectasis',
#  'dopp',
#  'put',
#  'thickened',
#  'hyperacute',
#  'meningeal',
#  'bulges',
#  'type',
#  'bulb',
#  'swollen',
#  'normal-appearing',
#  'proved',
#  'report',
#  'penetrating',
#  'requirements',
#  'probability',
#  'aloc',
#  'extent',
#  'embolism',
#  'sfv',
#  'mucocele',
#  'sfa',
#  'trending',
#  'term',
#  'reported',
#  'caudad',
#  'torcula',
#  'barium',
#  'colostomy',
#  'he',
#  'pneumonnia',
#  'physical',
#  'porto-caval',
#  'text',
#  'disease/atelectasis',
#  'nondiagnostic',
#  'subarachnoid',
#  'fibular',
#  'pnuemothorax',
#  'hepatology',
#  'effusion\\pericardial',
#  'emesis',
#  'intraparenchymal',
#  'taking',
#  'neuropathic',
#  'spot',
#  'broken',
#  'desating',
#  'herniation',
#  'prednisone',
#  'neurology',
#  'expectation',
#  'bleeding',
#  'fibrosis/cirrhosis',
#  'decompensating',
#  'indices',
#  'bas',
#  'benefit',
#  'comminution',
#  'malrotated',
#  'hemodialysis',
#  'total-length',
#  'unremarkble',
#  'tb',
#  'angulation',
#  'intubation',
#  'beyond',
#  'summation',
#  'effusion/thickening',
#  'created',
#  'cavitation',
#  'anterolateral',
#  'sch',
#  'granuloma',
#  'occur',
#  'overload',
#  'raises',
#  'pre-cyberknife',
#  'non-hodgkins',
#  'general',
#  'reevaluation',
#  'assume',
#  'multilevel',
#  'void',
#  'patchy',
#  'transition',
#  'suntroch',
#  'd-d/d',
#  'yo',
#  'acidosis',
#  'dependent',
#  'notably',
#  'tunnedled',
#  'cistern',
#  'faint',
#  'scapulae',
#  'closure',
#  'outlines',
#  'narrowed',
#  'bx',
#  'premedicate',
#  'know',
#  'd-french',
#  'paracardiac',
#  'visibility',
#  'differentiate',
#  'sublcavian',
#  'stones',
#  'pre-contrast',
#  'intraconal',
#  'lymphadenopathy/metastatic',
#  'adhesion',
#  'duct',
#  'resection',
#  'sinogram',
#  'sp',
#  'impairment',
#  'massive',
#  'terminated',
#  'severely',
#  'retromesentery',
#  'check/change',
#  'angiographic',
#  'plcmnt',
#  'd-d-d',
#  'mutiple',
#  'nearly',
#  'overload/chf',
#  'mca/aca',
#  'splenectomy',
#  'drug',
#  'inspiratory',
#  'foreshortening',
#  'clivus',
#  'stool',
#  'angles',
#  'recons',
#  'h/o',
#  'seizure/altered',
#  'bx-needle',
#  'pathologically',
#  'preclude',
#  'hepatocellular',
#  'shoot',
#  'edema/ards',
#  'food',
#  'deposit',
#  'parallel',
#  'geographic',
#  'fdg',
#  'unusual',
#  'artifact',
#  'suggests',
#  'has',
#  'appropriately',
#  'intravas',
#  'foramen',
#  'shifted',
#  'bringing',
#  'take',
#  'not',
#  'proleen',
#  'ab',
#  'bibasilar',
#  'supraclinoid',
#  'ddcm',
#  'petechial',
#  'gad',
#  ...}

# %%
from gensim.parsing.preprocessing import STOPWORDS
STOPWORDS
# Out:
# frozenset({'a',
#            'about',
#            'above',
#            'across',
#            'after',
#            'afterwards',
#            'again',
#            'against',
#            'all',
#            'almost',
#            'alone',
#            'along',
#            'already',
#            'also',
#            'although',
#            'always',
#            'am',
#            'among',
#            'amongst',
#            'amoungst',
#            'amount',
#            'an',
#            'and',
#            'another',
#            'any',
#            'anyhow',
#            'anyone',
#            'anything',
#            'anyway',
#            'anywhere',
#            'are',
#            'around',
#            'as',
#            'at',
#            'back',
#            'be',
#            'became',
#            'because',
#            'become',
#            'becomes',
#            'becoming',
#            'been',
#            'before',
#            'beforehand',
#            'behind',
#            'being',
#            'below',
#            'beside',
#            'besides',
#            'between',
#            'beyond',
#            'bill',
#            'both',
#            'bottom',
#            'but',
#            'by',
#            'call',
#            'can',
#            'cannot',
#            'cant',
#            'co',
#            'computer',
#            'con',
#            'could',
#            'couldnt',
#            'cry',
#            'de',
#            'describe',
#            'detail',
#            'did',
#            'didn',
#            'do',
#            'does',
#            'doesn',
#            'doing',
#            'don',
#            'done',
#            'down',
#            'due',
#            'during',
#            'each',
#            'eg',
#            'eight',
#            'either',
#            'eleven',
#            'else',
#            'elsewhere',
#            'empty',
#            'enough',
#            'etc',
#            'even',
#            'ever',
#            'every',
#            'everyone',
#            'everything',
#            'everywhere',
#            'except',
#            'few',
#            'fifteen',
#            'fify',
#            'fill',
#            'find',
#            'fire',
#            'first',
#            'five',
#            'for',
#            'former',
#            'formerly',
#            'forty',
#            'found',
#            'four',
#            'from',
#            'front',
#            'full',
#            'further',
#            'get',
#            'give',
#            'go',
#            'had',
#            'has',
#            'hasnt',
#            'have',
#            'he',
#            'hence',
#            'her',
#            'here',
#            'hereafter',
#            'hereby',
#            'herein',
#            'hereupon',
#            'hers',
#            'herself',
#            'him',
#            'himself',
#            'his',
#            'how',
#            'however',
#            'hundred',
#            'i',
#            'ie',
#            'if',
#            'in',
#            'inc',
#            'indeed',
#            'interest',
#            'into',
#            'is',
#            'it',
#            'its',
#            'itself',
#            'just',
#            'keep',
#            'kg',
#            'km',
#            'last',
#            'latter',
#            'latterly',
#            'least',
#            'less',
#            'ltd',
#            'made',
#            'make',
#            'many',
#            'may',
#            'me',
#            'meanwhile',
#            'might',
#            'mill',
#            'mine',
#            'more',
#            'moreover',
#            'most',
#            'mostly',
#            'move',
#            'much',
#            'must',
#            'my',
#            'myself',
#            'name',
#            'namely',
#            'neither',
#            'never',
#            'nevertheless',
#            'next',
#            'nine',
#            'no',
#            'nobody',
#            'none',
#            'noone',
#            'nor',
#            'not',
#            'nothing',
#            'now',
#            'nowhere',
#            'of',
#            'off',
#            'often',
#            'on',
#            'once',
#            'one',
#            'only',
#            'onto',
#            'or',
#            'other',
#            'others',
#            'otherwise',
#            'our',
#            'ours',
#            'ourselves',
#            'out',
#            'over',
#            'own',
#            'part',
#            'per',
#            'perhaps',
#            'please',
#            'put',
#            'quite',
#            'rather',
#            're',
#            'really',
#            'regarding',
#            'same',
#            'say',
#            'see',
#            'seem',
#            'seemed',
#            'seeming',
#            'seems',
#            'serious',
#            'several',
#            'she',
#            'should',
#            'show',
#            'side',
#            'since',
#            'sincere',
#            'six',
#            'sixty',
#            'so',
#            'some',
#            'somehow',
#            'someone',
#            'something',
#            'sometime',
#            'sometimes',
#            'somewhere',
#            'still',
#            'such',
#            'system',
#            'take',
#            'ten',
#            'than',
#            'that',
#            'the',
#            'their',
#            'them',
#            'themselves',
#            'then',
#            'thence',
#            'there',
#            'thereafter',
#            'thereby',
#            'therefore',
#            'therein',
#            'thereupon',
#            'these',
#            'they',
#            'thick',
#            'thin',
#            'third',
#            'this',
#            'those',
#            'though',
#            'three',
#            'through',
#            'throughout',
#            'thru',
#            'thus',
#            'to',
#            'together',
#            'too',
#            'top',
#            'toward',
#            'towards',
#            'twelve',
#            'twenty',
#            'two',
#            'un',
#            'under',
#            'unless',
#            'until',
#            'up',
#            'upon',
#            'us',
#            'used',
#            'using',
#            'various',
#            'very',
#            'via',
#            'was',
#            'we',
#            'well',
#            'were',
#            'what',
#            'whatever',
#            'when',
#            'whence',
#            'whenever',
#            'where',
#            'whereafter',
#            'whereas',
#            'whereby',
#            'wherein',
#            'whereupon',
#            'wherever',
#            'whether',
#            'which',
#            'while',
#            'whither',
#            'who',
#            'whoever',
#            'whole',
#            'whom',
#            'whose',
#            'why',
#            'will',
#            'with',
#            'within',
#            'without',
#            'would',
#            'yet',
#            'you',
#            'your',
#            'yours',
#            'yourself',
#            'yourselves'})

# %%
my_stop_words = frozenset(["a", "am", "an", "and", "are", "as", "at", "be", "for", "is", "the", "is", "of", "which", ])

# %% [markdown]
# ## Create a single string with all the reports
#
# #### Hints, etc.
# * Use List Comprehension
# * Use string joins
# * Iterate over the rows of the data frame

# %% [markdown]
# ### Define a vector space for the radiology corpus
#
# #### Hints
#
# 1. How would you build a corpus from words only occuring more than N times?

# %% [markdown]
# ### Create a new column named `"impression no stops"` where [stop words](https://en.wikipedia.org/wiki/Stop_words) have been dropped from the impression
#
# * The gensim package has stop words defined (``from gensim.parsing.preprocessing import STOPWORDS``
#
# #### Hints
# 1. Do you agree with dropping all the stop words?
# 1. How could we create a new stopwords frozen set absent the terms we wan't to keep (double negative?)
# 1. You could use a regular expressions substitution or token the report first and operate on the list of words.

# %%
rad_data["impression no stops"] = \
rad_data.apply(lambda row: \
               " ".join([word for word in row["impression"].split() if  word not in my_stop_words]), 
   axis=1)
rad_data.head()
# Out:
#    subject_id  hadm_id                                               text  \
# 0          56  28766.0  \n\n\n     DATE: [**2644-1-17**] 10:53 AM\n   ...
# 1          56  28766.0  \n\n\n     DATE: [**2644-1-17**] 10:43 AM\n   ...
# 2          56  28766.0  \n\n\n     DATE: [**2644-1-17**] 6:37 AM\n    ...
# 3          56  28766.0  \n\n\n     DATE: [**2644-1-19**] 12:09 PM\n   ...
# 4          37  18052.0  \n\n\n     DATE: [**3264-8-14**] 6:06 AM\n    ...
#
#                                           impression  \
# 0  \n\n\n     date dd:dd am\n     mr head w & w/o...
# 1  impression:  stable appearance of right pariet...
# 2  impression:\n     \n     cardiomegaly and mild...
# 3  impression:\n     \n     marked improvement in...
# 4  impression: stable cardiomegaly with pulmonary...
#
#                                  impression no stops
# 0  date dd:dd mr head w & w/o contrast; mr contra...
# 1  impression: stable appearance right parietal l...
# 2  impression: cardiomegaly mild chf. nasogastric...
# 3  impression: marked improvement in left perihil...
# 4  impression: stable cardiomegaly with pulmonary...

# %%
rad_data.iloc[0]["impression"]
# Out:
# "\n\n\n     date dd:dd am\n     mr head w & w/o contrast; mr contrast gadolin                   clip # clip\n     reason: r icb and hx brain mets - eval - also with dwi for cva do mr\n      contrast: magnevist amt: dd\n     \n\n     underlying medical condition:\n      [**age over dd **] year old woman with lung ca- mets to brain                                   \n     reason for this examination:\n      r icb and hx brain mets - eval - also with dwi for cva do mri both with and \n      without contast please\n     \n\n                                     final report\n     examination:  mri of the brain with and without gadolinium.\n     \n     indication:  [**age over dd **] year old woman with lung cancer and right intracranial bleed\n     and history of brain metastases.  please evaluate for acute infarct.\n     \n     technique:  multiplanar td and td-weighted images of the brain with gadolinium\n     according to standard departmental protocol.  no prior study for comparison.\n     \n     findings:  on diffusion-weighted images there is a small area of restricted\n     diffusion along the falx within the left occipitotemporal lobe.  it is also\n     bright on flair-weighted images and may represent a subacute infarct. clinical\n     correlation is recommended.  on gradient echo images there is a large area of\n     intraparenchymal hemorrhage within the right parietal lobe and left thalamus\n     which following administration of gadolinium reveals ring-enhancing lesions.\n     these are suspicious for hemorrhagic metastases given the patient's history.\n     additional ring-enhancing lesions throughout the supra- and infratentorial\n     compartments are visualized.  there is a moderate amount of peritumoral edema\n     involving the right parietal lobe lesion in addition to a second right\n     parietal lesion along the falx high in the vertex.  the other areas of\n     metastases reveal a minimal amount of peritumoral edema.\n     \n\n"

# %%
rad_data.iloc[0]["impression no stops"]
# Out:
# "date dd:dd mr head w & w/o contrast; mr contrast gadolin clip # clip reason: r icb hx brain mets - eval - also with dwi cva do mr contrast: magnevist amt: dd underlying medical condition: [**age over dd **] year old woman with lung ca- mets to brain reason this examination: r icb hx brain mets - eval - also with dwi cva do mri both with without contast please final report examination: mri brain with without gadolinium. indication: [**age over dd **] year old woman with lung cancer right intracranial bleed history brain metastases. please evaluate acute infarct. technique: multiplanar td td-weighted images brain with gadolinium according to standard departmental protocol. no prior study comparison. findings: on diffusion-weighted images there small area restricted diffusion along falx within left occipitotemporal lobe. it also bright on flair-weighted images may represent subacute infarct. clinical correlation recommended. on gradient echo images there large area intraparenchymal hemorrhage within right parietal lobe left thalamus following administration gadolinium reveals ring-enhancing lesions. these suspicious hemorrhagic metastases given patient's history. additional ring-enhancing lesions throughout supra- infratentorial compartments visualized. there moderate amount peritumoral edema involving right parietal lobe lesion in addition to second right parietal lesion along falx high in vertex. other areas metastases reveal minimal amount peritumoral edema."

# %% [markdown]
# ### What are the unique words in our vocabulary?

# %%
unique_impression_words = set(TextBlob(" ".join(rad_data["impression no stops"])).words)

# %% [markdown]
# ### We'll create a vocabulary with `zip` and `dict`

# %%
word_map = dict(zip(unique_impression_words,range(len(unique_impression_words))))

# %%
len(word_map)
# Out:
# 7396

# %%
word_map
# Out:
# {'infiltrative': 0,
#  'quadriceps': 3654,
#  'embolized': 1,
#  'hypoxic': 2,
#  'deterioration': 3657,
#  'caking': 3,
#  'gyrus': 4,
#  'tendon': 5,
#  'exact': 6,
#  'wider': 7,
#  'esophagogram': 8,
#  'window': 3661,
#  'ris': 3663,
#  'vertebra': 3664,
#  'slight': 3665,
#  'congestion/acute': 3666,
#  'swallow': 3667,
#  'intraoperative': 3655,
#  'unstable': 9,
#  'two-view': 3668,
#  'visualizing': 10,
#  'complicated': 11,
#  'o': 3656,
#  'fibrotic': 12,
#  'linear': 13,
#  'ill-defined': 1292,
#  'worsened': 3669,
#  'urologists': 15,
#  'extracted': 3670,
#  'get': 3671,
#  's': 3672,
#  'conus': 16,
#  'mvmt': 3675,
#  'intrapelvic': 17,
#  'pneumoperitoneum': 18,
#  'cardiomediastinal': 3676,
#  'liter': 5561,
#  'microvenous': 21,
#  'organisms': 22,
#  'exclude': 3678,
#  'seizure': 3679,
#  'interactive': 6235,
#  'dddf': 3680,
#  'consolidation': 23,
#  'discrete': 24,
#  'murmur': 3682,
#  'rightclip': 27,
#  'use': 26,
#  'productive': 3683,
#  'extensions': 6567,
#  'wheezing': 28,
#  'steps': 30,
#  'posterofrontal': 31,
#  'd-dimer': 32,
#  'sg': 33,
#  'csru': 34,
#  'failure/fluid': 3660,
#  'diverticulosis': 35,
#  'ld-ld': 6194,
#  'gave': 36,
#  'mpa-d': 3796,
#  'mid-lung': 3662,
#  'value': 3687,
#  'reversibility': 3688,
#  'g/j': 37,
#  'pneumothroax': 3689,
#  'exposure': 6542,
#  'bronchi': 3690,
#  'vertical': 38,
#  'introducer': 3691,
#  'approaching': 39,
#  'ray': 40,
#  'plane': 3692,
#  'amylase': 3693,
#  'g-i': 3694,
#  'reformatted': 41,
#  'good': 42,
#  'o.r': 43,
#  'uo': 4957,
#  'convexities': 5874,
#  'dwi': 612,
#  'reverses': 44,
#  'midpole': 3695,
#  'labeled': 45,
#  'observed': 46,
#  'discerned': 3696,
#  'dish': 47,
#  'aneurysms': 48,
#  'cysts': 3699,
#  'balanced': 1849,
#  'give': 49,
#  'termination': 50,
#  'breathing': 51,
#  'projection': 3701,
#  'multicompartmental': 3702,
#  'sequela': 5915,
#  'microperforation': 7332,
#  'radiological': 4308,
#  'gas-producing': 3705,
#  'contractions': 3706,
#  'wi': 3707,
#  'never': 3708,
#  'updated': 52,
#  'blue': 5953,
#  'cxrs': 54,
#  'all': 3709,
#  'connection': 3710,
#  'hip': 3714,
#  'tapered': 5914,
#  'hypoechoic': 3715,
#  'fm': 3716,
#  'obscures': 55,
#  'spiculation': 1851,
#  'we': 4959,
#  'description': 3717,
#  'effussion': 57,
#  'clearing': 3719,
#  'gasless': 58,
#  'underinflated': 59,
#  'answering': 3721,
#  'hypodensity': 3722,
#  'identified.possible': 3723,
#  'considered': 3724,
#  'asd': 3725,
#  'year': 5572,
#  'lock': 60,
#  'sutured': 61,
#  'h./o': 3726,
#  'maxilla': 7111,
#  'lima': 1855,
#  'calculated': 3727,
#  'barely': 62,
#  'supporting': 4315,
#  'bmt': 3730,
#  'uncal': 63,
#  'icd': 6793,
#  'para': 3731,
#  'perform': 5573,
#  'subtalar': 6607,
#  'presented': 64,
#  'oncology': 3732,
#  'limited': 3733,
#  'nerve': 7375,
#  'tomographic': 3735,
#  'granular': 3736,
#  'edema': 65,
#  'resected': 3738,
#  'requiring': 3739,
#  'comparison': 67,
#  'reactive': 68,
#  'jejunum': 3439,
#  'flagged': 1397,
#  'plate': 69,
#  'pcn': 619,
#  'huberon': 70,
#  'masses': 6795,
#  'deforming': 2421,
#  'e.g': 71,
#  'xanthogranuloma': 3742,
#  'chamber': 6217,
#  'discussion': 14,
#  'fu': 72,
#  'atheromatous': 73,
#  'injury': 3743,
#  'delineated': 74,
#  'overlies': 75,
#  'bicarb': 76,
#  'd-dddd': 5576,
#  'enlarge': 3744,
#  'guidewire': 78,
#  'complete': 79,
#  'openings': 80,
#  'costophrenic': 3747,
#  'bedside': 1541,
#  'eg': 81,
#  'passage': 82,
#  'commonly': 3749,
#  'non-significant': 6798,
#  'cad': 3750,
#  'well-evaluated': 3752,
#  'aspects': 3753,
#  'gtt': 83,
#  'disseminated': 85,
#  'adrenal': 3754,
#  'surface': 86,
#  'osteolytic': 87,
#  'fixating': 6200,
#  'interim': 5578,
#  'etoh': 3757,
#  'atelectasis/consolidation/effusion': 88,
#  'non-obstructing': 89,
#  'w/u': 90,
#  'plaques': 92,
#  'lower': 93,
#  'revisn': 3760,
#  'structures': 6202,
#  'ascites': 94,
#  'disida': 95,
#  'lie': 3673,
#  'basilic': 96,
#  'adenoca': 7225,
#  'clotted': 6802,
#  'bronchiectasis': 3761,
#  'thoracoabdominal': 3674,
#  'mprg': 3763,
#  'weighted': 97,
#  'start': 3764,
#  'lbp': 100,
#  'pair': 101,
#  'projects': 102,
#  'plantar': 3765,
#  'gadolinium-enhanced': 3767,
#  'processes': 103,
#  'ngt': 6387,
#  'n-g': 6804,
#  'telephone/fax': 3768,
#  'duodenojejunal': 3769,
#  'chb': 104,
#  'chf/infi': 2481,
#  'ramus': 105,
#  'granulomatous': 106,
#  'efforts': 3771,
#  'centra': 3772,
#  'bilatera': 107,
#  'desatting': 3774,
#  'units': 3775,
#  'relayed': 19,
#  'dressing': 108,
#  'hemetemesis': 6806,
#  'nonetheless': 3776,
#  'parietal': 3777,
#  'dm': 109,
#  'picture': 3778,
#  'lactate': 1218,
#  'carinal': 110,
#  'ovoid': 3779,
#  'crus': 3094,
#  'simple-appearing': 111,
#  'enhances': 3780,
#  'obstructive/cholecystitis': 112,
#  'increase/development': 20,
#  'interparenchymal': 113,
#  'greatest': 114,
#  'situated': 3781,
#  'afferent': 7100,
#  'instructed': 115,
#  'ventilatory': 3782,
#  'intbation': 116,
#  'brachial': 635,
#  'nonspecfic': 117,
#  'pancolitis': 118,
#  'congestion': 3784,
#  'permacatheter': 3787,
#  'felt': 120,
#  'resistive': 687,
#  'onsite': 3788,
#  'hypotensive': 3789,
#  't': 121,
#  'retro': 122,
#  'mental': 123,
#  'displacing': 6210,
#  'nephronia': 3790,
#  'abrupt': 124,
#  'straight': 125,
#  'cause': 126,
#  'caused': 127,
#  'observation': 6808,
#  'fistulogram': 128,
#  'sounds/aspiration': 3794,
#  'tranpslnt': 3795,
#  'free': 130,
#  'air/sbft': 131,
#  'ea': 670,
#  'repair': 132,
#  'viral': 3798,
#  'tunnelled': 3799,
#  'nonconvulsive': 3681,
#  'camera': 133,
#  'dnd/drd': 134,
#  're-demonstration': 3802,
#  'drained': 135,
#  'abdomal': 3803,
#  'lopressor': 136,
#  'y/o': 3804,
#  'sigmoid': 3806,
#  'w/contrast': 137,
#  'auscultory': 138,
#  'convenience': 139,
#  'refluxing': 140,
#  'describes': 141,
#  'stabilizing': 6214,
#  'splenomegaly': 6811,
#  're-accumulation': 3810,
#  'modest': 3812,
#  'testicular': 143,
#  'atrium': 144,
#  'l': 3813,
#  'fitulogram': 146,
#  'd-mm': 147,
#  'rectus': 148,
#  'placememt': 149,
#  'tympanitic': 3815,
#  'mtp': 150,
#  'transhepatically': 3817,
#  'derived': 25,
#  'non-aggressive': 151,
#  'addendum': 3102,
#  'recovery': 3819,
#  'viable': 3820,
#  'blunt': 156,
#  'throat': 155,
#  'verification': 3821,
#  'rewiring': 3822,
#  'obvious': 158,
#  'feeding': 159,
#  'fundus': 160,
#  'correlate': 3824,
#  'subacute': 3825,
#  'lymphoid': 3826,
#  'diffrence': 164,
#  'salvageabl': 163,
#  'restaging': 3828,
#  'advance': 5231,
#  'mixd': 165,
#  'mcas': 3829,
#  'bullae': 5592,
#  'stroke': 166,
#  'picc': 167,
#  'shunting': 168,
#  'silhouett': 5594,
#  'made': 169,
#  'creatin': 170,
#  'effsion': 3832,
#  'a': 3833,
#  'akinesis': 3834,
#  'attempt': 3835,
#  'compenents': 3836,
#  'descending': 171,
#  'object': 172,
#  'avr/asd': 3837,
#  'makes': 173,
#  'uneventful': 174,
#  'whereas': 3839,
#  'sponge': 3107,
#  'modality': 175,
#  'basal': 3840,
#  'j': 176,
#  'middle': 3685,
#  'chf': 3841,
#  'ischemia': 177,
#  'collateral': 3842,
#  'effusion/pna': 178,
#  'y': 6220,
#  'transudative': 179,
#  'whether': 3843,
#  'neoplasm': 180,
#  'shown': 2489,
#  'dual-chamber': 182,
#  'spiculated': 183,
#  'vertebral': 184,
#  'outlining': 185,
#  'periosseous': 643,
#  'occlusive': 3846,
#  'retraction': 3686,
#  'pushed': 187,
#  'tagged': 3848,
#  'belly': 3849,
#  'replacement': 3850,
#  'remainder': 3852,
#  'transtentorial': 189,
#  'products': 3854,
#  'ect': 191,
#  'thrombosis': 192,
#  'shoulders': 3856,
#  'leftglenohumeral': 3857,
#  'osteoblastic': 193,
#  'especially': 3858,
#  'tie': 3859,
#  'siza': 194,
#  'temporary': 195,
#  'thorax': 3860,
#  'spectral': 197,
#  'uncerwent': 198,
#  'discuseed': 199,
#  'mal-placement': 3861,
#  'underperfusion': 3862,
#  'dht': 3863,
#  'hysterectomy': 1721,
#  'regarding': 7189,
#  'yom': 3659,
#  'switched': 200,
#  'pull-up': 3864,
#  'bm': 201,
#  'encreased': 3865,
#  'pedicles': 5805,
#  'pheresis': 3866,
#  'sump': 6815,
#  'distally': 3868,
#  'mayi': 202,
#  'incisional': 204,
#  'periampullary': 3869,
#  'tub': 205,
#  'recording': 3284,
#  'sdh': 206,
#  'indicate': 207,
#  'mandibular': 3870,
#  'degradation': 1877,
#  'ingestion': 209,
#  'wall-to-wall': 3872,
#  'form': 210,
#  'cavoatrial': 4986,
#  'upon': 211,
#  'infiltrate/atelectasis': 6229,
#  'spurring': 212,
#  'preserves': 3874,
#  'even': 3875,
#  'sister': 3876,
#  'pacemaker': 2565,
#  'gastrectomy': 3880,
#  'punctuate': 213,
#  'hydrocele': 214,
#  'complication': 3883,
#  'embo': 216,
#  'scalpel': 217,
#  're-expansion': 218,
#  'ligament': 6230,
#  'projected': 219,
#  'compressing': 220,
#  'esophagram': 221,
#  'dystrophic': 4989,
#  'conducted': 222,
#  'featureless': 215,
#  'patterns': 223,
#  'toward': 5601,
#  'his': 6231,
#  'angiography': 1616,
#  'hydroureter': 3886,
#  'presently': 3887,
#  'parenchyma.mri': 3888,
#  'diaphyseal': 224,
#  'tracheotomy': 3890,
#  'creatinine-dehydration': 225,
#  'did': 226,
#  'calcified': 227,
#  'instrument': 3893,
#  'transaminitis': 228,
#  'graft': 2497,
#  'lungs': 229,
#  'ards': 230,
#  'dmo': 3895,
#  'intact': 3896,
#  'single-lumen': 3898,
#  'sized': 231,
#  'iac': 232,
#  'asssss': 233,
#  'pm': 3900,
#  'the': 234,
#  'quadrant': 3901,
#  'calcinosis': 3902,
#  'cerebellar': 3903,
#  'safe': 3904,
#  'cannulation': 235,
#  'posture': 3905,
#  'craniectomy': 3906,
#  'scheduled': 3907,
#  'l.central': 237,
#  'pseudo-obstruction': 3908,
#  'lever': 3909,
#  'external-internal': 3910,
#  'confluent': 238,
#  'symmetry': 239,
#  'syncope': 3914,
#  'bloo': 3916,
#  'desaturated': 5609,
#  'orthopedic': 240,
#  'subcarinal': 3918,
#  'peritoneum': 3919,
#  'embolectomy': 6822,
#  'exclusion': 243,
#  'chemo': 242,
#  'electronically': 244,
#  'reimaging': 245,
#  'porta': 246,
#  'fistula/graft': 247,
#  'compression': 3920,
#  'bili': 1235,
#  'traverses': 248,
#  'while': 249,
#  'abut': 250,
#  'decision': 3923,
#  'congenital': 3924,
#  'hemoconcentration': 251,
#  'aspergillosis': 252,
#  'resultant': 3926,
#  'epilepticus/respiratory': 3698,
#  'decompression': 253,
#  'supression': 3928,
#  'non-ionic': 3929,
#  'heb': 254,
#  'count': 3930,
#  'ddcc': 255,
#  'pathologist': 256,
#  'para-aortic': 257,
#  'cover': 3931,
#  'physicians': 3700,
#  'projectional': 258,
#  'mapping': 259,
#  'ground': 260,
#  'mediastinitis': 261,
#  'raise': 3933,
#  'duration': 3934,
#  'sillhoutte': 1559,
#  'alveolar': 262,
#  'determination': 3935,
#  'ddd.d': 263,
#  'arota': 3936,
#  'inappropriate': 3937,
#  'purple': 598,
#  'fiberglass': 3938,
#  'superimposition': 658,
#  'dfdgf': 3939,
#  'sighted': 265,
#  'retrocrural': 3118,
#  'deeply': 3940,
#  'lasix': 266,
#  'brachiocephalic/svc': 267,
#  'smoothly': 3881,
#  'gliome': 3941,
#  'needed': 3942,
#  'copy': 6828,
#  'hd': 3943,
#  'rather': 3944,
#  'continuing': 268,
#  'backed': 269,
#  'each': 270,
#  'abnormally': 3831,
#  'interoperative': 2507,
#  'terminate': 271,
#  'mostly': 272,
#  'sided': 273,
#  'temporo-occipital': 274,
#  'mid-body': 276,
#  'non-enhanced': 278,
#  'fahh': 3949,
#  'plaque': 3950,
#  'cd': 279,
#  'dd.dd': 6240,
#  'above-mentioned': 3951,
#  're-eval': 3952,
#  'trauma': 280,
#  'sixteen': 281,
#  'loss': 282,
#  'concerned': 3123,
#  'tendinitis': 3703,
#  'concentration': 285,
#  'discussed': 5005,
#  'subcm': 1510,
#  'margin': 3954,
#  'p.m': 3955,
#  'brought': 286,
#  'nonenhancing': 6688,
#  'rewire': 3956,
#  'dysplasia': 287,
#  'multiforme': 288,
#  'carinii': 289,
#  'axial': 290,
#  'sacrum': 3959,
#  'effn': 3960,
#  'fem-dp': 291,
#  'relate': 3961,
#  'ild': 5533,
#  'was': 292,
#  'temporooccipital': 293,
#  'hospitald': 3962,
#  'fasc': 294,
#  'consolidation/partial': 2874,
#  'stenotic': 295,
#  'hand': 3963,
#  'stopped': 296,
#  'vertex': 3965,
#  'prostheses': 297,
#  'obl': 298,
#  'necrotizing': 6247,
#  'restage': 3967,
#  'maintain': 3968,
#  'our': 7370,
#  're-expanded': 3969,
#  'kyphosis.liklet': 302,
#  'increasing': 3970,
#  'whiteout': 3971,
#  'conned': 3972,
#  'non-small': 3973,
#  'pleuradesis': 3974,
#  'transcath': 3975,
#  'opposed': 3976,
#  'atelectasis/inflammation': 1247,
#  'however': 3977,
#  'largest': 1372,
#  'walled': 1248,
#  'td-dd': 3979,
#  'noticeable': 3981,
#  'distension': 3982,
#  'septum': 304,
#  'pca': 305,
#  'heights': 3983,
#  'edema/anasarca': 6489,
#  'being': 3984,
#  'stone': 1249,
#  'droop': 3985,
#  'compartments': 53,
#  'definition': 306,
#  'isprobably': 307,
#  'block': 309,
#  'd-day-old': 310,
#  'online': 3712,
#  'caudate': 3986,
#  'palliative': 3988,
#  'evidenced': 312,
#  'analgesia': 3713,
#  'hypoalbuminemic': 313,
#  'fibula': 1250,
#  'properties': 3990,
#  'turned': 316,
#  'overt': 3991,
#  'fever/seizures': 1576,
#  'opague': 317,
#  'chronic': 3992,
#  'today': 3993,
#  'celclage': 3995,
#  'gastrograffin': 3996,
#  'hepatojejunostomy': 3997,
#  'ppm': 3998,
#  'campus': 319,
#  'aberrant': 3999,
#  'drainage': 4000,
#  'dd.d': 321,
#  'post-biopsy': 322,
#  'ankles': 4001,
#  'wet': 324,
#  'means': 4003,
#  'pyelonephritis': 325,
#  'still': 5016,
#  'angled': 326,
#  'mid-line': 327,
#  'cmp': 4005,
#  'lue': 7299,
#  'rotoablation': 328,
#  'paralysis': 4006,
#  'lumbar': 329,
#  'd-hour': 4007,
#  'i': 331,
#  'reformats': 56,
#  'edematous': 4008,
#  'questions': 5624,
#  'coated': 4009,
#  'subsequently': 4010,
#  'debris': 4011,
#  'f/b': 3786,
#  'a-gram': 668,
#  'undetectable': 4012,
#  'malleolus': 332,
#  'paracentecis': 333,
#  'carried': 4013,
#  'conoslidation': 334,
#  'two-lumen': 4014,
#  'calcaneal': 335,
#  'cine': 4016,
#  'had': 1255,
#  'view': 336,
#  'brachycephalic': 4017,
#  'hepatectomy': 337,
#  'dehydration': 3718,
#  'localization': 672,
#  'extermity': 338,
#  'stress-induced': 4018,
#  'testing': 5627,
#  'echoic': 340,
#  'pulmonic': 4020,
#  'greater': 341,
#  'nature': 342,
#  'fasciitis': 343,
#  'hypopharynx': 4021,
#  'attempted': 344,
#  'consolidated': 346,
#  'column': 4022,
#  'admitted': 4023,
#  'uptake': 347,
#  'rapidly': 348,
#  'suspected': 4024,
#  'symptom': 349,
#  'nondistended': 3720,
#  'aware': 4025,
#  'error': 4027,
#  'about': 350,
#  'obstructive': 351,
#  'sbe': 4028,
#  'such': 4029,
#  'three-vessel': 675,
#  'nonocclusive': 352,
#  'inf': 353,
#  'frontal-temporal': 4030,
#  'consists': 355,
#  'evacuations': 357,
#  'evolution': 358,
#  'hida': 360,
#  'heading': 4032,
#  'methicillin': 361,
#  'incision': 4033,
#  'cannulate': 4035,
#  'cricopharyngeal': 362,
#  'difficulties': 363,
#  'assymetric': 4037,
#  'produced': 6686,
#  'tbili': 364,
#  'stably': 365,
#  'om': 4038,
#  'backflow': 366,
#  'intiation': 818,
#  'traced': 367,
#  'allow': 4039,
#  'yet': 368,
#  'manifested': 4374,
#  'subclavian': 6845,
#  'rou-en-y': 4041,
#  'draped': 3140,
#  'project': 369,
#  'antral': 6256,
#  'widespread': 4042,
#  'pancytopenia': 4043,
#  'valves': 370,
#  'side': 4044,
#  'new': 371,
#  'chest/abdomen': 6848,
#  'xrt': 372,
#  'nonionic': 4045,
#  'hrs': 373,
#  'edema/effusions/atelectasis/consolidations': 374,
#  'needles': 375,
#  'west': 376,
#  'aortoenteric': 4047,
#  'pericardial': 2529,
#  'downsized': 4049,
#  'cadrioversion': 4050,
#  'd-fu': 377,
#  'request': 378,
#  'md/d': 6851,
#  'herself': 379,
#  'relation': 677,
#  'hemithoraces': 380,
#  'obviously': 381,
#  'dd-year-odl': 382,
#  'witnessed': 383,
#  'loculations': 384,
#  'signal': 4053,
#  'thecal': 385,
#  'round': 386,
#  'dddd-d-d': 4055,
#  'developing': 6260,
#  'loop': 387,
#  'floor': 388,
#  'difference': 4057,
#  'prandial': 389,
#  'g/gj': 390,
#  'nipple': 6852,
#  'epilepticus': 391,
#  'hemothorax': 393,
#  'become': 394,
#  'radiographs': 4059,
#  'going': 4060,
#  'withdrawn': 395,
#  'nonunion': 6261,
#  'carpus': 4062,
#  'hilum': 3146,
#  'mellitus': 396,
#  'complex': 6796,
#  'acquired': 4063,
#  'sacroiliac': 4064,
#  'arthrocentesis': 397,
#  'lll': 398,
#  'andcardioversion': 399,
#  'jejunostomy': 4066,
#  'physicianclip': 400,
#  'greek': 401,
#  'trigger': 402,
#  'congenitally': 4067,
#  'cordis': 4068,
#  'shape': 1908,
#  'inspiration': 4070,
#  'returned': 4071,
#  'infarction': 4072,
#  'blade': 6854,
#  'urosepsis': 404,
#  'cava/ra': 6264,
#  'leukemia/lymphoma': 405,
#  'ddemonstrated': 4074,
#  'confirmed': 407,
#  'ic': 408,
#  'fluro': 4075,
#  'thank': 409,
#  'emission': 4076,
#  'carcinoma': 4077,
#  'include': 410,
#  'lefet': 411,
#  'non-coronary': 4079,
#  'patent': 4081,
#  'w/infection': 6269,
#  'hyperechogenic': 5632,
#  'chf/hydrostatic': 414,
#  'achieved': 415,
#  'fragment': 4083,
#  'found': 416,
#  'sludge-filled': 417,
#  'nodes': 418,
#  'callosum': 4084,
#  'n-j': 419,
#  'unable': 420,
#  'require': 4085,
#  'cytology': 4086,
#  'embolizable': 4087,
#  'paraspinal': 421,
#  'flow-limiting': 683,
#  'exaggerate': 4088,
#  'before': 3728,
#  'bones': 423,
#  'versusimited': 425,
#  'uniform': 426,
#  'bowels': 427,
#  'portably': 4383,
#  'mvr': 4089,
#  'guidance': 428,
#  'activity': 4090,
#  'uerteric': 4091,
#  'significantly-enlarged': 4092,
#  'oxymetry': 429,
#  'retention': 1912,
#  'getting': 430,
#  'dmz': 431,
#  'modifications': 1552,
#  'subchondral': 6271,
#  'tract': 4094,
#  'tubular': 4095,
#  'document': 4096,
#  'divided': 434,
#  'crystals': 4097,
#  'immediatly': 5033,
#  'amounts': 5639,
#  'cvl/picc': 4098,
#  'loc': 436,
#  'non-filling': 437,
#  'silicone': 438,
#  'immediate': 439,
#  'cvvh': 4100,
#  'thoracentesis': 5035,
#  'hyper-aeration': 440,
#  'definite': 441,
#  'fractures': 6858,
#  'abx': 443,
#  'essentially': 444,
#  'periodclip': 4101,
#  'rotational': 4102,
#  'handed': 4103,
#  'parieto-occipital': 6273,
#  'pharmacologic': 445,
#  'collection/abscess/osteo': 4104,
#  'precisely': 446,
#  'prevous': 447,
#  'soft': 3156,
#  'reval': 448,
#  'pr': 4105,
#  'immunocompromised': 449,
#  'afib': 6547,
#  'past': 450,
#  'edema/effusions/atelectasis/consolidati': 6276,
#  'orogastric': 4106,
#  'fluid-filled': 451,
#  'intr': 452,
#  'lbo': 453,
#  'is': 4107,
#  'recurred': 454,
#  'gtube': 455,
#  'cavitary': 4108,
#  'currently': 4109,
#  'predominantly': 6278,
#  'path': 4110,
#  'clips': 4111,
#  'delective': 456,
#  'psoriatic': 4112,
#  'straw': 4114,
#  'low-pressure': 457,
#  'echogenicity': 460,
#  'typical': 1916,
#  'predominating': 4115,
#  'mid-svc': 1437,
#  'indcation': 4117,
#  'recent': 3734,
#  'country': 4118,
#  'radiolabeled': 4388,
#  'manner': 461,
#  'thus': 4119,
#  'query': 6863,
#  'l-thoracotomy/h-graft': 4120,
#  'secure': 7088,
#  'aspiration/pneumonia': 691,
#  'ptt': 462,
#  'hypervascularity': 4122,
#  'inferiorly': 5644,
#  'well-characterized': 2546,
#  'cava/right': 4123,
#  'allegedly': 464,
#  'discomfort': 465,
#  'hyperintense': 466,
#  'tachy.lymphoma.r/o': 467,
#  'pre-procedural': 468,
#  'emptied': 469,
#  'hypogastric': 4124,
#  'into': 4391,
#  're-reviewed': 4125,
#  'sterily': 471,
#  'aortobiiliac': 4126,
#  'fungal': 472,
#  'gangrene': 473,
#  'harvested': 474,
#  'rapidity': 475,
#  'improve': 4127,
#  'circumflex': 4128,
#  'intertransverse': 4129,
#  'lesion': 6283,
#  'function': 4130,
#  'ligamentous': 1268,
#  'three-month': 476,
#  'subdiaphragmatic': 4133,
#  'trachoplasty': 4134,
#  'fractured': 477,
#  'neoplastic': 4135,
#  'zilver': 4136,
#  'recurs': 478,
#  'certainly': 4138,
#  'pseudoaneurys': 479,
#  'pre-medicated': 480,
#  'radiosurgery': 481,
#  'likewise': 482,
#  'afixed': 483,
#  'via': 4141,
#  'fluorodeoxyglucose': 484,
#  'megacolon': 485,
#  'tail': 486,
#  'anterolisthesis': 3737,
#  'specimens': 4142,
#  'crossing': 4143,
#  'improved/resolved': 6869,
#  'posituion': 488,
#  'femoral': 4394,
#  'light': 4144,
#  'tension': 3740,
#  'internal/external': 4145,
#  'cyst': 595,
#  'produces': 4146,
#  'pre-existing': 4147,
#  'tablet': 4148,
#  'bandage': 4149,
#  'neutropenic': 6243,
#  'po': 4150,
#  'branching': 3741,
#  'rim': 4151,
#  'poor': 4152,
#  'dysplastic': 6215,
#  'presence': 489,
#  'aspirate': 4154,
#  'postero-anterior': 4155,
#  'labrum': 721,
#  'hydropneumthorax': 4157,
#  'cardiopulm': 2549,
#  'fanconi': 490,
#  'sizeable': 4158,
#  'dial': 4159,
#  'wean': 7092,
#  'section': 2177,
#  'abnormality/displacement': 491,
#  'nonhealing': 493,
#  'triple': 494,
#  'corpus': 495,
#  'enteric': 2142,
#  'definitely': 4160,
#  'faintly': 4161,
#  'rehabilitation': 496,
#  'symptoms': 5648,
#  'omniflush': 498,
#  'drs': 4164,
#  'j-tube': 4165,
#  'diagnosed': 499,
#  'uncommon': 4166,
#  'pager': 4167,
#  'consider': 500,
#  'polycystic': 4169,
#  'intraarterial': 501,
#  'qa': 4170,
#  'cc': 4171,
#  'opaque': 502,
#  'eight': 503,
#  'aortogram': 504,
#  ...}

# %% [markdown]
# ### Save for use in our next notebook

# %%
import gzip
import pickle

with open("rad_data.pickle.gz", "wb") as f0:
    pickle.dump(rad_data, f0)

# %%
with open("rad_vocabulary.pickle.gz", "wb") as f0:
    pickle.dump(word_map, f0)
